# %%
df_ols = pd.read_csv('dataset.csv', encoding='utf-8-sig')

# %%
df_ols = df_ols.drop(['player_name', 'age_y', 'height_y', 'weight_y', 'rating_y'], axis=1)

# %%
df_ols.corr()[df_ols.corr() > 0.7]
# Out:
#                        value  follower  shots_total  shots_on  goals_total  \
# value                    1.0       NaN          NaN       NaN          NaN
# follower                 NaN       1.0          NaN       NaN          NaN
# shots_total              NaN       NaN     1.000000  0.959943     0.788272
# shots_on                 NaN       NaN     0.959943  1.000000     0.877377
# goals_total              NaN       NaN     0.788272  0.877377     1.000000
# goals_assists            NaN       NaN          NaN       NaN          NaN
# passes_total             NaN       NaN          NaN       NaN          NaN
# passes_key               NaN       NaN          NaN       NaN          NaN
# passes_accuracy          NaN       NaN          NaN       NaN          NaN
# tackles_total            NaN       NaN          NaN       NaN          NaN
# tackles_blocks           NaN       NaN          NaN       NaN          NaN
# tackles_interceptions    NaN       NaN          NaN       NaN          NaN
# duels_total              NaN       NaN          NaN       NaN          NaN
# duels_won                NaN       NaN          NaN       NaN          NaN
# dribbles_attempts        NaN       NaN          NaN       NaN          NaN
# dribbles_success         NaN       NaN          NaN       NaN          NaN
# fouls_drawn              NaN       NaN          NaN       NaN          NaN
# fouls_committed          NaN       NaN          NaN       NaN          NaN
# cards_yellow             NaN       NaN          NaN       NaN          NaN
# cards_yellowred          NaN       NaN          NaN       NaN          NaN
# cards_red                NaN       NaN          NaN       NaN          NaN
# penalty_won              NaN       NaN          NaN       NaN          NaN
# penalty_commited         NaN       NaN          NaN       NaN          NaN
# penalty_success          NaN       NaN          NaN       NaN          NaN
# penalty_missed           NaN       NaN          NaN       NaN          NaN
# games_appearences        NaN       NaN          NaN       NaN          NaN
# games_lineups            NaN       NaN          NaN       NaN          NaN
# substitutes_in           NaN       NaN          NaN       NaN          NaN
# substitutes_out          NaN       NaN          NaN       NaN          NaN
# substitutes_bench        NaN       NaN          NaN       NaN          NaN
# age_x                    NaN       NaN          NaN       NaN          NaN
# height_x                 NaN       NaN          NaN       NaN          NaN
# weight_x                 NaN       NaN          NaN       NaN          NaN
# rating_x                 NaN       NaN          NaN       NaN          NaN
#
#                        goals_assists  passes_total  passes_key  \
# value                            NaN           NaN         NaN
# follower                         NaN           NaN         NaN
# shots_total                      NaN           NaN         NaN
# shots_on                         NaN           NaN         NaN
# goals_total                      NaN           NaN         NaN
# goals_assists               1.000000           NaN    0.806733
# passes_total                     NaN           1.0         NaN
# passes_key                  0.806733           NaN    1.000000
# passes_accuracy                  NaN           NaN         NaN
# tackles_total                    NaN           NaN         NaN
# tackles_blocks                   NaN           NaN         NaN
# tackles_interceptions            NaN           NaN         NaN
# duels_total                      NaN           NaN         NaN
# duels_won                        NaN           NaN         NaN
# dribbles_attempts                NaN           NaN         NaN
# dribbles_success                 NaN           NaN         NaN
# fouls_drawn                      NaN           NaN         NaN
# fouls_committed                  NaN           NaN         NaN
# cards_yellow                     NaN           NaN         NaN
# cards_yellowred                  NaN           NaN         NaN
# cards_red                        NaN           NaN         NaN
# penalty_won                      NaN           NaN         NaN
# penalty_commited                 NaN           NaN         NaN
# penalty_success                  NaN           NaN         NaN
# penalty_missed                   NaN           NaN         NaN
# games_appearences                NaN           NaN         NaN
# games_lineups                    NaN           NaN         NaN
# substitutes_in                   NaN           NaN         NaN
# substitutes_out                  NaN           NaN         NaN
# substitutes_bench                NaN           NaN         NaN
# age_x                            NaN           NaN         NaN
# height_x                         NaN           NaN         NaN
# weight_x                         NaN           NaN         NaN
# rating_x                         NaN           NaN         NaN
#
#                        passes_accuracy  tackles_total  ...  penalty_missed  \
# value                              NaN            NaN  ...             NaN
# follower                           NaN            NaN  ...             NaN
# shots_total                        NaN            NaN  ...             NaN
# shots_on                           NaN            NaN  ...             NaN
# goals_total                        NaN            NaN  ...             NaN
# goals_assists                      NaN            NaN  ...             NaN
# passes_total                       NaN            NaN  ...             NaN
# passes_key                         NaN            NaN  ...             NaN
# passes_accuracy               1.000000            NaN  ...             NaN
# tackles_total                      NaN            1.0  ...             NaN
# tackles_blocks                     NaN            NaN  ...             NaN
# tackles_interceptions              NaN            NaN  ...             NaN
# duels_total                        NaN            NaN  ...             NaN
# duels_won                          NaN            NaN  ...             NaN
# dribbles_attempts                  NaN            NaN  ...             NaN
# dribbles_success                   NaN            NaN  ...             NaN
# fouls_drawn                        NaN            NaN  ...             NaN
# fouls_committed                    NaN            NaN  ...             NaN
# cards_yellow                       NaN            NaN  ...             NaN
# cards_yellowred                    NaN            NaN  ...             NaN
# cards_red                          NaN            NaN  ...             NaN
# penalty_won                        NaN            NaN  ...             NaN
# penalty_commited                   NaN            NaN  ...             NaN
# penalty_success                    NaN            NaN  ...             NaN
# penalty_missed                     NaN            NaN  ...             1.0
# games_appearences             0.915708            NaN  ...             NaN
# games_lineups                      NaN            NaN  ...             NaN
# substitutes_in                0.901033            NaN  ...             NaN
# substitutes_out                    NaN            NaN  ...             NaN
# substitutes_bench                  NaN            NaN  ...             NaN
# age_x                              NaN            NaN  ...             NaN
# height_x                           NaN            NaN  ...             NaN
# weight_x                           NaN            NaN  ...             NaN
# rating_x                           NaN            NaN  ...             NaN
#
#                        games_appearences  games_lineups  substitutes_in  \
# value                                NaN            NaN             NaN
# follower                             NaN            NaN             NaN
# shots_total                          NaN            NaN             NaN
# shots_on                             NaN            NaN             NaN
# goals_total                          NaN            NaN             NaN
# goals_assists                        NaN            NaN             NaN
# passes_total                         NaN            NaN             NaN
# passes_key                           NaN            NaN             NaN
# passes_accuracy                 0.915708            NaN        0.901033
# tackles_total                        NaN            NaN             NaN
# tackles_blocks                       NaN            NaN             NaN
# tackles_interceptions                NaN            NaN             NaN
# duels_total                          NaN            NaN             NaN
# duels_won                            NaN            NaN             NaN
# dribbles_attempts                    NaN            NaN             NaN
# dribbles_success                     NaN            NaN             NaN
# fouls_drawn                          NaN            NaN             NaN
# fouls_committed                      NaN            NaN             NaN
# cards_yellow                         NaN            NaN             NaN
# cards_yellowred                      NaN            NaN             NaN
# cards_red                            NaN            NaN             NaN
# penalty_won                          NaN            NaN             NaN
# penalty_commited                     NaN            NaN             NaN
# penalty_success                      NaN            NaN             NaN
# penalty_missed                       NaN            NaN             NaN
# games_appearences               1.000000            NaN        0.996492
# games_lineups                        NaN            1.0             NaN
# substitutes_in                  0.996492            NaN        1.000000
# substitutes_out                      NaN            NaN             NaN
# substitutes_bench                    NaN            NaN             NaN
# age_x                                NaN            NaN             NaN
# height_x                             NaN            NaN             NaN
# weight_x                             NaN            NaN             NaN
# rating_x                             NaN            NaN             NaN
#
#                        substitutes_out  substitutes_bench  age_x  height_x  \
# value                              NaN                NaN    NaN       NaN
# follower                           NaN                NaN    NaN       NaN
# shots_total                        NaN                NaN    NaN       NaN
# shots_on                           NaN                NaN    NaN       NaN
# goals_total                        NaN                NaN    NaN       NaN
# goals_assists                      NaN                NaN    NaN       NaN
# passes_total                       NaN                NaN    NaN       NaN
# passes_key                         NaN                NaN    NaN       NaN
# passes_accuracy                    NaN                NaN    NaN       NaN
# tackles_total                      NaN                NaN    NaN       NaN
# tackles_blocks                     NaN                NaN    NaN       NaN
# tackles_interceptions              NaN                NaN    NaN       NaN
# duels_total                        NaN                NaN    NaN       NaN
# duels_won                          NaN                NaN    NaN       NaN
# dribbles_attempts                  NaN                NaN    NaN       NaN
# dribbles_success                   NaN                NaN    NaN       NaN
# fouls_drawn                        NaN                NaN    NaN       NaN
# fouls_committed                    NaN                NaN    NaN       NaN
# cards_yellow                       NaN                NaN    NaN       NaN
# cards_yellowred                    NaN                NaN    NaN       NaN
# cards_red                          NaN                NaN    NaN       NaN
# penalty_won                        NaN                NaN    NaN       NaN
# penalty_commited                   NaN                NaN    NaN       NaN
# penalty_success                    NaN                NaN    NaN       NaN
# penalty_missed                     NaN                NaN    NaN       NaN
# games_appearences                  NaN                NaN    NaN       NaN
# games_lineups                      NaN                NaN    NaN       NaN
# substitutes_in                     NaN                NaN    NaN       NaN
# substitutes_out                    1.0                NaN    NaN       NaN
# substitutes_bench                  NaN                1.0    NaN       NaN
# age_x                              NaN                NaN    1.0       NaN
# height_x                           NaN                NaN    NaN       1.0
# weight_x                           NaN                NaN    NaN       NaN
# rating_x                           NaN                NaN    NaN       NaN
#
#                        weight_x  rating_x
# value                       NaN       NaN
# follower                    NaN       NaN
# shots_total                 NaN       NaN
# shots_on                    NaN       NaN
# goals_total                 NaN       NaN
# goals_assists               NaN       NaN
# passes_total                NaN       NaN
# passes_key                  NaN       NaN
# passes_accuracy             NaN       NaN
# tackles_total               NaN       NaN
# tackles_blocks              NaN       NaN
# tackles_interceptions       NaN       NaN
# duels_total                 NaN       NaN
# duels_won                   NaN       NaN
# dribbles_attempts           NaN       NaN
# dribbles_success            NaN       NaN
# fouls_drawn                 NaN       NaN
# fouls_committed             NaN       NaN
# cards_yellow                NaN       NaN
# cards_yellowred             NaN       NaN
# cards_red                   NaN       NaN
# penalty_won                 NaN       NaN
# penalty_commited            NaN       NaN
# penalty_success             NaN       NaN
# penalty_missed              NaN       NaN
# games_appearences           NaN       NaN
# games_lineups               NaN       NaN
# substitutes_in              NaN       NaN
# substitutes_out             NaN       NaN
# substitutes_bench           NaN       NaN
# age_x                       NaN       NaN
# height_x                    NaN       NaN
# weight_x                    1.0       NaN
# rating_x                    NaN       1.0
#
# [34 rows x 34 columns]

# %% [markdown]
# # 결측치 제거

# %%
df_ols = df_ols.dropna()

# %% [markdown]
# # 높은 상관관계를 보이는 Feature들
# 1. shots_total, shots_on, goals_total
# 2. goals_assists, passes_key
# 3. passes_accuracy, games_appearences, substitutes_in
# 4. duels_total, duels_won
# 5. dribbles_attempts, dribbles_success

# %%
df_pos = df_ols

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.preprocessing import MinMaxScaler

# %%
# 1. shots_on, shots_total and goals_total PCA
df_pos_sotgt = df_pos[['shots_on', 'shots_total', 'goals_total']]
df_pos_sotgt = StandardScaler().fit_transform(df_pos_sotgt)
df_pos_pca_sg = pd.DataFrame(data = PCA(n_components=1).fit_transform(df_pos_sotgt), columns=['shotsOnTotal_goalsTotal'])
df_pos_pca_sg['shotsOnTotal_goalsTotal'] = MinMaxScaler().fit_transform(df_pos_pca_sg)

# %%
# 2. goals_assists, passes_key
df_pos_gapk = StandardScaler().fit_transform(df_pos[['goals_assists', 'passes_key']])
df_pos_pca_gapk = pd.DataFrame(data = PCA(n_components=1).fit_transform(df_pos_gapk), columns=['goalsAssist_passesKey'])
df_pos_pca_gapk['goalsAssist_passesKey'] = MinMaxScaler().fit_transform(df_pos_pca_gapk)

# %%
# 3. passes_accuracy, games_appearences, substitutes_in
df_pos_pagasi = StandardScaler().fit_transform(df_pos[['passes_accuracy', 'games_appearences', 'substitutes_in']])
df_pos_pca_pagasi = pd.DataFrame(data = PCA(n_components=1).fit_transform(df_pos_pagasi), columns=['passesAcc_gamesApp_subIn'])
df_pos_pca_pagasi['passesAcc_gamesApp_subIn'] = MinMaxScaler().fit_transform(df_pos_pca_pagasi)

# %%
# 4. duels_total, duels_won
df_pos_duels = df_pos[['duels_total', 'duels_won']]
df_pos_duels = StandardScaler().fit_transform(df_pos_duels)
df_pos_pca_duels = pd.DataFrame(data = PCA(n_components=1).fit_transform(df_pos_duels), columns=['duelsWonTotal'])
df_pos_pca_duels['duelsWonTotal'] = MinMaxScaler().fit_transform(df_pos_pca_duels)

# %%
# 5. dribbles_attempts, dribbles_success
df_pos_dribbles = df_pos[['dribbles_attempts', 'dribbles_success']]
df_pos_dribbles = StandardScaler().fit_transform(df_pos_dribbles)
df_pos_pca_dribbles = pd.DataFrame(data = PCA(n_components=1).fit_transform(df_pos_dribbles), columns=['dribblesAtmptsSuc'])
df_pos_pca_dribbles['dribblesAtmptsSuc'] = MinMaxScaler().fit_transform(df_pos_pca_dribbles)

# %% [markdown]
# # PCA Feature Table

# %%
df_pca = pd.concat([df_pos_pca_sg, df_pos_pca_gapk, df_pos_pca_pagasi, 
                    df_pos_pca_duels, df_pos_pca_dribbles], axis=1)
df_pca
# Out:
#      shotsOnTotal_goalsTotal  goalsAssist_passesKey  passesAcc_gamesApp_subIn  \
# 0                   0.054994               0.034725                  0.023985
# 1                   0.051068               0.047031                  0.021084
# 2                   0.447513               0.212191                  0.003561
# 3                   0.031310               0.033221                  0.009314
# 4                   0.303993               0.393255                  0.032514
# ..                       ...                    ...                       ...
# 452                 0.209095               0.121558                  0.013524
# 453                 0.338150               0.495260                  0.051046
# 454                 0.116657               0.079595                  0.012985
# 455                 0.325388               0.396598                  0.024402
# 456                 0.229515               0.274902                  0.011315
#
#      duelsWonTotal  dribblesAtmptsSuc
# 0         0.108779           0.191225
# 1         0.183587           0.083586
# 2         0.380663           0.204123
# 3         0.239780           0.024259
# 4         0.362438           0.493859
# ..             ...                ...
# 452       0.401370           0.744906
# 453       0.360554           0.644546
# 454       0.345182           0.024297
# 455       0.443935           0.198977
# 456       0.314084           0.169869
#
# [457 rows x 5 columns]

# %%
df_pca.corr()[df_pca.corr() > 0.7]
# Out:
#                           shotsOnTotal_goalsTotal  goalsAssist_passesKey  \
# shotsOnTotal_goalsTotal                       1.0                    NaN
# goalsAssist_passesKey                         NaN                    1.0
# passesAcc_gamesApp_subIn                      NaN                    NaN
# duelsWonTotal                                 NaN                    NaN
# dribblesAtmptsSuc                             NaN                    NaN
#
#                           passesAcc_gamesApp_subIn  duelsWonTotal  \
# shotsOnTotal_goalsTotal                        NaN            NaN
# goalsAssist_passesKey                          NaN            NaN
# passesAcc_gamesApp_subIn                       1.0            NaN
# duelsWonTotal                                  NaN            1.0
# dribblesAtmptsSuc                              NaN            NaN
#
#                           dribblesAtmptsSuc
# shotsOnTotal_goalsTotal                 NaN
# goalsAssist_passesKey                   NaN
# passesAcc_gamesApp_subIn                NaN
# duelsWonTotal                           NaN
# dribblesAtmptsSuc                       1.0

# %% [markdown]
# # PCA feature들과 그 외 feature들의 OLS 확인

# %%
pca_cols = ['shots_total', 'shots_on', 'goals_total', 'goals_assists', 'passes_key', 'passes_accuracy', 'games_appearences', 'substitutes_in', 'duels_total', 'duels_won', 'dribbles_attempts', 'dribbles_success']
npca_cols = df_pos.columns.tolist()
npca_features = [item for item in npca_cols if item not in pca_cols]

# %%
df_ols = pd.concat([df_pos[npca_features].reset_index(drop=True), df_pca.reset_index(drop=True)], axis=1)
df_ols_f = df_ols
df_ols_f
# Out:
#      value  follower  passes_total  tackles_total  tackles_blocks  \
# 0     20.0     67879       22.1879         1.2112          0.1417
# 1     31.5    232370       40.9924         1.0431          0.7048
# 2     32.0    740918       12.3215         0.4629          0.0985
# 3     24.0    601838       58.0206         1.0302          0.3802
# 4     32.0    652886       23.4885         0.7757          0.1141
# ..     ...       ...           ...            ...             ...
# 452   20.0   1955121       28.5984         1.5835          0.2127
# 453   22.5    797767       22.6878         0.0000          0.0000
# 454   20.0   3339896       46.6951         1.4925          0.5686
# 455   24.0    109000       16.8654         0.3936          0.0695
# 456   44.0    282254       38.4372         1.0018          0.1371
#
#      tackles_interceptions  fouls_drawn  fouls_committed  cards_yellow  \
# 0                   0.8504       0.5283           0.7473        0.1804
# 1                   1.1841       1.2405           1.2969        0.1973
# 2                   0.2659       2.8563           1.7039        0.1083
# 3                   1.3368       0.5641           0.5887        0.0981
# 4                   0.9354       1.6085           1.6541        0.2738
# ..                     ...          ...              ...           ...
# 452                 1.8435       2.0326           1.4417        0.3782
# 453                 0.4088       1.1753           1.0220        0.2044
# 454                 0.9950       0.5686           0.9476        0.1895
# 455                 0.3010       1.8636           1.7595        0.1042
# 456                 0.9807       1.4341           1.2232        0.1582
#
#      cards_yellowred  ...  substitutes_bench  age_x  height_x  weight_x  \
# 0             0.0129  ...             0.5927   25.0     184.0      78.0
# 1             0.0000  ...             1.6070   21.0     190.0      75.0
# 2             0.0000  ...             0.0689   27.0     181.0      72.0
# 3             0.0000  ...             0.7604   24.0     188.0      78.0
# 4             0.0114  ...             0.6160   25.0     171.0      70.0
# ..               ...  ...                ...    ...       ...       ...
# 452           0.0000  ...             0.3782   24.0     176.0      64.0
# 453           0.0000  ...             1.2775   27.0     180.0      71.0
# 454           0.0000  ...             0.5449   26.0     195.0      94.0
# 455           0.0000  ...             0.5788   26.0     192.0      84.0
# 456           0.0000  ...             0.2636   23.0     176.0      72.0
#
#      rating_x  shotsOnTotal_goalsTotal  goalsAssist_passesKey  \
# 0    2.333333                 0.054994               0.034725
# 1    4.777778                 0.051068               0.047031
# 2    5.250000                 0.447513               0.212191
# 3    6.000000                 0.031310               0.033221
# 4    7.000000                 0.303993               0.393255
# ..        ...                      ...                    ...
# 452  3.333333                 0.209095               0.121558
# 453  4.857143                 0.338150               0.495260
# 454  6.125000                 0.116657               0.079595
# 455  6.545455                 0.325388               0.396598
# 456  4.384615                 0.229515               0.274902
#
#      passesAcc_gamesApp_subIn  duelsWonTotal  dribblesAtmptsSuc
# 0                    0.023985       0.108779           0.191225
# 1                    0.021084       0.183587           0.083586
# 2                    0.003561       0.380663           0.204123
# 3                    0.009314       0.239780           0.024259
# 4                    0.032514       0.362438           0.493859
# ..                        ...            ...                ...
# 452                  0.013524       0.401370           0.744906
# 453                  0.051046       0.360554           0.644546
# 454                  0.012985       0.345182           0.024297
# 455                  0.024402       0.443935           0.198977
# 456                  0.011315       0.314084           0.169869
#
# [457 rows x 27 columns]

# %% [markdown]
# # Follower feature 제거

# %%
df_ols_nf = df_ols.drop('follower', axis=1)

# %% [markdown]
# # OLS - Basic Model

# %%
from sklearn.model_selection import train_test_split

df_ols = df_ols_nf
dfX = df_ols.drop(['value'], axis=1)
dfy = df_ols['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

formula = "value ~ " + "+".join(feature_names)

model = sm.OLS.from_formula(formula, data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(5)
cv = KFold(5, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula(formula, data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
#    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.317
# Model:                            OLS   Adj. R-squared:                  0.259
# Method:                 Least Squares   F-statistic:                     5.450
# Date:                Mon, 29 Jun 2020   Prob (F-statistic):           1.07e-13
# Time:                        17:35:31   Log-Likelihood:                -1328.7
# No. Observations:                 319   AIC:                             2709.
# Df Residuals:                     293   BIC:                             2807.
# Df Model:                          25
# Covariance Type:            nonrobust
# ===================================================================================================
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# Intercept                          31.7335      0.911     34.851      0.000      29.941      33.526
# scale(passes_total)                 7.3373      1.390      5.278      0.000       4.601      10.073
# scale(tackles_total)               -0.6127      1.333     -0.460      0.646      -3.236       2.010
# scale(tackles_blocks)              -0.1711      1.343     -0.127      0.899      -2.814       2.472
# scale(tackles_interceptions)       -0.9564      1.705     -0.561      0.575      -4.311       2.398
# scale(fouls_drawn)                 -2.0604      1.373     -1.501      0.134      -4.762       0.642
# scale(fouls_committed)             -4.4513      1.259     -3.536      0.000      -6.929      -1.974
# scale(cards_yellow)                 1.7288      1.231      1.405      0.161      -0.693       4.151
# scale(cards_yellowred)              1.4059      0.993      1.416      0.158      -0.548       3.360
# scale(cards_red)                    1.9673      0.948      2.074      0.039       0.101       3.834
# scale(penalty_won)                  2.2672      1.180      1.922      0.056      -0.055       4.589
# scale(penalty_commited)            -1.6118      1.107     -1.456      0.146      -3.791       0.567
# scale(penalty_success)             -0.4020      1.327     -0.303      0.762      -3.013       2.209
# scale(penalty_missed)               0.2611      1.151      0.227      0.821      -2.005       2.527
# scale(games_lineups)                4.6036      2.041      2.256      0.025       0.587       8.620
# scale(substitutes_out)             -5.0114      1.423     -3.521      0.000      -7.813      -2.210
# scale(substitutes_bench)            1.6799      1.547      1.086      0.278      -1.365       4.725
# scale(age_x)                       -4.6139      1.266     -3.644      0.000      -7.106      -2.122
# scale(height_x)                    -1.6721      1.388     -1.204      0.229      -4.404       1.060
# scale(weight_x)                     2.7619      1.441      1.916      0.056      -0.075       5.599
# scale(rating_x)                    -1.2194      1.244     -0.981      0.328      -3.667       1.228
# scale(shotsOnTotal_goalsTotal)     10.0505      1.946      5.165      0.000       6.221      13.880
# scale(goalsAssist_passesKey)       -0.1849      1.554     -0.119      0.905      -3.243       2.873
# scale(passesAcc_gamesApp_subIn)    -0.7062      1.745     -0.405      0.686      -4.141       2.729
# scale(duelsWonTotal)                1.5672      1.247      1.257      0.210      -0.887       4.021
# scale(dribblesAtmptsSuc)            3.8667      1.559      2.480      0.014       0.799       6.935
# ==============================================================================
# Omnibus:                      177.134   Durbin-Watson:                   1.874
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1493.758
# Skew:                           2.158   Prob(JB):                         0.00
# Kurtosis:                      12.682   Cond. No.                         6.67
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 모델 성능 : -0.32202006563648033

# %% [markdown]
# # OLS - 큰 P값 Feature 제거

# %%
df_ols_nf_1 = df_ols_nf.drop(['goalsAssist_passesKey', 'tackles_blocks', 'penalty_missed', 'penalty_success', 
                              'passesAcc_gamesApp_subIn', 'tackles_interceptions', 'tackles_total', 'substitutes_bench',
                             'duelsWonTotal', 'height_x', 'cards_yellow', 'fouls_drawn', 'rating_x', 'penalty_commited',
                             'cards_yellowred', 'penalty_won', 'weight_x', ], axis=1)
len(df_ols_nf_1.columns)
# Out:
# 9

# %%
from sklearn.model_selection import train_test_split

df_ols = df_ols_nf_1
dfX = df_ols.drop(['value'], axis=1)
dfy = df_ols['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

formula = "value ~ " + "+".join(feature_names)

model = sm.OLS.from_formula(formula, data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(5)
cv = KFold(5, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula(formula, data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
    #print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.277
# Model:                            OLS   Adj. R-squared:                  0.258
# Method:                 Least Squares   F-statistic:                     14.81
# Date:                Mon, 29 Jun 2020   Prob (F-statistic):           2.33e-18
# Time:                        17:35:34   Log-Likelihood:                -1338.0
# No. Observations:                 319   AIC:                             2694.
# Df Residuals:                     310   BIC:                             2728.
# Df Model:                           8
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                         31.7335      0.911     34.820      0.000      29.940      33.527
# scale(passes_total)                5.9115      1.154      5.123      0.000       3.641       8.182
# scale(fouls_committed)            -3.8076      0.955     -3.987      0.000      -5.687      -1.928
# scale(cards_red)                   2.1629      0.922      2.346      0.020       0.348       3.977
# scale(games_lineups)               2.9569      1.025      2.884      0.004       0.939       4.975
# scale(substitutes_out)            -4.5401      1.176     -3.860      0.000      -6.854      -2.226
# scale(age_x)                      -3.4270      1.108     -3.093      0.002      -5.607      -1.247
# scale(shotsOnTotal_goalsTotal)    10.1315      1.300      7.796      0.000       7.574      12.689
# scale(dribblesAtmptsSuc)           3.6131      1.154      3.130      0.002       1.342       5.884
# ==============================================================================
# Omnibus:                      184.210   Durbin-Watson:                   1.858
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1583.913
# Skew:                           2.266   Prob(JB):                         0.00
# Kurtosis:                      12.931   Cond. No.                         2.83
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 모델 성능 : 0.18818453864154

# %% [markdown]
# # 다항기저모형

# %%
from sklearn.model_selection import train_test_split

df_ols = df_ols_nf_1
dfX = df_ols.drop(['value'], axis=1)
dfy = df_ols['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

formula = "value ~ scale(passes_total) + \
                scale(fouls_committed) + \
                scale(cards_red) + \
                scale(games_lineups) + \
                scale(substitutes_out) + \
                scale(age_x) + \
                scale(shotsOnTotal_goalsTotal) + scale(I(shotsOnTotal_goalsTotal**2)) + \
                scale(dribblesAtmptsSuc)"

model = sm.OLS.from_formula(formula, data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(3)
cv = KFold(3, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula(formula, data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
#    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.302
# Model:                            OLS   Adj. R-squared:                  0.282
# Method:                 Least Squares   F-statistic:                     14.85
# Date:                Mon, 29 Jun 2020   Prob (F-statistic):           5.00e-20
# Time:                        17:35:35   Log-Likelihood:                -1332.3
# No. Observations:                 319   AIC:                             2685.
# Df Residuals:                     309   BIC:                             2722.
# Df Model:                           9
# Covariance Type:            nonrobust
# ==========================================================================================================
#                                              coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------
# Intercept                                 31.7335      0.897     35.391      0.000      29.969      33.498
# scale(passes_total)                        5.3880      1.146      4.702      0.000       3.133       7.643
# scale(fouls_committed)                    -3.4955      0.944     -3.702      0.000      -5.353      -1.638
# scale(cards_red)                           2.1194      0.907      2.336      0.020       0.334       3.905
# scale(games_lineups)                       3.1723      1.011      3.138      0.002       1.183       5.161
# scale(substitutes_out)                    -3.5894      1.191     -3.013      0.003      -5.934      -1.245
# scale(age_x)                              -3.2800      1.091     -3.007      0.003      -5.427      -1.133
# scale(shotsOnTotal_goalsTotal)            -1.1235      3.590     -0.313      0.755      -8.187       5.940
# scale(I(shotsOnTotal_goalsTotal ** 2))    10.6639      3.178      3.356      0.001       4.411      16.917
# scale(dribblesAtmptsSuc)                   4.4932      1.166      3.855      0.000       2.200       6.787
# ==============================================================================
# Omnibus:                      188.557   Durbin-Watson:                   1.820
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1699.573
# Skew:                           2.317   Prob(JB):                         0.00
# Kurtosis:                      13.315   Cond. No.                         8.89
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 모델 성능 : 0.205373973383963

# %% [markdown]
# # OLS - Follower feature 추가
# # OLS - Basic Model

# %%
from sklearn.model_selection import train_test_split

df_ols = df_ols_f
dfX = df_ols.drop(['value'], axis=1)
dfy = df_ols['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

formula = "value ~ " + "+".join(feature_names)

model = sm.OLS.from_formula(formula, data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula(formula, data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
    #print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.354
# Model:                            OLS   Adj. R-squared:                  0.296
# Method:                 Least Squares   F-statistic:                     6.152
# Date:                Mon, 29 Jun 2020   Prob (F-statistic):           2.99e-16
# Time:                        17:35:36   Log-Likelihood:                -1320.0
# No. Observations:                 319   AIC:                             2694.
# Df Residuals:                     292   BIC:                             2796.
# Df Model:                          26
# Covariance Type:            nonrobust
# ===================================================================================================
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# Intercept                          31.7335      0.887     35.760      0.000      29.987      33.480
# scale(follower)                     4.4023      1.084      4.061      0.000       2.269       6.536
# scale(passes_total)                 6.3496      1.376      4.613      0.000       3.641       9.059
# scale(tackles_total)               -0.3995      1.300     -0.307      0.759      -2.958       2.159
# scale(tackles_blocks)              -0.3565      1.309     -0.272      0.786      -2.934       2.221
# scale(tackles_interceptions)       -0.9999      1.661     -0.602      0.548      -4.270       2.270
# scale(fouls_drawn)                 -2.1915      1.338     -1.637      0.103      -4.826       0.443
# scale(fouls_committed)             -3.8349      1.236     -3.102      0.002      -6.268      -1.402
# scale(cards_yellow)                 1.1457      1.208      0.949      0.344      -1.231       3.523
# scale(cards_yellowred)              1.1872      0.969      1.225      0.222      -0.720       3.095
# scale(cards_red)                    1.7823      0.925      1.926      0.055      -0.039       3.604
# scale(penalty_won)                  2.7520      1.156      2.381      0.018       0.477       5.027
# scale(penalty_commited)            -1.4181      1.080     -1.313      0.190      -3.544       0.707
# scale(penalty_success)             -1.7820      1.337     -1.333      0.184      -4.413       0.849
# scale(penalty_missed)               1.0010      1.137      0.881      0.379      -1.236       3.238
# scale(games_lineups)                4.3866      1.990      2.205      0.028       0.471       8.302
# scale(substitutes_out)             -3.8064      1.418     -2.683      0.008      -6.598      -1.015
# scale(substitutes_bench)            1.5600      1.508      1.034      0.302      -1.408       4.528
# scale(age_x)                       -5.2046      1.243     -4.188      0.000      -7.650      -2.759
# scale(height_x)                    -1.4396      1.354     -1.063      0.289      -4.105       1.226
# scale(weight_x)                     2.6983      1.405      1.921      0.056      -0.067       5.463
# scale(rating_x)                    -0.4936      1.225     -0.403      0.687      -2.905       1.917
# scale(shotsOnTotal_goalsTotal)      7.7870      1.977      3.940      0.000       3.897      11.677
# scale(goalsAssist_passesKey)        0.4278      1.522      0.281      0.779      -2.567       3.422
# scale(passesAcc_gamesApp_subIn)    -0.8184      1.701     -0.481      0.631      -4.167       2.530
# scale(duelsWonTotal)                1.8697      1.217      1.536      0.126      -0.526       4.266
# scale(dribblesAtmptsSuc)            2.4267      1.560      1.555      0.121      -0.644       5.497
# ==============================================================================
# Omnibus:                      169.163   Durbin-Watson:                   1.849
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1419.418
# Skew:                           2.033   Prob(JB):                    5.99e-309
# Kurtosis:                      12.501   Cond. No.                         6.78
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 모델 성능 : -0.16498602651171346

# %% [markdown]
# # OLS - 큰 P값 feature 제거

# %%
df_ols_f_1 = df_ols_f.drop(['tackles_blocks', 'tackles_total', 'goalsAssist_passesKey', 'rating_x', 
                            'passesAcc_gamesApp_subIn', 'tackles_interceptions', 'substitutes_bench',
                            'cards_yellow', 'height_x', 'penalty_missed', 'penalty_success', 'fouls_drawn',
                           'duelsWonTotal', 'penalty_commited', 'cards_yellowred', 'penalty_won'], axis=1)
len(df_ols_f_1.columns)
# Out:
# 11

# %%
from sklearn.model_selection import train_test_split

df_ols = df_ols_f_1
dfX = df_ols.drop(['value'], axis=1)
dfy = df_ols['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

formula = "value ~ " + "+".join(feature_names)

model = sm.OLS.from_formula(formula, data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula(formula, data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
    #print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.321
# Model:                            OLS   Adj. R-squared:                  0.299
# Method:                 Least Squares   F-statistic:                     14.55
# Date:                Mon, 29 Jun 2020   Prob (F-statistic):           3.74e-21
# Time:                        17:35:41   Log-Likelihood:                -1327.9
# No. Observations:                 319   AIC:                             2678.
# Df Residuals:                     308   BIC:                             2719.
# Df Model:                          10
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                         31.7335      0.886     35.821      0.000      29.990      33.477
# scale(follower)                    4.1390      1.012      4.091      0.000       2.148       6.130
# scale(passes_total)                5.1098      1.136      4.498      0.000       2.874       7.345
# scale(fouls_committed)            -3.6286      0.949     -3.823      0.000      -5.496      -1.761
# scale(cards_red)                   1.8553      0.899      2.064      0.040       0.086       3.624
# scale(games_lineups)               2.9380      0.997      2.948      0.003       0.977       4.899
# scale(substitutes_out)            -3.1156      1.187     -2.625      0.009      -5.451      -0.780
# scale(age_x)                      -4.4715      1.124     -3.978      0.000      -6.683      -2.260
# scale(weight_x)                    1.9920      0.980      2.032      0.043       0.063       3.921
# scale(shotsOnTotal_goalsTotal)     8.0583      1.349      5.974      0.000       5.404      10.712
# scale(dribblesAtmptsSuc)           2.9276      1.138      2.573      0.011       0.689       5.166
# ==============================================================================
# Omnibus:                      178.736   Durbin-Watson:                   1.812
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1649.265
# Skew:                           2.146   Prob(JB):                         0.00
# Kurtosis:                      13.279   Cond. No.                         2.95
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 모델 성능 : 0.0830155103195834

# %% [markdown]
# # 다항기저모형

# %%
from sklearn.model_selection import train_test_split

df_ols = df_ols_f_1
dfX = df_ols.drop(['value'], axis=1)
dfy = df_ols['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

formula = "value ~ scale(follower) + scale(I(follower**2)) + \
                scale(passes_total) + \
                scale(fouls_committed) + \
                scale(cards_red) + \
                scale(games_lineups) + \
                scale(substitutes_out) + \
                scale(age_x) + \
                scale(weight_x) + \
                scale(shotsOnTotal_goalsTotal) + \
                scale(dribblesAtmptsSuc)"

model = sm.OLS.from_formula(formula, data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(3)
cv = KFold(3, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula(formula, data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
#    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.426
# Model:                            OLS   Adj. R-squared:                  0.405
# Method:                 Least Squares   F-statistic:                     20.71
# Date:                Mon, 29 Jun 2020   Prob (F-statistic):           3.16e-31
# Time:                        17:35:44   Log-Likelihood:                -1301.1
# No. Observations:                 319   AIC:                             2626.
# Df Residuals:                     307   BIC:                             2671.
# Df Model:                          11
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                         31.7335      0.816     38.900      0.000      30.128      33.339
# scale(follower)                   22.1857      2.581      8.597      0.000      17.108      27.264
# scale(I(follower ** 2))          -18.2431      2.433     -7.499      0.000     -23.030     -13.456
# scale(passes_total)                3.8487      1.060      3.632      0.000       1.764       5.934
# scale(fouls_committed)            -2.8872      0.880     -3.283      0.001      -4.618      -1.157
# scale(cards_red)                   1.5941      0.829      1.924      0.055      -0.036       3.225
# scale(games_lineups)               2.8849      0.918      3.143      0.002       1.079       4.691
# scale(substitutes_out)            -2.7010      1.094     -2.468      0.014      -4.855      -0.547
# scale(age_x)                      -4.9357      1.037     -4.760      0.000      -6.976      -2.895
# scale(weight_x)                    2.1031      0.903      2.329      0.020       0.327       3.880
# scale(shotsOnTotal_goalsTotal)     6.3015      1.264      4.985      0.000       3.814       8.789
# scale(dribblesAtmptsSuc)           1.8289      1.058      1.729      0.085      -0.253       3.910
# ==============================================================================
# Omnibus:                      145.899   Durbin-Watson:                   1.832
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              868.854
# Skew:                           1.813   Prob(JB):                    2.14e-189
# Kurtosis:                      10.226   Cond. No.                         6.74
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 모델 성능 : 0.3186820894643885
