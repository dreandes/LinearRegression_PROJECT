# %%
df_ols = pd.read_csv('df_atk_ols.csv', encoding='utf-8-sig', index_col=0)
df_ols
# Out:
#           age    rating  value  follower  passes_accuracy  tackles_total  \
# 0   27.000000  5.250000   32.0    740918           4.0184         0.4629
# 1   25.000000  7.000000   32.0    652886           9.1609         0.7758
# 2   29.000000  6.666667   96.0  30243196           6.7839         0.4684
# 3   29.000000  6.777778   30.5    351898           8.9485         0.0880
# 4   29.000000  5.750000   48.0   3141100           8.6383         1.1633
# ..        ...       ...    ...       ...              ...            ...
# 92  28.000000  6.000000   21.5     48391           3.6346         0.4038
# 93  28.000000  3.888889   44.0   1028085           4.2611         1.1758
# 94  23.076923  1.615385   24.0     57900           2.3642         0.1397
# 95  32.000000  6.153846   22.5   8983450           8.6552         0.7696
# 96  26.000000  6.545455   24.0    109000           7.4315         0.3936
#
#     tackles_blocks  tackles_interceptions  fouls_drawn  fouls_committed  ...  \
# 0           0.0985                 0.2659       2.8562           1.7039  ...
# 1           0.1141                 0.9355       1.6086           1.6542  ...
# 2           0.0323                 0.4119       1.0499           0.6057  ...
# 3           0.0377                 0.2765       0.9175           0.3393  ...
# 4           0.0576                 0.3686       1.6470           1.6931  ...
# ..             ...                    ...          ...              ...  ...
# 92          0.0751                 0.1690       1.2397           1.1082  ...
# 93          0.0216                 0.3452       3.0097           1.4671  ...
# 94          0.0215                 0.0430       0.2794           0.5803  ...
# 95          0.0300                 0.5297       1.6691           0.6396  ...
# 96          0.0695                 0.3010       1.8637           1.7595  ...
#
#     penalty_missed  games_lineups  substitutes_out  games_played        hw  \
# 0           0.0295         0.9947           0.0689      101.5333  0.135092
# 1           0.0000         0.9697           0.6731       87.6556  0.172989
# 2           0.0000         1.0418           0.3634      123.8222  0.144042
# 3           0.0251         0.9677           0.2262       79.5667  0.141252
# 4           0.0000         1.0136           0.4953       86.8222  0.146832
# ..             ...            ...              ...           ...       ...
# 92          0.0094         1.0049           0.1221      106.4778  0.030463
# 93          0.0000         0.9924           0.0647       92.7000  0.167877
# 94          0.0107         1.0531           0.5158       93.0556  0.041084
# 95          0.0000         1.0294           0.5397      100.0556  0.126835
# 96          0.0000         0.9492           0.2894       86.3889  0.044413
#
#     shotsOnTotal_goalsTotal  passesKeyTotal_goalsAssists  duelsWonTotal  \
# 0                  0.410180                     0.247653       0.556537
# 1                  0.258458                     0.495514       0.529304
# 2                  0.449352                     0.546876       0.281113
# 3                  0.522966                     0.538682       0.210466
# 4                  0.451450                     0.444267       0.552810
# ..                      ...                          ...            ...
# 92                 0.460795                     0.357580       0.345001
# 93                 0.244692                     0.397444       0.836112
# 94                 0.114543                     0.023259       0.028809
# 95                 0.333166                     0.842611       0.388996
# 96                 0.279174                     0.444154       0.651724
#
#     dribblesAtmptsSuc  gamesAppearance_sub
# 0            0.177385             0.030469
# 1            0.477339             0.542955
# 2            0.113115             0.060079
# 3            0.173616             0.182433
# 4            0.229560             0.295547
# ..                ...                  ...
# 92           0.054158             0.001575
# 93           0.776258             0.000774
# 94           0.000000             0.188988
# 95           0.482005             0.430106
# 96           0.172558             0.428896
#
# [97 rows x 26 columns]

# %% [markdown]
# # Follower Data 없이 OLS 진행

# %%
df_ols = df_ols.drop('follower', axis=1)

# %%
df_ols
# Out:
#           age    rating  value  passes_accuracy  tackles_total  \
# 0   27.000000  5.250000   32.0           4.0184         0.4629
# 1   25.000000  7.000000   32.0           9.1609         0.7758
# 2   29.000000  6.666667   96.0           6.7839         0.4684
# 3   29.000000  6.777778   30.5           8.9485         0.0880
# 4   29.000000  5.750000   48.0           8.6383         1.1633
# ..        ...       ...    ...              ...            ...
# 92  28.000000  6.000000   21.5           3.6346         0.4038
# 93  28.000000  3.888889   44.0           4.2611         1.1758
# 94  23.076923  1.615385   24.0           2.3642         0.1397
# 95  32.000000  6.153846   22.5           8.6552         0.7696
# 96  26.000000  6.545455   24.0           7.4315         0.3936
#
#     tackles_blocks  tackles_interceptions  fouls_drawn  fouls_committed  \
# 0           0.0985                 0.2659       2.8562           1.7039
# 1           0.1141                 0.9355       1.6086           1.6542
# 2           0.0323                 0.4119       1.0499           0.6057
# 3           0.0377                 0.2765       0.9175           0.3393
# 4           0.0576                 0.3686       1.6470           1.6931
# ..             ...                    ...          ...              ...
# 92          0.0751                 0.1690       1.2397           1.1082
# 93          0.0216                 0.3452       3.0097           1.4671
# 94          0.0215                 0.0430       0.2794           0.5803
# 95          0.0300                 0.5297       1.6691           0.6396
# 96          0.0695                 0.3010       1.8637           1.7595
#
#     cards_yellow  ...  penalty_missed  games_lineups  substitutes_out  \
# 0         0.1083  ...          0.0295         0.9947           0.0689
# 1         0.2738  ...          0.0000         0.9697           0.6731
# 2         0.1696  ...          0.0000         1.0418           0.3634
# 3         0.1005  ...          0.0251         0.9677           0.2262
# 4         0.1267  ...          0.0000         1.0136           0.4953
# ..           ...  ...             ...            ...              ...
# 92        0.1784  ...          0.0094         1.0049           0.1221
# 93        0.2050  ...          0.0000         0.9924           0.0647
# 94        0.1612  ...          0.0107         1.0531           0.5158
# 95        0.0800  ...          0.0000         1.0294           0.5397
# 96        0.1042  ...          0.0000         0.9492           0.2894
#
#     games_played        hw  shotsOnTotal_goalsTotal  \
# 0       101.5333  0.135092                 0.410180
# 1        87.6556  0.172989                 0.258458
# 2       123.8222  0.144042                 0.449352
# 3        79.5667  0.141252                 0.522966
# 4        86.8222  0.146832                 0.451450
# ..           ...       ...                      ...
# 92      106.4778  0.030463                 0.460795
# 93       92.7000  0.167877                 0.244692
# 94       93.0556  0.041084                 0.114543
# 95      100.0556  0.126835                 0.333166
# 96       86.3889  0.044413                 0.279174
#
#     passesKeyTotal_goalsAssists  duelsWonTotal  dribblesAtmptsSuc  \
# 0                      0.247653       0.556537           0.177385
# 1                      0.495514       0.529304           0.477339
# 2                      0.546876       0.281113           0.113115
# 3                      0.538682       0.210466           0.173616
# 4                      0.444267       0.552810           0.229560
# ..                          ...            ...                ...
# 92                     0.357580       0.345001           0.054158
# 93                     0.397444       0.836112           0.776258
# 94                     0.023259       0.028809           0.000000
# 95                     0.842611       0.388996           0.482005
# 96                     0.444154       0.651724           0.172558
#
#     gamesAppearance_sub
# 0              0.030469
# 1              0.542955
# 2              0.060079
# 3              0.182433
# 4              0.295547
# ..                  ...
# 92             0.001575
# 93             0.000774
# 94             0.188988
# 95             0.430106
# 96             0.428896
#
# [97 rows x 25 columns]

# %%
# OLS - 0차

# %%
from sklearn.model_selection import train_test_split

df_ols
dfX = df_ols.drop(['value'], axis=1)
dfy = df_ols['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

#formula = "value ~ " + "+".join(feature_names)

model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.752
# Model:                            OLS   Adj. R-squared:                  0.610
# Method:                 Least Squares   F-statistic:                     5.302
# Date:                Wed, 24 Jun 2020   Prob (F-statistic):           1.30e-06
# Time:                        18:40:59   Log-Likelihood:                -278.80
# No. Observations:                  67   AIC:                             607.6
# Df Residuals:                      42   BIC:                             662.7
# Df Model:                          24
# Covariance Type:            nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Intercept                             42.6493      2.395     17.807      0.000      37.816      47.483
# scale(age)                           -17.4099      3.914     -4.448      0.000     -25.308      -9.512
# scale(rating)                         -1.8474      4.054     -0.456      0.651     -10.029       6.334
# scale(passes_accuracy)                 6.5625      4.762      1.378      0.175      -3.047      16.172
# scale(tackles_total)                  13.5296      4.971      2.722      0.009       3.498      23.561
# scale(tackles_blocks)                  2.1174      3.330      0.636      0.528      -4.603       8.837
# scale(tackles_interceptions)          -8.6835      3.592     -2.417      0.020     -15.933      -1.434
# scale(fouls_drawn)                     8.9912      5.388      1.669      0.103      -1.883      19.865
# scale(fouls_committed)               -17.4178      6.876     -2.533      0.015     -31.295      -3.541
# scale(cards_yellow)                    7.2219      4.142      1.743      0.089      -1.138      15.582
# scale(cards_yellowred)                -0.7145      3.300     -0.217      0.830      -7.374       5.945
# scale(cards_red)                       4.4003      2.920      1.507      0.139      -1.492      10.293
# scale(penalty_won)                     2.1313      3.492      0.610      0.545      -4.915       9.178
# scale(penalty_commited)                2.5189      2.826      0.891      0.378      -3.183       8.221
# scale(penalty_success)                -5.1297      4.107     -1.249      0.219     -13.418       3.158
# scale(penalty_missed)                 -2.9182      3.295     -0.886      0.381      -9.568       3.732
# scale(games_lineups)                 -17.9295      5.625     -3.187      0.003     -29.281      -6.578
# scale(substitutes_out)                15.3969      5.565      2.767      0.008       4.167      26.627
# scale(games_played)                   12.6901      4.274      2.969      0.005       4.066      21.315
# scale(hw)                             -5.2020      3.421     -1.521      0.136     -12.106       1.702
# scale(shotsOnTotal_goalsTotal)        23.2544      5.024      4.629      0.000      13.115      33.394
# scale(passesKeyTotal_goalsAssists)     2.5059      4.622      0.542      0.591      -6.821      11.833
# scale(duelsWonTotal)                   0.2256      4.716      0.048      0.962      -9.291       9.742
# scale(dribblesAtmptsSuc)              -2.2835      6.143     -0.372      0.712     -14.681      10.115
# scale(gamesAppearance_sub)           -24.1019      6.696     -3.599      0.001     -37.616     -10.588
# ==============================================================================
# Omnibus:                        5.189   Durbin-Watson:                   2.222
# Prob(Omnibus):                  0.075   Jarque-Bera (JB):                6.388
# Skew:                           0.205   Prob(JB):                       0.0410
# Kurtosis:                       4.456   Cond. No.                         9.49
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 학습 R2 = 0.63943613, 검증 R2 = 0.61053159
# 학습 R2 = 0.67346959, 검증 R2 = -0.17674848
# 학습 R2 = 0.68664818, 검증 R2 = -0.64509155
# 학습 R2 = 0.65207024, 검증 R2 = 0.40587475
# 학습 R2 = 0.66890126, 검증 R2 = -0.46280726
# 학습 R2 = 0.64377505, 검증 R2 = 0.55191371
# 학습 R2 = 0.66638110, 검증 R2 = -0.52181534
# 학습 R2 = 0.65041415, 검증 R2 = 0.30338138
# 학습 R2 = 0.61328007, 검증 R2 = 0.61997084
# 학습 R2 = 0.67019484, 검증 R2 = 0.17637384
# 모델 성능 : 0.08615834830908795

# %% [markdown]
# # OLS - 1차

# %%
df_ols_1 = df_ols.drop(['duelsWonTotal'], axis=1)
len(df_ols_1.columns), len(df_ols.columns)
# Out:
# (24, 25)

# %%
from sklearn.model_selection import train_test_split

df_ols = df_ols_1
dfX = df_ols.drop(['value'], axis=1)
dfy = df_ols['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

#formula = "value ~ " + "+".join(feature_names)

model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.752
# Model:                            OLS   Adj. R-squared:                  0.619
# Method:                 Least Squares   F-statistic:                     5.664
# Date:                Wed, 24 Jun 2020   Prob (F-statistic):           5.31e-07
# Time:                        18:42:19   Log-Likelihood:                -278.80
# No. Observations:                  67   AIC:                             605.6
# Df Residuals:                      43   BIC:                             658.5
# Df Model:                          23
# Covariance Type:            nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Intercept                             42.6493      2.367     18.017      0.000      37.875      47.423
# scale(age)                           -17.3834      3.829     -4.540      0.000     -25.106      -9.661
# scale(rating)                         -1.7998      3.884     -0.463      0.645      -9.634       6.034
# scale(passes_accuracy)                 6.5233      4.636      1.407      0.167      -2.826      15.873
# scale(tackles_total)                  13.5451      4.902      2.763      0.008       3.659      23.432
# scale(tackles_blocks)                  2.1538      3.204      0.672      0.505      -4.308       8.615
# scale(tackles_interceptions)          -8.6783      3.549     -2.445      0.019     -15.835      -1.521
# scale(fouls_drawn)                     8.9948      5.325      1.689      0.098      -1.744      19.734
# scale(fouls_committed)               -17.2907      6.268     -2.759      0.008     -29.931      -4.650
# scale(cards_yellow)                    7.1672      3.935      1.821      0.076      -0.769      15.104
# scale(cards_yellowred)                -0.6932      3.231     -0.215      0.831      -7.210       5.823
# scale(cards_red)                       4.4132      2.873      1.536      0.132      -1.381      10.208
# scale(penalty_won)                     2.1449      3.439      0.624      0.536      -4.791       9.081
# scale(penalty_commited)                2.4805      2.678      0.926      0.359      -2.920       7.881
# scale(penalty_success)                -5.1110      4.041     -1.265      0.213     -13.260       3.038
# scale(penalty_missed)                 -2.9267      3.252     -0.900      0.373      -9.485       3.631
# scale(games_lineups)                 -17.9206      5.556     -3.225      0.002     -29.126      -6.715
# scale(substitutes_out)                15.3928      5.499      2.799      0.008       4.303      26.483
# scale(games_played)                   12.7011      4.218      3.011      0.004       4.195      21.207
# scale(hw)                             -5.1824      3.357     -1.544      0.130     -11.952       1.587
# scale(shotsOnTotal_goalsTotal)        23.2192      4.912      4.727      0.000      13.313      33.125
# scale(passesKeyTotal_goalsAssists)     2.4649      4.489      0.549      0.586      -6.588      11.518
# scale(dribblesAtmptsSuc)              -2.1256      5.121     -0.415      0.680     -12.454       8.203
# scale(gamesAppearance_sub)           -24.0552      6.547     -3.674      0.001     -37.259     -10.851
# ==============================================================================
# Omnibus:                        5.181   Durbin-Watson:                   2.224
# Prob(Omnibus):                  0.075   Jarque-Bera (JB):                6.314
# Skew:                           0.212   Prob(JB):                       0.0425
# Kurtosis:                       4.443   Cond. No.                         9.01
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 학습 R2 = 0.63657591, 검증 R2 = 0.62867415
# 학습 R2 = 0.67289546, 검증 R2 = -0.18158285
# 학습 R2 = 0.68664781, 검증 R2 = -0.64408310
# 학습 R2 = 0.65105093, 검증 R2 = 0.41086824
# 학습 R2 = 0.66821553, 검증 R2 = -0.36428688
# 학습 R2 = 0.64351619, 검증 R2 = 0.54035946
# 학습 R2 = 0.66608709, 검증 R2 = -0.53628288
# 학습 R2 = 0.64936039, 검증 R2 = 0.30816424
# 학습 R2 = 0.61053372, 검증 R2 = 0.63180456
# 학습 R2 = 0.66801814, 검증 R2 = 0.21409974
# 모델 성능 : 0.10077346697423206

# %% [markdown]
# # OLS - 2차

# %%
df_ols_2 = df_ols_1.drop(['cards_yellowred'], axis=1)
len(df_ols_2.columns), len(df_ols_1.columns)
# Out:
# (23, 24)

# %%
from sklearn.model_selection import train_test_split

df_ols = df_ols_2
dfX = df_ols.drop(['value'], axis=1)
dfy = df_ols['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

#formula = "value ~ " + "+".join(feature_names)

model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.752
# Model:                            OLS   Adj. R-squared:                  0.627
# Method:                 Least Squares   F-statistic:                     6.050
# Date:                Wed, 24 Jun 2020   Prob (F-statistic):           2.14e-07
# Time:                        18:44:27   Log-Likelihood:                -278.84
# No. Observations:                  67   AIC:                             603.7
# Df Residuals:                      44   BIC:                             654.4
# Df Model:                          22
# Covariance Type:            nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Intercept                             42.6493      2.341     18.216      0.000      37.931      47.368
# scale(age)                           -17.3394      3.782     -4.585      0.000     -24.961      -9.717
# scale(rating)                         -1.6500      3.780     -0.437      0.665      -9.267       5.967
# scale(passes_accuracy)                 6.4322      4.566      1.409      0.166      -2.771      15.635
# scale(tackles_total)                  13.3654      4.778      2.798      0.008       3.737      22.994
# scale(tackles_blocks)                  2.2167      3.156      0.702      0.486      -4.143       8.577
# scale(tackles_interceptions)          -8.5547      3.464     -2.470      0.017     -15.535      -1.574
# scale(fouls_drawn)                     8.8058      5.194      1.695      0.097      -1.663      19.274
# scale(fouls_committed)               -17.1996      6.186     -2.781      0.008     -29.666      -4.734
# scale(cards_yellow)                    6.8998      3.692      1.869      0.068      -0.541      14.341
# scale(cards_red)                       4.4948      2.817      1.596      0.118      -1.183      10.172
# scale(penalty_won)                     2.4165      3.163      0.764      0.449      -3.958       8.791
# scale(penalty_commited)                2.4379      2.641      0.923      0.361      -2.885       7.761
# scale(penalty_success)                -5.2985      3.902     -1.358      0.181     -13.162       2.565
# scale(penalty_missed)                 -2.7446      3.105     -0.884      0.382      -9.002       3.513
# scale(games_lineups)                 -17.6504      5.353     -3.297      0.002     -28.438      -6.863
# scale(substitutes_out)                15.2529      5.401      2.824      0.007       4.368      26.138
# scale(games_played)                   12.7585      4.163      3.065      0.004       4.368      21.149
# scale(hw)                             -5.0272      3.242     -1.551      0.128     -11.561       1.507
# scale(shotsOnTotal_goalsTotal)        23.1906      4.857      4.775      0.000      13.403      32.978
# scale(passesKeyTotal_goalsAssists)     2.6483      4.359      0.608      0.547      -6.136      11.433
# scale(dribblesAtmptsSuc)              -2.2953      5.005     -0.459      0.649     -12.382       7.791
# scale(gamesAppearance_sub)           -23.7468      6.318     -3.759      0.000     -36.480     -11.014
# ==============================================================================
# Omnibus:                        5.219   Durbin-Watson:                   2.234
# Prob(Omnibus):                  0.074   Jarque-Bera (JB):                6.371
# Skew:                           0.216   Prob(JB):                       0.0413
# Kurtosis:                       4.448   Cond. No.                         8.83
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 학습 R2 = 0.63549049, 검증 R2 = 0.60778761
# 학습 R2 = 0.67005750, 검증 R2 = -0.18276659
# 학습 R2 = 0.68527406, 검증 R2 = -0.69176723
# 학습 R2 = 0.63795167, 검증 R2 = 0.54391766
# 학습 R2 = 0.66142233, 검증 R2 = -0.23974996
# 학습 R2 = 0.63803314, 검증 R2 = 0.61094724
# 학습 R2 = 0.66355467, 검증 R2 = -0.54498568
# 학습 R2 = 0.64890049, 검증 R2 = 0.28732231
# 학습 R2 = 0.60698059, 검증 R2 = 0.62941702
# 학습 R2 = 0.66794037, 검증 R2 = 0.20241528
# 모델 성능 : 0.12225376702270903

# %% [markdown]
# # OLS - 3차

# %%
df_ols_3 = df_ols_2.drop(['rating'], axis=1)
len(df_ols_3.columns), len(df_ols_2.columns)
# Out:
# (22, 23)

# %%
from sklearn.model_selection import train_test_split

df_ols = df_ols_3
dfX = df_ols.drop(['value'], axis=1)
dfy = df_ols['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

#formula = "value ~ " + "+".join(feature_names)

model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.750
# Model:                            OLS   Adj. R-squared:                  0.634
# Method:                 Least Squares   F-statistic:                     6.445
# Date:                Wed, 24 Jun 2020   Prob (F-statistic):           8.88e-08
# Time:                        18:46:02   Log-Likelihood:                -278.98
# No. Observations:                  67   AIC:                             602.0
# Df Residuals:                      45   BIC:                             650.5
# Df Model:                          21
# Covariance Type:            nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Intercept                             42.6493      2.320     18.382      0.000      37.976      47.322
# scale(age)                           -17.4833      3.734     -4.683      0.000     -25.003      -9.964
# scale(passes_accuracy)                 5.4779      3.973      1.379      0.175      -2.524      13.480
# scale(tackles_total)                  13.5742      4.711      2.882      0.006       4.087      23.062
# scale(tackles_blocks)                  2.3289      3.117      0.747      0.459      -3.949       8.606
# scale(tackles_interceptions)          -8.8393      3.371     -2.622      0.012     -15.629      -2.050
# scale(fouls_drawn)                     8.7139      5.143      1.694      0.097      -1.645      19.073
# scale(fouls_committed)               -17.6647      6.038     -2.926      0.005     -29.826      -5.503
# scale(cards_yellow)                    6.9729      3.655      1.908      0.063      -0.389      14.335
# scale(cards_red)                       4.7128      2.747      1.715      0.093      -0.821      10.246
# scale(penalty_won)                     2.5415      3.122      0.814      0.420      -3.746       8.829
# scale(penalty_commited)                2.2153      2.568      0.863      0.393      -2.957       7.388
# scale(penalty_success)                -5.3209      3.866     -1.376      0.176     -13.108       2.466
# scale(penalty_missed)                 -2.7114      3.076     -0.882      0.383      -8.906       3.484
# scale(games_lineups)                 -17.3216      5.252     -3.298      0.002     -27.899      -6.744
# scale(substitutes_out)                14.9549      5.309      2.817      0.007       4.262      25.648
# scale(games_played)                   12.0516      3.801      3.171      0.003       4.396      19.707
# scale(hw)                             -4.8707      3.193     -1.525      0.134     -11.302       1.561
# scale(shotsOnTotal_goalsTotal)        22.8487      4.750      4.811      0.000      13.282      32.415
# scale(passesKeyTotal_goalsAssists)     2.7441      4.314      0.636      0.528      -5.944      11.433
# scale(dribblesAtmptsSuc)              -2.2511      4.959     -0.454      0.652     -12.238       7.736
# scale(gamesAppearance_sub)           -23.4460      6.224     -3.767      0.000     -35.981     -10.911
# ==============================================================================
# Omnibus:                        5.431   Durbin-Watson:                   2.228
# Prob(Omnibus):                  0.066   Jarque-Bera (JB):                6.689
# Skew:                           0.237   Prob(JB):                       0.0353
# Kurtosis:                       4.474   Cond. No.                         8.64
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 학습 R2 = 0.63003841, 검증 R2 = 0.62957552
# 학습 R2 = 0.66369554, 검증 R2 = -0.11515195
# 학습 R2 = 0.68526776, 검증 R2 = -0.69925816
# 학습 R2 = 0.63441910, 검증 R2 = 0.54635892
# 학습 R2 = 0.65831532, 검증 R2 = -0.24722985
# 학습 R2 = 0.63216407, 검증 R2 = 0.66995660
# 학습 R2 = 0.65858633, 검증 R2 = -0.44050236
# 학습 R2 = 0.64597280, 검증 R2 = 0.29004219
# 학습 R2 = 0.60650723, 검증 R2 = 0.62002299
# 학습 R2 = 0.66308134, 검증 R2 = 0.23872465
# 모델 성능 : 0.14925385496410842

# %%
# OLS - 4차

# %%
df_ols_4 = df_ols_3.drop(['dribblesAtmptsSuc'], axis=1)
len(df_ols_4.columns), len(df_ols_3.columns)
# Out:
# (21, 22)

# %%
from sklearn.model_selection import train_test_split

df_ols = df_ols_4
dfX = df_ols.drop(['value'], axis=1)
dfy = df_ols['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

#formula = "value ~ " + "+".join(feature_names)

model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.749
# Model:                            OLS   Adj. R-squared:                  0.640
# Method:                 Least Squares   F-statistic:                     6.876
# Date:                Wed, 24 Jun 2020   Prob (F-statistic):           3.60e-08
# Time:                        18:47:44   Log-Likelihood:                -279.14
# No. Observations:                  67   AIC:                             600.3
# Df Residuals:                      46   BIC:                             646.6
# Df Model:                          20
# Covariance Type:            nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Intercept                             42.6493      2.300     18.543      0.000      38.019      47.279
# scale(age)                           -17.1985      3.649     -4.714      0.000     -24.543      -9.854
# scale(passes_accuracy)                 5.7936      3.878      1.494      0.142      -2.012      13.599
# scale(tackles_total)                  12.5085      4.049      3.090      0.003       4.359      20.658
# scale(tackles_blocks)                  2.4174      3.084      0.784      0.437      -3.790       8.625
# scale(tackles_interceptions)          -8.4885      3.253     -2.610      0.012     -15.036      -1.941
# scale(fouls_drawn)                     7.3032      4.063      1.798      0.079      -0.875      15.481
# scale(fouls_committed)               -16.3848      5.293     -3.095      0.003     -27.039      -5.730
# scale(cards_yellow)                    6.5265      3.490      1.870      0.068      -0.498      13.551
# scale(cards_red)                       4.6960      2.723      1.724      0.091      -0.786      10.178
# scale(penalty_won)                     2.5238      3.094      0.816      0.419      -3.705       8.752
# scale(penalty_commited)                2.1449      2.541      0.844      0.403      -2.970       7.260
# scale(penalty_success)                -5.0192      3.776     -1.329      0.190     -12.620       2.581
# scale(penalty_missed)                 -2.5424      3.027     -0.840      0.405      -8.635       3.550
# scale(games_lineups)                 -17.0068      5.161     -3.296      0.002     -27.395      -6.619
# scale(substitutes_out)                14.4143      5.129      2.810      0.007       4.090      24.739
# scale(games_played)                   11.9444      3.761      3.176      0.003       4.375      19.514
# scale(hw)                             -4.7247      3.150     -1.500      0.140     -11.064       1.615
# scale(shotsOnTotal_goalsTotal)        22.2645      4.532      4.912      0.000      13.141      31.388
# scale(passesKeyTotal_goalsAssists)     1.8291      3.781      0.484      0.631      -5.782       9.440
# scale(gamesAppearance_sub)           -23.1038      6.124     -3.772      0.000     -35.431     -10.776
# ==============================================================================
# Omnibus:                        5.986   Durbin-Watson:                   2.234
# Prob(Omnibus):                  0.050   Jarque-Bera (JB):                7.114
# Skew:                           0.323   Prob(JB):                       0.0285
# Kurtosis:                       4.460   Cond. No.                         7.56
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 학습 R2 = 0.62814436, 검증 R2 = 0.64320309
# 학습 R2 = 0.66369553, 검증 R2 = -0.11524095
# 학습 R2 = 0.68520223, 검증 R2 = -0.70449013
# 학습 R2 = 0.63432691, 검증 R2 = 0.55009422
# 학습 R2 = 0.65321399, 검증 R2 = -0.05079056
# 학습 R2 = 0.63209934, 검증 R2 = 0.66600799
# 학습 R2 = 0.65841788, 검증 R2 = -0.40472155
# 학습 R2 = 0.64580825, 검증 R2 = 0.30148042
# 학습 R2 = 0.60476828, 검증 R2 = 0.62554439
# 학습 R2 = 0.66301055, 검증 R2 = 0.23609525
# 모델 성능 : 0.17471821722334185

# %% [markdown]
# # OLS - 5차

# %%
df_ols_5 = df_ols_4.drop(['passesKeyTotal_goalsAssists'], axis=1)
len(df_ols_5.columns), len(df_ols_4.columns)
# Out:
# (20, 21)

# %%
from sklearn.model_selection import train_test_split

df_ols = df_ols_5
dfX = df_ols.drop(['value'], axis=1)
dfy = df_ols['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

#formula = "value ~ " + "+".join(feature_names)

model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.748
# Model:                            OLS   Adj. R-squared:                  0.646
# Method:                 Least Squares   F-statistic:                     7.345
# Date:                Wed, 24 Jun 2020   Prob (F-statistic):           1.43e-08
# Time:                        18:58:08   Log-Likelihood:                -279.31
# No. Observations:                  67   AIC:                             598.6
# Df Residuals:                      47   BIC:                             642.7
# Df Model:                          19
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                         42.6493      2.281     18.696      0.000      38.060      47.239
# scale(age)                       -17.1984      3.619     -4.753      0.000     -24.478      -9.918
# scale(passes_accuracy)             5.9982      3.823      1.569      0.123      -1.693      13.689
# scale(tackles_total)              13.1332      3.806      3.451      0.001       5.477      20.790
# scale(tackles_blocks)              2.4101      3.058      0.788      0.435      -3.743       8.563
# scale(tackles_interceptions)      -8.1443      3.148     -2.587      0.013     -14.477      -1.811
# scale(fouls_drawn)                 8.3981      3.346      2.510      0.016       1.666      15.130
# scale(fouls_committed)           -17.4682      4.757     -3.672      0.001     -27.038      -7.899
# scale(cards_yellow)                6.5729      3.460      1.900      0.064      -0.388      13.533
# scale(cards_red)                   4.3741      2.619      1.670      0.102      -0.895       9.643
# scale(penalty_won)                 2.2319      3.010      0.741      0.462      -3.823       8.287
# scale(penalty_commited)            2.2500      2.511      0.896      0.375      -2.802       7.302
# scale(penalty_success)            -5.2255      3.721     -1.404      0.167     -12.711       2.260
# scale(penalty_missed)             -2.6996      2.985     -0.905      0.370      -8.704       3.305
# scale(games_lineups)             -17.0264      5.118     -3.327      0.002     -27.323      -6.730
# scale(substitutes_out)            14.8348      5.014      2.959      0.005       4.749      24.921
# scale(games_played)               12.2277      3.684      3.319      0.002       4.816      19.640
# scale(hw)                         -5.1315      3.010     -1.705      0.095     -11.188       0.924
# scale(shotsOnTotal_goalsTotal)    23.0994      4.157      5.557      0.000      14.737      31.462
# scale(gamesAppearance_sub)       -23.2709      6.064     -3.837      0.000     -35.471     -11.071
# ==============================================================================
# Omnibus:                        5.648   Durbin-Watson:                   2.224
# Prob(Omnibus):                  0.059   Jarque-Bera (JB):                6.433
# Skew:                           0.316   Prob(JB):                       0.0401
# Kurtosis:                       4.380   Cond. No.                         7.42
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 학습 R2 = 0.61013441, 검증 R2 = 0.57660038
# 학습 R2 = 0.65335045, 검증 R2 = -0.33477618
# 학습 R2 = 0.66146708, 검증 R2 = -0.80993429
# 학습 R2 = 0.60939594, 검증 R2 = 0.53732488
# 학습 R2 = 0.63221182, 검증 R2 = -0.13137003
# 학습 R2 = 0.61405034, 검증 R2 = 0.55824972
# 학습 R2 = 0.63487024, 검증 R2 = -0.34677002
# 학습 R2 = 0.63723738, 검증 R2 = 0.14728309
# 학습 R2 = 0.57270065, 검증 R2 = 0.63462176
# 학습 R2 = 0.62515147, 검증 R2 = 0.41244088
# 모델 성능 : 0.12436701927725427

# %% [markdown]
# # OLS - 6차

# %%
df_ols_6 = df_ols_5.drop(['penalty_won'], axis=1)
len(df_ols_6.columns), len(df_ols_5.columns)
# Out:
# (19, 20)

# %%
from sklearn.model_selection import train_test_split

df_ols = df_ols_6
dfX = df_ols.drop(['value'], axis=1)
dfy = df_ols['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

#formula = "value ~ " + "+".join(feature_names)

model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.745
# Model:                            OLS   Adj. R-squared:                  0.650
# Method:                 Least Squares   F-statistic:                     7.796
# Date:                Wed, 24 Jun 2020   Prob (F-statistic):           6.33e-09
# Time:                        18:59:52   Log-Likelihood:                -279.69
# No. Observations:                  67   AIC:                             597.4
# Df Residuals:                      48   BIC:                             639.3
# Df Model:                          18
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                         42.6493      2.271     18.784      0.000      38.084      47.214
# scale(age)                       -17.5539      3.570     -4.917      0.000     -24.732     -10.376
# scale(passes_accuracy)             6.0781      3.803      1.598      0.117      -1.569      13.725
# scale(tackles_total)              13.6366      3.727      3.659      0.001       6.143      21.131
# scale(tackles_blocks)              1.8206      2.939      0.619      0.539      -4.090       7.731
# scale(tackles_interceptions)      -8.5189      3.093     -2.755      0.008     -14.737      -2.301
# scale(fouls_drawn)                 9.2722      3.117      2.974      0.005       3.005      15.540
# scale(fouls_committed)           -16.8328      4.657     -3.615      0.001     -26.196      -7.469
# scale(cards_yellow)                6.1746      3.402      1.815      0.076      -0.665      13.015
# scale(cards_red)                   4.4928      2.602      1.727      0.091      -0.739       9.724
# scale(penalty_commited)            2.1739      2.497      0.870      0.388      -2.848       7.195
# scale(penalty_success)            -4.5746      3.599     -1.271      0.210     -11.811       2.662
# scale(penalty_missed)             -3.3601      2.835     -1.185      0.242      -9.061       2.340
# scale(games_lineups)             -17.3543      5.075     -3.419      0.001     -27.558      -7.150
# scale(substitutes_out)            14.7047      4.987      2.949      0.005       4.678      24.732
# scale(games_played)               12.0048      3.655      3.285      0.002       4.656      19.353
# scale(hw)                         -5.3549      2.981     -1.796      0.079     -11.349       0.639
# scale(shotsOnTotal_goalsTotal)    23.2331      4.133      5.621      0.000      14.923      31.544
# scale(gamesAppearance_sub)       -23.3703      6.035     -3.873      0.000     -35.503     -11.237
# ==============================================================================
# Omnibus:                        6.739   Durbin-Watson:                   2.316
# Prob(Omnibus):                  0.034   Jarque-Bera (JB):                7.319
# Skew:                           0.447   Prob(JB):                       0.0257
# Kurtosis:                       4.350   Cond. No.                         7.41
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 학습 R2 = 0.59024211, 검증 R2 = 0.37854176
# 학습 R2 = 0.62181879, 검증 R2 = -0.63286493
# 학습 R2 = 0.63290312, 검증 R2 = -1.13680931
# 학습 R2 = 0.56254119, 검증 R2 = 0.53842927
# 학습 R2 = 0.59785826, 검증 R2 = -0.32949903
# 학습 R2 = 0.57583757, 검증 R2 = 0.48414893
# 학습 R2 = 0.58050671, 검증 R2 = 0.18470566
# 학습 R2 = 0.57972123, 검증 R2 = 0.26850986
# 학습 R2 = 0.53630517, 검증 R2 = 0.55092500
# 학습 R2 = 0.57741425, 검증 R2 = 0.45578770
# 모델 성능 : 0.07618749177166739

# %% [markdown]
# # OLS - 7차

# %%
df_ols_7 = df_ols_6.drop(['tackles_blocks'], axis=1)
len(df_ols_7.columns), len(df_ols_6.columns)
# Out:
# (18, 19)

# %%
from sklearn.model_selection import train_test_split

df_ols = df_ols_7
dfX = df_ols.drop(['value'], axis=1)
dfy = df_ols['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

#formula = "value ~ " + "+".join(feature_names)

model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.743
# Model:                            OLS   Adj. R-squared:                  0.654
# Method:                 Least Squares   F-statistic:                     8.336
# Date:                Wed, 24 Jun 2020   Prob (F-statistic):           2.52e-09
# Time:                        19:01:19   Log-Likelihood:                -279.96
# No. Observations:                  67   AIC:                             595.9
# Df Residuals:                      49   BIC:                             635.6
# Df Model:                          17
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                         42.6493      2.256     18.903      0.000      38.115      47.183
# scale(age)                       -16.9805      3.426     -4.956      0.000     -23.865     -10.095
# scale(passes_accuracy)             6.3346      3.757      1.686      0.098      -1.215      13.885
# scale(tackles_total)              13.1790      3.630      3.630      0.001       5.884      20.474
# scale(tackles_interceptions)      -8.4441      3.071     -2.750      0.008     -14.615      -2.273
# scale(fouls_drawn)                 8.9518      3.055      2.931      0.005       2.813      15.090
# scale(fouls_committed)           -15.3459      3.965     -3.870      0.000     -23.314      -7.377
# scale(cards_yellow)                5.6036      3.254      1.722      0.091      -0.935      12.143
# scale(cards_red)                   4.5754      2.582      1.772      0.083      -0.614       9.764
# scale(penalty_commited)            2.1779      2.482      0.878      0.384      -2.809       7.165
# scale(penalty_success)            -4.5766      3.576     -1.280      0.207     -11.763       2.610
# scale(penalty_missed)             -3.5124      2.807     -1.251      0.217      -9.153       2.128
# scale(games_lineups)             -17.3717      5.043     -3.445      0.001     -27.506      -7.237
# scale(substitutes_out)            14.3005      4.913      2.911      0.005       4.428      24.173
# scale(games_played)               11.3517      3.477      3.264      0.002       4.364      18.340
# scale(hw)                         -4.9907      2.904     -1.718      0.092     -10.827       0.845
# scale(shotsOnTotal_goalsTotal)    22.8327      4.057      5.629      0.000      14.681      30.985
# scale(gamesAppearance_sub)       -23.4774      5.994     -3.917      0.000     -35.523     -11.432
# ==============================================================================
# Omnibus:                        6.786   Durbin-Watson:                   2.339
# Prob(Omnibus):                  0.034   Jarque-Bera (JB):                6.943
# Skew:                           0.488   Prob(JB):                       0.0311
# Kurtosis:                       4.238   Cond. No.                         7.35
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 학습 R2 = 0.58625867, 검증 R2 = 0.40792002
# 학습 R2 = 0.62170187, 검증 R2 = -0.64486727
# 학습 R2 = 0.63220250, 검증 R2 = -1.04464417
# 학습 R2 = 0.56187286, 검증 R2 = 0.53853232
# 학습 R2 = 0.59664718, 검증 R2 = -0.30896115
# 학습 R2 = 0.57517855, 검증 R2 = 0.48027834
# 학습 R2 = 0.57834377, 검증 R2 = 0.24413673
# 학습 R2 = 0.57503702, 검증 R2 = 0.32665232
# 학습 R2 = 0.53487436, 검증 R2 = 0.55039558
# 학습 R2 = 0.57675252, 검증 R2 = 0.45000533
# 모델 성능 : 0.09994480498774576

# %% [markdown]
# # OLS - 8차

# %%
df_ols_8 = df_ols_7.drop(['penalty_commited'], axis=1)
len(df_ols_8.columns), len(df_ols_7.columns)
# Out:
# (17, 18)

# %%
from sklearn.model_selection import train_test_split

df_ols = df_ols_8
dfX = df_ols.drop(['value'], axis=1)
dfy = df_ols['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

#formula = "value ~ " + "+".join(feature_names)

model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.739
# Model:                            OLS   Adj. R-squared:                  0.656
# Method:                 Least Squares   F-statistic:                     8.850
# Date:                Wed, 24 Jun 2020   Prob (F-statistic):           1.16e-09
# Time:                        19:02:47   Log-Likelihood:                -280.48
# No. Observations:                  67   AIC:                             595.0
# Df Residuals:                      50   BIC:                             632.4
# Df Model:                          16
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                         42.6493      2.251     18.947      0.000      38.128      47.171
# scale(age)                       -16.7188      3.405     -4.910      0.000     -23.558      -9.879
# scale(passes_accuracy)             6.5853      3.737      1.762      0.084      -0.922      14.092
# scale(tackles_total)              13.0581      3.619      3.608      0.001       5.789      20.328
# scale(tackles_interceptions)      -8.1799      3.049     -2.683      0.010     -14.304      -2.056
# scale(fouls_drawn)                 8.7744      3.041      2.885      0.006       2.667      14.882
# scale(fouls_committed)           -14.7068      3.889     -3.782      0.000     -22.518      -6.896
# scale(cards_yellow)                5.1969      3.213      1.617      0.112      -1.257      11.651
# scale(cards_red)                   4.7996      2.564      1.872      0.067      -0.349       9.949
# scale(penalty_success)            -4.2387      3.547     -1.195      0.238     -11.364       2.886
# scale(penalty_missed)             -3.4800      2.800     -1.243      0.220      -9.104       2.144
# scale(games_lineups)             -16.8924      5.002     -3.377      0.001     -26.939      -6.846
# scale(substitutes_out)            13.4506      4.805      2.799      0.007       3.799      23.103
# scale(games_played)               11.1823      3.464      3.228      0.002       4.225      18.140
# scale(hw)                         -5.3288      2.872     -1.856      0.069     -11.097       0.439
# scale(shotsOnTotal_goalsTotal)    22.0156      3.939      5.589      0.000      14.103      29.928
# scale(gamesAppearance_sub)       -22.7557      5.924     -3.842      0.000     -34.654     -10.858
# ==============================================================================
# Omnibus:                        7.705   Durbin-Watson:                   2.299
# Prob(Omnibus):                  0.021   Jarque-Bera (JB):                8.064
# Skew:                           0.550   Prob(JB):                       0.0177
# Kurtosis:                       4.295   Cond. No.                         7.24
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 학습 R2 = 0.58615683, 검증 R2 = 0.40609296
# 학습 R2 = 0.62083568, 검증 R2 = -0.63598135
# 학습 R2 = 0.63070557, 검증 R2 = -0.99895216
# 학습 R2 = 0.55922496, 검증 R2 = 0.55324571
# 학습 R2 = 0.59663992, 검증 R2 = -0.31211149
# 학습 R2 = 0.57511340, 검증 R2 = 0.47605422
# 학습 R2 = 0.57828691, 검증 R2 = 0.23353324
# 학습 R2 = 0.57502313, 검증 R2 = 0.32454950
# 학습 R2 = 0.53429649, 검증 R2 = 0.55152283
# 학습 R2 = 0.57618757, 검증 R2 = 0.45455860
# 모델 성능 : 0.10525120615533372

# %% [markdown]
# # OLS - 9차

# %%
df_ols_9 = df_ols_8.drop(['penalty_success'], axis=1)
len(df_ols_9.columns), len(df_ols_8.columns)
# Out:
# (16, 17)

# %%
from sklearn.model_selection import train_test_split

df_ols = df_ols_9
dfX = df_ols.drop(['value'], axis=1)
dfy = df_ols['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

#formula = "value ~ " + "+".join(feature_names)

model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.732
# Model:                            OLS   Adj. R-squared:                  0.653
# Method:                 Least Squares   F-statistic:                     9.267
# Date:                Wed, 24 Jun 2020   Prob (F-statistic):           6.99e-10
# Time:                        19:04:25   Log-Likelihood:                -281.43
# No. Observations:                  67   AIC:                             594.9
# Df Residuals:                      51   BIC:                             630.1
# Df Model:                          15
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                         42.6493      2.260     18.868      0.000      38.111      47.187
# scale(age)                       -17.9324      3.264     -5.494      0.000     -24.485     -11.380
# scale(passes_accuracy)             7.2456      3.712      1.952      0.056      -0.206      14.697
# scale(tackles_total)              13.3769      3.624      3.691      0.001       6.101      20.653
# scale(tackles_interceptions)      -8.1398      3.062     -2.659      0.010     -14.286      -1.994
# scale(fouls_drawn)                 8.4038      3.038      2.766      0.008       2.305      14.502
# scale(fouls_committed)           -13.7369      3.819     -3.597      0.001     -21.404      -6.070
# scale(cards_yellow)                4.8644      3.215      1.513      0.136      -1.589      11.318
# scale(cards_red)                   5.5252      2.501      2.209      0.032       0.504      10.546
# scale(penalty_missed)             -4.3039      2.725     -1.579      0.120      -9.775       1.167
# scale(games_lineups)             -17.1989      5.016     -3.429      0.001     -27.269      -7.129
# scale(substitutes_out)            13.4607      4.825      2.790      0.007       3.773      23.148
# scale(games_played)               11.9325      3.421      3.488      0.001       5.065      18.800
# scale(hw)                         -5.2582      2.883     -1.824      0.074     -11.046       0.530
# scale(shotsOnTotal_goalsTotal)    20.0875      3.609      5.567      0.000      12.843      27.332
# scale(gamesAppearance_sub)       -22.3977      5.941     -3.770      0.000     -34.324     -10.471
# ==============================================================================
# Omnibus:                        8.207   Durbin-Watson:                   2.291
# Prob(Omnibus):                  0.017   Jarque-Bera (JB):                9.204
# Skew:                           0.546   Prob(JB):                       0.0100
# Kurtosis:                       4.451   Cond. No.                         6.73
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 학습 R2 = 0.57954994, 검증 R2 = 0.39595221
# 학습 R2 = 0.61106673, 검증 R2 = -0.58706688
# 학습 R2 = 0.62592675, 검증 R2 = -1.06840060
# 학습 R2 = 0.55695610, 검증 R2 = 0.53107142
# 학습 R2 = 0.58917161, 검증 R2 = -0.31203559
# 학습 R2 = 0.56212883, 검증 R2 = 0.59317477
# 학습 R2 = 0.57173439, 검증 R2 = 0.20093610
# 학습 R2 = 0.55802862, 검증 R2 = 0.44809817
# 학습 R2 = 0.53040521, 검증 R2 = 0.53077180
# 학습 R2 = 0.57330395, 검증 R2 = 0.41686409
# 모델 성능 : 0.11493654786492277

# %% [markdown]
# # OLS - 10차

# %%
df_ols_10 = df_ols_9.drop(['cards_yellow'], axis=1)
len(df_ols_10.columns), len(df_ols_9.columns)
# Out:
# (15, 16)

# %%
from sklearn.model_selection import train_test_split

df_ols = df_ols_10
dfX = df_ols.drop(['value'], axis=1)
dfy = df_ols['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

#formula = "value ~ " + "+".join(feature_names)

model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.720
# Model:                            OLS   Adj. R-squared:                  0.644
# Method:                 Least Squares   F-statistic:                     9.529
# Date:                Wed, 24 Jun 2020   Prob (F-statistic):           6.07e-10
# Time:                        19:05:57   Log-Likelihood:                -282.90
# No. Observations:                  67   AIC:                             595.8
# Df Residuals:                      52   BIC:                             628.9
# Df Model:                          14
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                         42.6493      2.288     18.638      0.000      38.057      47.241
# scale(age)                       -18.3206      3.294     -5.562      0.000     -24.930     -11.711
# scale(passes_accuracy)             8.1312      3.711      2.191      0.033       0.685      15.577
# scale(tackles_total)              11.6480      3.482      3.345      0.002       4.661      18.635
# scale(tackles_interceptions)      -7.3764      3.057     -2.413      0.019     -13.510      -1.242
# scale(fouls_drawn)                 9.0077      3.048      2.955      0.005       2.891      15.125
# scale(fouls_committed)           -11.1853      3.469     -3.224      0.002     -18.146      -4.224
# scale(cards_red)                   6.0182      2.510      2.397      0.020       0.981      11.055
# scale(penalty_missed)             -4.5833      2.752     -1.665      0.102     -10.106       0.940
# scale(games_lineups)             -16.4873      5.056     -3.261      0.002     -26.632      -6.343
# scale(substitutes_out)            11.8490      4.764      2.487      0.016       2.288      21.410
# scale(games_played)               10.8059      3.380      3.197      0.002       4.023      17.588
# scale(hw)                         -5.0553      2.916     -1.734      0.089     -10.906       0.795
# scale(shotsOnTotal_goalsTotal)    19.8005      3.648      5.428      0.000      12.480      27.121
# scale(gamesAppearance_sub)       -22.2160      6.013     -3.695      0.001     -34.282     -10.150
# ==============================================================================
# Omnibus:                        8.521   Durbin-Watson:                   2.270
# Prob(Omnibus):                  0.014   Jarque-Bera (JB):                8.545
# Skew:                           0.648   Prob(JB):                       0.0139
# Kurtosis:                       4.174   Cond. No.                         6.66
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 학습 R2 = 0.57954555, 검증 R2 = 0.39614033
# 학습 R2 = 0.61045688, 검증 R2 = -0.56235467
# 학습 R2 = 0.62495922, 검증 R2 = -1.01176777
# 학습 R2 = 0.55676622, 검증 R2 = 0.53399446
# 학습 R2 = 0.58776928, 검증 R2 = -0.25485812
# 학습 R2 = 0.56186572, 검증 R2 = 0.60187115
# 학습 R2 = 0.57159421, 검증 R2 = 0.21052405
# 학습 R2 = 0.55292822, 검증 R2 = 0.55591870
# 학습 R2 = 0.53040233, 검증 R2 = 0.53095091
# 학습 R2 = 0.57313641, 검증 R2 = 0.41404129
# 모델 성능 : 0.14144603202641703

# %% [markdown]
# # OLS - 11차

# %%
df_ols_11 = df_ols_10.drop(['penalty_missed'], axis=1)
len(df_ols_11.columns), len(df_ols_10.columns)
# Out:
# (14, 15)

# %%
from sklearn.model_selection import train_test_split

df_ols = df_ols_11
dfX = df_ols.drop(['value'], axis=1)
dfy = df_ols['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

#formula = "value ~ " + "+".join(feature_names)

model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.705
# Model:                            OLS   Adj. R-squared:                  0.632
# Method:                 Least Squares   F-statistic:                     9.724
# Date:                Wed, 24 Jun 2020   Prob (F-statistic):           6.45e-10
# Time:                        19:07:43   Log-Likelihood:                -284.64
# No. Observations:                  67   AIC:                             597.3
# Df Residuals:                      53   BIC:                             628.1
# Df Model:                          13
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                         42.6493      2.326     18.334      0.000      37.983      47.315
# scale(age)                       -19.1520      3.310     -5.786      0.000     -25.791     -12.513
# scale(passes_accuracy)             7.5792      3.757      2.017      0.049       0.043      15.115
# scale(tackles_total)              12.5355      3.498      3.584      0.001       5.519      19.552
# scale(tackles_interceptions)      -7.9797      3.086     -2.586      0.012     -14.169      -1.791
# scale(fouls_drawn)                 9.5542      3.081      3.101      0.003       3.374      15.734
# scale(fouls_committed)           -12.1056      3.481     -3.477      0.001     -19.088      -5.123
# scale(cards_red)                   5.5562      2.536      2.191      0.033       0.469      10.643
# scale(games_lineups)             -17.6367      5.091     -3.464      0.001     -27.849      -7.425
# scale(substitutes_out)            13.3737      4.753      2.814      0.007       3.840      22.907
# scale(games_played)               10.7542      3.436      3.130      0.003       3.863      17.646
# scale(hw)                         -5.1911      2.963     -1.752      0.086     -11.134       0.752
# scale(shotsOnTotal_goalsTotal)    18.4776      3.620      5.105      0.000      11.218      25.737
# scale(gamesAppearance_sub)       -22.8006      6.102     -3.737      0.000     -35.040     -10.561
# ==============================================================================
# Omnibus:                       12.150   Durbin-Watson:                   2.169
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):               13.555
# Skew:                           0.840   Prob(JB):                      0.00114
# Kurtosis:                       4.426   Cond. No.                         6.41
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 학습 R2 = 0.57222546, 검증 R2 = 0.44486212
# 학습 R2 = 0.60517524, 검증 R2 = -0.46255941
# 학습 R2 = 0.62247975, 검증 R2 = -1.00411576
# 학습 R2 = 0.55581057, 검증 R2 = 0.52599442
# 학습 R2 = 0.58748387, 검증 R2 = -0.27535966
# 학습 R2 = 0.56132446, 검증 R2 = 0.58540225
# 학습 R2 = 0.56892595, 검증 R2 = 0.23820442
# 학습 R2 = 0.55173885, 검증 R2 = 0.54453251
# 학습 R2 = 0.53035057, 검증 R2 = 0.53476199
# 학습 R2 = 0.57251005, 검증 R2 = 0.40266648
# 모델 성능 : 0.15343893596833375

# %% [markdown]
# # OLS - 12차

# %%
df_ols_12 = df_ols_11.drop(['hw'], axis=1)
len(df_ols_12.columns), len(df_ols_11.columns)
# Out:
# (13, 14)

# %%
from sklearn.model_selection import train_test_split

df_ols = df_ols_12
dfX = df_ols.drop(['value'], axis=1)
dfy = df_ols['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

#formula = "value ~ " + "+".join(feature_names)

model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.687
# Model:                            OLS   Adj. R-squared:                  0.618
# Method:                 Least Squares   F-statistic:                     9.899
# Date:                Wed, 24 Jun 2020   Prob (F-statistic):           7.73e-10
# Time:                        19:10:00   Log-Likelihood:                -286.52
# No. Observations:                  67   AIC:                             599.0
# Df Residuals:                      54   BIC:                             627.7
# Df Model:                          12
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                         42.6493      2.370     17.992      0.000      37.897      47.402
# scale(age)                       -17.7569      3.274     -5.424      0.000     -24.320     -11.194
# scale(passes_accuracy)             8.1137      3.816      2.126      0.038       0.464      15.764
# scale(tackles_total)              10.8300      3.424      3.163      0.003       3.966      17.694
# scale(tackles_interceptions)      -9.3824      3.037     -3.090      0.003     -15.470      -3.294
# scale(fouls_drawn)                 9.2965      3.136      2.964      0.005       3.009      15.584
# scale(fouls_committed)           -10.0720      3.345     -3.011      0.004     -16.777      -3.366
# scale(cards_red)                   5.9768      2.573      2.323      0.024       0.819      11.135
# scale(games_lineups)             -17.1860      5.181     -3.317      0.002     -27.574      -6.798
# scale(substitutes_out)            14.2205      4.818      2.951      0.005       4.560      23.881
# scale(games_played)               11.7956      3.448      3.421      0.001       4.882      18.709
# scale(shotsOnTotal_goalsTotal)    17.5603      3.649      4.812      0.000      10.244      24.877
# scale(gamesAppearance_sub)       -22.5353      6.216     -3.625      0.001     -34.998     -10.073
# ==============================================================================
# Omnibus:                        9.919   Durbin-Watson:                   2.086
# Prob(Omnibus):                  0.007   Jarque-Bera (JB):               10.334
# Skew:                           0.729   Prob(JB):                      0.00570
# Kurtosis:                       4.254   Cond. No.                         6.33
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 학습 R2 = 0.55814727, 검증 R2 = 0.44719705
# 학습 R2 = 0.59445543, 검증 R2 = -0.50363455
# 학습 R2 = 0.60684290, 검증 R2 = -0.88607697
# 학습 R2 = 0.54355683, 검증 R2 = 0.52991217
# 학습 R2 = 0.57896110, 검증 R2 = -0.40404234
# 학습 R2 = 0.54634196, 검증 R2 = 0.63458576
# 학습 R2 = 0.55841499, 검증 R2 = 0.17899981
# 학습 R2 = 0.53771764, 검증 R2 = 0.55922010
# 학습 R2 = 0.51191478, 검증 R2 = 0.54162598
# 학습 R2 = 0.57148025, 검증 R2 = 0.31777930
# 모델 성능 : 0.14155663163408866

# %% [markdown]
# # 가중치

# %%
from sklearn.model_selection import train_test_split

df_ols = df_ols_12
dfX = df_ols.drop(['value'], axis=1)
dfy = df_ols['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

#feature_names = list(dfX.columns)
#feature_names = ["scale({})".format(name) for name in feature_names]

formula = "value ~ scale(age) + scale(I(age**2)) + scale(I(age**3)) + \
            scale(passes_accuracy) + \
            scale(tackles_total) + \
            scale(tackles_interceptions) + \
            scale(fouls_drawn) + \
            scale(fouls_committed) + \
            scale(cards_red) + \
            scale(games_lineups) + \
            scale(substitutes_out) + \
            scale(games_played) + \
            scale(shotsOnTotal_goalsTotal) + \
            scale(gamesAppearance_sub)"

model = sm.OLS.from_formula(formula, data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula(formula, data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.703
# Model:                            OLS   Adj. R-squared:                  0.623
# Method:                 Least Squares   F-statistic:                     8.783
# Date:                Wed, 24 Jun 2020   Prob (F-statistic):           2.40e-09
# Time:                        19:28:03   Log-Likelihood:                -284.84
# No. Observations:                  67   AIC:                             599.7
# Df Residuals:                      52   BIC:                             632.8
# Df Model:                          14
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                         42.6493      2.356     18.105      0.000      37.922      47.376
# scale(age)                      -746.9246    446.385     -1.673      0.100   -1642.662     148.813
# scale(I(age ** 2))              1444.2731    882.337      1.637      0.108    -326.265    3214.811
# scale(I(age ** 3))              -718.7809    439.188     -1.637      0.108   -1600.076     162.514
# scale(passes_accuracy)             7.2564      3.834      1.893      0.064      -0.436      14.949
# scale(tackles_total)               9.4427      3.508      2.692      0.010       2.403      16.482
# scale(tackles_interceptions)      -7.6765      3.195     -2.402      0.020     -14.088      -1.265
# scale(fouls_drawn)                 9.8884      3.320      2.978      0.004       3.226      16.551
# scale(fouls_committed)            -9.4181      3.362     -2.801      0.007     -16.165      -2.672
# scale(cards_red)                   6.2634      2.566      2.441      0.018       1.114      11.413
# scale(games_lineups)             -15.9889      5.236     -3.054      0.004     -26.495      -5.482
# scale(substitutes_out)            13.8514      5.019      2.760      0.008       3.781      23.922
# scale(games_played)               13.2327      3.719      3.558      0.001       5.771      20.695
# scale(shotsOnTotal_goalsTotal)    17.9885      3.689      4.877      0.000      10.586      25.391
# scale(gamesAppearance_sub)       -21.0872      6.273     -3.361      0.001     -33.676      -8.499
# ==============================================================================
# Omnibus:                        7.282   Durbin-Watson:                   2.031
# Prob(Omnibus):                  0.026   Jarque-Bera (JB):                6.813
# Skew:                           0.602   Prob(JB):                       0.0332
# Kurtosis:                       3.996   Cond. No.                         945.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 학습 R2 = 0.57284254, 검증 R2 = 0.48080141
# 학습 R2 = 0.61183447, 검증 R2 = -0.53207364
# 학습 R2 = 0.62321432, 검증 R2 = -0.86160565
# 학습 R2 = 0.56298700, 검증 R2 = 0.53445204
# 학습 R2 = 0.59584772, 검증 R2 = -0.51682136
# 학습 R2 = 0.56537060, 검증 R2 = 0.54760650
# 학습 R2 = 0.57819018, 검증 R2 = -0.00007425
# 학습 R2 = 0.55203774, 검증 R2 = 0.60467503
# 학습 R2 = 0.52976856, 검증 R2 = 0.56148412
# 학습 R2 = 0.59034365, 검증 R2 = 0.31056406
# 모델 성능 : 0.11290082681614874

# %% [markdown]
# # feature 1개 제거

# %%
from sklearn.model_selection import train_test_split

df_ols = df_ols_12
dfX = df_ols.drop(['value'], axis=1)
dfy = df_ols['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

#feature_names = list(dfX.columns)
#feature_names = ["scale({})".format(name) for name in feature_names]

formula = "value ~ scale(age) + scale(I(age**2)) + scale(I(age**3)) + \
            scale(tackles_total) + \
            scale(tackles_interceptions) + \
            scale(fouls_drawn) + \
            scale(fouls_committed) + \
            scale(cards_red) + \
            scale(games_lineups) + \
            scale(substitutes_out) + \
            scale(games_played) + \
            scale(shotsOnTotal_goalsTotal) + \
            scale(gamesAppearance_sub)"

model = sm.OLS.from_formula(formula, data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula(formula, data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.682
# Model:                            OLS   Adj. R-squared:                  0.604
# Method:                 Least Squares   F-statistic:                     8.756
# Date:                Wed, 24 Jun 2020   Prob (F-statistic):           3.74e-09
# Time:                        19:30:11   Log-Likelihood:                -287.07
# No. Observations:                  67   AIC:                             602.1
# Df Residuals:                      53   BIC:                             633.0
# Df Model:                          13
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                         42.6493      2.412     17.680      0.000      37.811      47.488
# scale(age)                      -864.1657    452.710     -1.909      0.062   -1772.187      43.856
# scale(I(age ** 2))              1674.2213    894.974      1.871      0.067    -120.869    3469.311
# scale(I(age ** 3))              -831.0547    445.641     -1.865      0.068   -1724.897      62.787
# scale(tackles_total)              11.7793      3.363      3.503      0.001       5.034      18.524
# scale(tackles_interceptions)      -7.9081      3.270     -2.418      0.019     -14.467      -1.349
# scale(fouls_drawn)                11.2320      3.321      3.382      0.001       4.570      17.894
# scale(fouls_committed)           -11.6820      3.218     -3.630      0.001     -18.136      -5.228
# scale(cards_red)                   5.7657      2.614      2.205      0.032       0.522      11.010
# scale(games_lineups)             -14.1162      5.265     -2.681      0.010     -24.677      -3.555
# scale(substitutes_out)            14.8390      5.112      2.903      0.005       4.587      25.091
# scale(games_played)               12.2304      3.769      3.245      0.002       4.670      19.791
# scale(shotsOnTotal_goalsTotal)    20.8763      3.439      6.070      0.000      13.978      27.775
# scale(gamesAppearance_sub)       -16.5302      5.932     -2.786      0.007     -28.429      -4.631
# ==============================================================================
# Omnibus:                        8.533   Durbin-Watson:                   2.011
# Prob(Omnibus):                  0.014   Jarque-Bera (JB):                9.760
# Skew:                           0.559   Prob(JB):                      0.00760
# Kurtosis:                       4.499   Cond. No.                         935.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 학습 R2 = 0.53731659, 검증 R2 = 0.29275619
# 학습 R2 = 0.56121439, 검증 R2 = -0.77115644
# 학습 R2 = 0.55840112, 검증 R2 = -0.61739686
# 학습 R2 = 0.48380859, 검증 R2 = 0.65312167
# 학습 R2 = 0.56085241, 검증 R2 = -1.06995896
# 학습 R2 = 0.51538583, 검증 R2 = 0.30693351
# 학습 R2 = 0.52806667, 검증 R2 = -0.33910996
# 학습 R2 = 0.48918127, 검증 R2 = 0.57811819
# 학습 R2 = 0.48275924, 검증 R2 = 0.45826006
# 학습 R2 = 0.53119595, 검증 R2 = 0.28498866
# 모델 성능 : -0.022344394361822596

# %% [markdown]
# # OLS - 13차

# %%
df_ols_13 = df_ols_12.drop(['passes_accuracy'], axis=1)
len(df_ols_13.columns), len(df_ols_12.columns)
# Out:
# (12, 13)

# %%
from sklearn.model_selection import train_test_split

df_ols = df_ols_13
dfX = df_ols.drop(['value'], axis=1)
dfy = df_ols['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

#formula = "value ~ " + "+".join(feature_names)

model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.661
# Model:                            OLS   Adj. R-squared:                  0.594
# Method:                 Least Squares   F-statistic:                     9.762
# Date:                Wed, 24 Jun 2020   Prob (F-statistic):           1.74e-09
# Time:                        19:32:21   Log-Likelihood:                -289.22
# No. Observations:                  67   AIC:                             602.4
# Df Residuals:                      55   BIC:                             628.9
# Df Model:                          11
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                         42.6493      2.445     17.443      0.000      37.749      47.549
# scale(age)                       -16.6188      3.331     -4.989      0.000     -23.295      -9.943
# scale(tackles_total)              13.7371      3.238      4.243      0.000       7.248      20.226
# scale(tackles_interceptions)      -9.9711      3.119     -3.197      0.002     -16.222      -3.720
# scale(fouls_drawn)                10.5970      3.173      3.340      0.002       4.239      16.955
# scale(fouls_committed)           -12.8140      3.183     -4.025      0.000     -19.193      -6.435
# scale(cards_red)                   5.3400      2.636      2.026      0.048       0.058      10.622
# scale(games_lineups)             -15.1902      5.256     -2.890      0.006     -25.724      -4.657
# scale(substitutes_out)            15.2405      4.946      3.082      0.003       5.329      25.152
# scale(games_played)               10.2555      3.478      2.949      0.005       3.286      17.225
# scale(shotsOnTotal_goalsTotal)    20.8567      3.408      6.120      0.000      14.027      27.686
# scale(gamesAppearance_sub)       -17.5127      5.931     -2.953      0.005     -29.399      -5.627
# ==============================================================================
# Omnibus:                       12.729   Durbin-Watson:                   2.081
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):               16.805
# Skew:                           0.761   Prob(JB):                     0.000224
# Kurtosis:                       4.924   Cond. No.                         6.05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 학습 R2 = 0.51790835, 검증 R2 = 0.22558006
# 학습 R2 = 0.53670292, 검증 R2 = -0.76510957
# 학습 R2 = 0.53302098, 검증 R2 = -0.66279258
# 학습 R2 = 0.45230340, 검증 R2 = 0.65636750
# 학습 R2 = 0.53618023, 검증 R2 = -1.06200082
# 학습 R2 = 0.48205709, 검증 R2 = 0.58636022
# 학습 R2 = 0.49655930, 검증 R2 = -0.01595278
# 학습 R2 = 0.46931591, 검증 R2 = 0.49640136
# 학습 R2 = 0.45774282, 검증 R2 = 0.42585135
# 학습 R2 = 0.50251692, 검증 R2 = 0.29094833
# 모델 성능 : 0.017565306538119486

# %% [markdown]
# # OLS - 14차

# %%
df_ols_14 = df_ols_13.drop(['cards_red'], axis=1)
len(df_ols_14.columns), len(df_ols_13.columns)
# Out:
# (11, 12)

# %%
from sklearn.model_selection import train_test_split

df_ols = df_ols_14
dfX = df_ols.drop(['value'], axis=1)
dfy = df_ols['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

#formula = "value ~ " + "+".join(feature_names)

model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.636
# Model:                            OLS   Adj. R-squared:                  0.571
# Method:                 Least Squares   F-statistic:                     9.786
# Date:                Wed, 24 Jun 2020   Prob (F-statistic):           3.27e-09
# Time:                        19:33:50   Log-Likelihood:                -291.63
# No. Observations:                  67   AIC:                             605.3
# Df Residuals:                      56   BIC:                             629.5
# Df Model:                          10
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                         42.6493      2.512     16.978      0.000      37.617      47.681
# scale(age)                       -16.4055      3.421     -4.796      0.000     -23.258      -9.553
# scale(tackles_total)              12.7699      3.290      3.881      0.000       6.179      19.361
# scale(tackles_interceptions)      -9.1911      3.180     -2.890      0.005     -15.561      -2.821
# scale(fouls_drawn)                10.0402      3.247      3.092      0.003       3.535      16.545
# scale(fouls_committed)           -11.7239      3.223     -3.637      0.001     -18.181      -5.267
# scale(games_lineups)             -13.2792      5.312     -2.500      0.015     -23.921      -2.637
# scale(substitutes_out)            15.1434      5.081      2.981      0.004       4.966      25.321
# scale(games_played)                9.7119      3.562      2.726      0.009       2.576      16.848
# scale(shotsOnTotal_goalsTotal)    21.9015      3.461      6.328      0.000      14.969      28.834
# scale(gamesAppearance_sub)       -16.6716      6.078     -2.743      0.008     -28.848      -4.496
# ==============================================================================
# Omnibus:                       28.893   Durbin-Watson:                   2.106
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               75.161
# Skew:                           1.298   Prob(JB):                     4.78e-17
# Kurtosis:                       7.493   Cond. No.                         6.02
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 학습 R2 = 0.50565024, 검증 R2 = 0.22942385
# 학습 R2 = 0.52537980, 검증 R2 = -0.77473228
# 학습 R2 = 0.51392792, 검증 R2 = -0.40309375
# 학습 R2 = 0.44349013, 검증 R2 = 0.63685446
# 학습 R2 = 0.51611957, 검증 R2 = -0.83866722
# 학습 R2 = 0.47141594, 검증 R2 = 0.57059880
# 학습 R2 = 0.48137515, 검증 R2 = 0.24414537
# 학습 R2 = 0.45919096, 검증 R2 = 0.47939246
# 학습 R2 = 0.45756561, 검증 R2 = 0.44085599
# 학습 R2 = 0.49234019, 검증 R2 = 0.26587997
# 모델 성능 : 0.08506576350759402

# %% [markdown]
# # 가중치

# %%
from sklearn.model_selection import train_test_split

df_ols = df_ols_14
dfX = df_ols.drop(['value'], axis=1)
dfy = df_ols['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

#feature_names = list(dfX.columns)
#feature_names = ["scale({})".format(name) for name in feature_names]

formula = "value ~ scale(age) + scale(I(age**2)) + scale(I(age**3)) + \
            scale(tackles_total) + \
            scale(tackles_interceptions) + \
            scale(fouls_drawn) + \
            scale(fouls_committed) + \
            scale(games_lineups) + \
            scale(substitutes_out) + \
            scale(games_played) + \
            scale(shotsOnTotal_goalsTotal) + \
            scale(gamesAppearance_sub)"

model = sm.OLS.from_formula(formula, data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula(formula, data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.653
# Model:                            OLS   Adj. R-squared:                  0.576
# Method:                 Least Squares   F-statistic:                     8.474
# Date:                Wed, 24 Jun 2020   Prob (F-statistic):           1.01e-08
# Time:                        19:42:28   Log-Likelihood:                -290.01
# No. Observations:                  67   AIC:                             606.0
# Df Residuals:                      54   BIC:                             634.7
# Df Model:                          12
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                         42.6493      2.497     17.079      0.000      37.643      47.656
# scale(age)                      -776.7702    466.828     -1.664      0.102   -1712.703     159.163
# scale(I(age ** 2))              1507.1136    923.113      1.633      0.108    -343.616    3357.844
# scale(I(age ** 3))              -750.7012    459.764     -1.633      0.108   -1672.473     171.070
# scale(tackles_total)              10.9339      3.458      3.162      0.003       4.000      17.868
# scale(tackles_interceptions)      -7.2968      3.373     -2.164      0.035     -14.059      -0.535
# scale(fouls_drawn)                10.4442      3.418      3.055      0.003       3.591      17.297
# scale(fouls_committed)           -10.6762      3.297     -3.238      0.002     -17.287      -4.066
# scale(games_lineups)             -12.0990      5.368     -2.254      0.028     -22.860      -1.338
# scale(substitutes_out)            14.5940      5.290      2.759      0.008       3.988      25.200
# scale(games_played)               11.3083      3.878      2.916      0.005       3.534      19.083
# scale(shotsOnTotal_goalsTotal)    22.0780      3.515      6.281      0.000      15.030      29.126
# scale(gamesAppearance_sub)       -15.6327      6.127     -2.552      0.014     -27.916      -3.350
# ==============================================================================
# Omnibus:                       26.179   Durbin-Watson:                   2.070
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               66.194
# Skew:                           1.168   Prob(JB):                     4.23e-15
# Kurtosis:                       7.272   Cond. No.                         932.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 학습 R2 = 0.52242101, 검증 R2 = 0.30146888
# 학습 R2 = 0.54867918, 검증 R2 = -0.79151885
# 학습 R2 = 0.53836379, 검증 R2 = -0.39015802
# 학습 R2 = 0.47319487, 검증 R2 = 0.63128527
# 학습 R2 = 0.54066799, 검증 R2 = -0.89092889
# 학습 R2 = 0.50629606, 검증 R2 = 0.19582945
# 학습 R2 = 0.50765135, 검증 R2 = 0.13119286
# 학습 R2 = 0.47682589, 검증 R2 = 0.56336227
# 학습 R2 = 0.48273269, 검증 R2 = 0.46416840
# 학습 R2 = 0.51953935, 검증 R2 = 0.25495363
# 모델 성능 : 0.04696550014201811
