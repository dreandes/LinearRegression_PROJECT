# %%
df_ols = pd.read_csv('dataset_20200629.csv', encoding='utf-8-sig')

# %%
# Out:
#         player_name  value  follower  shots_total  shots_on  goals_total  \
# 0       A. Anguissa   20.0     67879       0.5541    0.1288       0.0129
# 1        A. Bastoni   31.5    232370       0.3101    0.1128       0.0564
# 2        A. Belotti   32.0    740918       2.8169    1.0539       0.4432
# 3    A. Christensen   24.0    601838       0.3802    0.0613       0.0000
# 4         A. Correa   32.0    652886       1.9735    0.8442       0.2282
# ..              ...    ...       ...          ...       ...          ...
# 454         Y. Atal   20.0   1955121       1.3472    0.5672       0.1654
# 455     Y. Carrasco   22.5    797767       2.6060    0.8687       0.2044
# 456         Y. Mina   20.0   3339896       0.8766    0.3080       0.0711
# 457      Y. Poulsen   24.0    109000       2.0141    0.7524       0.3357
# 458    Y. Tielemans   44.0    282254       1.6978    0.6011       0.1476
#
#      goals_assists  passes_total  passes_key  passes_accuracy  ...  \
# 0           0.0000       22.1879      0.2706           3.2985  ...
# 1           0.0000       40.9924      0.3665          13.7863  ...
# 2           0.0985       12.3215      0.9554           4.0185  ...
# 3           0.0123       58.0206      0.1717          13.4535  ...
# 4           0.2167       23.4885      1.5286           9.1604  ...
# ..             ...           ...         ...              ...  ...
# 454         0.0236       28.5984      0.7800           5.6251  ...
# 455         0.3066       22.6878      1.6863          20.3373  ...
# 456         0.0474       46.6951      0.2843          14.5226  ...
# 457         0.2662       16.8654      1.2038           7.4314  ...
# 458         0.1371       38.4372      1.1705           6.6013  ...
#
#      substitutes_out  substitutes_bench  age_x  height_x  weight_x  rating_x  \
# 0             0.2577             0.5927   25.0     184.0      78.0  2.333333
# 1             0.0564             1.6070   21.0     190.0      75.0  4.777778
# 2             0.0689             0.0689   27.0     181.0      72.0  5.250000
# 3             0.1840             0.7604   24.0     188.0      78.0  6.000000
# 4             0.6731             0.6160   25.0     171.0      70.0  7.000000
# ..               ...                ...    ...       ...       ...       ...
# 454           0.1418             0.3782   24.0     176.0      64.0  3.333333
# 455           0.6643             1.2775   27.0     180.0      71.0  4.857143
# 456           0.0948             0.5449   26.0     195.0      94.0  6.125000
# 457           0.2894             0.5788   26.0     192.0      84.0  6.545455
# 458           0.3058             0.2636   23.0     176.0      72.0  4.384615
#
#      age_y  height_y  weight_y  rating_y
# 0     25.0     184.0      78.0  2.333333
# 1     21.0     190.0      75.0  4.777778
# 2     27.0     181.0      72.0  5.250000
# 3     24.0     188.0      78.0  6.000000
# 4     25.0     171.0      70.0  7.000000
# ..     ...       ...       ...       ...
# 454   24.0     176.0      64.0  3.333333
# 455   27.0     180.0      71.0  4.857143
# 456   26.0     195.0      94.0  6.125000
# 457   26.0     192.0      84.0  6.545455
# 458   23.0     176.0      72.0  4.384615
#
# [459 rows x 39 columns]

# %%
df_ols = df_ols.drop('player_name', axis=1)

# %%
df_ols = df_ols.drop(['age_y', 'height_y', 'weight_y', 'rating_y'], axis=1)

# %%
df_ols
# Out:
#      value  follower  shots_total  shots_on  goals_total  goals_assists  \
# 0     20.0     67879       0.5541    0.1288       0.0129         0.0000
# 1     31.5    232370       0.3101    0.1128       0.0564         0.0000
# 2     32.0    740918       2.8169    1.0539       0.4432         0.0985
# 3     24.0    601838       0.3802    0.0613       0.0000         0.0123
# 4     32.0    652886       1.9735    0.8442       0.2282         0.2167
# ..     ...       ...          ...       ...          ...            ...
# 454   20.0   1955121       1.3472    0.5672       0.1654         0.0236
# 455   22.5    797767       2.6060    0.8687       0.2044         0.3066
# 456   20.0   3339896       0.8766    0.3080       0.0711         0.0474
# 457   24.0    109000       2.0141    0.7524       0.3357         0.2662
# 458   44.0    282254       1.6978    0.6011       0.1476         0.1371
#
#      passes_total  passes_key  passes_accuracy  tackles_total  ...  \
# 0         22.1879      0.2706           3.2985         1.2112  ...
# 1         40.9924      0.3665          13.7863         1.0431  ...
# 2         12.3215      0.9554           4.0185         0.4629  ...
# 3         58.0206      0.1717          13.4535         1.0302  ...
# 4         23.4885      1.5286           9.1604         0.7757  ...
# ..            ...         ...              ...            ...  ...
# 454       28.5984      0.7800           5.6251         1.5835  ...
# 455       22.6878      1.6863          20.3373         0.0000  ...
# 456       46.6951      0.2843          14.5226         1.4925  ...
# 457       16.8654      1.2038           7.4314         0.3936  ...
# 458       38.4372      1.1705           6.6013         1.0018  ...
#
#      penalty_missed  games_appearences  games_lineups  substitutes_in  \
# 0            0.0000             1.4045         0.9277          0.4767
# 1            0.0000             1.2969         0.9304          0.3665
# 2            0.0295             1.0539         0.9948          0.0591
# 3            0.0000             1.1160         1.0056          0.1104
# 4            0.0000             1.5514         0.9697          0.5818
# ..              ...                ...            ...             ...
# 454          0.0236             1.2290         0.9927          0.2364
# 455          0.0000             1.7885         0.8687          0.9198
# 456          0.0000             1.1846         1.0187          0.1658
# 457          0.0000             1.4006         0.9492          0.4514
# 458          0.0000             1.2022         1.0334          0.1687
#
#      substitutes_out  substitutes_bench  age_x  height_x  weight_x  rating_x
# 0             0.2577             0.5927   25.0     184.0      78.0  2.333333
# 1             0.0564             1.6070   21.0     190.0      75.0  4.777778
# 2             0.0689             0.0689   27.0     181.0      72.0  5.250000
# 3             0.1840             0.7604   24.0     188.0      78.0  6.000000
# 4             0.6731             0.6160   25.0     171.0      70.0  7.000000
# ..               ...                ...    ...       ...       ...       ...
# 454           0.1418             0.3782   24.0     176.0      64.0  3.333333
# 455           0.6643             1.2775   27.0     180.0      71.0  4.857143
# 456           0.0948             0.5449   26.0     195.0      94.0  6.125000
# 457           0.2894             0.5788   26.0     192.0      84.0  6.545455
# 458           0.3058             0.2636   23.0     176.0      72.0  4.384615
#
# [459 rows x 34 columns]

# %%
df_ols.corr()[df_ols.corr() > 0.7].to_csv('df_ols_corr_20200629.csv', encoding='utf-8-sig')
df_ols.corr()[df_ols.corr() > 0.7]
# Out:
#                        value  follower  shots_total  shots_on  goals_total  \
# value                    1.0       NaN          NaN       NaN          NaN
# follower                 NaN       1.0          NaN       NaN          NaN
# shots_total              NaN       NaN     1.000000  0.959943     0.788272
# shots_on                 NaN       NaN     0.959943  1.000000     0.877377
# goals_total              NaN       NaN     0.788272  0.877377     1.000000
# goals_assists            NaN       NaN          NaN       NaN          NaN
# passes_total             NaN       NaN          NaN       NaN          NaN
# passes_key               NaN       NaN          NaN       NaN          NaN
# passes_accuracy          NaN       NaN          NaN       NaN          NaN
# tackles_total            NaN       NaN          NaN       NaN          NaN
# tackles_blocks           NaN       NaN          NaN       NaN          NaN
# tackles_interceptions    NaN       NaN          NaN       NaN          NaN
# duels_total              NaN       NaN          NaN       NaN          NaN
# duels_won                NaN       NaN          NaN       NaN          NaN
# dribbles_attempts        NaN       NaN          NaN       NaN          NaN
# dribbles_success         NaN       NaN          NaN       NaN          NaN
# fouls_drawn              NaN       NaN          NaN       NaN          NaN
# fouls_committed          NaN       NaN          NaN       NaN          NaN
# cards_yellow             NaN       NaN          NaN       NaN          NaN
# cards_yellowred          NaN       NaN          NaN       NaN          NaN
# cards_red                NaN       NaN          NaN       NaN          NaN
# penalty_won              NaN       NaN          NaN       NaN          NaN
# penalty_commited         NaN       NaN          NaN       NaN          NaN
# penalty_success          NaN       NaN          NaN       NaN          NaN
# penalty_missed           NaN       NaN          NaN       NaN          NaN
# games_appearences        NaN       NaN          NaN       NaN          NaN
# games_lineups            NaN       NaN          NaN       NaN          NaN
# substitutes_in           NaN       NaN          NaN       NaN          NaN
# substitutes_out          NaN       NaN          NaN       NaN          NaN
# substitutes_bench        NaN       NaN          NaN       NaN          NaN
# age_x                    NaN       NaN          NaN       NaN          NaN
# height_x                 NaN       NaN          NaN       NaN          NaN
# weight_x                 NaN       NaN          NaN       NaN          NaN
# rating_x                 NaN       NaN          NaN       NaN          NaN
#
#                        goals_assists  passes_total  passes_key  \
# value                            NaN           NaN         NaN
# follower                         NaN           NaN         NaN
# shots_total                      NaN           NaN         NaN
# shots_on                         NaN           NaN         NaN
# goals_total                      NaN           NaN         NaN
# goals_assists               1.000000           NaN    0.806733
# passes_total                     NaN           1.0         NaN
# passes_key                  0.806733           NaN    1.000000
# passes_accuracy                  NaN           NaN         NaN
# tackles_total                    NaN           NaN         NaN
# tackles_blocks                   NaN           NaN         NaN
# tackles_interceptions            NaN           NaN         NaN
# duels_total                      NaN           NaN         NaN
# duels_won                        NaN           NaN         NaN
# dribbles_attempts                NaN           NaN         NaN
# dribbles_success                 NaN           NaN         NaN
# fouls_drawn                      NaN           NaN         NaN
# fouls_committed                  NaN           NaN         NaN
# cards_yellow                     NaN           NaN         NaN
# cards_yellowred                  NaN           NaN         NaN
# cards_red                        NaN           NaN         NaN
# penalty_won                      NaN           NaN         NaN
# penalty_commited                 NaN           NaN         NaN
# penalty_success                  NaN           NaN         NaN
# penalty_missed                   NaN           NaN         NaN
# games_appearences                NaN           NaN         NaN
# games_lineups                    NaN           NaN         NaN
# substitutes_in                   NaN           NaN         NaN
# substitutes_out                  NaN           NaN         NaN
# substitutes_bench                NaN           NaN         NaN
# age_x                            NaN           NaN         NaN
# height_x                         NaN           NaN         NaN
# weight_x                         NaN           NaN         NaN
# rating_x                         NaN           NaN         NaN
#
#                        passes_accuracy  tackles_total  ...  penalty_missed  \
# value                              NaN            NaN  ...             NaN
# follower                           NaN            NaN  ...             NaN
# shots_total                        NaN            NaN  ...             NaN
# shots_on                           NaN            NaN  ...             NaN
# goals_total                        NaN            NaN  ...             NaN
# goals_assists                      NaN            NaN  ...             NaN
# passes_total                       NaN            NaN  ...             NaN
# passes_key                         NaN            NaN  ...             NaN
# passes_accuracy               1.000000            NaN  ...             NaN
# tackles_total                      NaN            1.0  ...             NaN
# tackles_blocks                     NaN            NaN  ...             NaN
# tackles_interceptions              NaN            NaN  ...             NaN
# duels_total                        NaN            NaN  ...             NaN
# duels_won                          NaN            NaN  ...             NaN
# dribbles_attempts                  NaN            NaN  ...             NaN
# dribbles_success                   NaN            NaN  ...             NaN
# fouls_drawn                        NaN            NaN  ...             NaN
# fouls_committed                    NaN            NaN  ...             NaN
# cards_yellow                       NaN            NaN  ...             NaN
# cards_yellowred                    NaN            NaN  ...             NaN
# cards_red                          NaN            NaN  ...             NaN
# penalty_won                        NaN            NaN  ...             NaN
# penalty_commited                   NaN            NaN  ...             NaN
# penalty_success                    NaN            NaN  ...             NaN
# penalty_missed                     NaN            NaN  ...             1.0
# games_appearences             0.915708            NaN  ...             NaN
# games_lineups                      NaN            NaN  ...             NaN
# substitutes_in                0.901033            NaN  ...             NaN
# substitutes_out                    NaN            NaN  ...             NaN
# substitutes_bench                  NaN            NaN  ...             NaN
# age_x                              NaN            NaN  ...             NaN
# height_x                           NaN            NaN  ...             NaN
# weight_x                           NaN            NaN  ...             NaN
# rating_x                           NaN            NaN  ...             NaN
#
#                        games_appearences  games_lineups  substitutes_in  \
# value                                NaN            NaN             NaN
# follower                             NaN            NaN             NaN
# shots_total                          NaN            NaN             NaN
# shots_on                             NaN            NaN             NaN
# goals_total                          NaN            NaN             NaN
# goals_assists                        NaN            NaN             NaN
# passes_total                         NaN            NaN             NaN
# passes_key                           NaN            NaN             NaN
# passes_accuracy                 0.915708            NaN        0.901033
# tackles_total                        NaN            NaN             NaN
# tackles_blocks                       NaN            NaN             NaN
# tackles_interceptions                NaN            NaN             NaN
# duels_total                          NaN            NaN             NaN
# duels_won                            NaN            NaN             NaN
# dribbles_attempts                    NaN            NaN             NaN
# dribbles_success                     NaN            NaN             NaN
# fouls_drawn                          NaN            NaN             NaN
# fouls_committed                      NaN            NaN             NaN
# cards_yellow                         NaN            NaN             NaN
# cards_yellowred                      NaN            NaN             NaN
# cards_red                            NaN            NaN             NaN
# penalty_won                          NaN            NaN             NaN
# penalty_commited                     NaN            NaN             NaN
# penalty_success                      NaN            NaN             NaN
# penalty_missed                       NaN            NaN             NaN
# games_appearences               1.000000            NaN        0.996492
# games_lineups                        NaN            1.0             NaN
# substitutes_in                  0.996492            NaN        1.000000
# substitutes_out                      NaN            NaN             NaN
# substitutes_bench                    NaN            NaN             NaN
# age_x                                NaN            NaN             NaN
# height_x                             NaN            NaN             NaN
# weight_x                             NaN            NaN             NaN
# rating_x                             NaN            NaN             NaN
#
#                        substitutes_out  substitutes_bench  age_x  height_x  \
# value                              NaN                NaN    NaN       NaN
# follower                           NaN                NaN    NaN       NaN
# shots_total                        NaN                NaN    NaN       NaN
# shots_on                           NaN                NaN    NaN       NaN
# goals_total                        NaN                NaN    NaN       NaN
# goals_assists                      NaN                NaN    NaN       NaN
# passes_total                       NaN                NaN    NaN       NaN
# passes_key                         NaN                NaN    NaN       NaN
# passes_accuracy                    NaN                NaN    NaN       NaN
# tackles_total                      NaN                NaN    NaN       NaN
# tackles_blocks                     NaN                NaN    NaN       NaN
# tackles_interceptions              NaN                NaN    NaN       NaN
# duels_total                        NaN                NaN    NaN       NaN
# duels_won                          NaN                NaN    NaN       NaN
# dribbles_attempts                  NaN                NaN    NaN       NaN
# dribbles_success                   NaN                NaN    NaN       NaN
# fouls_drawn                        NaN                NaN    NaN       NaN
# fouls_committed                    NaN                NaN    NaN       NaN
# cards_yellow                       NaN                NaN    NaN       NaN
# cards_yellowred                    NaN                NaN    NaN       NaN
# cards_red                          NaN                NaN    NaN       NaN
# penalty_won                        NaN                NaN    NaN       NaN
# penalty_commited                   NaN                NaN    NaN       NaN
# penalty_success                    NaN                NaN    NaN       NaN
# penalty_missed                     NaN                NaN    NaN       NaN
# games_appearences                  NaN                NaN    NaN       NaN
# games_lineups                      NaN                NaN    NaN       NaN
# substitutes_in                     NaN                NaN    NaN       NaN
# substitutes_out                    1.0                NaN    NaN       NaN
# substitutes_bench                  NaN                1.0    NaN       NaN
# age_x                              NaN                NaN    1.0       NaN
# height_x                           NaN                NaN    NaN       1.0
# weight_x                           NaN                NaN    NaN       NaN
# rating_x                           NaN                NaN    NaN       NaN
#
#                        weight_x  rating_x
# value                       NaN       NaN
# follower                    NaN       NaN
# shots_total                 NaN       NaN
# shots_on                    NaN       NaN
# goals_total                 NaN       NaN
# goals_assists               NaN       NaN
# passes_total                NaN       NaN
# passes_key                  NaN       NaN
# passes_accuracy             NaN       NaN
# tackles_total               NaN       NaN
# tackles_blocks              NaN       NaN
# tackles_interceptions       NaN       NaN
# duels_total                 NaN       NaN
# duels_won                   NaN       NaN
# dribbles_attempts           NaN       NaN
# dribbles_success            NaN       NaN
# fouls_drawn                 NaN       NaN
# fouls_committed             NaN       NaN
# cards_yellow                NaN       NaN
# cards_yellowred             NaN       NaN
# cards_red                   NaN       NaN
# penalty_won                 NaN       NaN
# penalty_commited            NaN       NaN
# penalty_success             NaN       NaN
# penalty_missed              NaN       NaN
# games_appearences           NaN       NaN
# games_lineups               NaN       NaN
# substitutes_in              NaN       NaN
# substitutes_out             NaN       NaN
# substitutes_bench           NaN       NaN
# age_x                       NaN       NaN
# height_x                    NaN       NaN
# weight_x                    1.0       NaN
# rating_x                    NaN       1.0
#
# [34 rows x 34 columns]

# %%
df_ols_c = pd.read_csv('df_ols_corred_20200629.csv', index_col=0)
df_ols_c
# Out:
#                    shots_total  shots_on  goals_total  goals_assists  \
# shots_total           1.000000  0.959943     0.788272            NaN
# shots_on              0.959943  1.000000     0.877377            NaN
# goals_total           0.788272  0.877377     1.000000            NaN
# goals_assists              NaN       NaN          NaN       1.000000
# passes_key                 NaN       NaN          NaN       0.806733
# passes_accuracy            NaN       NaN          NaN            NaN
# duels_total                NaN       NaN          NaN            NaN
# duels_won                  NaN       NaN          NaN            NaN
# dribbles_attempts          NaN       NaN          NaN            NaN
# dribbles_success           NaN       NaN          NaN            NaN
# games_appearences          NaN       NaN          NaN            NaN
# substitutes_in             NaN       NaN          NaN            NaN
#
#                    passes_key  passes_accuracy  duels_total  duels_won  \
# shots_total               NaN              NaN          NaN        NaN
# shots_on                  NaN              NaN          NaN        NaN
# goals_total               NaN              NaN          NaN        NaN
# goals_assists        0.806733              NaN          NaN        NaN
# passes_key           1.000000              NaN          NaN        NaN
# passes_accuracy           NaN         1.000000          NaN        NaN
# duels_total               NaN              NaN     1.000000   0.933866
# duels_won                 NaN              NaN     0.933866   1.000000
# dribbles_attempts         NaN              NaN          NaN        NaN
# dribbles_success          NaN              NaN          NaN        NaN
# games_appearences         NaN         0.915708          NaN        NaN
# substitutes_in            NaN         0.901033          NaN        NaN
#
#                    dribbles_attempts  dribbles_success  games_appearences  \
# shots_total                      NaN               NaN                NaN
# shots_on                         NaN               NaN                NaN
# goals_total                      NaN               NaN                NaN
# goals_assists                    NaN               NaN                NaN
# passes_key                       NaN               NaN                NaN
# passes_accuracy                  NaN               NaN           0.915708
# duels_total                      NaN               NaN                NaN
# duels_won                        NaN               NaN                NaN
# dribbles_attempts           1.000000          0.972017                NaN
# dribbles_success            0.972017          1.000000                NaN
# games_appearences                NaN               NaN           1.000000
# substitutes_in                   NaN               NaN           0.996492
#
#                    substitutes_in
# shots_total                   NaN
# shots_on                      NaN
# goals_total                   NaN
# goals_assists                 NaN
# passes_key                    NaN
# passes_accuracy          0.901033
# duels_total                   NaN
# duels_won                     NaN
# dribbles_attempts             NaN
# dribbles_success              NaN
# games_appearences        0.996492
# substitutes_in           1.000000

# %% [markdown]
# # 결측치 제거

# %%
df_ols
# Out:
#      value  follower  shots_total  shots_on  goals_total  goals_assists  \
# 0     20.0     67879       0.5541    0.1288       0.0129         0.0000
# 1     31.5    232370       0.3101    0.1128       0.0564         0.0000
# 2     32.0    740918       2.8169    1.0539       0.4432         0.0985
# 3     24.0    601838       0.3802    0.0613       0.0000         0.0123
# 4     32.0    652886       1.9735    0.8442       0.2282         0.2167
# ..     ...       ...          ...       ...          ...            ...
# 454   20.0   1955121       1.3472    0.5672       0.1654         0.0236
# 455   22.5    797767       2.6060    0.8687       0.2044         0.3066
# 456   20.0   3339896       0.8766    0.3080       0.0711         0.0474
# 457   24.0    109000       2.0141    0.7524       0.3357         0.2662
# 458   44.0    282254       1.6978    0.6011       0.1476         0.1371
#
#      passes_total  passes_key  passes_accuracy  tackles_total  ...  \
# 0         22.1879      0.2706           3.2985         1.2112  ...
# 1         40.9924      0.3665          13.7863         1.0431  ...
# 2         12.3215      0.9554           4.0185         0.4629  ...
# 3         58.0206      0.1717          13.4535         1.0302  ...
# 4         23.4885      1.5286           9.1604         0.7757  ...
# ..            ...         ...              ...            ...  ...
# 454       28.5984      0.7800           5.6251         1.5835  ...
# 455       22.6878      1.6863          20.3373         0.0000  ...
# 456       46.6951      0.2843          14.5226         1.4925  ...
# 457       16.8654      1.2038           7.4314         0.3936  ...
# 458       38.4372      1.1705           6.6013         1.0018  ...
#
#      penalty_missed  games_appearences  games_lineups  substitutes_in  \
# 0            0.0000             1.4045         0.9277          0.4767
# 1            0.0000             1.2969         0.9304          0.3665
# 2            0.0295             1.0539         0.9948          0.0591
# 3            0.0000             1.1160         1.0056          0.1104
# 4            0.0000             1.5514         0.9697          0.5818
# ..              ...                ...            ...             ...
# 454          0.0236             1.2290         0.9927          0.2364
# 455          0.0000             1.7885         0.8687          0.9198
# 456          0.0000             1.1846         1.0187          0.1658
# 457          0.0000             1.4006         0.9492          0.4514
# 458          0.0000             1.2022         1.0334          0.1687
#
#      substitutes_out  substitutes_bench  age_x  height_x  weight_x  rating_x
# 0             0.2577             0.5927   25.0     184.0      78.0  2.333333
# 1             0.0564             1.6070   21.0     190.0      75.0  4.777778
# 2             0.0689             0.0689   27.0     181.0      72.0  5.250000
# 3             0.1840             0.7604   24.0     188.0      78.0  6.000000
# 4             0.6731             0.6160   25.0     171.0      70.0  7.000000
# ..               ...                ...    ...       ...       ...       ...
# 454           0.1418             0.3782   24.0     176.0      64.0  3.333333
# 455           0.6643             1.2775   27.0     180.0      71.0  4.857143
# 456           0.0948             0.5449   26.0     195.0      94.0  6.125000
# 457           0.2894             0.5788   26.0     192.0      84.0  6.545455
# 458           0.3058             0.2636   23.0     176.0      72.0  4.384615
#
# [459 rows x 34 columns]

# %%
df_ols = df_ols.dropna()
df_ols
# Out:
#      value  follower  shots_total  shots_on  goals_total  goals_assists  \
# 0     20.0     67879       0.5541    0.1288       0.0129         0.0000
# 1     31.5    232370       0.3101    0.1128       0.0564         0.0000
# 2     32.0    740918       2.8169    1.0539       0.4432         0.0985
# 3     24.0    601838       0.3802    0.0613       0.0000         0.0123
# 4     32.0    652886       1.9735    0.8442       0.2282         0.2167
# ..     ...       ...          ...       ...          ...            ...
# 454   20.0   1955121       1.3472    0.5672       0.1654         0.0236
# 455   22.5    797767       2.6060    0.8687       0.2044         0.3066
# 456   20.0   3339896       0.8766    0.3080       0.0711         0.0474
# 457   24.0    109000       2.0141    0.7524       0.3357         0.2662
# 458   44.0    282254       1.6978    0.6011       0.1476         0.1371
#
#      passes_total  passes_key  passes_accuracy  tackles_total  ...  \
# 0         22.1879      0.2706           3.2985         1.2112  ...
# 1         40.9924      0.3665          13.7863         1.0431  ...
# 2         12.3215      0.9554           4.0185         0.4629  ...
# 3         58.0206      0.1717          13.4535         1.0302  ...
# 4         23.4885      1.5286           9.1604         0.7757  ...
# ..            ...         ...              ...            ...  ...
# 454       28.5984      0.7800           5.6251         1.5835  ...
# 455       22.6878      1.6863          20.3373         0.0000  ...
# 456       46.6951      0.2843          14.5226         1.4925  ...
# 457       16.8654      1.2038           7.4314         0.3936  ...
# 458       38.4372      1.1705           6.6013         1.0018  ...
#
#      penalty_missed  games_appearences  games_lineups  substitutes_in  \
# 0            0.0000             1.4045         0.9277          0.4767
# 1            0.0000             1.2969         0.9304          0.3665
# 2            0.0295             1.0539         0.9948          0.0591
# 3            0.0000             1.1160         1.0056          0.1104
# 4            0.0000             1.5514         0.9697          0.5818
# ..              ...                ...            ...             ...
# 454          0.0236             1.2290         0.9927          0.2364
# 455          0.0000             1.7885         0.8687          0.9198
# 456          0.0000             1.1846         1.0187          0.1658
# 457          0.0000             1.4006         0.9492          0.4514
# 458          0.0000             1.2022         1.0334          0.1687
#
#      substitutes_out  substitutes_bench  age_x  height_x  weight_x  rating_x
# 0             0.2577             0.5927   25.0     184.0      78.0  2.333333
# 1             0.0564             1.6070   21.0     190.0      75.0  4.777778
# 2             0.0689             0.0689   27.0     181.0      72.0  5.250000
# 3             0.1840             0.7604   24.0     188.0      78.0  6.000000
# 4             0.6731             0.6160   25.0     171.0      70.0  7.000000
# ..               ...                ...    ...       ...       ...       ...
# 454           0.1418             0.3782   24.0     176.0      64.0  3.333333
# 455           0.6643             1.2775   27.0     180.0      71.0  4.857143
# 456           0.0948             0.5449   26.0     195.0      94.0  6.125000
# 457           0.2894             0.5788   26.0     192.0      84.0  6.545455
# 458           0.3058             0.2636   23.0     176.0      72.0  4.384615
#
# [457 rows x 34 columns]

# %% [markdown]
# # 높은 상관관계를 보이는 Feature들
# 1. shots_total, shots_on, goals_total
# 2. goals_assists, passes_key
# 3. passes_accuracy, games_appearences, substitutes_in
# 4. duels_total, duels_won
# 5. dribbles_attempts, dribbles_success

# %%
df_pos = df_ols

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.preprocessing import MinMaxScaler

# %%
# 1. shots_on, shots_total and goals_total PCA
df_pos_sotgt = df_pos[['shots_on', 'shots_total', 'goals_total']]
df_pos_sotgt = StandardScaler().fit_transform(df_pos_sotgt)
df_pos_pca_sg = pd.DataFrame(data = PCA(n_components=1).fit_transform(df_pos_sotgt), columns=['shotsOnTotal_goalsTotal'])
df_pos_pca_sg['shotsOnTotal_goalsTotal'] = MinMaxScaler().fit_transform(df_pos_pca_sg)
df_pos_pca_sg
# Out:
#      shotsOnTotal_goalsTotal
# 0                  -1.682615
# 1                  -1.716242
# 2                   1.679798
# 3                  -1.885495
# 4                   0.450374
# ..                       ...
# 452                -0.362550
# 453                 0.742967
# 454                -1.154388
# 455                 0.633646
# 456                -0.187624
#
# [457 rows x 1 columns]

# %%
# 2. goals_assists, passes_key
df_pos_gapk = StandardScaler().fit_transform(df_pos[['goals_assists', 'passes_key']])
df_pos_pca_gapk = pd.DataFrame(data = PCA(n_components=1).fit_transform(df_pos_gapk), columns=['goalsAssist_passesKey'])
df_pos_pca_gapk['goalsAssist_passesKey'] = MinMaxScaler().fit_transform(df_pos_pca_gapk)
df_pos_pca_gapk
# Out:
#      goalsAssist_passesKey
# 0                 0.034725
# 1                 0.047031
# 2                 0.212191
# 3                 0.033221
# 4                 0.393255
# ..                     ...
# 452               0.121558
# 453               0.495260
# 454               0.079595
# 455               0.396598
# 456               0.274902
#
# [457 rows x 1 columns]

# %%
# 3. passes_accuracy, games_appearences, substitutes_in
df_pos_pagasi = StandardScaler().fit_transform(df_pos[['passes_accuracy', 'games_appearences', 'substitutes_in']])
df_pos_pca_pagasi = pd.DataFrame(data = PCA(n_components=1).fit_transform(df_pos_pagasi), columns=['passesAcc_gamesApp_subIn'])
df_pos_pca_pagasi['passesAcc_gamesApp_subIn'] = MinMaxScaler().fit_transform(df_pos_pca_pagasi)
df_pos_pca_pagasi
# Out:
#      passesAcc_gamesApp_subIn
# 0                    0.023985
# 1                    0.021084
# 2                    0.003561
# 3                    0.009314
# 4                    0.032514
# ..                        ...
# 452                  0.013524
# 453                  0.051046
# 454                  0.012985
# 455                  0.024402
# 456                  0.011315
#
# [457 rows x 1 columns]

# %%
# 4. duels_total, duels_won
df_pos_duels = df_pos[['duels_total', 'duels_won']]
df_pos_duels = StandardScaler().fit_transform(df_pos_duels)
df_pos_pca_duels = pd.DataFrame(data = PCA(n_components=1).fit_transform(df_pos_duels), columns=['duelsWonTotal'])
df_pos_pca_duels['duelsWonTotal'] = MinMaxScaler().fit_transform(df_pos_pca_duels)
df_pos_pca_duels
# Out:
#      duelsWonTotal
# 0         0.108779
# 1         0.183587
# 2         0.380663
# 3         0.239780
# 4         0.362438
# ..             ...
# 452       0.401370
# 453       0.360554
# 454       0.345182
# 455       0.443935
# 456       0.314084
#
# [457 rows x 1 columns]

# %%
# 5. dribbles_attempts, dribbles_success
df_pos_dribbles = df_pos[['dribbles_attempts', 'dribbles_success']]
df_pos_dribbles = StandardScaler().fit_transform(df_pos_dribbles)
df_pos_pca_dribbles = pd.DataFrame(data = PCA(n_components=1).fit_transform(df_pos_dribbles), columns=['dribblesAtmptsSuc'])
df_pos_pca_dribbles['dribblesAtmptsSuc'] = MinMaxScaler().fit_transform(df_pos_pca_dribbles)
df_pos_pca_dribbles
# Out:
#      dribblesAtmptsSuc
# 0             0.191225
# 1             0.083586
# 2             0.204123
# 3             0.024259
# 4             0.493859
# ..                 ...
# 452           0.744906
# 453           0.644546
# 454           0.024297
# 455           0.198977
# 456           0.169869
#
# [457 rows x 1 columns]

# %% [markdown]
# # PCA Feature Table

# %%
df_pca = pd.concat([df_pos_pca_sg, df_pos_pca_gapk, df_pos_pca_pagasi, 
                    df_pos_pca_duels, df_pos_pca_dribbles], axis=1)
df_pca
# Out:
#      shotsOnTotal_goalsTotal  goalsAssist_passesKey  passesAcc_gamesApp_subIn  \
# 0                  -1.682615               0.034725                  0.023985
# 1                  -1.716242               0.047031                  0.021084
# 2                   1.679798               0.212191                  0.003561
# 3                  -1.885495               0.033221                  0.009314
# 4                   0.450374               0.393255                  0.032514
# ..                       ...                    ...                       ...
# 452                -0.362550               0.121558                  0.013524
# 453                 0.742967               0.495260                  0.051046
# 454                -1.154388               0.079595                  0.012985
# 455                 0.633646               0.396598                  0.024402
# 456                -0.187624               0.274902                  0.011315
#
#      duelsWonTotal  dribblesAtmptsSuc
# 0         0.108779           0.191225
# 1         0.183587           0.083586
# 2         0.380663           0.204123
# 3         0.239780           0.024259
# 4         0.362438           0.493859
# ..             ...                ...
# 452       0.401370           0.744906
# 453       0.360554           0.644546
# 454       0.345182           0.024297
# 455       0.443935           0.198977
# 456       0.314084           0.169869
#
# [457 rows x 5 columns]

# %%
df_pca.corr()[df_pca.corr() > 0.7]
# Out:
#                           shotsOnTotal_goalsTotal  goalsAssist_passesKey  \
# shotsOnTotal_goalsTotal                       1.0                    NaN
# goalsAssist_passesKey                         NaN                    1.0
# passesAcc_gamesApp_subIn                      NaN                    NaN
# duelsWonTotal                                 NaN                    NaN
# dribblesAtmptsSuc                             NaN                    NaN
#
#                           passesAcc_gamesApp_subIn  duelsWonTotal  \
# shotsOnTotal_goalsTotal                        NaN            NaN
# goalsAssist_passesKey                          NaN            NaN
# passesAcc_gamesApp_subIn                       1.0            NaN
# duelsWonTotal                                  NaN            1.0
# dribblesAtmptsSuc                              NaN            NaN
#
#                           dribblesAtmptsSuc
# shotsOnTotal_goalsTotal                 NaN
# goalsAssist_passesKey                   NaN
# passesAcc_gamesApp_subIn                NaN
# duelsWonTotal                           NaN
# dribblesAtmptsSuc                       1.0

# %% [markdown]
# # PCA feature들과 그 외 feature들의 OLS 확인

# %%
pca_cols = ['shots_total', 'shots_on', 'goals_total', 'goals_assists', 'passes_key', 'passes_accuracy', 'games_appearences', 'substitutes_in', 'duels_total', 'duels_won', 'dribbles_attempts', 'dribbles_success']
npca_cols = df_pos.columns.tolist()
npca_features = [item for item in npca_cols if item not in pca_cols]

# %%
df_ols = pd.concat([df_pos[npca_features].reset_index(drop=True), df_pca.reset_index(drop=True)], axis=1)
df_ols_f = df_ols
df_ols_f
# Out:
#      value  follower  passes_total  tackles_total  tackles_blocks  \
# 0     20.0     67879       22.1879         1.2112          0.1417
# 1     31.5    232370       40.9924         1.0431          0.7048
# 2     32.0    740918       12.3215         0.4629          0.0985
# 3     24.0    601838       58.0206         1.0302          0.3802
# 4     32.0    652886       23.4885         0.7757          0.1141
# ..     ...       ...           ...            ...             ...
# 452   20.0   1955121       28.5984         1.5835          0.2127
# 453   22.5    797767       22.6878         0.0000          0.0000
# 454   20.0   3339896       46.6951         1.4925          0.5686
# 455   24.0    109000       16.8654         0.3936          0.0695
# 456   44.0    282254       38.4372         1.0018          0.1371
#
#      tackles_interceptions  fouls_drawn  fouls_committed  cards_yellow  \
# 0                   0.8504       0.5283           0.7473        0.1804
# 1                   1.1841       1.2405           1.2969        0.1973
# 2                   0.2659       2.8563           1.7039        0.1083
# 3                   1.3368       0.5641           0.5887        0.0981
# 4                   0.9354       1.6085           1.6541        0.2738
# ..                     ...          ...              ...           ...
# 452                 1.8435       2.0326           1.4417        0.3782
# 453                 0.4088       1.1753           1.0220        0.2044
# 454                 0.9950       0.5686           0.9476        0.1895
# 455                 0.3010       1.8636           1.7595        0.1042
# 456                 0.9807       1.4341           1.2232        0.1582
#
#      cards_yellowred  cards_red  penalty_won  penalty_commited  \
# 0             0.0129     0.0000       0.0000            0.0000
# 1             0.0000     0.0000       0.0000            0.0564
# 2             0.0000     0.0000       0.0394            0.0000
# 3             0.0000     0.0000       0.0000            0.0000
# 4             0.0114     0.0114       0.0114            0.0114
# ..               ...        ...          ...               ...
# 452           0.0000     0.0000       0.0945            0.0236
# 453           0.0000     0.0000       0.0000            0.0000
# 454           0.0000     0.0000       0.0237            0.0000
# 455           0.0000     0.0000       0.0463            0.0000
# 456           0.0000     0.0000       0.0000            0.0000
#
#      penalty_success  penalty_missed  games_lineups  substitutes_out  \
# 0             0.0000          0.0000         0.9277           0.2577
# 1             0.0000          0.0000         0.9304           0.0564
# 2             0.0985          0.0295         0.9948           0.0689
# 3             0.0000          0.0000         1.0056           0.1840
# 4             0.0000          0.0000         0.9697           0.6731
# ..               ...             ...            ...              ...
# 452           0.0000          0.0236         0.9927           0.1418
# 453           0.0000          0.0000         0.8687           0.6643
# 454           0.0000          0.0000         1.0187           0.0948
# 455           0.0116          0.0000         0.9492           0.2894
# 456           0.0105          0.0000         1.0334           0.3058
#
#      substitutes_bench  age_x  height_x  weight_x  rating_x  \
# 0               0.5927   25.0     184.0      78.0  2.333333
# 1               1.6070   21.0     190.0      75.0  4.777778
# 2               0.0689   27.0     181.0      72.0  5.250000
# 3               0.7604   24.0     188.0      78.0  6.000000
# 4               0.6160   25.0     171.0      70.0  7.000000
# ..                 ...    ...       ...       ...       ...
# 452             0.3782   24.0     176.0      64.0  3.333333
# 453             1.2775   27.0     180.0      71.0  4.857143
# 454             0.5449   26.0     195.0      94.0  6.125000
# 455             0.5788   26.0     192.0      84.0  6.545455
# 456             0.2636   23.0     176.0      72.0  4.384615
#
#      shotsOnTotal_goalsTotal  goalsAssist_passesKey  passesAcc_gamesApp_subIn  \
# 0                  -1.682615               0.034725                  0.023985
# 1                  -1.716242               0.047031                  0.021084
# 2                   1.679798               0.212191                  0.003561
# 3                  -1.885495               0.033221                  0.009314
# 4                   0.450374               0.393255                  0.032514
# ..                       ...                    ...                       ...
# 452                -0.362550               0.121558                  0.013524
# 453                 0.742967               0.495260                  0.051046
# 454                -1.154388               0.079595                  0.012985
# 455                 0.633646               0.396598                  0.024402
# 456                -0.187624               0.274902                  0.011315
#
#      duelsWonTotal  dribblesAtmptsSuc
# 0         0.108779           0.191225
# 1         0.183587           0.083586
# 2         0.380663           0.204123
# 3         0.239780           0.024259
# 4         0.362438           0.493859
# ..             ...                ...
# 452       0.401370           0.744906
# 453       0.360554           0.644546
# 454       0.345182           0.024297
# 455       0.443935           0.198977
# 456       0.314084           0.169869
#
# [457 rows x 27 columns]

# %% [markdown]
# # follower 제거

# %%
df_ols_nf = df_ols.drop('follower', axis=1)

# %%
df_ols_nf
# Out:
#      value  passes_total  tackles_total  tackles_blocks  \
# 0     20.0       22.1879         1.2112          0.1417
# 1     31.5       40.9924         1.0431          0.7048
# 2     32.0       12.3215         0.4629          0.0985
# 3     24.0       58.0206         1.0302          0.3802
# 4     32.0       23.4885         0.7757          0.1141
# ..     ...           ...            ...             ...
# 452   20.0       28.5984         1.5835          0.2127
# 453   22.5       22.6878         0.0000          0.0000
# 454   20.0       46.6951         1.4925          0.5686
# 455   24.0       16.8654         0.3936          0.0695
# 456   44.0       38.4372         1.0018          0.1371
#
#      tackles_interceptions  fouls_drawn  fouls_committed  cards_yellow  \
# 0                   0.8504       0.5283           0.7473        0.1804
# 1                   1.1841       1.2405           1.2969        0.1973
# 2                   0.2659       2.8563           1.7039        0.1083
# 3                   1.3368       0.5641           0.5887        0.0981
# 4                   0.9354       1.6085           1.6541        0.2738
# ..                     ...          ...              ...           ...
# 452                 1.8435       2.0326           1.4417        0.3782
# 453                 0.4088       1.1753           1.0220        0.2044
# 454                 0.9950       0.5686           0.9476        0.1895
# 455                 0.3010       1.8636           1.7595        0.1042
# 456                 0.9807       1.4341           1.2232        0.1582
#
#      cards_yellowred  cards_red  penalty_won  penalty_commited  \
# 0             0.0129     0.0000       0.0000            0.0000
# 1             0.0000     0.0000       0.0000            0.0564
# 2             0.0000     0.0000       0.0394            0.0000
# 3             0.0000     0.0000       0.0000            0.0000
# 4             0.0114     0.0114       0.0114            0.0114
# ..               ...        ...          ...               ...
# 452           0.0000     0.0000       0.0945            0.0236
# 453           0.0000     0.0000       0.0000            0.0000
# 454           0.0000     0.0000       0.0237            0.0000
# 455           0.0000     0.0000       0.0463            0.0000
# 456           0.0000     0.0000       0.0000            0.0000
#
#      penalty_success  penalty_missed  games_lineups  substitutes_out  \
# 0             0.0000          0.0000         0.9277           0.2577
# 1             0.0000          0.0000         0.9304           0.0564
# 2             0.0985          0.0295         0.9948           0.0689
# 3             0.0000          0.0000         1.0056           0.1840
# 4             0.0000          0.0000         0.9697           0.6731
# ..               ...             ...            ...              ...
# 452           0.0000          0.0236         0.9927           0.1418
# 453           0.0000          0.0000         0.8687           0.6643
# 454           0.0000          0.0000         1.0187           0.0948
# 455           0.0116          0.0000         0.9492           0.2894
# 456           0.0105          0.0000         1.0334           0.3058
#
#      substitutes_bench  age_x  height_x  weight_x  rating_x  \
# 0               0.5927   25.0     184.0      78.0  2.333333
# 1               1.6070   21.0     190.0      75.0  4.777778
# 2               0.0689   27.0     181.0      72.0  5.250000
# 3               0.7604   24.0     188.0      78.0  6.000000
# 4               0.6160   25.0     171.0      70.0  7.000000
# ..                 ...    ...       ...       ...       ...
# 452             0.3782   24.0     176.0      64.0  3.333333
# 453             1.2775   27.0     180.0      71.0  4.857143
# 454             0.5449   26.0     195.0      94.0  6.125000
# 455             0.5788   26.0     192.0      84.0  6.545455
# 456             0.2636   23.0     176.0      72.0  4.384615
#
#      shotsOnTotal_goalsTotal  goalsAssist_passesKey  passesAcc_gamesApp_subIn  \
# 0                  -1.682615               0.034725                  0.023985
# 1                  -1.716242               0.047031                  0.021084
# 2                   1.679798               0.212191                  0.003561
# 3                  -1.885495               0.033221                  0.009314
# 4                   0.450374               0.393255                  0.032514
# ..                       ...                    ...                       ...
# 452                -0.362550               0.121558                  0.013524
# 453                 0.742967               0.495260                  0.051046
# 454                -1.154388               0.079595                  0.012985
# 455                 0.633646               0.396598                  0.024402
# 456                -0.187624               0.274902                  0.011315
#
#      duelsWonTotal  dribblesAtmptsSuc
# 0         0.108779           0.191225
# 1         0.183587           0.083586
# 2         0.380663           0.204123
# 3         0.239780           0.024259
# 4         0.362438           0.493859
# ..             ...                ...
# 452       0.401370           0.744906
# 453       0.360554           0.644546
# 454       0.345182           0.024297
# 455       0.443935           0.198977
# 456       0.314084           0.169869
#
# [457 rows x 26 columns]

# %% [markdown]
# # OLS - 0차

# %%
from sklearn.model_selection import train_test_split

df_ols = df_ols_nf
dfX = df_ols.drop(['value'], axis=1)
dfy = df_ols['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

formula = "value ~ " + "+".join(feature_names)

model = sm.OLS.from_formula(formula, data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(5)
cv = KFold(5, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula(formula, data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.317
# Model:                            OLS   Adj. R-squared:                  0.259
# Method:                 Least Squares   F-statistic:                     5.450
# Date:                Mon, 29 Jun 2020   Prob (F-statistic):           1.07e-13
# Time:                        14:37:33   Log-Likelihood:                -1328.7
# No. Observations:                 319   AIC:                             2709.
# Df Residuals:                     293   BIC:                             2807.
# Df Model:                          25
# Covariance Type:            nonrobust
# ===================================================================================================
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# Intercept                          31.7335      0.911     34.851      0.000      29.941      33.526
# scale(passes_total)                 7.3373      1.390      5.278      0.000       4.601      10.073
# scale(tackles_total)               -0.6127      1.333     -0.460      0.646      -3.236       2.010
# scale(tackles_blocks)              -0.1711      1.343     -0.127      0.899      -2.814       2.472
# scale(tackles_interceptions)       -0.9564      1.705     -0.561      0.575      -4.311       2.398
# scale(fouls_drawn)                 -2.0604      1.373     -1.501      0.134      -4.762       0.642
# scale(fouls_committed)             -4.4513      1.259     -3.536      0.000      -6.929      -1.974
# scale(cards_yellow)                 1.7288      1.231      1.405      0.161      -0.693       4.151
# scale(cards_yellowred)              1.4059      0.993      1.416      0.158      -0.548       3.360
# scale(cards_red)                    1.9673      0.948      2.074      0.039       0.101       3.834
# scale(penalty_won)                  2.2672      1.180      1.922      0.056      -0.055       4.589
# scale(penalty_commited)            -1.6118      1.107     -1.456      0.146      -3.791       0.567
# scale(penalty_success)             -0.4020      1.327     -0.303      0.762      -3.013       2.209
# scale(penalty_missed)               0.2611      1.151      0.227      0.821      -2.005       2.527
# scale(games_lineups)                4.6036      2.041      2.256      0.025       0.587       8.620
# scale(substitutes_out)             -5.0114      1.423     -3.521      0.000      -7.813      -2.210
# scale(substitutes_bench)            1.6799      1.547      1.086      0.278      -1.365       4.725
# scale(age_x)                       -4.6139      1.266     -3.644      0.000      -7.106      -2.122
# scale(height_x)                    -1.6721      1.388     -1.204      0.229      -4.404       1.060
# scale(weight_x)                     2.7619      1.441      1.916      0.056      -0.075       5.599
# scale(rating_x)                    -1.2194      1.244     -0.981      0.328      -3.667       1.228
# scale(shotsOnTotal_goalsTotal)     10.0505      1.946      5.165      0.000       6.221      13.880
# scale(goalsAssist_passesKey)       -0.1849      1.554     -0.119      0.905      -3.243       2.873
# scale(passesAcc_gamesApp_subIn)    -0.7062      1.745     -0.405      0.686      -4.141       2.729
# scale(duelsWonTotal)                1.5672      1.247      1.257      0.210      -0.887       4.021
# scale(dribblesAtmptsSuc)            3.8667      1.559      2.480      0.014       0.799       6.935
# ==============================================================================
# Omnibus:                      177.134   Durbin-Watson:                   1.874
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1493.758
# Skew:                           2.158   Prob(JB):                         0.00
# Kurtosis:                      12.682   Cond. No.                         6.67
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 학습 R2 = 0.29061210, 검증 R2 = 0.14012162
# 학습 R2 = 0.30132074, 검증 R2 = 0.19107226
# 학습 R2 = 0.29651469, 검증 R2 = -0.08177450
# 학습 R2 = 0.30883244, 검증 R2 = -2.00202732
# 학습 R2 = 0.30755983, 검증 R2 = 0.14250762
# 모델 성능 : -0.32202006563648194

# %% [markdown]
# # OLS - 1

# %%
df_ols_nf_1 = df_ols_nf.drop(['goalsAssist_passesKey'], axis=1)
len(df_ols_nf_1.columns)
# Out:
# 25

# %%
from sklearn.model_selection import train_test_split

df_ols = df_ols_nf_1
dfX = df_ols.drop(['value'], axis=1)
dfy = df_ols['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

formula = "value ~ " + "+".join(feature_names)

model = sm.OLS.from_formula(formula, data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(5)
cv = KFold(5, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula(formula, data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.317
# Model:                            OLS   Adj. R-squared:                  0.262
# Method:                 Least Squares   F-statistic:                     5.696
# Date:                Mon, 29 Jun 2020   Prob (F-statistic):           4.41e-14
# Time:                        14:37:36   Log-Likelihood:                -1328.7
# No. Observations:                 319   AIC:                             2707.
# Df Residuals:                     294   BIC:                             2802.
# Df Model:                          24
# Covariance Type:            nonrobust
# ===================================================================================================
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# Intercept                          31.7335      0.909     34.909      0.000      29.945      33.523
# scale(passes_total)                 7.3034      1.358      5.377      0.000       4.630       9.977
# scale(tackles_total)               -0.6236      1.328     -0.470      0.639      -3.236       1.989
# scale(tackles_blocks)              -0.1325      1.301     -0.102      0.919      -2.693       2.428
# scale(tackles_interceptions)       -0.9554      1.702     -0.561      0.575      -4.304       2.394
# scale(fouls_drawn)                 -2.0781      1.363     -1.525      0.128      -4.760       0.603
# scale(fouls_committed)             -4.4392      1.253     -3.544      0.000      -6.904      -1.974
# scale(cards_yellow)                 1.7405      1.225      1.421      0.156      -0.670       4.150
# scale(cards_yellowred)              1.4142      0.989      1.430      0.154      -0.532       3.360
# scale(cards_red)                    1.9680      0.947      2.078      0.039       0.104       3.831
# scale(penalty_won)                  2.2723      1.177      1.931      0.054      -0.044       4.589
# scale(penalty_commited)            -1.6012      1.102     -1.454      0.147      -3.769       0.567
# scale(penalty_success)             -0.4089      1.323     -0.309      0.758      -3.013       2.195
# scale(penalty_missed)               0.2657      1.149      0.231      0.817      -1.995       2.526
# scale(games_lineups)                4.5937      2.036      2.257      0.025       0.588       8.600
# scale(substitutes_out)             -5.0183      1.420     -3.535      0.000      -7.812      -2.224
# scale(substitutes_bench)            1.6633      1.538      1.081      0.280      -1.364       4.691
# scale(age_x)                       -4.6372      1.249     -3.713      0.000      -7.095      -2.179
# scale(height_x)                    -1.6670      1.385     -1.203      0.230      -4.393       1.059
# scale(weight_x)                     2.7693      1.438      1.926      0.055      -0.060       5.599
# scale(rating_x)                    -1.2310      1.238     -0.995      0.321      -3.667       1.205
# scale(shotsOnTotal_goalsTotal)      9.9963      1.889      5.292      0.000       6.279      13.714
# scale(passesAcc_gamesApp_subIn)    -0.6983      1.741     -0.401      0.689      -4.125       2.729
# scale(duelsWonTotal)                1.5778      1.242      1.271      0.205      -0.866       4.021
# scale(dribblesAtmptsSuc)            3.7947      1.434      2.646      0.009       0.972       6.617
# ==============================================================================
# Omnibus:                      177.169   Durbin-Watson:                   1.873
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1492.761
# Skew:                           2.159   Prob(JB):                         0.00
# Kurtosis:                      12.678   Cond. No.                         6.38
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 학습 R2 = 0.29047000, 검증 R2 = 0.14504573
# 학습 R2 = 0.29769530, 검증 R2 = 0.19423567
# 학습 R2 = 0.29449497, 검증 R2 = -0.06069776
# 학습 R2 = 0.30531444, 검증 R2 = -2.45693098
# 학습 R2 = 0.30411634, 검증 R2 = 0.14410451
# 모델 성능 : -0.406848565872339

# %% [markdown]
# # OLS - 2

# %%
df_ols_nf_2 = df_ols_nf_1.drop(['tackles_blocks'], axis=1)
len(df_ols_nf_2.columns)
# Out:
# 24

# %%
from sklearn.model_selection import train_test_split

df_ols = df_ols_nf_2
dfX = df_ols.drop(['value'], axis=1)
dfy = df_ols['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

formula = "value ~ " + "+".join(feature_names)

model = sm.OLS.from_formula(formula, data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(5)
cv = KFold(5, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula(formula, data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.317
# Model:                            OLS   Adj. R-squared:                  0.264
# Method:                 Least Squares   F-statistic:                     5.963
# Date:                Mon, 29 Jun 2020   Prob (F-statistic):           1.78e-14
# Time:                        14:37:40   Log-Likelihood:                -1328.8
# No. Observations:                 319   AIC:                             2706.
# Df Residuals:                     295   BIC:                             2796.
# Df Model:                          23
# Covariance Type:            nonrobust
# ===================================================================================================
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# Intercept                          31.7335      0.908     34.968      0.000      29.948      33.520
# scale(passes_total)                 7.2878      1.347      5.409      0.000       4.636       9.940
# scale(tackles_total)               -0.6397      1.316     -0.486      0.627      -3.229       1.950
# scale(tackles_interceptions)       -0.9718      1.691     -0.575      0.566      -4.300       2.357
# scale(fouls_drawn)                 -2.0739      1.360     -1.525      0.128      -4.750       0.602
# scale(fouls_committed)             -4.4471      1.248     -3.563      0.000      -6.903      -1.991
# scale(cards_yellow)                 1.7431      1.222      1.426      0.155      -0.662       4.148
# scale(cards_yellowred)              1.4264      0.980      1.456      0.147      -0.502       3.355
# scale(cards_red)                    1.9681      0.945      2.082      0.038       0.108       3.828
# scale(penalty_won)                  2.2761      1.174      1.938      0.054      -0.035       4.587
# scale(penalty_commited)            -1.6255      1.074     -1.514      0.131      -3.739       0.488
# scale(penalty_success)             -0.4076      1.321     -0.309      0.758      -3.007       2.192
# scale(penalty_missed)               0.2645      1.147      0.231      0.818      -1.992       2.521
# scale(games_lineups)                4.5653      2.013      2.268      0.024       0.604       8.527
# scale(substitutes_out)             -4.9922      1.394     -3.581      0.000      -7.736      -2.249
# scale(substitutes_bench)            1.6598      1.535      1.081      0.281      -1.362       4.681
# scale(age_x)                       -4.6224      1.238     -3.733      0.000      -7.060      -2.185
# scale(height_x)                    -1.6664      1.383     -1.205      0.229      -4.388       1.055
# scale(weight_x)                     2.7499      1.423      1.933      0.054      -0.050       5.550
# scale(rating_x)                    -1.2295      1.236     -0.995      0.320      -3.661       1.202
# scale(shotsOnTotal_goalsTotal)     10.0110      1.880      5.325      0.000       6.311      13.711
# scale(passesAcc_gamesApp_subIn)    -0.7059      1.737     -0.406      0.685      -4.124       2.712
# scale(duelsWonTotal)                1.5823      1.239      1.277      0.203      -0.856       4.020
# scale(dribblesAtmptsSuc)            3.8145      1.419      2.689      0.008       1.023       6.606
# ==============================================================================
# Omnibus:                      177.237   Durbin-Watson:                   1.873
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1494.873
# Skew:                           2.160   Prob(JB):                         0.00
# Kurtosis:                      12.685   Cond. No.                         6.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 학습 R2 = 0.28970907, 검증 R2 = 0.14153596
# 학습 R2 = 0.29759143, 검증 R2 = 0.19116701
# 학습 R2 = 0.29096111, 검증 R2 = -0.00791150
# 학습 R2 = 0.30459059, 검증 R2 = -2.60347098
# 학습 R2 = 0.30129339, 검증 R2 = 0.15638409
# 모델 성능 : -0.42445908456736026

# %% [markdown]
# # OLS - 3

# %%
df_ols_nf_3 = df_ols_nf_2.drop(['penalty_missed'], axis=1)
len(df_ols_nf_3.columns)
# Out:
# 23

# %%
from sklearn.model_selection import train_test_split

df_ols = df_ols_nf_3
dfX = df_ols.drop(['value'], axis=1)
dfy = df_ols['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

formula = "value ~ " + "+".join(feature_names)

model = sm.OLS.from_formula(formula, data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(5)
cv = KFold(5, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula(formula, data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.317
# Model:                            OLS   Adj. R-squared:                  0.266
# Method:                 Least Squares   F-statistic:                     6.252
# Date:                Mon, 29 Jun 2020   Prob (F-statistic):           7.12e-15
# Time:                        14:37:43   Log-Likelihood:                -1328.8
# No. Observations:                 319   AIC:                             2704.
# Df Residuals:                     296   BIC:                             2790.
# Df Model:                          22
# Covariance Type:            nonrobust
# ===================================================================================================
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# Intercept                          31.7335      0.906     35.024      0.000      29.950      33.517
# scale(passes_total)                 7.2655      1.342      5.415      0.000       4.625       9.906
# scale(tackles_total)               -0.6684      1.308     -0.511      0.610      -3.242       1.905
# scale(tackles_interceptions)       -0.9711      1.689     -0.575      0.566      -4.294       2.352
# scale(fouls_drawn)                 -2.0697      1.357     -1.525      0.128      -4.741       0.602
# scale(fouls_committed)             -4.4362      1.245     -3.563      0.000      -6.887      -1.986
# scale(cards_yellow)                 1.7485      1.220      1.433      0.153      -0.653       4.150
# scale(cards_yellowred)              1.4097      0.976      1.445      0.150      -0.511       3.330
# scale(cards_red)                    1.9633      0.944      2.081      0.038       0.106       3.820
# scale(penalty_won)                  2.2354      1.159      1.928      0.055      -0.046       4.517
# scale(penalty_commited)            -1.6132      1.071     -1.507      0.133      -3.720       0.494
# scale(penalty_success)             -0.3096      1.249     -0.248      0.804      -2.767       2.148
# scale(games_lineups)                4.5981      2.005      2.294      0.023       0.653       8.543
# scale(substitutes_out)             -5.0084      1.390     -3.603      0.000      -7.744      -2.273
# scale(substitutes_bench)            1.6688      1.532      1.089      0.277      -1.347       4.684
# scale(age_x)                       -4.5924      1.230     -3.735      0.000      -7.012      -2.173
# scale(height_x)                    -1.6779      1.380     -1.216      0.225      -4.393       1.038
# scale(weight_x)                     2.7551      1.420      1.940      0.053      -0.040       5.550
# scale(rating_x)                    -1.2614      1.226     -1.029      0.304      -3.674       1.151
# scale(shotsOnTotal_goalsTotal)     10.0851      1.850      5.453      0.000       6.445      13.725
# scale(passesAcc_gamesApp_subIn)    -0.6952      1.733     -0.401      0.689      -4.106       2.716
# scale(duelsWonTotal)                1.5866      1.237      1.283      0.201      -0.847       4.020
# scale(dribblesAtmptsSuc)            3.8197      1.416      2.697      0.007       1.033       6.607
# ==============================================================================
# Omnibus:                      176.436   Durbin-Watson:                   1.872
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1475.688
# Skew:                           2.151   Prob(JB):                         0.00
# Kurtosis:                      12.619   Cond. No.                         5.83
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 학습 R2 = 0.28903667, 검증 R2 = 0.14532048
# 학습 R2 = 0.29654402, 검증 R2 = 0.19773136
# 학습 R2 = 0.29096074, 검증 R2 = -0.00792438
# 학습 R2 = 0.30453309, 검증 R2 = -2.58782540
# 학습 R2 = 0.30028360, 검증 R2 = 0.16672587
# 모델 성능 : -0.41719441470549257

# %% [markdown]
# # OLS - 4

# %%
df_ols_nf_4 = df_ols_nf_3.drop(['penalty_success'], axis=1)
len(df_ols_nf_4.columns)
# Out:
# 22

# %%
from sklearn.model_selection import train_test_split

df_ols = df_ols_nf_4
dfX = df_ols.drop(['value'], axis=1)
dfy = df_ols['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

formula = "value ~ " + "+".join(feature_names)

model = sm.OLS.from_formula(formula, data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(5)
cv = KFold(5, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula(formula, data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.317
# Model:                            OLS   Adj. R-squared:                  0.269
# Method:                 Least Squares   F-statistic:                     6.567
# Date:                Mon, 29 Jun 2020   Prob (F-statistic):           2.79e-15
# Time:                        14:38:45   Log-Likelihood:                -1328.8
# No. Observations:                 319   AIC:                             2702.
# Df Residuals:                     297   BIC:                             2784.
# Df Model:                          21
# Covariance Type:            nonrobust
# ===================================================================================================
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# Intercept                          31.7335      0.905     35.080      0.000      29.953      33.514
# scale(passes_total)                 7.2523      1.339      5.418      0.000       4.618       9.887
# scale(tackles_total)               -0.6895      1.303     -0.529      0.597      -3.254       1.875
# scale(tackles_interceptions)       -0.9385      1.681     -0.558      0.577      -4.246       2.369
# scale(fouls_drawn)                 -2.0777      1.355     -1.534      0.126      -4.744       0.588
# scale(fouls_committed)             -4.4059      1.237     -3.561      0.000      -6.841      -1.971
# scale(cards_yellow)                 1.7525      1.218      1.439      0.151      -0.645       4.149
# scale(cards_yellowred)              1.4060      0.974      1.443      0.150      -0.511       3.323
# scale(cards_red)                    1.9568      0.942      2.078      0.039       0.104       3.810
# scale(penalty_won)                  2.1734      1.130      1.923      0.055      -0.051       4.397
# scale(penalty_commited)            -1.6221      1.068     -1.518      0.130      -3.725       0.480
# scale(games_lineups)                4.5819      2.000      2.290      0.023       0.645       8.519
# scale(substitutes_out)             -4.9651      1.377     -3.606      0.000      -7.675      -2.255
# scale(substitutes_bench)            1.6431      1.526      1.076      0.283      -1.361       4.647
# scale(age_x)                       -4.6359      1.215     -3.815      0.000      -7.027      -2.245
# scale(height_x)                    -1.6658      1.377     -1.210      0.227      -4.375       1.044
# scale(weight_x)                     2.7570      1.418      1.945      0.053      -0.033       5.547
# scale(rating_x)                    -1.2660      1.224     -1.035      0.302      -3.674       1.142
# scale(shotsOnTotal_goalsTotal)      9.8990      1.688      5.865      0.000       6.578      13.220
# scale(passesAcc_gamesApp_subIn)    -0.6917      1.730     -0.400      0.690      -4.097       2.714
# scale(duelsWonTotal)                1.5887      1.235      1.287      0.199      -0.841       4.019
# scale(dribblesAtmptsSuc)            3.8764      1.395      2.778      0.006       1.130       6.622
# ==============================================================================
# Omnibus:                      178.117   Durbin-Watson:                   1.868
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1523.611
# Skew:                           2.168   Prob(JB):                         0.00
# Kurtosis:                      12.789   Cond. No.                         5.63
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 학습 R2 = 0.28894452, 검증 R2 = 0.14346580
# 학습 R2 = 0.29519176, 검증 R2 = 0.19711669
# 학습 R2 = 0.28611092, 검증 R2 = 0.03694291
# 학습 R2 = 0.30191646, 검증 R2 = -2.35557166
# 학습 R2 = 0.29919860, 검증 R2 = 0.16420121
# 모델 성능 : -0.36276901124359034

# %% [markdown]
# # OLS - 5

# %%
df_ols_nf_5 = df_ols_nf_4.drop(['passesAcc_gamesApp_subIn'], axis=1)
len(df_ols_nf_5.columns)
# Out:
# 21

# %%
from sklearn.model_selection import train_test_split

df_ols = df_ols_nf_5
dfX = df_ols.drop(['value'], axis=1)
dfy = df_ols['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

formula = "value ~ " + "+".join(feature_names)

model = sm.OLS.from_formula(formula, data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula(formula, data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.317
# Model:                            OLS   Adj. R-squared:                  0.271
# Method:                 Least Squares   F-statistic:                     6.907
# Date:                Mon, 29 Jun 2020   Prob (F-statistic):           1.11e-15
# Time:                        14:44:23   Log-Likelihood:                -1328.9
# No. Observations:                 319   AIC:                             2700.
# Df Residuals:                     298   BIC:                             2779.
# Df Model:                          20
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                         31.7335      0.903     35.129      0.000      29.956      33.511
# scale(passes_total)                7.1719      1.322      5.427      0.000       4.571       9.773
# scale(tackles_total)              -0.7414      1.295     -0.573      0.567      -3.289       1.806
# scale(tackles_interceptions)      -0.8028      1.644     -0.488      0.626      -4.038       2.432
# scale(fouls_drawn)                -2.0305      1.348     -1.507      0.133      -4.683       0.622
# scale(fouls_committed)            -4.3930      1.235     -3.557      0.000      -6.824      -1.963
# scale(cards_yellow)                1.7606      1.216      1.448      0.149      -0.633       4.154
# scale(cards_yellowred)             1.3717      0.969      1.416      0.158      -0.535       3.278
# scale(cards_red)                   1.9316      0.938      2.059      0.040       0.085       3.778
# scale(penalty_won)                 2.1858      1.128      1.938      0.054      -0.034       4.406
# scale(penalty_commited)           -1.6381      1.066     -1.536      0.125      -3.736       0.460
# scale(games_lineups)               5.0631      1.595      3.174      0.002       1.923       8.203
# scale(substitutes_out)            -5.1077      1.328     -3.846      0.000      -7.721      -2.494
# scale(substitutes_bench)           1.5310      1.498      1.022      0.308      -1.418       4.480
# scale(age_x)                      -4.6783      1.209     -3.870      0.000      -7.057      -2.300
# scale(height_x)                   -1.7412      1.362     -1.278      0.202      -4.421       0.939
# scale(weight_x)                    2.8131      1.409      1.997      0.047       0.040       5.586
# scale(rating_x)                   -1.2528      1.222     -1.026      0.306      -3.657       1.151
# scale(shotsOnTotal_goalsTotal)     9.9298      1.684      5.898      0.000       6.617      13.243
# scale(duelsWonTotal)               1.3925      1.131      1.231      0.219      -0.834       3.619
# scale(dribblesAtmptsSuc)           3.9599      1.378      2.874      0.004       1.249       6.671
# ==============================================================================
# Omnibus:                      177.691   Durbin-Watson:                   1.869
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1511.304
# Skew:                           2.164   Prob(JB):                         0.00
# Kurtosis:                      12.746   Cond. No.                         5.10
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 학습 R2 = 0.27550848, 검증 R2 = 0.20846220
# 학습 R2 = 0.29146856, 검증 R2 = 0.13859649
# 학습 R2 = 0.30094957, 검증 R2 = -0.09976982
# 학습 R2 = 0.27537588, 검증 R2 = 0.28628009
# 학습 R2 = 0.28841342, 검증 R2 = 0.04123936
# 학습 R2 = 0.28027914, 검증 R2 = 0.05863321
# 학습 R2 = 0.30397644, 검증 R2 = -0.03675922
# 학습 R2 = 0.26714088, 검증 R2 = 0.41602549
# 학습 R2 = 0.29280635, 검증 R2 = -0.09011588
# 학습 R2 = 0.28500704, 검증 R2 = 0.21162543
# 모델 성능 : 0.11342173666363276

# %% [markdown]
# # OLS - 6

# %%
df_ols_nf_6 = df_ols_nf_5.drop(['tackles_interceptions'], axis=1)
len(df_ols_nf_6.columns)
# Out:
# 20

# %%
from sklearn.model_selection import train_test_split

df_ols = df_ols_nf_6
dfX = df_ols.drop(['value'], axis=1)
dfy = df_ols['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

formula = "value ~ " + "+".join(feature_names)

model = sm.OLS.from_formula(formula, data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula(formula, data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.316
# Model:                            OLS   Adj. R-squared:                  0.273
# Method:                 Least Squares   F-statistic:                     7.277
# Date:                Mon, 29 Jun 2020   Prob (F-statistic):           4.48e-16
# Time:                        14:54:12   Log-Likelihood:                -1329.0
# No. Observations:                 319   AIC:                             2698.
# Df Residuals:                     299   BIC:                             2773.
# Df Model:                          19
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                         31.7335      0.902     35.174      0.000      29.958      33.509
# scale(passes_total)                7.0967      1.311      5.414      0.000       4.517       9.676
# scale(tackles_total)              -0.9918      1.187     -0.835      0.404      -3.328       1.345
# scale(fouls_drawn)                -2.0687      1.344     -1.540      0.125      -4.713       0.576
# scale(fouls_committed)            -4.3966      1.233     -3.565      0.000      -6.824      -1.969
# scale(cards_yellow)                1.7129      1.211      1.415      0.158      -0.670       4.095
# scale(cards_yellowred)             1.3177      0.961      1.371      0.171      -0.574       3.210
# scale(cards_red)                   1.9507      0.936      2.083      0.038       0.108       3.793
# scale(penalty_won)                 2.1447      1.123      1.909      0.057      -0.066       4.356
# scale(penalty_commited)           -1.7125      1.054     -1.625      0.105      -3.786       0.361
# scale(games_lineups)               4.8616      1.539      3.159      0.002       1.833       7.891
# scale(substitutes_out)            -4.9190      1.269     -3.876      0.000      -7.416      -2.422
# scale(substitutes_bench)           1.1958      1.330      0.899      0.369      -1.422       3.813
# scale(age_x)                      -4.6875      1.207     -3.883      0.000      -7.063      -2.312
# scale(height_x)                   -1.7100      1.359     -1.259      0.209      -4.384       0.964
# scale(weight_x)                    2.7897      1.406      1.984      0.048       0.022       5.557
# scale(rating_x)                   -1.3293      1.210     -1.099      0.273      -3.710       1.052
# scale(shotsOnTotal_goalsTotal)    10.1761      1.604      6.343      0.000       7.019      13.333
# scale(duelsWonTotal)               1.3419      1.125      1.193      0.234      -0.872       3.556
# scale(dribblesAtmptsSuc)           4.0148      1.371      2.928      0.004       1.316       6.714
# ==============================================================================
# Omnibus:                      177.443   Durbin-Watson:                   1.868
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1496.216
# Skew:                           2.163   Prob(JB):                         0.00
# Kurtosis:                      12.687   Cond. No.                         4.46
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 학습 R2 = 0.27399912, 검증 R2 = 0.21462755
# 학습 R2 = 0.29146660, 검증 R2 = 0.13903052
# 학습 R2 = 0.30017143, 검증 R2 = -0.09281443
# 학습 R2 = 0.27455875, 검증 R2 = 0.28844058
# 학습 R2 = 0.28692982, 검증 R2 = 0.07686375
# 학습 R2 = 0.27972569, 검증 R2 = 0.12300997
# 학습 R2 = 0.30379771, 검증 R2 = -0.02397498
# 학습 R2 = 0.26676680, 검증 R2 = 0.41468876
# 학습 R2 = 0.29213537, 검증 R2 = -0.08523233
# 학습 R2 = 0.28358238, 검증 R2 = 0.22215546
# 모델 성능 : 0.12767948349054714

# %% [markdown]
# # OLS - 7

# %%
df_ols_nf_7 = df_ols_nf_6.drop(['tackles_total'], axis=1)
len(df_ols_nf_7.columns)
# Out:
# 19

# %%
from sklearn.model_selection import train_test_split

df_ols = df_ols_nf_7
dfX = df_ols.drop(['value'], axis=1)
dfy = df_ols['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

formula = "value ~ " + "+".join(feature_names)

model = sm.OLS.from_formula(formula, data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula(formula, data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.315
# Model:                            OLS   Adj. R-squared:                  0.273
# Method:                 Least Squares   F-statistic:                     7.650
# Date:                Mon, 29 Jun 2020   Prob (F-statistic):           2.15e-16
# Time:                        14:56:07   Log-Likelihood:                -1329.4
# No. Observations:                 319   AIC:                             2697.
# Df Residuals:                     300   BIC:                             2768.
# Df Model:                          18
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                         31.7335      0.902     35.192      0.000      29.959      33.508
# scale(passes_total)                6.9117      1.291      5.352      0.000       4.370       9.453
# scale(fouls_drawn)                -1.9884      1.340     -1.484      0.139      -4.625       0.648
# scale(fouls_committed)            -4.6397      1.198     -3.873      0.000      -6.997      -2.282
# scale(cards_yellow)                1.6460      1.207      1.363      0.174      -0.730       4.022
# scale(cards_yellowred)             1.3909      0.957      1.454      0.147      -0.492       3.274
# scale(cards_red)                   2.0070      0.933      2.150      0.032       0.170       3.844
# scale(penalty_won)                 2.1832      1.122      1.946      0.053      -0.025       4.391
# scale(penalty_commited)           -1.7092      1.053     -1.623      0.106      -3.782       0.364
# scale(games_lineups)               4.6274      1.513      3.059      0.002       1.651       7.604
# scale(substitutes_out)            -4.8587      1.266     -3.837      0.000      -7.351      -2.367
# scale(substitutes_bench)           1.1322      1.327      0.853      0.394      -1.480       3.744
# scale(age_x)                      -4.5579      1.196     -3.809      0.000      -6.912      -2.203
# scale(height_x)                   -1.6206      1.354     -1.197      0.232      -4.285       1.043
# scale(weight_x)                    2.8128      1.405      2.002      0.046       0.047       5.578
# scale(rating_x)                   -1.5070      1.190     -1.266      0.207      -3.850       0.836
# scale(shotsOnTotal_goalsTotal)    10.4849      1.560      6.720      0.000       7.414      13.555
# scale(duelsWonTotal)               1.2599      1.120      1.125      0.262      -0.945       3.464
# scale(dribblesAtmptsSuc)           3.8354      1.354      2.833      0.005       1.171       6.500
# ==============================================================================
# Omnibus:                      176.414   Durbin-Watson:                   1.878
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1471.529
# Skew:                           2.151   Prob(JB):                         0.00
# Kurtosis:                      12.602   Cond. No.                         4.45
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 학습 R2 = 0.27150855, 검증 R2 = 0.22444509
# 학습 R2 = 0.29101313, 검증 R2 = 0.13681080
# 학습 R2 = 0.29986742, 검증 R2 = -0.10011920
# 학습 R2 = 0.27377012, 검증 R2 = 0.28841334
# 학습 R2 = 0.28656834, 검증 R2 = 0.07543015
# 학습 R2 = 0.27950073, 검증 R2 = 0.11659406
# 학습 R2 = 0.30216960, 검증 R2 = -0.00910811
# 학습 R2 = 0.26602292, 검증 R2 = 0.41589219
# 학습 R2 = 0.29133158, 검증 R2 = -0.08318920
# 학습 R2 = 0.28325063, 검증 R2 = 0.21910184
# 모델 성능 : 0.1284270969110381

# %% [markdown]
# # OLS - 8

# %%
df_ols_nf_8 = df_ols_nf_7.drop(['substitutes_bench'], axis=1)
len(df_ols_nf_8.columns)
# Out:
# 18

# %%
from sklearn.model_selection import train_test_split

df_ols = df_ols_nf_8
dfX = df_ols.drop(['value'], axis=1)
dfy = df_ols['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

formula = "value ~ " + "+".join(feature_names)

model = sm.OLS.from_formula(formula, data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula(formula, data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.313
# Model:                            OLS   Adj. R-squared:                  0.274
# Method:                 Least Squares   F-statistic:                     8.064
# Date:                Mon, 29 Jun 2020   Prob (F-statistic):           1.02e-16
# Time:                        14:57:12   Log-Likelihood:                -1329.8
# No. Observations:                 319   AIC:                             2696.
# Df Residuals:                     301   BIC:                             2763.
# Df Model:                          17
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                         31.7335      0.901     35.208      0.000      29.960      33.507
# scale(passes_total)                6.9952      1.287      5.435      0.000       4.462       9.528
# scale(fouls_drawn)                -1.9662      1.339     -1.469      0.143      -4.601       0.668
# scale(fouls_committed)            -4.5813      1.195     -3.832      0.000      -6.934      -2.229
# scale(cards_yellow)                1.5612      1.203      1.298      0.195      -0.806       3.928
# scale(cards_yellowred)             1.4137      0.956      1.479      0.140      -0.468       3.295
# scale(cards_red)                   2.0552      0.931      2.207      0.028       0.223       3.888
# scale(penalty_won)                 2.1560      1.121      1.923      0.055      -0.050       4.362
# scale(penalty_commited)           -1.6737      1.052     -1.591      0.113      -3.744       0.396
# scale(games_lineups)               3.7468      1.105      3.390      0.001       1.572       5.922
# scale(substitutes_out)            -4.6261      1.236     -3.743      0.000      -7.058      -2.194
# scale(age_x)                      -4.4208      1.185     -3.730      0.000      -6.753      -2.089
# scale(height_x)                   -1.4859      1.344     -1.106      0.270      -4.131       1.159
# scale(weight_x)                    2.8415      1.404      2.024      0.044       0.078       5.605
# scale(rating_x)                   -1.5751      1.187     -1.327      0.186      -3.911       0.761
# scale(shotsOnTotal_goalsTotal)    10.3575      1.552      6.672      0.000       7.303      13.412
# scale(duelsWonTotal)               1.2130      1.118      1.085      0.279      -0.988       3.414
# scale(dribblesAtmptsSuc)           3.8441      1.353      2.841      0.005       1.181       6.507
# ==============================================================================
# Omnibus:                      176.881   Durbin-Watson:                   1.866
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1474.625
# Skew:                           2.159   Prob(JB):                         0.00
# Kurtosis:                      12.607   Cond. No.                         4.21
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 학습 R2 = 0.27055810, 검증 R2 = 0.22391511
# 학습 R2 = 0.29030848, 검증 R2 = 0.13536681
# 학습 R2 = 0.29858298, 검증 R2 = -0.09200163
# 학습 R2 = 0.27270783, 검증 R2 = 0.28947807
# 학습 R2 = 0.28265405, 검증 R2 = 0.18981038
# 학습 R2 = 0.27930365, 검증 R2 = 0.21425324
# 학습 R2 = 0.30146654, 검증 R2 = -0.01250397
# 학습 R2 = 0.26477353, 검증 R2 = 0.42000504
# 학습 R2 = 0.29068892, 검증 R2 = -0.08809473
# 학습 R2 = 0.28314749, 검증 R2 = 0.21485969
# 모델 성능 : 0.1495088022152533

# %% [markdown]
# # OLS - 9

# %%
df_ols_nf_9 = df_ols_nf_8.drop(['duelsWonTotal'], axis=1)
len(df_ols_nf_9.columns)
# Out:
# 17

# %%
from sklearn.model_selection import train_test_split

df_ols = df_ols_nf_9
dfX = df_ols.drop(['value'], axis=1)
dfy = df_ols['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

formula = "value ~ " + "+".join(feature_names)

model = sm.OLS.from_formula(formula, data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula(formula, data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.310
# Model:                            OLS   Adj. R-squared:                  0.274
# Method:                 Least Squares   F-statistic:                     8.490
# Date:                Mon, 29 Jun 2020   Prob (F-statistic):           5.76e-17
# Time:                        14:58:15   Log-Likelihood:                -1330.4
# No. Observations:                 319   AIC:                             2695.
# Df Residuals:                     302   BIC:                             2759.
# Df Model:                          16
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                         31.7335      0.902     35.197      0.000      29.959      33.508
# scale(passes_total)                7.0198      1.287      5.453      0.000       4.487       9.553
# scale(fouls_drawn)                -1.5746      1.289     -1.221      0.223      -4.112       0.963
# scale(fouls_committed)            -4.4249      1.187     -3.727      0.000      -6.761      -2.089
# scale(cards_yellow)                1.4774      1.201      1.231      0.219      -0.885       3.840
# scale(cards_yellowred)             1.3650      0.955      1.429      0.154      -0.515       3.245
# scale(cards_red)                   2.0662      0.931      2.218      0.027       0.233       3.899
# scale(penalty_won)                 2.2569      1.117      2.020      0.044       0.058       4.456
# scale(penalty_commited)           -1.6090      1.051     -1.532      0.127      -3.676       0.458
# scale(games_lineups)               3.4655      1.075      3.225      0.001       1.351       5.580
# scale(substitutes_out)            -4.7382      1.232     -3.846      0.000      -7.163      -2.314
# scale(age_x)                      -4.1103      1.150     -3.573      0.000      -6.374      -1.847
# scale(height_x)                   -1.5436      1.343     -1.149      0.251      -4.187       1.100
# scale(weight_x)                    3.0124      1.396      2.158      0.032       0.266       5.759
# scale(rating_x)                   -1.5647      1.188     -1.318      0.189      -3.902       0.772
# scale(shotsOnTotal_goalsTotal)    10.1089      1.536      6.582      0.000       7.087      13.131
# scale(dribblesAtmptsSuc)           4.2251      1.307      3.232      0.001       1.653       6.797
# ==============================================================================
# Omnibus:                      175.821   Durbin-Watson:                   1.858
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1441.867
# Skew:                           2.149   Prob(JB):                         0.00
# Kurtosis:                      12.487   Cond. No.                         4.08
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 학습 R2 = 0.26565467, 검증 R2 = 0.23148308
# 학습 R2 = 0.28831364, 검증 R2 = 0.12693083
# 학습 R2 = 0.29588332, 검증 R2 = -0.09814136
# 학습 R2 = 0.26831442, 검증 R2 = 0.29522530
# 학습 R2 = 0.27836134, 검증 R2 = 0.21406702
# 학습 R2 = 0.27717170, 검증 R2 = 0.19555482
# 학습 R2 = 0.29989358, 검증 R2 = -0.02950626
# 학습 R2 = 0.26062536, 검증 R2 = 0.43244218
# 학습 R2 = 0.28876489, 검증 R2 = -0.11443256
# 학습 R2 = 0.27864725, 검증 R2 = 0.22767484
# 모델 성능 : 0.14812978911871016

# %% [markdown]
# # OLS - 10

# %%
df_ols_nf_10 = df_ols_nf_9.drop(['height_x'], axis=1)
len(df_ols_nf_10.columns)
# Out:
# 16

# %%
from sklearn.model_selection import train_test_split

df_ols = df_ols_nf_10
dfX = df_ols.drop(['value'], axis=1)
dfy = df_ols['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

formula = "value ~ " + "+".join(feature_names)

model = sm.OLS.from_formula(formula, data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula(formula, data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.307
# Model:                            OLS   Adj. R-squared:                  0.273
# Method:                 Least Squares   F-statistic:                     8.958
# Date:                Mon, 29 Jun 2020   Prob (F-statistic):           3.39e-17
# Time:                        14:59:54   Log-Likelihood:                -1331.1
# No. Observations:                 319   AIC:                             2694.
# Df Residuals:                     303   BIC:                             2754.
# Df Model:                          15
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                         31.7335      0.902     35.179      0.000      29.958      33.509
# scale(passes_total)                6.8437      1.279      5.352      0.000       4.327       9.360
# scale(fouls_drawn)                -1.4270      1.284     -1.112      0.267      -3.953       1.099
# scale(fouls_committed)            -4.3762      1.187     -3.687      0.000      -6.712      -2.040
# scale(cards_yellow)                1.2900      1.190      1.084      0.279      -1.052       3.632
# scale(cards_yellowred)             1.3533      0.956      1.416      0.158      -0.527       3.234
# scale(cards_red)                   2.1573      0.929      2.323      0.021       0.330       3.985
# scale(penalty_won)                 2.1863      1.116      1.958      0.051      -0.011       4.383
# scale(penalty_commited)           -1.4418      1.041     -1.385      0.167      -3.490       0.607
# scale(games_lineups)               3.2613      1.060      3.076      0.002       1.175       5.348
# scale(substitutes_out)            -4.7861      1.232     -3.885      0.000      -7.210      -2.362
# scale(age_x)                      -4.0819      1.151     -3.547      0.000      -6.346      -1.818
# scale(weight_x)                    1.9176      1.021      1.879      0.061      -0.091       3.926
# scale(rating_x)                   -1.4173      1.181     -1.200      0.231      -3.742       0.907
# scale(shotsOnTotal_goalsTotal)    10.0138      1.534      6.526      0.000       6.994      13.033
# scale(dribblesAtmptsSuc)           4.2481      1.308      3.249      0.001       1.675       6.821
# ==============================================================================
# Omnibus:                      175.801   Durbin-Watson:                   1.860
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1428.049
# Skew:                           2.153   Prob(JB):                    8.00e-311
# Kurtosis:                      12.429   Cond. No.                         3.90
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 학습 R2 = 0.26112499, 검증 R2 = 0.23484415
# 학습 R2 = 0.28539811, 검증 R2 = 0.12299591
# 학습 R2 = 0.29384808, 검증 R2 = -0.12041444
# 학습 R2 = 0.26329284, 검증 R2 = 0.30562629
# 학습 R2 = 0.27689090, 검증 R2 = 0.18209977
# 학습 R2 = 0.27395353, 검증 R2 = 0.19836328
# 학습 R2 = 0.29707986, 검증 R2 = -0.04172148
# 학습 R2 = 0.25611638, 검증 R2 = 0.44610221
# 학습 R2 = 0.28593342, 검증 R2 = -0.12655855
# 학습 R2 = 0.27586763, 검증 R2 = 0.22105979
# 모델 성능 : 0.1422396939589669

# %% [markdown]
# # OLS - 11

# %%
df_ols_nf_11 = df_ols_nf_10.drop(['cards_yellow'], axis=1)
len(df_ols_nf_11.columns)
# Out:
# 15

# %%
from sklearn.model_selection import train_test_split

df_ols = df_ols_nf_11
dfX = df_ols.drop(['value'], axis=1)
dfy = df_ols['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

formula = "value ~ " + "+".join(feature_names)

model = sm.OLS.from_formula(formula, data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula(formula, data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.305
# Model:                            OLS   Adj. R-squared:                  0.273
# Method:                 Least Squares   F-statistic:                     9.509
# Date:                Mon, 29 Jun 2020   Prob (F-statistic):           1.82e-17
# Time:                        15:00:53   Log-Likelihood:                -1331.7
# No. Observations:                 319   AIC:                             2693.
# Df Residuals:                     304   BIC:                             2750.
# Df Model:                          14
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                         31.7335      0.902     35.169      0.000      29.958      33.509
# scale(passes_total)                6.7072      1.273      5.269      0.000       4.202       9.212
# scale(fouls_drawn)                -1.1840      1.264     -0.936      0.350      -3.672       1.304
# scale(fouls_committed)            -3.8244      1.073     -3.566      0.000      -5.935      -1.714
# scale(cards_yellowred)             1.5528      0.938      1.655      0.099      -0.293       3.399
# scale(cards_red)                   2.3035      0.919      2.507      0.013       0.495       4.112
# scale(penalty_won)                 2.1572      1.116      1.932      0.054      -0.040       4.354
# scale(penalty_commited)           -1.3889      1.040     -1.335      0.183      -3.436       0.658
# scale(games_lineups)               3.3514      1.057      3.169      0.002       1.271       5.432
# scale(substitutes_out)            -4.8379      1.231     -3.929      0.000      -7.261      -2.415
# scale(age_x)                      -4.0044      1.149     -3.486      0.001      -6.265      -1.744
# scale(weight_x)                    1.8665      1.020      1.830      0.068      -0.140       3.874
# scale(rating_x)                   -1.3731      1.181     -1.163      0.246      -3.697       0.951
# scale(shotsOnTotal_goalsTotal)     9.6199      1.491      6.451      0.000       6.686      12.554
# scale(dribblesAtmptsSuc)           4.0513      1.295      3.128      0.002       1.502       6.600
# ==============================================================================
# Omnibus:                      176.536   Durbin-Watson:                   1.870
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1441.304
# Skew:                           2.163   Prob(JB):                         0.00
# Kurtosis:                      12.473   Cond. No.                         3.80
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 학습 R2 = 0.25707177, 검증 R2 = 0.22267914
# 학습 R2 = 0.28055912, 검증 R2 = 0.11351796
# 학습 R2 = 0.28856593, 검증 R2 = -0.12897489
# 학습 R2 = 0.25886242, 검증 R2 = 0.29681439
# 학습 R2 = 0.27193414, 검증 R2 = 0.17142841
# 학습 R2 = 0.26434706, 검증 R2 = 0.28886598
# 학습 R2 = 0.29205189, 검증 R2 = -0.05546718
# 학습 R2 = 0.25132484, 검증 R2 = 0.43334895
# 학습 R2 = 0.27995139, 검증 R2 = -0.12301725
# 학습 R2 = 0.27040196, 검증 R2 = 0.21597759
# 모델 성능 : 0.14351731004450746

# %% [markdown]
# # OLS - 12

# %%
df_ols_nf_12 = df_ols_nf_11.drop(['fouls_drawn'], axis=1)
len(df_ols_nf_12.columns)
# Out:
# 14

# %%
from sklearn.model_selection import train_test_split

df_ols = df_ols_nf_12
dfX = df_ols.drop(['value'], axis=1)
dfy = df_ols['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

formula = "value ~ " + "+".join(feature_names)

model = sm.OLS.from_formula(formula, data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula(formula, data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.303
# Model:                            OLS   Adj. R-squared:                  0.273
# Method:                 Least Squares   F-statistic:                     10.18
# Date:                Mon, 29 Jun 2020   Prob (F-statistic):           8.26e-18
# Time:                        15:01:31   Log-Likelihood:                -1332.2
# No. Observations:                 319   AIC:                             2692.
# Df Residuals:                     305   BIC:                             2745.
# Df Model:                          13
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                         31.7335      0.902     35.176      0.000      29.958      33.509
# scale(passes_total)                6.5776      1.265      5.199      0.000       4.088       9.067
# scale(fouls_committed)            -4.2031      0.993     -4.232      0.000      -6.157      -2.249
# scale(cards_yellowred)             1.4808      0.935      1.584      0.114      -0.359       3.320
# scale(cards_red)                   2.2703      0.918      2.473      0.014       0.464       4.077
# scale(penalty_won)                 1.9936      1.102      1.808      0.072      -0.176       4.163
# scale(penalty_commited)           -1.2541      1.030     -1.218      0.224      -3.281       0.773
# scale(games_lineups)               3.2348      1.050      3.081      0.002       1.169       5.301
# scale(substitutes_out)            -4.7346      1.226     -3.861      0.000      -7.147      -2.322
# scale(age_x)                      -3.9489      1.147     -3.443      0.001      -6.206      -1.692
# scale(weight_x)                    1.9161      1.018      1.882      0.061      -0.088       3.920
# scale(rating_x)                   -1.2558      1.174     -1.070      0.286      -3.566       1.054
# scale(shotsOnTotal_goalsTotal)     9.4702      1.482      6.389      0.000       6.553      12.387
# scale(dribblesAtmptsSuc)           3.4867      1.146      3.042      0.003       1.231       5.742
# ==============================================================================
# Omnibus:                      179.628   Durbin-Watson:                   1.874
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1516.268
# Skew:                           2.199   Prob(JB):                         0.00
# Kurtosis:                      12.734   Cond. No.                         3.58
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 학습 R2 = 0.25408161, 검증 R2 = 0.19965767
# 학습 R2 = 0.27676765, 검증 R2 = 0.08765705
# 학습 R2 = 0.27597694, 검증 R2 = -0.03830706
# 학습 R2 = 0.25127959, 검증 R2 = 0.28576585
# 학습 R2 = 0.26166440, 검증 R2 = 0.20543560
# 학습 R2 = 0.25355259, 검증 R2 = 0.34296350
# 학습 R2 = 0.28344441, 검증 R2 = -0.05192190
# 학습 R2 = 0.24086302, 검증 R2 = 0.45845439
# 학습 R2 = 0.27093944, 검증 R2 = -0.10683264
# 학습 R2 = 0.26422677, 검증 R2 = 0.19373657
# 모델 성능 : 0.15766090200378108

# %% [markdown]
# # OLS - 13

# %%
df_ols_nf_13 = df_ols_nf_12.drop(['rating_x'], axis=1)
len(df_ols_nf_13.columns)
# Out:
# 13

# %%
from sklearn.model_selection import train_test_split

df_ols = df_ols_nf_13
dfX = df_ols.drop(['value'], axis=1)
dfy = df_ols['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

formula = "value ~ " + "+".join(feature_names)

model = sm.OLS.from_formula(formula, data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula(formula, data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.300
# Model:                            OLS   Adj. R-squared:                  0.272
# Method:                 Least Squares   F-statistic:                     10.92
# Date:                Mon, 29 Jun 2020   Prob (F-statistic):           4.10e-18
# Time:                        15:02:16   Log-Likelihood:                -1332.8
# No. Observations:                 319   AIC:                             2692.
# Df Residuals:                     306   BIC:                             2741.
# Df Model:                          12
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                         31.7335      0.902     35.167      0.000      29.958      33.509
# scale(passes_total)                6.0249      1.155      5.216      0.000       3.752       8.298
# scale(fouls_committed)            -4.4011      0.976     -4.509      0.000      -6.322      -2.481
# scale(cards_yellowred)             1.5449      0.933      1.656      0.099      -0.291       3.381
# scale(cards_red)                   2.1972      0.916      2.399      0.017       0.395       3.999
# scale(penalty_won)                 1.9754      1.103      1.792      0.074      -0.194       4.145
# scale(penalty_commited)           -1.2505      1.030     -1.214      0.226      -3.278       0.777
# scale(games_lineups)               3.0238      1.031      2.932      0.004       0.994       5.053
# scale(substitutes_out)            -4.6609      1.225     -3.806      0.000      -7.070      -2.251
# scale(age_x)                      -4.0130      1.146     -3.503      0.001      -6.267      -1.759
# scale(weight_x)                    1.7022      0.999      1.704      0.089      -0.263       3.667
# scale(shotsOnTotal_goalsTotal)     8.9678      1.406      6.377      0.000       6.201      11.735
# scale(dribblesAtmptsSuc)           3.5020      1.146      3.055      0.002       1.246       5.758
# ==============================================================================
# Omnibus:                      184.111   Durbin-Watson:                   1.871
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1625.313
# Skew:                           2.253   Prob(JB):                         0.00
# Kurtosis:                      13.099   Cond. No.                         3.28
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 학습 R2 = 0.25394295, 검증 R2 = 0.20184725
# 학습 R2 = 0.27661472, 검증 R2 = 0.09067268
# 학습 R2 = 0.27595614, 검증 R2 = -0.03852289
# 학습 R2 = 0.25047372, 검증 R2 = 0.29295774
# 학습 R2 = 0.26164873, 검증 R2 = 0.20509436
# 학습 R2 = 0.25345043, 검증 R2 = 0.34449808
# 학습 R2 = 0.28342750, 검증 R2 = -0.05230668
# 학습 R2 = 0.24036108, 검증 R2 = 0.46645078
# 학습 R2 = 0.27093509, 검증 R2 = -0.10721836
# 학습 R2 = 0.26420292, 검증 R2 = 0.19356535
# 모델 성능 : 0.15970383139898803

# %% [markdown]
# # OLS - 14

# %%
df_ols_nf_14 = df_ols_nf_13.drop(['penalty_commited'], axis=1)
len(df_ols_nf_14.columns)
# Out:
# 12

# %%
from sklearn.model_selection import train_test_split

df_ols = df_ols_nf_14
dfX = df_ols.drop(['value'], axis=1)
dfy = df_ols['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

formula = "value ~ " + "+".join(feature_names)

model = sm.OLS.from_formula(formula, data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula(formula, data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.297
# Model:                            OLS   Adj. R-squared:                  0.271
# Method:                 Least Squares   F-statistic:                     11.77
# Date:                Mon, 29 Jun 2020   Prob (F-statistic):           2.28e-18
# Time:                        15:03:02   Log-Likelihood:                -1333.5
# No. Observations:                 319   AIC:                             2691.
# Df Residuals:                     307   BIC:                             2736.
# Df Model:                          11
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                         31.7335      0.903     35.140      0.000      29.957      33.510
# scale(passes_total)                6.0299      1.156      5.216      0.000       3.755       8.305
# scale(fouls_committed)            -4.4542      0.976     -4.565      0.000      -6.374      -2.534
# scale(cards_yellowred)             1.5535      0.934      1.664      0.097      -0.284       3.391
# scale(cards_red)                   2.1391      0.915      2.337      0.020       0.338       3.940
# scale(penalty_won)                 1.9800      1.103      1.795      0.074      -0.191       4.151
# scale(games_lineups)               2.8251      1.019      2.772      0.006       0.820       4.830
# scale(substitutes_out)            -4.2303      1.173     -3.607      0.000      -6.538      -1.922
# scale(age_x)                      -3.8732      1.141     -3.395      0.001      -6.118      -1.628
# scale(weight_x)                    1.7299      0.999      1.731      0.084      -0.236       3.696
# scale(shotsOnTotal_goalsTotal)     9.1973      1.395      6.595      0.000       6.453      11.941
# scale(dribblesAtmptsSuc)           3.5266      1.147      3.074      0.002       1.269       5.784
# ==============================================================================
# Omnibus:                      186.638   Durbin-Watson:                   1.830
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1676.522
# Skew:                           2.287   Prob(JB):                         0.00
# Kurtosis:                      13.258   Cond. No.                         3.14
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 학습 R2 = 0.25318182, 검증 R2 = 0.19842243
# 학습 R2 = 0.27374280, 검증 R2 = 0.09976045
# 학습 R2 = 0.27431335, 검증 R2 = -0.03338192
# 학습 R2 = 0.24936568, 검증 R2 = 0.29084841
# 학습 R2 = 0.26011480, 검증 R2 = 0.20820127
# 학습 R2 = 0.25258710, 검증 R2 = 0.33351674
# 학습 R2 = 0.28157932, 검증 R2 = -0.04599363
# 학습 R2 = 0.23877687, 검증 R2 = 0.46785243
# 학습 R2 = 0.27055167, 검증 R2 = -0.12248895
# 학습 R2 = 0.26332276, 검증 R2 = 0.18894352
# 모델 성능 : 0.1585680745336079

# %% [markdown]
# # OLS - 15

# %%
df_ols_nf_15 = df_ols_nf_14.drop(['cards_yellowred'], axis=1)
len(df_ols_nf_15.columns)
# Out:
# 11

# %%
from sklearn.model_selection import train_test_split

df_ols = df_ols_nf_15
dfX = df_ols.drop(['value'], axis=1)
dfy = df_ols['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

formula = "value ~ " + "+".join(feature_names)

model = sm.OLS.from_formula(formula, data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula(formula, data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.290
# Model:                            OLS   Adj. R-squared:                  0.267
# Method:                 Least Squares   F-statistic:                     12.59
# Date:                Mon, 29 Jun 2020   Prob (F-statistic):           2.24e-18
# Time:                        15:04:23   Log-Likelihood:                -1335.0
# No. Observations:                 319   AIC:                             2692.
# Df Residuals:                     308   BIC:                             2733.
# Df Model:                          10
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                         31.7335      0.906     35.040      0.000      29.952      33.516
# scale(passes_total)                5.9436      1.158      5.132      0.000       3.665       8.222
# scale(fouls_committed)            -4.1766      0.964     -4.332      0.000      -6.074      -2.279
# scale(cards_red)                   2.1912      0.917      2.389      0.018       0.386       3.996
# scale(penalty_won)                 1.8208      1.102      1.652      0.100      -0.348       3.990
# scale(games_lineups)               2.9560      1.019      2.901      0.004       0.951       4.961
# scale(substitutes_out)            -4.3585      1.174     -3.713      0.000      -6.668      -2.049
# scale(age_x)                      -3.8698      1.144     -3.382      0.001      -6.121      -1.619
# scale(weight_x)                    1.7141      1.002      1.711      0.088      -0.258       3.686
# scale(shotsOnTotal_goalsTotal)     9.0858      1.397      6.504      0.000       6.337      11.834
# scale(dribblesAtmptsSuc)           3.5521      1.150      3.088      0.002       1.289       5.815
# ==============================================================================
# Omnibus:                      182.960   Durbin-Watson:                   1.845
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1584.881
# Skew:                           2.242   Prob(JB):                         0.00
# Kurtosis:                      12.957   Cond. No.                         3.13
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 학습 R2 = 0.25277734, 검증 R2 = 0.20028387
# 학습 R2 = 0.27319661, 검증 R2 = 0.10287842
# 학습 R2 = 0.27266789, 검증 R2 = 0.01161141
# 학습 R2 = 0.24935267, 검증 R2 = 0.29158137
# 학습 R2 = 0.26007869, 검증 R2 = 0.21185613
# 학습 R2 = 0.25245807, 검증 R2 = 0.33363233
# 학습 R2 = 0.28154876, 검증 R2 = -0.04669216
# 학습 R2 = 0.23869624, 검증 R2 = 0.47205055
# 학습 R2 = 0.27033270, 검증 R2 = -0.12057919
# 학습 R2 = 0.26306053, 검증 R2 = 0.19045983
# 모델 성능 : 0.16470825757837187

# %% [markdown]
# # OLS - 16

# %%
df_ols_nf_16 = df_ols_nf_15.drop(['penalty_won'], axis=1)
len(df_ols_nf_16.columns)
# Out:
# 10

# %%
from sklearn.model_selection import train_test_split

df_ols = df_ols_nf_16
dfX = df_ols.drop(['value'], axis=1)
dfy = df_ols['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

formula = "value ~ " + "+".join(feature_names)

model = sm.OLS.from_formula(formula, data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula(formula, data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.284
# Model:                            OLS   Adj. R-squared:                  0.263
# Method:                 Least Squares   F-statistic:                     13.61
# Date:                Mon, 29 Jun 2020   Prob (F-statistic):           2.09e-18
# Time:                        15:05:25   Log-Likelihood:                -1336.4
# No. Observations:                 319   AIC:                             2693.
# Df Residuals:                     309   BIC:                             2730.
# Df Model:                           9
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                         31.7335      0.908     34.942      0.000      29.947      33.521
# scale(passes_total)                5.7315      1.154      4.966      0.000       3.460       8.002
# scale(fouls_committed)            -4.1003      0.966     -4.246      0.000      -6.000      -2.200
# scale(cards_red)                   2.1301      0.919      2.318      0.021       0.322       3.939
# scale(games_lineups)               2.9478      1.022      2.885      0.004       0.937       4.958
# scale(substitutes_out)            -4.3479      1.177     -3.694      0.000      -6.664      -2.032
# scale(age_x)                      -3.9727      1.146     -3.468      0.001      -6.227      -1.719
# scale(weight_x)                    1.7924      1.004      1.786      0.075      -0.183       3.767
# scale(shotsOnTotal_goalsTotal)     9.9491      1.299      7.659      0.000       7.393      12.505
# scale(dribblesAtmptsSuc)           3.6812      1.151      3.199      0.002       1.417       5.946
# ==============================================================================
# Omnibus:                      185.393   Durbin-Watson:                   1.843
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1616.908
# Skew:                           2.279   Prob(JB):                         0.00
# Kurtosis:                      13.043   Cond. No.                         2.83
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 학습 R2 = 0.24360464, 검증 R2 = 0.20785267
# 학습 R2 = 0.26837397, 검증 R2 = 0.08489874
# 학습 R2 = 0.26667847, 검증 R2 = -0.00458999
# 학습 R2 = 0.24498976, 검증 R2 = 0.27421330
# 학습 R2 = 0.25308204, 검증 R2 = 0.21435809
# 학습 R2 = 0.24465021, 검증 R2 = 0.35117417
# 학습 R2 = 0.27286800, 검증 R2 = -0.02520422
# 학습 R2 = 0.23312953, 검증 R2 = 0.45548819
# 학습 R2 = 0.26245293, 검증 R2 = -0.10167464
# 학습 R2 = 0.25789394, 검증 R2 = 0.16946517
# 모델 성능 : 0.16259814823605998

# %% [markdown]
# # OLS - 17

# %%
df_ols_nf_17 = df_ols_nf_16.drop(['weight_x'], axis=1)
len(df_ols_nf_17.columns)
# Out:
# 9

# %%
from sklearn.model_selection import train_test_split

df_ols = df_ols_nf_17
dfX = df_ols.drop(['value'], axis=1)
dfy = df_ols['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

formula = "value ~ " + "+".join(feature_names)

model = sm.OLS.from_formula(formula, data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula(formula, data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.277
# Model:                            OLS   Adj. R-squared:                  0.258
# Method:                 Least Squares   F-statistic:                     14.81
# Date:                Mon, 29 Jun 2020   Prob (F-statistic):           2.33e-18
# Time:                        15:06:26   Log-Likelihood:                -1338.0
# No. Observations:                 319   AIC:                             2694.
# Df Residuals:                     310   BIC:                             2728.
# Df Model:                           8
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                         31.7335      0.911     34.820      0.000      29.940      33.527
# scale(passes_total)                5.9115      1.154      5.123      0.000       3.641       8.182
# scale(fouls_committed)            -3.8076      0.955     -3.987      0.000      -5.687      -1.928
# scale(cards_red)                   2.1629      0.922      2.346      0.020       0.348       3.977
# scale(games_lineups)               2.9569      1.025      2.884      0.004       0.939       4.975
# scale(substitutes_out)            -4.5401      1.176     -3.860      0.000      -6.854      -2.226
# scale(age_x)                      -3.4270      1.108     -3.093      0.002      -5.607      -1.247
# scale(shotsOnTotal_goalsTotal)    10.1315      1.300      7.796      0.000       7.574      12.689
# scale(dribblesAtmptsSuc)           3.6131      1.154      3.130      0.002       1.342       5.884
# ==============================================================================
# Omnibus:                      184.210   Durbin-Watson:                   1.858
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1583.913
# Skew:                           2.266   Prob(JB):                         0.00
# Kurtosis:                      12.931   Cond. No.                         2.83
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 학습 R2 = 0.23295762, 검증 R2 = 0.23621172
# 학습 R2 = 0.26470851, 검증 R2 = 0.07706912
# 학습 R2 = 0.26436936, 검증 R2 = -0.03742522
# 학습 R2 = 0.24073778, 검증 R2 = 0.26888100
# 학습 R2 = 0.24994992, 검증 R2 = 0.19530555
# 학습 R2 = 0.24219877, 검증 R2 = 0.31409654
# 학습 R2 = 0.26741205, 검증 R2 = -0.01119966
# 학습 R2 = 0.22752812, 검증 R2 = 0.46560737
# 학습 R2 = 0.25773085, 검증 R2 = -0.09874713
# 학습 R2 = 0.25470506, 검증 R2 = 0.15455525
# 모델 성능 : 0.15643545325109107

# %% [markdown]
# # OLS - Follower feature 추가
# # OLS - 0

# %%
from sklearn.model_selection import train_test_split

df_ols = df_ols_f
dfX = df_ols.drop(['value'], axis=1)
dfy = df_ols['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

formula = "value ~ " + "+".join(feature_names)

model = sm.OLS.from_formula(formula, data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula(formula, data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.354
# Model:                            OLS   Adj. R-squared:                  0.296
# Method:                 Least Squares   F-statistic:                     6.152
# Date:                Mon, 29 Jun 2020   Prob (F-statistic):           2.99e-16
# Time:                        15:08:15   Log-Likelihood:                -1320.0
# No. Observations:                 319   AIC:                             2694.
# Df Residuals:                     292   BIC:                             2796.
# Df Model:                          26
# Covariance Type:            nonrobust
# ===================================================================================================
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# Intercept                          31.7335      0.887     35.760      0.000      29.987      33.480
# scale(follower)                     4.4023      1.084      4.061      0.000       2.269       6.536
# scale(passes_total)                 6.3496      1.376      4.613      0.000       3.641       9.059
# scale(tackles_total)               -0.3995      1.300     -0.307      0.759      -2.958       2.159
# scale(tackles_blocks)              -0.3565      1.309     -0.272      0.786      -2.934       2.221
# scale(tackles_interceptions)       -0.9999      1.661     -0.602      0.548      -4.270       2.270
# scale(fouls_drawn)                 -2.1915      1.338     -1.637      0.103      -4.826       0.443
# scale(fouls_committed)             -3.8349      1.236     -3.102      0.002      -6.268      -1.402
# scale(cards_yellow)                 1.1457      1.208      0.949      0.344      -1.231       3.523
# scale(cards_yellowred)              1.1872      0.969      1.225      0.222      -0.720       3.095
# scale(cards_red)                    1.7823      0.925      1.926      0.055      -0.039       3.604
# scale(penalty_won)                  2.7520      1.156      2.381      0.018       0.477       5.027
# scale(penalty_commited)            -1.4181      1.080     -1.313      0.190      -3.544       0.707
# scale(penalty_success)             -1.7820      1.337     -1.333      0.184      -4.413       0.849
# scale(penalty_missed)               1.0010      1.137      0.881      0.379      -1.236       3.238
# scale(games_lineups)                4.3866      1.990      2.205      0.028       0.471       8.302
# scale(substitutes_out)             -3.8064      1.418     -2.683      0.008      -6.598      -1.015
# scale(substitutes_bench)            1.5600      1.508      1.034      0.302      -1.408       4.528
# scale(age_x)                       -5.2046      1.243     -4.188      0.000      -7.650      -2.759
# scale(height_x)                    -1.4396      1.354     -1.063      0.289      -4.105       1.226
# scale(weight_x)                     2.6983      1.405      1.921      0.056      -0.067       5.463
# scale(rating_x)                    -0.4936      1.225     -0.403      0.687      -2.905       1.917
# scale(shotsOnTotal_goalsTotal)      7.7870      1.977      3.940      0.000       3.897      11.677
# scale(goalsAssist_passesKey)        0.4278      1.522      0.281      0.779      -2.567       3.422
# scale(passesAcc_gamesApp_subIn)    -0.8184      1.701     -0.481      0.631      -4.167       2.530
# scale(duelsWonTotal)                1.8697      1.217      1.536      0.126      -0.526       4.266
# scale(dribblesAtmptsSuc)            2.4267      1.560      1.555      0.121      -0.644       5.497
# ==============================================================================
# Omnibus:                      169.163   Durbin-Watson:                   1.849
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1419.418
# Skew:                           2.033   Prob(JB):                    5.99e-309
# Kurtosis:                      12.501   Cond. No.                         6.78
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 학습 R2 = 0.31816367, 검증 R2 = 0.27488759
# 학습 R2 = 0.34667404, 검증 R2 = 0.15555736
# 학습 R2 = 0.34818141, 검증 R2 = -0.00713309
# 학습 R2 = 0.31646547, 검증 R2 = 0.37743598
# 학습 R2 = 0.33903258, 검증 R2 = 0.12220614
# 학습 R2 = 0.36185932, 검증 R2 = -0.91134374
# 학습 R2 = 0.35839384, 검증 R2 = -2.35575907
# 학습 R2 = 0.31272113, 검증 R2 = 0.50611569
# 학습 R2 = 0.34255421, 검증 R2 = -0.02887471
# 학습 R2 = 0.33890938, 검증 R2 = 0.21704758
# 모델 성능 : -0.1649860265117134

# %% [markdown]
# # OLS - 1

# %%
df_ols_f_1 = df_ols_f.drop(['tackles_blocks'], axis=1)
len(df_ols_f_1.columns)
# Out:
# 26

# %%
from sklearn.model_selection import train_test_split

df_ols = df_ols_f_1
dfX = df_ols.drop(['value'], axis=1)
dfy = df_ols['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

formula = "value ~ " + "+".join(feature_names)

model = sm.OLS.from_formula(formula, data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula(formula, data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.354
# Model:                            OLS   Adj. R-squared:                  0.299
# Method:                 Least Squares   F-statistic:                     6.415
# Date:                Mon, 29 Jun 2020   Prob (F-statistic):           1.20e-16
# Time:                        15:09:49   Log-Likelihood:                -1320.0
# No. Observations:                 319   AIC:                             2692.
# Df Residuals:                     293   BIC:                             2790.
# Df Model:                          25
# Covariance Type:            nonrobust
# ===================================================================================================
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# Intercept                          31.7335      0.886     35.817      0.000      29.990      33.477
# scale(follower)                     4.3920      1.082      4.060      0.000       2.263       6.521
# scale(passes_total)                 6.2943      1.359      4.631      0.000       3.619       8.969
# scale(tackles_total)               -0.4467      1.286     -0.347      0.729      -2.978       2.085
# scale(tackles_interceptions)       -1.0407      1.652     -0.630      0.529      -4.292       2.210
# scale(fouls_drawn)                 -2.1900      1.336     -1.639      0.102      -4.820       0.440
# scale(fouls_committed)             -3.8498      1.233     -3.123      0.002      -6.276      -1.423
# scale(cards_yellow)                 1.1601      1.205      0.963      0.336      -1.211       3.531
# scale(cards_yellowred)              1.2230      0.959      1.276      0.203      -0.664       3.110
# scale(cards_red)                    1.7834      0.924      1.930      0.055      -0.035       3.602
# scale(penalty_won)                  2.7632      1.153      2.396      0.017       0.493       5.033
# scale(penalty_commited)            -1.4743      1.058     -1.393      0.165      -3.557       0.609
# scale(penalty_success)             -1.7792      1.335     -1.333      0.184      -4.406       0.848
# scale(penalty_missed)               0.9988      1.135      0.880      0.380      -1.235       3.232
# scale(games_lineups)                4.3098      1.966      2.192      0.029       0.440       8.180
# scale(substitutes_out)             -3.7469      1.399     -2.678      0.008      -6.501      -0.993
# scale(substitutes_bench)            1.5424      1.504      1.025      0.306      -1.418       4.503
# scale(age_x)                       -5.1784      1.237     -4.186      0.000      -7.613      -2.744
# scale(height_x)                    -1.4360      1.352     -1.062      0.289      -4.097       1.225
# scale(weight_x)                     2.6532      1.393      1.905      0.058      -0.088       5.394
# scale(rating_x)                    -0.4978      1.223     -0.407      0.684      -2.905       1.909
# scale(shotsOnTotal_goalsTotal)      7.8003      1.973      3.954      0.000       3.917      11.683
# scale(goalsAssist_passesKey)        0.5258      1.476      0.356      0.722      -2.379       3.431
# scale(passesAcc_gamesApp_subIn)    -0.8333      1.698     -0.491      0.624      -4.174       2.508
# scale(duelsWonTotal)                1.8860      1.214      1.553      0.121      -0.503       4.275
# scale(dribblesAtmptsSuc)            2.4414      1.557      1.568      0.118      -0.622       5.505
# ==============================================================================
# Omnibus:                      169.505   Durbin-Watson:                   1.846
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1425.392
# Skew:                           2.037   Prob(JB):                    3.02e-310
# Kurtosis:                      12.521   Cond. No.                         6.41
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 학습 R2 = 0.31643178, 검증 R2 = 0.27750634
# 학습 R2 = 0.34580486, 검증 R2 = 0.15272909
# 학습 R2 = 0.34784002, 검증 R2 = -0.01873114
# 학습 R2 = 0.31611996, 검증 R2 = 0.37319356
# 학습 R2 = 0.33755898, 검증 R2 = 0.13863447
# 학습 R2 = 0.36009218, 검증 R2 = -0.93559091
# 학습 R2 = 0.35761791, 검증 R2 = -2.42228025
# 학습 R2 = 0.31151652, 검증 R2 = 0.50866612
# 학습 R2 = 0.34114986, 검증 R2 = -0.02170627
# 학습 R2 = 0.33729840, 검증 R2 = 0.22664214
# 모델 성능 : -0.17209368588240975

# %% [markdown]
# # OLS - 2

# %%
df_ols_f_2 = df_ols_f_1.drop(['tackles_total'], axis=1)
len(df_ols_f_2.columns)
# Out:
# 25

# %%
from sklearn.model_selection import train_test_split

df_ols = df_ols_f_2
dfX = df_ols.drop(['value'], axis=1)
dfy = df_ols['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

formula = "value ~ " + "+".join(feature_names)

model = sm.OLS.from_formula(formula, data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula(formula, data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.353
# Model:                            OLS   Adj. R-squared:                  0.301
# Method:                 Least Squares   F-statistic:                     6.698
# Date:                Mon, 29 Jun 2020   Prob (F-statistic):           4.77e-17
# Time:                        15:10:27   Log-Likelihood:                -1320.1
# No. Observations:                 319   AIC:                             2690.
# Df Residuals:                     294   BIC:                             2784.
# Df Model:                          24
# Covariance Type:            nonrobust
# ===================================================================================================
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# Intercept                          31.7335      0.885     35.871      0.000      29.992      33.475
# scale(follower)                     4.4056      1.079      4.082      0.000       2.281       6.530
# scale(passes_total)                 6.2573      1.353      4.625      0.000       3.595       8.920
# scale(tackles_interceptions)       -1.2747      1.506     -0.847      0.398      -4.238       1.689
# scale(fouls_drawn)                 -2.1522      1.330     -1.618      0.107      -4.769       0.465
# scale(fouls_committed)             -3.9437      1.201     -3.283      0.001      -6.308      -1.580
# scale(cards_yellow)                 1.1437      1.202      0.951      0.342      -1.222       3.509
# scale(cards_yellowred)              1.2692      0.948      1.339      0.182      -0.597       3.135
# scale(cards_red)                    1.8018      0.921      1.956      0.051      -0.011       3.615
# scale(penalty_won)                  2.7998      1.147      2.441      0.015       0.543       5.057
# scale(penalty_commited)            -1.4537      1.055     -1.378      0.169      -3.530       0.623
# scale(penalty_success)             -1.8237      1.327     -1.375      0.170      -4.435       0.787
# scale(penalty_missed)               1.0372      1.128      0.920      0.358      -1.182       3.257
# scale(games_lineups)                4.2338      1.951      2.170      0.031       0.394       8.074
# scale(substitutes_out)             -3.7603      1.397     -2.692      0.008      -6.509      -1.011
# scale(substitutes_bench)            1.6220      1.485      1.093      0.275      -1.300       4.544
# scale(age_x)                       -5.1236      1.225     -4.182      0.000      -7.535      -2.713
# scale(height_x)                    -1.4043      1.347     -1.043      0.298      -4.055       1.246
# scale(weight_x)                     2.6609      1.391      1.913      0.057      -0.076       5.398
# scale(rating_x)                    -0.5354      1.216     -0.440      0.660      -2.929       1.858
# scale(shotsOnTotal_goalsTotal)      7.8502      1.965      3.996      0.000       3.983      11.717
# scale(goalsAssist_passesKey)        0.5085      1.473      0.345      0.730      -2.391       3.408
# scale(passesAcc_gamesApp_subIn)    -0.8948      1.686     -0.531      0.596      -4.213       2.423
# scale(duelsWonTotal)                1.8852      1.212      1.555      0.121      -0.501       4.271
# scale(dribblesAtmptsSuc)            2.3510      1.532      1.534      0.126      -0.665       5.367
# ==============================================================================
# Omnibus:                      169.093   Durbin-Watson:                   1.850
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1419.143
# Skew:                           2.031   Prob(JB):                    6.87e-309
# Kurtosis:                      12.501   Cond. No.                         6.30
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 학습 R2 = 0.31616412, 검증 R2 = 0.27858643
# 학습 R2 = 0.34566367, 검증 R2 = 0.15311857
# 학습 R2 = 0.34783844, 검증 R2 = -0.01912359
# 학습 R2 = 0.31604145, 검증 R2 = 0.37326121
# 학습 R2 = 0.33751319, 검증 R2 = 0.14130548
# 학습 R2 = 0.35991739, 검증 R2 = -0.91221184
# 학습 R2 = 0.35700253, 검증 R2 = -2.59035899
# 학습 R2 = 0.31116614, 검증 R2 = 0.51382422
# 학습 R2 = 0.34108918, 검증 R2 = -0.02181296
# 학습 R2 = 0.33728616, 검증 R2 = 0.22736999
# 모델 성능 : -0.18560414816245835

# %% [markdown]
# # OLS - 3

# %%
df_ols_f_3 = df_ols_f_2.drop(['goalsAssist_passesKey'], axis=1)
len(df_ols_f_3.columns)
# Out:
# 24

# %%
from sklearn.model_selection import train_test_split

df_ols = df_ols_f_3
dfX = df_ols.drop(['value'], axis=1)
dfy = df_ols['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

formula = "value ~ " + "+".join(feature_names)

model = sm.OLS.from_formula(formula, data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula(formula, data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.353
# Model:                            OLS   Adj. R-squared:                  0.303
# Method:                 Least Squares   F-statistic:                     7.005
# Date:                Mon, 29 Jun 2020   Prob (F-statistic):           1.86e-17
# Time:                        15:11:50   Log-Likelihood:                -1320.1
# No. Observations:                 319   AIC:                             2688.
# Df Residuals:                     295   BIC:                             2779.
# Df Model:                          23
# Covariance Type:            nonrobust
# ===================================================================================================
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# Intercept                          31.7335      0.883     35.924      0.000      29.995      33.472
# scale(follower)                     4.3638      1.071      4.075      0.000       2.256       6.471
# scale(passes_total)                 6.3479      1.325      4.790      0.000       3.740       8.956
# scale(tackles_interceptions)       -1.2821      1.503     -0.853      0.394      -4.241       1.677
# scale(fouls_drawn)                 -2.1007      1.319     -1.592      0.112      -4.697       0.496
# scale(fouls_committed)             -3.9854      1.193     -3.340      0.001      -6.334      -1.637
# scale(cards_yellow)                 1.1201      1.198      0.935      0.351      -1.238       3.478
# scale(cards_yellowred)              1.2566      0.946      1.328      0.185      -0.605       3.118
# scale(cards_red)                    1.8013      0.920      1.958      0.051      -0.009       3.611
# scale(penalty_won)                  2.7830      1.144      2.433      0.016       0.531       5.034
# scale(penalty_commited)            -1.5040      1.043     -1.441      0.151      -3.557       0.549
# scale(penalty_success)             -1.7893      1.321     -1.355      0.177      -4.389       0.810
# scale(penalty_missed)               1.0156      1.124      0.903      0.367      -1.197       3.228
# scale(games_lineups)                4.2432      1.948      2.178      0.030       0.409       8.077
# scale(substitutes_out)             -3.7320      1.392     -2.681      0.008      -6.472      -0.992
# scale(substitutes_bench)            1.6629      1.478      1.125      0.261      -1.245       4.571
# scale(age_x)                       -5.0449      1.202     -4.198      0.000      -7.410      -2.680
# scale(height_x)                    -1.4211      1.344     -1.057      0.291      -4.066       1.224
# scale(weight_x)                     2.6260      1.385      1.896      0.059      -0.099       5.351
# scale(rating_x)                    -0.5084      1.212     -0.419      0.675      -2.894       1.877
# scale(shotsOnTotal_goalsTotal)      8.0286      1.893      4.242      0.000       4.304      11.753
# scale(passesAcc_gamesApp_subIn)    -0.9194      1.682     -0.547      0.585      -4.229       2.391
# scale(duelsWonTotal)                1.8571      1.208      1.538      0.125      -0.520       4.234
# scale(dribblesAtmptsSuc)            2.5790      1.381      1.868      0.063      -0.138       5.296
# ==============================================================================
# Omnibus:                      169.083   Durbin-Watson:                   1.851
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1426.299
# Skew:                           2.029   Prob(JB):                    1.92e-310
# Kurtosis:                      12.531   Cond. No.                         5.95
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 학습 R2 = 0.31582760, 검증 R2 = 0.26488779
# 학습 R2 = 0.33671499, 검증 R2 = 0.16022199
# 학습 R2 = 0.34128116, 검증 R2 = -0.02271266
# 학습 R2 = 0.30915265, 검증 R2 = 0.37053413
# 학습 R2 = 0.33049618, 검증 R2 = 0.11703031
# 학습 R2 = 0.35443237, 검증 R2 = -1.18699552
# 학습 R2 = 0.35157448, 검증 R2 = -3.51627458
# 학습 R2 = 0.30209596, 검증 R2 = 0.53818549
# 학습 R2 = 0.33309231, 검증 R2 = 0.00362714
# 학습 R2 = 0.33000384, 검증 R2 = 0.22889013
# 모델 성능 : -0.3042605793677414

# %% [markdown]
# # OLS - 4

# %%
df_ols_f_4 = df_ols_f_3.drop(['rating_x'], axis=1)
len(df_ols_f_4.columns)
# Out:
# 23

# %%
from sklearn.model_selection import train_test_split

df_ols = df_ols_f_4
dfX = df_ols.drop(['value'], axis=1)
dfy = df_ols['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

formula = "value ~ " + "+".join(feature_names)

model = sm.OLS.from_formula(formula, data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula(formula, data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.353
# Model:                            OLS   Adj. R-squared:                  0.305
# Method:                 Least Squares   F-statistic:                     7.336
# Date:                Mon, 29 Jun 2020   Prob (F-statistic):           7.28e-18
# Time:                        15:13:07   Log-Likelihood:                -1320.2
# No. Observations:                 319   AIC:                             2686.
# Df Residuals:                     296   BIC:                             2773.
# Df Model:                          22
# Covariance Type:            nonrobust
# ===================================================================================================
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# Intercept                          31.7335      0.882     35.974      0.000      29.998      33.470
# scale(follower)                     4.4348      1.056      4.200      0.000       2.357       6.513
# scale(passes_total)                 6.1375      1.225      5.011      0.000       3.727       8.548
# scale(tackles_interceptions)       -1.3916      1.479     -0.941      0.347      -4.301       1.518
# scale(fouls_drawn)                 -2.0384      1.309     -1.557      0.121      -4.615       0.538
# scale(fouls_committed)             -4.0500      1.182     -3.428      0.001      -6.375      -1.725
# scale(cards_yellow)                 1.0977      1.195      0.918      0.359      -1.255       3.450
# scale(cards_yellowred)              1.2817      0.943      1.360      0.175      -0.574       3.137
# scale(cards_red)                    1.7696      0.915      1.933      0.054      -0.032       3.571
# scale(penalty_won)                  2.7898      1.142      2.442      0.015       0.542       5.038
# scale(penalty_commited)            -1.4817      1.041     -1.424      0.156      -3.530       0.566
# scale(penalty_success)             -1.8425      1.313     -1.403      0.162      -4.427       0.742
# scale(penalty_missed)               1.0833      1.111      0.975      0.330      -1.103       3.270
# scale(games_lineups)                4.2171      1.944      2.169      0.031       0.391       8.044
# scale(substitutes_out)             -3.7187      1.390     -2.675      0.008      -6.454      -0.983
# scale(substitutes_bench)            1.7423      1.463      1.191      0.235      -1.138       4.622
# scale(age_x)                       -5.0848      1.196     -4.250      0.000      -7.439      -2.730
# scale(height_x)                    -1.3722      1.337     -1.026      0.306      -4.003       1.259
# scale(weight_x)                     2.5085      1.354      1.852      0.065      -0.157       5.174
# scale(shotsOnTotal_goalsTotal)      7.7449      1.765      4.387      0.000       4.271      11.219
# scale(passesAcc_gamesApp_subIn)    -0.9120      1.679     -0.543      0.588      -4.217       2.393
# scale(duelsWonTotal)                1.8655      1.206      1.547      0.123      -0.508       4.239
# scale(dribblesAtmptsSuc)            2.5390      1.376      1.846      0.066      -0.168       5.246
# ==============================================================================
# Omnibus:                      170.897   Durbin-Watson:                   1.851
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1469.721
# Skew:                           2.050   Prob(JB):                         0.00
# Kurtosis:                      12.683   Cond. No.                         5.92
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 학습 R2 = 0.31549152, 검증 R2 = 0.26412718
# 학습 R2 = 0.33670581, 검증 R2 = 0.16115207
# 학습 R2 = 0.34081566, 검증 R2 = -0.02143049
# 학습 R2 = 0.30768686, 검증 R2 = 0.37747693
# 학습 R2 = 0.32971646, 검증 R2 = 0.13572901
# 학습 R2 = 0.35424941, 검증 R2 = -1.18043529
# 학습 R2 = 0.35066730, 검증 R2 = -3.19954323
# 학습 R2 = 0.30087756, 검증 R2 = 0.54965837
# 학습 R2 = 0.33274451, 검증 R2 = 0.00220929
# 학습 R2 = 0.32962556, 검증 R2 = 0.22865528
# 모델 성능 : -0.26824008768748986

# %% [markdown]
# # OLS - 5

# %%
df_ols_f_5 = df_ols_f_4.drop(['passesAcc_gamesApp_subIn'], axis=1)
len(df_ols_f_5.columns)
# Out:
# 22

# %%
from sklearn.model_selection import train_test_split

df_ols = df_ols_f_5
dfX = df_ols.drop(['value'], axis=1)
dfy = df_ols['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

formula = "value ~ " + "+".join(feature_names)

model = sm.OLS.from_formula(formula, data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula(formula, data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.352
# Model:                            OLS   Adj. R-squared:                  0.306
# Method:                 Least Squares   F-statistic:                     7.689
# Date:                Mon, 29 Jun 2020   Prob (F-statistic):           2.93e-18
# Time:                        15:17:34   Log-Likelihood:                -1320.4
# No. Observations:                 319   AIC:                             2685.
# Df Residuals:                     297   BIC:                             2768.
# Df Model:                          21
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                         31.7335      0.881     36.017      0.000      30.000      33.467
# scale(follower)                    4.4231      1.055      4.194      0.000       2.348       6.498
# scale(passes_total)                6.0279      1.207      4.995      0.000       3.653       8.403
# scale(tackles_interceptions)      -1.2462      1.452     -0.858      0.392      -4.104       1.612
# scale(fouls_drawn)                -1.9702      1.302     -1.514      0.131      -4.532       0.591
# scale(fouls_committed)            -4.0473      1.180     -3.429      0.001      -6.370      -1.725
# scale(cards_yellow)                1.1085      1.194      0.929      0.354      -1.241       3.458
# scale(cards_yellowred)             1.2428      0.939      1.324      0.187      -0.605       3.090
# scale(cards_red)                   1.7397      0.913      1.906      0.058      -0.056       3.536
# scale(penalty_won)                 2.8072      1.141      2.461      0.014       0.563       5.052
# scale(penalty_commited)           -1.4993      1.039     -1.443      0.150      -3.544       0.545
# scale(penalty_success)            -1.8336      1.311     -1.398      0.163      -4.414       0.747
# scale(penalty_missed)              1.0702      1.110      0.965      0.336      -1.113       3.254
# scale(games_lineups)               4.8482      1.557      3.114      0.002       1.784       7.912
# scale(substitutes_out)            -3.9150      1.340     -2.921      0.004      -6.553      -1.277
# scale(substitutes_bench)           1.6049      1.440      1.115      0.266      -1.228       4.438
# scale(age_x)                      -5.1297      1.192     -4.303      0.000      -7.476      -2.784
# scale(height_x)                   -1.4691      1.324     -1.110      0.268      -4.074       1.136
# scale(weight_x)                    2.5869      1.345      1.923      0.055      -0.060       5.234
# scale(shotsOnTotal_goalsTotal)     7.8043      1.760      4.435      0.000       4.341      11.268
# scale(duelsWonTotal)               1.6038      1.104      1.453      0.147      -0.569       3.776
# scale(dribblesAtmptsSuc)           2.6396      1.361      1.939      0.053      -0.040       5.319
# ==============================================================================
# Omnibus:                      170.187   Durbin-Watson:                   1.853
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1452.466
# Skew:                           2.042   Prob(JB):                         0.00
# Kurtosis:                      12.623   Cond. No.                         5.34
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 학습 R2 = 0.31422294, 검증 R2 = 0.26383951
# 학습 R2 = 0.33579061, 검증 R2 = 0.15848785
# 학습 R2 = 0.33976308, 검증 R2 = -0.02347233
# 학습 R2 = 0.30608031, 검증 R2 = 0.37942592
# 학습 R2 = 0.32965251, 검증 R2 = 0.11905584
# 학습 R2 = 0.35423352, 검증 R2 = -1.23536388
# 학습 R2 = 0.34256907, 검증 R2 = 0.04138432
# 학습 R2 = 0.29978691, 검증 R2 = 0.54852364
# 학습 R2 = 0.33130095, 검증 R2 = 0.00795359
# 학습 R2 = 0.32710373, 검증 R2 = 0.24422576
# 모델 성능 : 0.050406021422247885

# %% [markdown]
# # OLS - 6

# %%
df_ols_f_6 = df_ols_f_5.drop(['tackles_interceptions'], axis=1)
len(df_ols_f_6.columns)
# Out:
# 21

# %%
from sklearn.model_selection import train_test_split

df_ols = df_ols_f_6
dfX = df_ols.drop(['value'], axis=1)
dfy = df_ols['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

formula = "value ~ " + "+".join(feature_names)

model = sm.OLS.from_formula(formula, data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula(formula, data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.351
# Model:                            OLS   Adj. R-squared:                  0.307
# Method:                 Least Squares   F-statistic:                     8.044
# Date:                Mon, 29 Jun 2020   Prob (F-statistic):           1.40e-18
# Time:                        15:40:33   Log-Likelihood:                -1320.8
# No. Observations:                 319   AIC:                             2684.
# Df Residuals:                     298   BIC:                             2763.
# Df Model:                          20
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                         31.7335      0.881     36.033      0.000      30.000      33.467
# scale(follower)                    4.4562      1.053      4.230      0.000       2.383       6.529
# scale(passes_total)                5.7556      1.164      4.946      0.000       3.465       8.046
# scale(fouls_drawn)                -1.9783      1.301     -1.521      0.129      -4.539       0.582
# scale(fouls_committed)            -4.1696      1.171     -3.561      0.000      -6.474      -1.865
# scale(cards_yellow)                0.9963      1.186      0.840      0.402      -1.338       3.330
# scale(cards_yellowred)             1.1970      0.937      1.278      0.202      -0.647       3.041
# scale(cards_red)                   1.7803      0.911      1.954      0.052      -0.013       3.573
# scale(penalty_won)                 2.7549      1.138      2.420      0.016       0.515       4.995
# scale(penalty_commited)           -1.6121      1.030     -1.565      0.119      -3.639       0.415
# scale(penalty_success)            -1.8110      1.311     -1.382      0.168      -4.390       0.768
# scale(penalty_missed)              1.1389      1.106      1.030      0.304      -1.038       3.316
# scale(games_lineups)               4.4131      1.471      2.999      0.003       1.517       7.309
# scale(substitutes_out)            -3.5715      1.279     -2.793      0.006      -6.088      -1.055
# scale(substitutes_bench)           1.0675      1.296      0.824      0.411      -1.482       3.617
# scale(age_x)                      -5.1211      1.191     -4.298      0.000      -7.466      -2.776
# scale(height_x)                   -1.3606      1.317     -1.033      0.302      -3.952       1.231
# scale(weight_x)                    2.5146      1.342      1.874      0.062      -0.126       5.155
# scale(shotsOnTotal_goalsTotal)     8.1651      1.708      4.780      0.000       4.804      11.527
# scale(duelsWonTotal)               1.4937      1.096      1.363      0.174      -0.663       3.651
# scale(dribblesAtmptsSuc)           2.6484      1.361      1.946      0.053      -0.029       5.326
# ==============================================================================
# Omnibus:                      170.307   Durbin-Watson:                   1.854
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1449.518
# Skew:                           2.045   Prob(JB):                         0.00
# Kurtosis:                      12.609   Cond. No.                         4.76
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 학습 R2 = 0.31132887, 검증 R2 = 0.27741403
# 학습 R2 = 0.33575800, 검증 R2 = 0.15673487
# 학습 R2 = 0.33887463, 검증 R2 = -0.01989792
# 학습 R2 = 0.30518968, 검증 R2 = 0.38027031
# 학습 R2 = 0.32852367, 검증 R2 = 0.13516724
# 학습 R2 = 0.35355260, 검증 R2 = -1.14873656
# 학습 R2 = 0.34256818, 검증 R2 = 0.04211203
# 학습 R2 = 0.29904916, 검증 R2 = 0.54804877
# 학습 R2 = 0.33013797, 검증 R2 = 0.01882685
# 학습 R2 = 0.32560278, 검증 R2 = 0.25186242
# 모델 성능 : 0.06418020402046296

# %% [markdown]
# # OLS - 7

# %%
df_ols_f_7 = df_ols_f_6.drop(['substitutes_bench'], axis=1)
len(df_ols_f_7.columns)
# Out:
# 21

# %%
from sklearn.model_selection import train_test_split

df_ols = df_ols_f_7
dfX = df_ols.drop(['value'], axis=1)
dfy = df_ols['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

formula = "value ~ " + "+".join(feature_names)

model = sm.OLS.from_formula(formula, data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula(formula, data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.349
# Model:                            OLS   Adj. R-squared:                  0.308
# Method:                 Least Squares   F-statistic:                     8.441
# Date:                Mon, 29 Jun 2020   Prob (F-statistic):           6.39e-19
# Time:                        15:42:28   Log-Likelihood:                -1321.2
# No. Observations:                 319   AIC:                             2682.
# Df Residuals:                     299   BIC:                             2758.
# Df Model:                          19
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                         31.7335      0.880     36.052      0.000      30.001      33.466
# scale(follower)                    4.4827      1.052      4.260      0.000       2.412       6.554
# scale(passes_total)                5.8051      1.162      4.998      0.000       3.519       8.091
# scale(fouls_drawn)                -1.9519      1.300     -1.502      0.134      -4.510       0.606
# scale(fouls_committed)            -4.1176      1.169     -3.523      0.000      -6.417      -1.818
# scale(cards_yellow)                0.9104      1.181      0.771      0.441      -1.413       3.234
# scale(cards_yellowred)             1.2211      0.936      1.305      0.193      -0.621       3.063
# scale(cards_red)                   1.8212      0.909      2.003      0.046       0.032       3.610
# scale(penalty_won)                 2.7278      1.137      2.399      0.017       0.490       4.966
# scale(penalty_commited)           -1.5786      1.029     -1.535      0.126      -3.603       0.446
# scale(penalty_success)            -1.7940      1.310     -1.370      0.172      -4.371       0.783
# scale(penalty_missed)              1.1750      1.105      1.064      0.288      -0.999       3.349
# scale(games_lineups)               3.5704      1.057      3.377      0.001       1.490       5.651
# scale(substitutes_out)            -3.3360      1.246     -2.678      0.008      -5.787      -0.885
# scale(age_x)                      -5.0064      1.183     -4.233      0.000      -7.334      -2.679
# scale(height_x)                   -1.2237      1.306     -0.937      0.349      -3.793       1.346
# scale(weight_x)                    2.5269      1.341      1.884      0.060      -0.112       5.166
# scale(shotsOnTotal_goalsTotal)     7.9766      1.692      4.715      0.000       4.647      11.306
# scale(duelsWonTotal)               1.4507      1.094      1.326      0.186      -0.703       3.604
# scale(dribblesAtmptsSuc)           2.6540      1.360      1.952      0.052      -0.022       5.330
# ==============================================================================
# Omnibus:                      171.172   Durbin-Watson:                   1.843
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1462.460
# Skew:                           2.057   Prob(JB):                         0.00
# Kurtosis:                      12.649   Cond. No.                         4.44
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 학습 R2 = 0.31048395, 검증 R2 = 0.27765704
# 학습 R2 = 0.33522273, 검증 R2 = 0.15552827
# 학습 R2 = 0.33787031, 검증 R2 = -0.01301087
# 학습 R2 = 0.30435243, 검증 R2 = 0.38128121
# 학습 R2 = 0.32597282, 검증 R2 = 0.20295158
# 학습 R2 = 0.35294809, 검증 R2 = -0.93622633
# 학습 R2 = 0.34209213, 검증 R2 = 0.03854287
# 학습 R2 = 0.29809515, 검증 R2 = 0.55101929
# 학습 R2 = 0.32960225, 검증 R2 = 0.01585951
# 학습 R2 = 0.32550358, 검증 R2 = 0.24845740
# 모델 성능 : 0.0922059964333002

# %% [markdown]
# # OLS - 8

# %%
df_ols_f_8 = df_ols_f_7.drop(['cards_yellow'], axis=1)
len(df_ols_f_8.columns)
# Out:
# 19

# %%
from sklearn.model_selection import train_test_split

df_ols = df_ols_f_8
dfX = df_ols.drop(['value'], axis=1)
dfy = df_ols['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

formula = "value ~ " + "+".join(feature_names)

model = sm.OLS.from_formula(formula, data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula(formula, data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.348
# Model:                            OLS   Adj. R-squared:                  0.309
# Method:                 Least Squares   F-statistic:                     8.888
# Date:                Mon, 29 Jun 2020   Prob (F-statistic):           2.73e-19
# Time:                        15:43:16   Log-Likelihood:                -1321.5
# No. Observations:                 319   AIC:                             2681.
# Df Residuals:                     300   BIC:                             2752.
# Df Model:                          18
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                         31.7335      0.880     36.077      0.000      30.003      33.465
# scale(follower)                    4.5740      1.045      4.377      0.000       2.518       6.630
# scale(passes_total)                5.7070      1.154      4.946      0.000       3.436       7.978
# scale(fouls_drawn)                -1.7647      1.276     -1.383      0.168      -4.276       0.747
# scale(fouls_committed)            -3.7085      1.041     -3.564      0.000      -5.756      -1.661
# scale(cards_yellowred)             1.3462      0.921      1.461      0.145      -0.467       3.159
# scale(cards_red)                   1.9286      0.898      2.148      0.032       0.162       3.695
# scale(penalty_won)                 2.7215      1.136      2.395      0.017       0.485       4.958
# scale(penalty_commited)           -1.5245      1.026     -1.486      0.138      -3.543       0.494
# scale(penalty_success)            -1.8397      1.307     -1.407      0.160      -4.413       0.733
# scale(penalty_missed)              1.1894      1.104      1.078      0.282      -0.983       3.361
# scale(games_lineups)               3.6125      1.055      3.424      0.001       1.536       5.689
# scale(substitutes_out)            -3.3607      1.244     -2.701      0.007      -5.810      -0.912
# scale(age_x)                      -4.9432      1.179     -4.193      0.000      -7.264      -2.623
# scale(height_x)                   -1.0944      1.294     -0.846      0.398      -3.641       1.452
# scale(weight_x)                    2.4150      1.332      1.813      0.071      -0.207       5.037
# scale(shotsOnTotal_goalsTotal)     7.6822      1.647      4.664      0.000       4.441      10.923
# scale(duelsWonTotal)               1.4022      1.092      1.284      0.200      -0.746       3.551
# scale(dribblesAtmptsSuc)           2.5154      1.347      1.867      0.063      -0.136       5.166
# ==============================================================================
# Omnibus:                      170.783   Durbin-Watson:                   1.852
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1458.730
# Skew:                           2.051   Prob(JB):                         0.00
# Kurtosis:                      12.640   Cond. No.                         4.27
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 학습 R2 = 0.30744900, 검증 R2 = 0.27365517
# 학습 R2 = 0.33313120, 검증 R2 = 0.14613971
# 학습 R2 = 0.33493718, 검증 R2 = -0.02135443
# 학습 R2 = 0.30161766, 검증 R2 = 0.37637903
# 학습 R2 = 0.32306237, 검증 R2 = 0.19579995
# 학습 R2 = 0.34964476, 검증 R2 = -0.98936836
# 학습 R2 = 0.33902235, 검증 R2 = 0.03185352
# 학습 R2 = 0.29468123, 검증 R2 = 0.54798895
# 학습 R2 = 0.32615296, 검증 R2 = 0.01495445
# 학습 R2 = 0.32230236, 검증 R2 = 0.24649362
# 모델 성능 : 0.08225416139488813

# %% [markdown]
# # OLS - 9

# %%
df_ols_f_9 = df_ols_f_8.drop(['height_x'], axis=1)
len(df_ols_f_9.columns)
# Out:
# 18

# %%
from sklearn.model_selection import train_test_split

df_ols = df_ols_f_9
dfX = df_ols.drop(['value'], axis=1)
dfy = df_ols['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

formula = "value ~ " + "+".join(feature_names)

model = sm.OLS.from_formula(formula, data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula(formula, data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.346
# Model:                            OLS   Adj. R-squared:                  0.309
# Method:                 Least Squares   F-statistic:                     9.378
# Date:                Mon, 29 Jun 2020   Prob (F-statistic):           1.20e-19
# Time:                        15:45:44   Log-Likelihood:                -1321.9
# No. Observations:                 319   AIC:                             2680.
# Df Residuals:                     301   BIC:                             2747.
# Df Model:                          17
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                         31.7335      0.879     36.094      0.000      30.003      33.464
# scale(follower)                    4.5732      1.044      4.379      0.000       2.518       6.628
# scale(passes_total)                5.6392      1.150      4.902      0.000       3.375       7.903
# scale(fouls_drawn)                -1.7115      1.274     -1.343      0.180      -4.219       0.796
# scale(fouls_committed)            -3.7128      1.040     -3.570      0.000      -5.760      -1.666
# scale(cards_yellowred)             1.3158      0.920      1.430      0.154      -0.495       3.126
# scale(cards_red)                   1.9834      0.895      2.216      0.027       0.222       3.745
# scale(penalty_won)                 2.6675      1.134      2.352      0.019       0.436       4.899
# scale(penalty_commited)           -1.4167      1.017     -1.393      0.165      -3.418       0.585
# scale(penalty_success)            -1.8052      1.306     -1.382      0.168      -4.376       0.765
# scale(penalty_missed)              1.1953      1.103      1.083      0.279      -0.976       3.366
# scale(games_lineups)               3.4868      1.044      3.340      0.001       1.432       5.541
# scale(substitutes_out)            -3.3879      1.243     -2.725      0.007      -5.835      -0.941
# scale(age_x)                      -4.9438      1.179     -4.195      0.000      -7.263      -2.625
# scale(weight_x)                    1.6567      0.985      1.682      0.094      -0.281       3.595
# scale(shotsOnTotal_goalsTotal)     7.6805      1.646      4.665      0.000       4.441      10.920
# scale(duelsWonTotal)               1.4481      1.090      1.329      0.185      -0.697       3.593
# scale(dribblesAtmptsSuc)           2.5476      1.346      1.893      0.059      -0.101       5.196
# ==============================================================================
# Omnibus:                      170.708   Durbin-Watson:                   1.850
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1447.344
# Skew:                           2.053   Prob(JB):                         0.00
# Kurtosis:                      12.594   Cond. No.                         4.26
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 학습 R2 = 0.30449020, 검증 R2 = 0.27739594
# 학습 R2 = 0.33164432, 검증 R2 = 0.14273723
# 학습 R2 = 0.33391140, 검증 R2 = -0.03747322
# 학습 R2 = 0.29757004, 검증 R2 = 0.39151340
# 학습 R2 = 0.32249240, 검증 R2 = 0.17556344
# 학습 R2 = 0.34806331, 검증 R2 = -0.99975296
# 학습 R2 = 0.33751563, 검증 R2 = 0.02093453
# 학습 R2 = 0.29203084, 검증 R2 = 0.55519735
# 학습 R2 = 0.32415065, 검증 R2 = 0.01660707
# 학습 R2 = 0.32069390, 검증 R2 = 0.24216199
# 모델 성능 : 0.078488476965344

# %% [markdown]
# # OLS - 10

# %%
df_ols_f_10 = df_ols_f_9.drop(['penalty_missed'], axis=1)
len(df_ols_f_10.columns)
# Out:
# 17

# %%
from sklearn.model_selection import train_test_split

df_ols = df_ols_f_10
dfX = df_ols.drop(['value'], axis=1)
dfy = df_ols['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

formula = "value ~ " + "+".join(feature_names)

model = sm.OLS.from_formula(formula, data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula(formula, data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.344
# Model:                            OLS   Adj. R-squared:                  0.309
# Method:                 Least Squares   F-statistic:                     9.885
# Date:                Mon, 29 Jun 2020   Prob (F-statistic):           6.37e-20
# Time:                        15:46:44   Log-Likelihood:                -1322.5
# No. Observations:                 319   AIC:                             2679.
# Df Residuals:                     302   BIC:                             2743.
# Df Model:                          16
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                         31.7335      0.879     36.084      0.000      30.003      33.464
# scale(follower)                    4.4282      1.036      4.274      0.000       2.389       6.467
# scale(passes_total)                5.4634      1.139      4.795      0.000       3.221       7.705
# scale(fouls_drawn)                -1.6525      1.273     -1.298      0.195      -4.158       0.853
# scale(fouls_committed)            -3.7380      1.040     -3.594      0.000      -5.785      -1.691
# scale(cards_yellowred)             1.2737      0.919      1.385      0.167      -0.536       3.083
# scale(cards_red)                   1.9731      0.895      2.204      0.028       0.211       3.735
# scale(penalty_won)                 2.4677      1.119      2.205      0.028       0.265       4.671
# scale(penalty_commited)           -1.3552      1.016     -1.334      0.183      -3.354       0.644
# scale(penalty_success)            -1.3322      1.231     -1.082      0.280      -3.756       1.091
# scale(games_lineups)               3.5030      1.044      3.355      0.001       1.448       5.558
# scale(substitutes_out)            -3.4639      1.242     -2.789      0.006      -5.908      -1.020
# scale(age_x)                      -4.7748      1.168     -4.086      0.000      -7.074      -2.475
# scale(weight_x)                    1.6268      0.985      1.652      0.100      -0.311       3.564
# scale(shotsOnTotal_goalsTotal)     8.0264      1.615      4.968      0.000       4.847      11.205
# scale(duelsWonTotal)               1.4575      1.090      1.337      0.182      -0.688       3.603
# scale(dribblesAtmptsSuc)           2.5677      1.346      1.907      0.057      -0.081       5.217
# ==============================================================================
# Omnibus:                      167.866   Durbin-Watson:                   1.850
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1384.817
# Skew:                           2.019   Prob(JB):                    1.95e-301
# Kurtosis:                      12.374   Cond. No.                         4.15
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 학습 R2 = 0.30141385, 검증 R2 = 0.29441599
# 학습 R2 = 0.33102845, 검증 R2 = 0.14295970
# 학습 R2 = 0.33390322, 검증 R2 = -0.03939417
# 학습 R2 = 0.29737599, 검증 R2 = 0.39043568
# 학습 R2 = 0.32158803, 검증 R2 = 0.18433963
# 학습 R2 = 0.34790457, 검증 R2 = -1.00737229
# 학습 R2 = 0.33684621, 검증 R2 = 0.02495729
# 학습 R2 = 0.29175380, 검증 R2 = 0.55440920
# 학습 R2 = 0.32391299, 검증 R2 = 0.01244521
# 학습 R2 = 0.32057300, 검증 R2 = 0.23995295
# 모델 성능 : 0.07971491984363697

# %% [markdown]
# # OLS - 11

# %%
df_ols_f_11 = df_ols_f_10.drop(['penalty_success'], axis=1)
len(df_ols_f_11.columns)
# Out:
# 16

# %%
from sklearn.model_selection import train_test_split

df_ols = df_ols_f_11
dfX = df_ols.drop(['value'], axis=1)
dfy = df_ols['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

formula = "value ~ " + "+".join(feature_names)

model = sm.OLS.from_formula(formula, data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula(formula, data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.341
# Model:                            OLS   Adj. R-squared:                  0.309
# Method:                 Least Squares   F-statistic:                     10.46
# Date:                Mon, 29 Jun 2020   Prob (F-statistic):           3.27e-20
# Time:                        15:47:23   Log-Likelihood:                -1323.1
# No. Observations:                 319   AIC:                             2678.
# Df Residuals:                     303   BIC:                             2738.
# Df Model:                          15
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                         31.7335      0.880     36.073      0.000      30.002      33.465
# scale(follower)                    4.2005      1.015      4.139      0.000       2.204       6.197
# scale(passes_total)                5.4372      1.139      4.772      0.000       3.195       7.679
# scale(fouls_drawn)                -1.6598      1.274     -1.303      0.193      -4.166       0.846
# scale(fouls_committed)            -3.6427      1.037     -3.514      0.001      -5.683      -1.603
# scale(cards_yellowred)             1.2963      0.920      1.410      0.160      -0.513       3.106
# scale(cards_red)                   1.9567      0.895      2.185      0.030       0.195       3.719
# scale(penalty_won)                 2.2022      1.092      2.016      0.045       0.052       4.352
# scale(penalty_commited)           -1.3875      1.016     -1.366      0.173      -3.386       0.611
# scale(games_lineups)               3.4871      1.044      3.339      0.001       1.432       5.542
# scale(substitutes_out)            -3.3820      1.240     -2.728      0.007      -5.822      -0.942
# scale(age_x)                      -4.9277      1.160     -4.247      0.000      -7.211      -2.645
# scale(weight_x)                    1.6591      0.985      1.685      0.093      -0.278       3.596
# scale(shotsOnTotal_goalsTotal)     7.2965      1.468      4.969      0.000       4.407      10.186
# scale(duelsWonTotal)               1.4580      1.090      1.337      0.182      -0.688       3.604
# scale(dribblesAtmptsSuc)           2.8293      1.325      2.136      0.033       0.223       5.436
# ==============================================================================
# Omnibus:                      176.410   Durbin-Watson:                   1.840
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1609.597
# Skew:                           2.113   Prob(JB):                         0.00
# Kurtosis:                      13.161   Cond. No.                         3.77
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 학습 R2 = 0.29690348, 검증 R2 = 0.29273495
# 학습 R2 = 0.32878915, 검증 R2 = 0.13075218
# 학습 R2 = 0.32934329, 검증 R2 = -0.02643063
# 학습 R2 = 0.29491107, 검증 R2 = 0.37940251
# 학습 R2 = 0.31517830, 검증 R2 = 0.22973463
# 학습 R2 = 0.34446081, 검증 R2 = -1.04015795
# 학습 R2 = 0.33396789, 검증 R2 = 0.01146235
# 학습 R2 = 0.28669923, 검증 R2 = 0.56898091
# 학습 R2 = 0.32134733, 검증 R2 = -0.01747740
# 학습 R2 = 0.31669749, 검증 R2 = 0.23706841
# 모델 성능 : 0.07660699595703338

# %% [markdown]
# # OLS - 12

# %%
df_ols_f_12 = df_ols_f_11.drop(['fouls_drawn'], axis=1)
len(df_ols_f_12.columns)
# Out:
# 15

# %%
from sklearn.model_selection import train_test_split

df_ols = df_ols_f_12
dfX = df_ols.drop(['value'], axis=1)
dfy = df_ols['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

formula = "value ~ " + "+".join(feature_names)

model = sm.OLS.from_formula(formula, data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula(formula, data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.337
# Model:                            OLS   Adj. R-squared:                  0.307
# Method:                 Least Squares   F-statistic:                     11.06
# Date:                Mon, 29 Jun 2020   Prob (F-statistic):           2.09e-20
# Time:                        15:48:07   Log-Likelihood:                -1324.0
# No. Observations:                 319   AIC:                             2678.
# Df Residuals:                     304   BIC:                             2734.
# Df Model:                          14
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                         31.7335      0.881     36.032      0.000      30.000      33.467
# scale(follower)                    4.1327      1.015      4.073      0.000       2.136       6.129
# scale(passes_total)                5.3564      1.139      4.703      0.000       3.115       7.598
# scale(fouls_committed)            -4.0817      0.982     -4.158      0.000      -6.013      -2.150
# scale(cards_yellowred)             1.1813      0.916      1.289      0.198      -0.622       2.984
# scale(cards_red)                   1.9281      0.896      2.152      0.032       0.165       3.692
# scale(penalty_won)                 2.0204      1.085      1.862      0.063      -0.114       4.155
# scale(penalty_commited)           -1.1927      1.006     -1.186      0.237      -3.172       0.787
# scale(games_lineups)               3.2682      1.032      3.167      0.002       1.238       5.299
# scale(substitutes_out)            -3.3116      1.240     -2.670      0.008      -5.752      -0.871
# scale(age_x)                      -4.7431      1.153     -4.114      0.000      -7.012      -2.475
# scale(weight_x)                    1.7892      0.981      1.825      0.069      -0.140       3.719
# scale(shotsOnTotal_goalsTotal)     7.1266      1.464      4.867      0.000       4.245      10.008
# scale(duelsWonTotal)               1.0752      1.051      1.023      0.307      -0.994       3.144
# scale(dribblesAtmptsSuc)           2.2304      1.244      1.793      0.074      -0.217       4.678
# ==============================================================================
# Omnibus:                      180.713   Durbin-Watson:                   1.845
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1701.934
# Skew:                           2.169   Prob(JB):                         0.00
# Kurtosis:                      13.451   Cond. No.                         3.55
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 학습 R2 = 0.29028720, 검증 R2 = 0.26104864
# 학습 R2 = 0.32271475, 검증 R2 = 0.09099239
# 학습 R2 = 0.31227793, 검증 R2 = 0.06298898
# 학습 R2 = 0.28208389, 검증 R2 = 0.36929614
# 학습 R2 = 0.29965489, 검증 R2 = 0.27874249
# 학습 R2 = 0.32924314, 검증 R2 = -0.98183926
# 학습 R2 = 0.32175184, 검증 R2 = 0.00418821
# 학습 R2 = 0.27103993, 검증 R2 = 0.59958788
# 학습 R2 = 0.30881116, 검증 R2 = -0.02275063
# 학습 R2 = 0.30655622, 검증 R2 = 0.20619524
# 모델 성능 : 0.08684500785358526

# %% [markdown]
# # OLS - 13

# %%
df_ols_f_13 = df_ols_f_12.drop(['duelsWonTotal'], axis=1)
len(df_ols_f_13.columns)
# Out:
# 14

# %%
from sklearn.model_selection import train_test_split

df_ols = df_ols_f_13
dfX = df_ols.drop(['value'], axis=1)
dfy = df_ols['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

formula = "value ~ " + "+".join(feature_names)

model = sm.OLS.from_formula(formula, data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula(formula, data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.335
# Model:                            OLS   Adj. R-squared:                  0.307
# Method:                 Least Squares   F-statistic:                     11.83
# Date:                Mon, 29 Jun 2020   Prob (F-statistic):           9.57e-21
# Time:                        15:49:15   Log-Likelihood:                -1324.5
# No. Observations:                 319   AIC:                             2677.
# Df Residuals:                     305   BIC:                             2730.
# Df Model:                          13
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                         31.7335      0.881     36.029      0.000      30.000      33.467
# scale(follower)                    4.0758      1.013      4.023      0.000       2.082       6.070
# scale(passes_total)                5.4165      1.138      4.762      0.000       3.178       7.655
# scale(fouls_committed)            -3.8788      0.961     -4.034      0.000      -5.771      -1.987
# scale(cards_yellowred)             1.1525      0.916      1.258      0.209      -0.650       2.955
# scale(cards_red)                   1.9435      0.896      2.169      0.031       0.180       3.707
# scale(penalty_won)                 2.1530      1.077      1.999      0.047       0.034       4.272
# scale(penalty_commited)           -1.1724      1.006     -1.166      0.245      -3.151       0.807
# scale(games_lineups)               3.0358      1.007      3.016      0.003       1.055       5.017
# scale(substitutes_out)            -3.4542      1.232     -2.803      0.005      -5.879      -1.029
# scale(age_x)                      -4.4822      1.124     -3.986      0.000      -6.695      -2.270
# scale(weight_x)                    1.8871      0.976      1.934      0.054      -0.033       3.808
# scale(shotsOnTotal_goalsTotal)     6.9889      1.458      4.793      0.000       4.120       9.858
# scale(dribblesAtmptsSuc)           2.7525      1.134      2.426      0.016       0.520       4.985
# ==============================================================================
# Omnibus:                      178.713   Durbin-Watson:                   1.838
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1642.889
# Skew:                           2.147   Prob(JB):                         0.00
# Kurtosis:                      13.255   Cond. No.                         3.44
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 학습 R2 = 0.28648565, 검증 R2 = 0.27097768
# 학습 R2 = 0.32127003, 검증 R2 = 0.08742547
# 학습 R2 = 0.31125821, 검증 R2 = 0.05101638
# 학습 R2 = 0.27932891, 검증 R2 = 0.37387759
# 학습 R2 = 0.29748516, 검증 R2 = 0.28494265
# 학습 R2 = 0.32806265, 검증 R2 = -0.98634441
# 학습 R2 = 0.32104757, 검증 R2 = -0.00714280
# 학습 R2 = 0.26931731, 검증 R2 = 0.59787170
# 학습 R2 = 0.30769981, 검증 R2 = -0.03745406
# 학습 R2 = 0.30329882, 검증 R2 = 0.22080298
# 모델 성능 : 0.08559731680234946

# %%
# OLS - 14

# %%
df_ols_f_14 = df_ols_f_13.drop(['penalty_commited'], axis=1)
len(df_ols_f_14.columns)
# Out:
# 13

# %%
from sklearn.model_selection import train_test_split

df_ols = df_ols_f_14
dfX = df_ols.drop(['value'], axis=1)
dfy = df_ols['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

formula = "value ~ " + "+".join(feature_names)

model = sm.OLS.from_formula(formula, data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula(formula, data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.332
# Model:                            OLS   Adj. R-squared:                  0.306
# Method:                 Least Squares   F-statistic:                     12.69
# Date:                Mon, 29 Jun 2020   Prob (F-statistic):           4.90e-21
# Time:                        15:49:53   Log-Likelihood:                -1325.2
# No. Observations:                 319   AIC:                             2676.
# Df Residuals:                     306   BIC:                             2725.
# Df Model:                          12
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                         31.7335      0.881     36.008      0.000      29.999      33.468
# scale(follower)                    4.0986      1.014      4.044      0.000       2.104       6.093
# scale(passes_total)                5.4178      1.138      4.760      0.000       3.178       7.658
# scale(fouls_committed)            -3.9257      0.961     -4.084      0.000      -5.817      -2.034
# scale(cards_yellowred)             1.1584      0.916      1.264      0.207      -0.645       2.962
# scale(cards_red)                   1.8876      0.895      2.108      0.036       0.126       3.649
# scale(penalty_won)                 2.1583      1.078      2.003      0.046       0.038       4.279
# scale(games_lineups)               2.8497      0.995      2.865      0.004       0.893       4.807
# scale(substitutes_out)            -3.0439      1.182     -2.576      0.010      -5.369      -0.719
# scale(age_x)                      -4.3539      1.120     -3.889      0.000      -6.557      -2.151
# scale(weight_x)                    1.9141      0.976      1.961      0.051      -0.007       3.835
# scale(shotsOnTotal_goalsTotal)     7.1930      1.448      4.966      0.000       4.343      10.043
# scale(dribblesAtmptsSuc)           2.7713      1.135      2.442      0.015       0.538       5.005
# ==============================================================================
# Omnibus:                      180.984   Durbin-Watson:                   1.799
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1691.114
# Skew:                           2.177   Prob(JB):                         0.00
# Kurtosis:                      13.406   Cond. No.                         3.29
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 학습 R2 = 0.28579003, 검증 R2 = 0.26758087
# 학습 R2 = 0.31838834, 검증 R2 = 0.09698281
# 학습 R2 = 0.30983402, 검증 R2 = 0.05275111
# 학습 R2 = 0.27826949, 검증 R2 = 0.37178201
# 학습 R2 = 0.29604932, 검증 R2 = 0.28715714
# 학습 R2 = 0.32711779, 검증 R2 = -0.99057918
# 학습 R2 = 0.31912717, 검증 R2 = 0.00115456
# 학습 R2 = 0.26779227, 검증 R2 = 0.59934831
# 학습 R2 = 0.30724059, 검증 R2 = -0.05176817
# 학습 R2 = 0.30249359, 검증 R2 = 0.21596332
# 모델 성능 : 0.08503727907219973

# %%
# OLS - 15

# %%
df_ols_f_15 = df_ols_f_14.drop(['cards_yellowred'], axis=1)
len(df_ols_f_15.columns)
# Out:
# 12

# %%
from sklearn.model_selection import train_test_split

df_ols = df_ols_f_15
dfX = df_ols.drop(['value'], axis=1)
dfy = df_ols['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

formula = "value ~ " + "+".join(feature_names)

model = sm.OLS.from_formula(formula, data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula(formula, data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.329
# Model:                            OLS   Adj. R-squared:                  0.305
# Method:                 Least Squares   F-statistic:                     13.67
# Date:                Mon, 29 Jun 2020   Prob (F-statistic):           2.71e-21
# Time:                        15:50:37   Log-Likelihood:                -1326.1
# No. Observations:                 319   AIC:                             2676.
# Df Residuals:                     307   BIC:                             2721.
# Df Model:                          11
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                         31.7335      0.882     35.973      0.000      29.998      33.469
# scale(follower)                    4.2352      1.009      4.198      0.000       2.250       6.220
# scale(passes_total)                5.3338      1.137      4.690      0.000       3.096       7.572
# scale(fouls_committed)            -3.7034      0.946     -3.915      0.000      -5.565      -1.842
# scale(cards_red)                   1.9176      0.896      2.140      0.033       0.155       3.680
# scale(penalty_won)                 2.0469      1.075      1.904      0.058      -0.069       4.162
# scale(games_lineups)               2.9470      0.993      2.969      0.003       0.994       4.900
# scale(substitutes_out)            -3.0989      1.182     -2.622      0.009      -5.425      -0.773
# scale(age_x)                      -4.3674      1.121     -3.897      0.000      -6.573      -2.162
# scale(weight_x)                    1.9085      0.977      1.953      0.052      -0.014       3.831
# scale(shotsOnTotal_goalsTotal)     7.0440      1.445      4.875      0.000       4.201       9.887
# scale(dribblesAtmptsSuc)           2.7649      1.136      2.434      0.016       0.530       5.000
# ==============================================================================
# Omnibus:                      176.428   Durbin-Watson:                   1.816
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1605.903
# Skew:                           2.114   Prob(JB):                         0.00
# Kurtosis:                      13.146   Cond. No.                         3.27
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 학습 R2 = 0.28578356, 검증 R2 = 0.26787495
# 학습 R2 = 0.31837422, 검증 R2 = 0.09748348
# 학습 R2 = 0.30940253, 검증 R2 = 0.07484323
# 학습 R2 = 0.27787513, 검증 R2 = 0.37505416
# 학습 R2 = 0.29553226, 검증 R2 = 0.29927131
# 학습 R2 = 0.32649275, 검증 R2 = -0.95841313
# 학습 R2 = 0.31897431, 검증 R2 = 0.00242199
# 학습 R2 = 0.26753188, 검증 R2 = 0.60273295
# 학습 R2 = 0.30721679, 검증 R2 = -0.05219179
# 학습 R2 = 0.30248505, 검증 R2 = 0.21569046
# 모델 성능 : 0.0924767619028491

# %%
# OLS - 16

# %%
df_ols_f_16 = df_ols_f_15.drop(['penalty_won'], axis=1)
len(df_ols_f_16.columns)
# Out:
# 11

# %%
from sklearn.model_selection import train_test_split

df_ols = df_ols_f_16
dfX = df_ols.drop(['value'], axis=1)
dfy = df_ols['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

formula = "value ~ " + "+".join(feature_names)

model = sm.OLS.from_formula(formula, data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula(formula, data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.321
# Model:                            OLS   Adj. R-squared:                  0.299
# Method:                 Least Squares   F-statistic:                     14.55
# Date:                Mon, 29 Jun 2020   Prob (F-statistic):           3.74e-21
# Time:                        16:15:07   Log-Likelihood:                -1327.9
# No. Observations:                 319   AIC:                             2678.
# Df Residuals:                     308   BIC:                             2719.
# Df Model:                          10
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                         31.7335      0.886     35.821      0.000      29.990      33.477
# scale(follower)                    4.1390      1.012      4.091      0.000       2.148       6.130
# scale(passes_total)                5.1098      1.136      4.498      0.000       2.874       7.345
# scale(fouls_committed)            -3.6286      0.949     -3.823      0.000      -5.496      -1.761
# scale(cards_red)                   1.8553      0.899      2.064      0.040       0.086       3.624
# scale(games_lineups)               2.9380      0.997      2.948      0.003       0.977       4.899
# scale(substitutes_out)            -3.1156      1.187     -2.625      0.009      -5.451      -0.780
# scale(age_x)                      -4.4715      1.124     -3.978      0.000      -6.683      -2.260
# scale(weight_x)                    1.9920      0.980      2.032      0.043       0.063       3.921
# scale(shotsOnTotal_goalsTotal)     8.0583      1.349      5.974      0.000       5.404      10.712
# scale(dribblesAtmptsSuc)           2.9276      1.138      2.573      0.011       0.689       5.166
# ==============================================================================
# Omnibus:                      178.736   Durbin-Watson:                   1.812
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1649.265
# Skew:                           2.146   Prob(JB):                         0.00
# Kurtosis:                      13.279   Cond. No.                         2.95
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 학습 R2 = 0.27439127, 검증 R2 = 0.26738486
# 학습 R2 = 0.31125435, 검증 R2 = 0.07064031
# 학습 R2 = 0.30041187, 검증 R2 = 0.05406539
# 학습 R2 = 0.27081513, 검증 R2 = 0.35185007
# 학습 R2 = 0.28523284, 검증 R2 = 0.30160404
# 학습 R2 = 0.31680024, 검증 R2 = -0.99650466
# 학습 R2 = 0.30644553, 검증 R2 = 0.03123218
# 학습 R2 = 0.25906812, 검증 R2 = 0.58044580
# 학습 R2 = 0.29550909, 검증 R2 = -0.01994819
# 학습 R2 = 0.29436768, 검증 R2 = 0.18938531
# 모델 성능 : 0.0830155103195836

# %%
from sklearn.model_selection import train_test_split

df_ols = df_ols_f_16
dfX = df_ols.drop(['value'], axis=1)
dfy = df_ols['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

formula = "value ~ scale(follower) + scale(I(follower**2)) + \
                scale(passes_total) + \
                scale(fouls_committed) + \
                scale(cards_red) + \
                scale(games_lineups) + \
                scale(substitutes_out) + \
                scale(age_x) + \
                scale(weight_x) + \
                scale(shotsOnTotal_goalsTotal) + \
                scale(dribblesAtmptsSuc)"

model = sm.OLS.from_formula(formula, data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(3)
cv = KFold(3, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula(formula, data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
#    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.426
# Model:                            OLS   Adj. R-squared:                  0.405
# Method:                 Least Squares   F-statistic:                     20.71
# Date:                Mon, 29 Jun 2020   Prob (F-statistic):           3.16e-31
# Time:                        16:48:34   Log-Likelihood:                -1301.1
# No. Observations:                 319   AIC:                             2626.
# Df Residuals:                     307   BIC:                             2671.
# Df Model:                          11
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                         31.7335      0.816     38.900      0.000      30.128      33.339
# scale(follower)                   22.1857      2.581      8.597      0.000      17.108      27.264
# scale(I(follower ** 2))          -18.2431      2.433     -7.499      0.000     -23.030     -13.456
# scale(passes_total)                3.8487      1.060      3.632      0.000       1.764       5.934
# scale(fouls_committed)            -2.8872      0.880     -3.283      0.001      -4.618      -1.157
# scale(cards_red)                   1.5941      0.829      1.924      0.055      -0.036       3.225
# scale(games_lineups)               2.8849      0.918      3.143      0.002       1.079       4.691
# scale(substitutes_out)            -2.7010      1.094     -2.468      0.014      -4.855      -0.547
# scale(age_x)                      -4.9357      1.037     -4.760      0.000      -6.976      -2.895
# scale(weight_x)                    2.1031      0.903      2.329      0.020       0.327       3.880
# scale(shotsOnTotal_goalsTotal)     6.3015      1.264      4.985      0.000       3.814       8.789
# scale(dribblesAtmptsSuc)           1.8289      1.058      1.729      0.085      -0.253       3.910
# ==============================================================================
# Omnibus:                      145.899   Durbin-Watson:                   1.832
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              868.854
# Skew:                           1.813   Prob(JB):                    2.14e-189
# Kurtosis:                      10.226   Cond. No.                         6.74
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 모델 성능 : 0.3186820894643888

# %%
from sklearn.model_selection import train_test_split

df_ols = df_ols_nf_17
dfX = df_ols.drop(['value'], axis=1)
dfy = df_ols['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

formula = "value ~ scale(passes_total) + \
                scale(fouls_committed) + \
                scale(cards_red) + \
                scale(games_lineups) + \
                scale(substitutes_out) + \
                scale(age_x) + \
                scale(shotsOnTotal_goalsTotal) + scale(I(shotsOnTotal_goalsTotal**2)) + \
                scale(dribblesAtmptsSuc)"

model = sm.OLS.from_formula(formula, data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(3)
cv = KFold(3, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula(formula, data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
#    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.302
# Model:                            OLS   Adj. R-squared:                  0.282
# Method:                 Least Squares   F-statistic:                     14.85
# Date:                Mon, 29 Jun 2020   Prob (F-statistic):           5.00e-20
# Time:                        16:48:37   Log-Likelihood:                -1332.3
# No. Observations:                 319   AIC:                             2685.
# Df Residuals:                     309   BIC:                             2722.
# Df Model:                           9
# Covariance Type:            nonrobust
# ==========================================================================================================
#                                              coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------
# Intercept                                 31.7335      0.897     35.391      0.000      29.969      33.498
# scale(passes_total)                        5.3880      1.146      4.702      0.000       3.133       7.643
# scale(fouls_committed)                    -3.4955      0.944     -3.702      0.000      -5.353      -1.638
# scale(cards_red)                           2.1194      0.907      2.336      0.020       0.334       3.905
# scale(games_lineups)                       3.1723      1.011      3.138      0.002       1.183       5.161
# scale(substitutes_out)                    -3.5894      1.191     -3.013      0.003      -5.934      -1.245
# scale(age_x)                              -3.2800      1.091     -3.007      0.003      -5.427      -1.133
# scale(shotsOnTotal_goalsTotal)             6.4967      1.676      3.877      0.000       3.199       9.794
# scale(I(shotsOnTotal_goalsTotal ** 2))     4.1835      1.247      3.356      0.001       1.730       6.637
# scale(dribblesAtmptsSuc)                   4.4932      1.166      3.855      0.000       2.200       6.787
# ==============================================================================
# Omnibus:                      188.557   Durbin-Watson:                   1.820
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1699.573
# Skew:                           2.317   Prob(JB):                         0.00
# Kurtosis:                      13.315   Cond. No.                         3.63
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 모델 성능 : 0.205373973383963
