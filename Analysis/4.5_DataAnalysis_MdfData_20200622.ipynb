# %% [markdown]
# # 작업 데이터 받기

# %%
df_pos = pd.read_csv('df_pos.csv', encoding='utf-8-sig', index_col=0)

# %% [markdown]
# # Position Rounding

# %%
df_pos.position.unique()
# Out:
# array([2.        , 4.        , 3.        , 1.        , 3.33333333,
#        1.84615385, 3.43478261, 1.09090909, 3.29411765, 2.56818182,
#        2.25      , 2.4       , 3.75      , 3.2       , 1.66666667,
#        2.16666667, 2.91304348, 2.63636364, 3.76923077])

# %%
df_pos.position = df_pos.position.round()

# %%
df_mdf = df_pos[df_pos.position == 2]
df_mdf
# Out:
#       player_name  position   age  height  weight    rating  value  follower  \
# 0     A. Anguissa       2.0  25.0   184.0    78.0  2.333333   20.0     67879
# 4    A. Di MarÃ­a       2.0  32.0   180.0    75.0  4.833333   32.0  11513791
# 5    A. DoucourÃ©       2.0  27.0   184.0    75.0  4.666667   20.0     46206
# 6      A. Golovin       2.0  24.0   180.0    69.0  4.666667   20.0     11440
# 10       A. Harit       2.0  23.0   180.0    67.0  6.714286   24.0   1019540
# ..            ...       ...   ...     ...     ...       ...    ...       ...
# 357    V. Rongier       2.0  26.0   172.0    66.0  4.100000   16.0    170526
# 359    W. Barrios       2.0  27.0   178.0    74.0  6.000000   16.0    820996
# 362   W. McKennie       2.0  22.0   185.0    84.0  7.000000   20.0    152427
# 363      W. Ndidi       2.0  24.0   183.0    74.0  7.125000   36.0    529117
# 370  Y. Tielemans       2.0  23.0   176.0    72.0  4.384615   44.0    282254
#
#      shots_total  shots_on  ...  penalty_commited  penalty_success  \
# 0         0.5540    0.1288  ...            0.0000           0.0000
# 4         3.0823    1.1138  ...            0.0192           0.0096
# 5         1.5438    0.4384  ...            0.0191           0.0000
# 6         1.7539    0.6715  ...            0.0000           0.0000
# 10        1.2031    0.5363  ...            0.0000           0.0435
# ..           ...       ...  ...               ...              ...
# 357       1.8926    0.4423  ...            0.0000           0.0103
# 359       0.3110    0.0444  ...            0.0000           0.0000
# 362       1.1419    0.3217  ...            0.0161           0.0000
# 363       1.2701    0.2200  ...            0.0100           0.0000
# 370       1.6977    0.6011  ...            0.0000           0.0105
#
#      penalty_missed  penalty_saved  games_appearences  games_lineups  \
# 0            0.0000            0.0             1.4044         0.9277
# 4            0.0096            0.0             1.2003         1.0754
# 5            0.0000            0.0             1.0388         1.0006
# 6            0.0100            0.0             1.1024         1.0323
# 10           0.0000            0.0             1.2756         1.0002
# ..              ...            ...                ...            ...
# 357          0.0309            0.0             1.1211         1.0183
# 359          0.0000            0.0             1.0365         1.0217
# 362          0.0000            0.0             1.3831         0.9811
# 363          0.0000            0.0             1.0701         1.0001
# 370          0.0000            0.0             1.2021         1.0334
#
#      substitutes_in  substitutes_out  substitutes_bench  games_played
# 0            0.4767           0.2577             0.5927       77.6111
# 4            0.1248           0.5857             0.2401      104.1444
# 5            0.0381           0.1048             0.0381      104.9333
# 6            0.0702           0.3408             0.0702       99.7778
# 10           0.2754           0.4928             0.4638       68.9889
# ..              ...              ...                ...           ...
# 357          0.1029           0.2571             0.1337       97.2222
# 359          0.0148           0.1037             0.0296       67.5333
# 362          0.4021           0.3538             0.5147       62.1778
# 363          0.0700           0.1000             0.1000       99.9889
# 370          0.1687           0.3058             0.2636       94.8333
#
# [156 rows x 39 columns]

# %%
df_mdf.reset_index(drop=True)
# Out:
#       player_name  position   age  height  weight    rating  value  follower  \
# 0     A. Anguissa       2.0  25.0   184.0    78.0  2.333333   20.0     67879
# 1    A. Di MarÃ­a       2.0  32.0   180.0    75.0  4.833333   32.0  11513791
# 2    A. DoucourÃ©       2.0  27.0   184.0    75.0  4.666667   20.0     46206
# 3      A. Golovin       2.0  24.0   180.0    69.0  4.666667   20.0     11440
# 4        A. Harit       2.0  23.0   180.0    67.0  6.714286   24.0   1019540
# ..            ...       ...   ...     ...     ...       ...    ...       ...
# 151    V. Rongier       2.0  26.0   172.0    66.0  4.100000   16.0    170526
# 152    W. Barrios       2.0  27.0   178.0    74.0  6.000000   16.0    820996
# 153   W. McKennie       2.0  22.0   185.0    84.0  7.000000   20.0    152427
# 154      W. Ndidi       2.0  24.0   183.0    74.0  7.125000   36.0    529117
# 155  Y. Tielemans       2.0  23.0   176.0    72.0  4.384615   44.0    282254
#
#      shots_total  shots_on  ...  penalty_commited  penalty_success  \
# 0         0.5540    0.1288  ...            0.0000           0.0000
# 1         3.0823    1.1138  ...            0.0192           0.0096
# 2         1.5438    0.4384  ...            0.0191           0.0000
# 3         1.7539    0.6715  ...            0.0000           0.0000
# 4         1.2031    0.5363  ...            0.0000           0.0435
# ..           ...       ...  ...               ...              ...
# 151       1.8926    0.4423  ...            0.0000           0.0103
# 152       0.3110    0.0444  ...            0.0000           0.0000
# 153       1.1419    0.3217  ...            0.0161           0.0000
# 154       1.2701    0.2200  ...            0.0100           0.0000
# 155       1.6977    0.6011  ...            0.0000           0.0105
#
#      penalty_missed  penalty_saved  games_appearences  games_lineups  \
# 0            0.0000            0.0             1.4044         0.9277
# 1            0.0096            0.0             1.2003         1.0754
# 2            0.0000            0.0             1.0388         1.0006
# 3            0.0100            0.0             1.1024         1.0323
# 4            0.0000            0.0             1.2756         1.0002
# ..              ...            ...                ...            ...
# 151          0.0309            0.0             1.1211         1.0183
# 152          0.0000            0.0             1.0365         1.0217
# 153          0.0000            0.0             1.3831         0.9811
# 154          0.0000            0.0             1.0701         1.0001
# 155          0.0000            0.0             1.2021         1.0334
#
#      substitutes_in  substitutes_out  substitutes_bench  games_played
# 0            0.4767           0.2577             0.5927       77.6111
# 1            0.1248           0.5857             0.2401      104.1444
# 2            0.0381           0.1048             0.0381      104.9333
# 3            0.0702           0.3408             0.0702       99.7778
# 4            0.2754           0.4928             0.4638       68.9889
# ..              ...              ...                ...           ...
# 151          0.1029           0.2571             0.1337       97.2222
# 152          0.0148           0.1037             0.0296       67.5333
# 153          0.4021           0.3538             0.5147       62.1778
# 154          0.0700           0.1000             0.1000       99.9889
# 155          0.1687           0.3058             0.2636       94.8333
#
# [156 rows x 39 columns]

# %% [markdown]
# # 상관관계 확인

# %%
df_mdf.corr()[df_mdf.corr() > 0.7].to_csv('df_mdf_corr.csv', encoding='utf-8-sig')
df_mdf.corr()[df_mdf.corr() > 0.7]
# Out:
#                        position  age  height  weight  rating  value  follower  \
# position                    NaN  NaN     NaN     NaN     NaN    NaN       NaN
# age                         NaN  1.0     NaN     NaN     NaN    NaN       NaN
# height                      NaN  NaN     1.0     NaN     NaN    NaN       NaN
# weight                      NaN  NaN     NaN     1.0     NaN    NaN       NaN
# rating                      NaN  NaN     NaN     NaN     1.0    NaN       NaN
# value                       NaN  NaN     NaN     NaN     NaN    1.0       NaN
# follower                    NaN  NaN     NaN     NaN     NaN    NaN       1.0
# shots_total                 NaN  NaN     NaN     NaN     NaN    NaN       NaN
# shots_on                    NaN  NaN     NaN     NaN     NaN    NaN       NaN
# goals_total                 NaN  NaN     NaN     NaN     NaN    NaN       NaN
# goals_conceded              NaN  NaN     NaN     NaN     NaN    NaN       NaN
# goals_assists               NaN  NaN     NaN     NaN     NaN    NaN       NaN
# passes_total                NaN  NaN     NaN     NaN     NaN    NaN       NaN
# passes_key                  NaN  NaN     NaN     NaN     NaN    NaN       NaN
# passes_accuracy             NaN  NaN     NaN     NaN     NaN    NaN       NaN
# tackles_total               NaN  NaN     NaN     NaN     NaN    NaN       NaN
# tackles_blocks              NaN  NaN     NaN     NaN     NaN    NaN       NaN
# tackles_interceptions       NaN  NaN     NaN     NaN     NaN    NaN       NaN
# duels_total                 NaN  NaN     NaN     NaN     NaN    NaN       NaN
# duels_won                   NaN  NaN     NaN     NaN     NaN    NaN       NaN
# dribbles_attempts           NaN  NaN     NaN     NaN     NaN    NaN       NaN
# dribbles_success            NaN  NaN     NaN     NaN     NaN    NaN       NaN
# fouls_drawn                 NaN  NaN     NaN     NaN     NaN    NaN       NaN
# fouls_committed             NaN  NaN     NaN     NaN     NaN    NaN       NaN
# cards_yellow                NaN  NaN     NaN     NaN     NaN    NaN       NaN
# cards_yellowred             NaN  NaN     NaN     NaN     NaN    NaN       NaN
# cards_red                   NaN  NaN     NaN     NaN     NaN    NaN       NaN
# penalty_won                 NaN  NaN     NaN     NaN     NaN    NaN       NaN
# penalty_commited            NaN  NaN     NaN     NaN     NaN    NaN       NaN
# penalty_success             NaN  NaN     NaN     NaN     NaN    NaN       NaN
# penalty_missed              NaN  NaN     NaN     NaN     NaN    NaN       NaN
# penalty_saved               NaN  NaN     NaN     NaN     NaN    NaN       NaN
# games_appearences           NaN  NaN     NaN     NaN     NaN    NaN       NaN
# games_lineups               NaN  NaN     NaN     NaN     NaN    NaN       NaN
# substitutes_in              NaN  NaN     NaN     NaN     NaN    NaN       NaN
# substitutes_out             NaN  NaN     NaN     NaN     NaN    NaN       NaN
# substitutes_bench           NaN  NaN     NaN     NaN     NaN    NaN       NaN
# games_played                NaN  NaN     NaN     NaN     NaN    NaN       NaN
#
#                        shots_total  shots_on  goals_total  ...  \
# position                       NaN       NaN          NaN  ...
# age                            NaN       NaN          NaN  ...
# height                         NaN       NaN          NaN  ...
# weight                         NaN       NaN          NaN  ...
# rating                         NaN       NaN          NaN  ...
# value                          NaN       NaN          NaN  ...
# follower                       NaN       NaN          NaN  ...
# shots_total               1.000000  0.953328     0.795128  ...
# shots_on                  0.953328  1.000000     0.873473  ...
# goals_total               0.795128  0.873473     1.000000  ...
# goals_conceded                 NaN       NaN          NaN  ...
# goals_assists                  NaN  0.727011          NaN  ...
# passes_total                   NaN       NaN          NaN  ...
# passes_key                0.704353  0.704631          NaN  ...
# passes_accuracy                NaN       NaN          NaN  ...
# tackles_total                  NaN       NaN          NaN  ...
# tackles_blocks                 NaN       NaN          NaN  ...
# tackles_interceptions          NaN       NaN          NaN  ...
# duels_total                    NaN       NaN          NaN  ...
# duels_won                      NaN       NaN          NaN  ...
# dribbles_attempts              NaN       NaN          NaN  ...
# dribbles_success               NaN       NaN          NaN  ...
# fouls_drawn                    NaN       NaN          NaN  ...
# fouls_committed                NaN       NaN          NaN  ...
# cards_yellow                   NaN       NaN          NaN  ...
# cards_yellowred                NaN       NaN          NaN  ...
# cards_red                      NaN       NaN          NaN  ...
# penalty_won                    NaN       NaN          NaN  ...
# penalty_commited               NaN       NaN          NaN  ...
# penalty_success                NaN       NaN          NaN  ...
# penalty_missed                 NaN       NaN          NaN  ...
# penalty_saved                  NaN       NaN          NaN  ...
# games_appearences              NaN       NaN          NaN  ...
# games_lineups                  NaN       NaN          NaN  ...
# substitutes_in                 NaN       NaN          NaN  ...
# substitutes_out                NaN       NaN          NaN  ...
# substitutes_bench              NaN       NaN          NaN  ...
# games_played                   NaN       NaN          NaN  ...
#
#                        penalty_commited  penalty_success  penalty_missed  \
# position                            NaN              NaN             NaN
# age                                 NaN              NaN             NaN
# height                              NaN              NaN             NaN
# weight                              NaN              NaN             NaN
# rating                              NaN              NaN             NaN
# value                               NaN              NaN             NaN
# follower                            NaN              NaN             NaN
# shots_total                         NaN              NaN             NaN
# shots_on                            NaN              NaN             NaN
# goals_total                         NaN              NaN             NaN
# goals_conceded                      NaN              NaN             NaN
# goals_assists                       NaN              NaN             NaN
# passes_total                        NaN              NaN             NaN
# passes_key                          NaN              NaN             NaN
# passes_accuracy                     NaN              NaN             NaN
# tackles_total                       NaN              NaN             NaN
# tackles_blocks                      NaN              NaN             NaN
# tackles_interceptions               NaN              NaN             NaN
# duels_total                         NaN              NaN             NaN
# duels_won                           NaN              NaN             NaN
# dribbles_attempts                   NaN              NaN             NaN
# dribbles_success                    NaN              NaN             NaN
# fouls_drawn                         NaN              NaN             NaN
# fouls_committed                     NaN              NaN             NaN
# cards_yellow                        NaN              NaN             NaN
# cards_yellowred                     NaN              NaN             NaN
# cards_red                           NaN              NaN             NaN
# penalty_won                         NaN              NaN             NaN
# penalty_commited                    1.0              NaN             NaN
# penalty_success                     NaN              1.0             NaN
# penalty_missed                      NaN              NaN             1.0
# penalty_saved                       NaN              NaN             NaN
# games_appearences                   NaN              NaN             NaN
# games_lineups                       NaN              NaN             NaN
# substitutes_in                      NaN              NaN             NaN
# substitutes_out                     NaN              NaN             NaN
# substitutes_bench                   NaN              NaN             NaN
# games_played                        NaN              NaN             NaN
#
#                        penalty_saved  games_appearences  games_lineups  \
# position                         NaN                NaN            NaN
# age                              NaN                NaN            NaN
# height                           NaN                NaN            NaN
# weight                           NaN                NaN            NaN
# rating                           NaN                NaN            NaN
# value                            NaN                NaN            NaN
# follower                         NaN                NaN            NaN
# shots_total                      NaN                NaN            NaN
# shots_on                         NaN                NaN            NaN
# goals_total                      NaN                NaN            NaN
# goals_conceded              0.814639                NaN            NaN
# goals_assists                    NaN                NaN            NaN
# passes_total                     NaN                NaN            NaN
# passes_key                       NaN                NaN            NaN
# passes_accuracy                  NaN                NaN            NaN
# tackles_total                    NaN                NaN            NaN
# tackles_blocks                   NaN                NaN            NaN
# tackles_interceptions            NaN                NaN            NaN
# duels_total                      NaN                NaN            NaN
# duels_won                        NaN                NaN            NaN
# dribbles_attempts                NaN                NaN            NaN
# dribbles_success                 NaN                NaN            NaN
# fouls_drawn                      NaN                NaN            NaN
# fouls_committed                  NaN                NaN            NaN
# cards_yellow                     NaN                NaN            NaN
# cards_yellowred                  NaN                NaN            NaN
# cards_red                        NaN                NaN            NaN
# penalty_won                      NaN                NaN            NaN
# penalty_commited                 NaN                NaN            NaN
# penalty_success                  NaN                NaN            NaN
# penalty_missed                   NaN                NaN            NaN
# penalty_saved               1.000000                NaN            NaN
# games_appearences                NaN           1.000000            NaN
# games_lineups                    NaN                NaN            1.0
# substitutes_in                   NaN           0.980354            NaN
# substitutes_out                  NaN                NaN            NaN
# substitutes_bench                NaN           0.925853            NaN
# games_played                     NaN                NaN            NaN
#
#                        substitutes_in  substitutes_out  substitutes_bench  \
# position                          NaN              NaN                NaN
# age                               NaN              NaN                NaN
# height                            NaN              NaN                NaN
# weight                            NaN              NaN                NaN
# rating                            NaN              NaN                NaN
# value                             NaN              NaN                NaN
# follower                          NaN              NaN                NaN
# shots_total                       NaN              NaN                NaN
# shots_on                          NaN              NaN                NaN
# goals_total                       NaN              NaN                NaN
# goals_conceded                    NaN              NaN                NaN
# goals_assists                     NaN              NaN                NaN
# passes_total                      NaN              NaN                NaN
# passes_key                        NaN              NaN                NaN
# passes_accuracy                   NaN              NaN                NaN
# tackles_total                     NaN              NaN                NaN
# tackles_blocks                    NaN              NaN                NaN
# tackles_interceptions             NaN              NaN                NaN
# duels_total                       NaN              NaN                NaN
# duels_won                         NaN              NaN                NaN
# dribbles_attempts                 NaN              NaN                NaN
# dribbles_success                  NaN              NaN                NaN
# fouls_drawn                       NaN              NaN                NaN
# fouls_committed                   NaN              NaN                NaN
# cards_yellow                      NaN              NaN                NaN
# cards_yellowred                   NaN              NaN                NaN
# cards_red                         NaN              NaN                NaN
# penalty_won                       NaN              NaN                NaN
# penalty_commited                  NaN              NaN                NaN
# penalty_success                   NaN              NaN                NaN
# penalty_missed                    NaN              NaN                NaN
# penalty_saved                     NaN              NaN                NaN
# games_appearences            0.980354              NaN           0.925853
# games_lineups                     NaN              NaN                NaN
# substitutes_in               1.000000              NaN           0.932678
# substitutes_out                   NaN              1.0                NaN
# substitutes_bench            0.932678              NaN           1.000000
# games_played                      NaN              NaN                NaN
#
#                        games_played
# position                        NaN
# age                             NaN
# height                          NaN
# weight                          NaN
# rating                          NaN
# value                           NaN
# follower                        NaN
# shots_total                     NaN
# shots_on                        NaN
# goals_total                     NaN
# goals_conceded                  NaN
# goals_assists                   NaN
# passes_total                    NaN
# passes_key                      NaN
# passes_accuracy                 NaN
# tackles_total                   NaN
# tackles_blocks                  NaN
# tackles_interceptions           NaN
# duels_total                     NaN
# duels_won                       NaN
# dribbles_attempts               NaN
# dribbles_success                NaN
# fouls_drawn                     NaN
# fouls_committed                 NaN
# cards_yellow                    NaN
# cards_yellowred                 NaN
# cards_red                       NaN
# penalty_won                     NaN
# penalty_commited                NaN
# penalty_success                 NaN
# penalty_missed                  NaN
# penalty_saved                   NaN
# games_appearences               NaN
# games_lineups                   NaN
# substitutes_in                  NaN
# substitutes_out                 NaN
# substitutes_bench               NaN
# games_played                    1.0
#
# [38 rows x 38 columns]

# %%
pd.read_csv('df_mdf_corrc.csv', encoding='utf-8-sig', index_col=0)
# Out:
#                    shots_total  shots_on  goals_total  goals_conceded  \
# shots_total           1.000000  0.953328     0.795128             NaN
# shots_on              0.953328  1.000000     0.873473             NaN
# goals_total           0.795128  0.873473     1.000000             NaN
# goals_conceded             NaN       NaN          NaN        1.000000
# goals_assists              NaN  0.727011          NaN             NaN
# passes_key            0.704353  0.704631          NaN             NaN
# duels_total                NaN       NaN          NaN             NaN
# duels_won                  NaN       NaN          NaN             NaN
# dribbles_attempts          NaN       NaN          NaN             NaN
# dribbles_success           NaN       NaN          NaN             NaN
# penalty_saved              NaN       NaN          NaN        0.814639
# games_appearences          NaN       NaN          NaN             NaN
# substitutes_in             NaN       NaN          NaN             NaN
# substitutes_bench          NaN       NaN          NaN             NaN
#
#                    goals_assists  passes_key  duels_total  duels_won  \
# shots_total                  NaN    0.704353          NaN        NaN
# shots_on                0.727011    0.704631          NaN        NaN
# goals_total                  NaN         NaN          NaN        NaN
# goals_conceded               NaN         NaN          NaN        NaN
# goals_assists           1.000000    0.841685          NaN        NaN
# passes_key              0.841685    1.000000          NaN        NaN
# duels_total                  NaN         NaN     1.000000   0.953163
# duels_won                    NaN         NaN     0.953163   1.000000
# dribbles_attempts            NaN         NaN          NaN        NaN
# dribbles_success             NaN         NaN          NaN        NaN
# penalty_saved                NaN         NaN          NaN        NaN
# games_appearences            NaN         NaN          NaN        NaN
# substitutes_in               NaN         NaN          NaN        NaN
# substitutes_bench            NaN         NaN          NaN        NaN
#
#                    dribbles_attempts  dribbles_success  penalty_saved  \
# shots_total                      NaN               NaN            NaN
# shots_on                         NaN               NaN            NaN
# goals_total                      NaN               NaN            NaN
# goals_conceded                   NaN               NaN       0.814639
# goals_assists                    NaN               NaN            NaN
# passes_key                       NaN               NaN            NaN
# duels_total                      NaN               NaN            NaN
# duels_won                        NaN               NaN            NaN
# dribbles_attempts           1.000000          0.972654            NaN
# dribbles_success            0.972654          1.000000            NaN
# penalty_saved                    NaN               NaN       1.000000
# games_appearences                NaN               NaN            NaN
# substitutes_in                   NaN               NaN            NaN
# substitutes_bench                NaN               NaN            NaN
#
#                    games_appearences  substitutes_in  substitutes_bench
# shots_total                      NaN             NaN                NaN
# shots_on                         NaN             NaN                NaN
# goals_total                      NaN             NaN                NaN
# goals_conceded                   NaN             NaN                NaN
# goals_assists                    NaN             NaN                NaN
# passes_key                       NaN             NaN                NaN
# duels_total                      NaN             NaN                NaN
# duels_won                        NaN             NaN                NaN
# dribbles_attempts                NaN             NaN                NaN
# dribbles_success                 NaN             NaN                NaN
# penalty_saved                    NaN             NaN                NaN
# games_appearences           1.000000        0.980354           0.925853
# substitutes_in              0.980354        1.000000           0.932678
# substitutes_bench           0.925853        0.932678           1.000000

# %% [markdown]
# # 높은 상관관계를 보이는 feature들
# 1. shots_on, shots_total, goals_total, goals_assists, passes_key
# 2. goals_conceded, penalty_saved
# 3. duels_total, duels_won
# 4. dribbles_attempts, dribbles_success
# 5. games_appearences, substitutes_in, substitutes_bench

# %%
df_pos = df_mdf

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.preprocessing import MinMaxScaler

# %%
# 1. shots_on, shots_total and goals_total, goals_assists, passes_key PCA
df_pos_sotgtapk = df_pos[['shots_on', 'shots_total', 'goals_total', 'goals_assists', 'passes_key']]
df_pos_sotgtapk = StandardScaler().fit_transform(df_pos_sotgtapk)
df_pos_pca_sgp = pd.DataFrame(data = PCA(n_components=1).fit_transform(df_pos_sotgtapk), columns=['shotsOnTotal_goalsTotalAssists_passesKey'])
df_pos_pca_sgp['shotsOnTotal_goalsTotalAssists_passesKey'] = MinMaxScaler().fit_transform(df_pos_pca_sgp)
df_pos_pca_sgp
# Out:
#      shotsOnTotal_goalsTotalAssists_passesKey
# 0                                    0.048409
# 1                                    0.787350
# 2                                    0.298519
# 3                                    0.366173
# 4                                    0.341665
# ..                                        ...
# 151                                  0.329289
# 152                                  0.036148
# 153                                  0.202299
# 154                                  0.156162
# 155                                  0.345472
#
# [156 rows x 1 columns]

# %%
# 2. goals_conceded, penalty_saved PCA
df_pos_gcps = df_pos[['goals_conceded', 'penalty_saved']]
df_pos_gcps = StandardScaler().fit_transform(df_pos_gcps)
df_pos_pca_gcps = pd.DataFrame(data = PCA(n_components=1).fit_transform(df_pos_gcps), columns=['goalsConceded_penaltySaved'])
df_pos_pca_gcps['goalsConceded_penaltySaved'] = MinMaxScaler().fit_transform(df_pos_pca_gcps)
df_pos_pca_gcps
# Out:
#      goalsConceded_penaltySaved
# 0                  2.237793e-16
# 1                  1.561251e-17
# 2                  0.000000e+00
# 3                  0.000000e+00
# 4                  0.000000e+00
# ..                          ...
# 151                0.000000e+00
# 152                0.000000e+00
# 153                0.000000e+00
# 154                0.000000e+00
# 155                0.000000e+00
#
# [156 rows x 1 columns]

# %%
# 3. duels_total, duels_won PCA
df_pos_duels = df_pos[['duels_total', 'duels_won']]
df_pos_duels = StandardScaler().fit_transform(df_pos_duels)
df_pos_pca_duels = pd.DataFrame(data = PCA(n_components=1).fit_transform(df_pos_duels), columns=['duelsWonTotal'])
df_pos_pca_duels['duelsWonTotal'] = MinMaxScaler().fit_transform(df_pos_pca_duels)
df_pos_pca_duels
# Out:
#      duelsWonTotal
# 0         0.168614
# 1         0.196216
# 2         0.496571
# 3         0.384989
# 4         0.501690
# ..             ...
# 151       0.349238
# 152       0.463436
# 153       0.501902
# 154       0.825752
# 155       0.486266
#
# [156 rows x 1 columns]

# %%
# 4. dribbles_attempts, dribbles_success PCA
df_pos_dribbles = df_pos[['dribbles_attempts', 'dribbles_success']]
df_pos_dribbles = StandardScaler().fit_transform(df_pos_dribbles)
df_pos_pca_dribbles = pd.DataFrame(data = PCA(n_components=1).fit_transform(df_pos_dribbles), columns=['dribblesAtmptsSuc'])
df_pos_pca_dribbles['dribblesAtmptsSuc'] = MinMaxScaler().fit_transform(df_pos_pca_dribbles)
df_pos_pca_dribbles
# Out:
#      dribblesAtmptsSuc
# 0             0.185963
# 1             0.346131
# 2             0.182581
# 3             0.265660
# 4             0.491508
# ..                 ...
# 151           0.211291
# 152           0.148212
# 153           0.149297
# 154           0.149969
# 155           0.163228
#
# [156 rows x 1 columns]

# %%
# 5. games_appearences, substitutes_in, substitutes_bench PCA
df_pos_gasub = df_pos[['games_appearences', 'substitutes_in', 'substitutes_bench']]
df_pos_gasub = StandardScaler().fit_transform(df_pos_gasub)
df_pos_pca_gasub = pd.DataFrame(data = PCA(n_components=1).fit_transform(df_pos_gasub), columns=['gamesAppearance_sub'])
df_pos_pca_gasub['gamesAppearance_sub'] = MinMaxScaler().fit_transform(df_pos_pca_gasub)
df_pos_pca_gasub
# Out:
#      gamesAppearance_sub
# 0               0.528566
# 1               0.186032
# 2               0.018626
# 3               0.070777
# 4               0.346803
# ..                   ...
# 151             0.110835
# 152             0.005196
# 153             0.465286
# 154             0.063765
# 155             0.212191
#
# [156 rows x 1 columns]

# %% [markdown]
# # PCA Feature Table

# %%
df_pca = pd.concat([df_pos_pca_sgp, df_pos_pca_gcps, df_pos_pca_duels, 
                    df_pos_pca_dribbles, df_pos_pca_gasub], axis=1)
df_pca
# Out:
#      shotsOnTotal_goalsTotalAssists_passesKey  goalsConceded_penaltySaved  \
# 0                                    0.048409                2.237793e-16
# 1                                    0.787350                1.561251e-17
# 2                                    0.298519                0.000000e+00
# 3                                    0.366173                0.000000e+00
# 4                                    0.341665                0.000000e+00
# ..                                        ...                         ...
# 151                                  0.329289                0.000000e+00
# 152                                  0.036148                0.000000e+00
# 153                                  0.202299                0.000000e+00
# 154                                  0.156162                0.000000e+00
# 155                                  0.345472                0.000000e+00
#
#      duelsWonTotal  dribblesAtmptsSuc  gamesAppearance_sub
# 0         0.168614           0.185963             0.528566
# 1         0.196216           0.346131             0.186032
# 2         0.496571           0.182581             0.018626
# 3         0.384989           0.265660             0.070777
# 4         0.501690           0.491508             0.346803
# ..             ...                ...                  ...
# 151       0.349238           0.211291             0.110835
# 152       0.463436           0.148212             0.005196
# 153       0.501902           0.149297             0.465286
# 154       0.825752           0.149969             0.063765
# 155       0.486266           0.163228             0.212191
#
# [156 rows x 5 columns]

# %%
df_pca.corr()[df_pca.corr() > 0.7]
# Out:
#                                           shotsOnTotal_goalsTotalAssists_passesKey  \
# shotsOnTotal_goalsTotalAssists_passesKey                                       1.0
# goalsConceded_penaltySaved                                                     NaN
# duelsWonTotal                                                                  NaN
# dribblesAtmptsSuc                                                              NaN
# gamesAppearance_sub                                                            NaN
#
#                                           goalsConceded_penaltySaved  \
# shotsOnTotal_goalsTotalAssists_passesKey                         NaN
# goalsConceded_penaltySaved                                       1.0
# duelsWonTotal                                                    NaN
# dribblesAtmptsSuc                                                NaN
# gamesAppearance_sub                                              NaN
#
#                                           duelsWonTotal  dribblesAtmptsSuc  \
# shotsOnTotal_goalsTotalAssists_passesKey            NaN                NaN
# goalsConceded_penaltySaved                          NaN                NaN
# duelsWonTotal                                       1.0                NaN
# dribblesAtmptsSuc                                   NaN                1.0
# gamesAppearance_sub                                 NaN                NaN
#
#                                           gamesAppearance_sub
# shotsOnTotal_goalsTotalAssists_passesKey                  NaN
# goalsConceded_penaltySaved                                NaN
# duelsWonTotal                                             NaN
# dribblesAtmptsSuc                                         NaN
# gamesAppearance_sub                                       1.0

# %% [markdown]
# # PCA feature들과 그 외 feature들의 OLS 확인

# %%
pca_cols = ['shots_on', 'shots_total', 'goals_total', 'goals_assists', 'passes_key', 'goals_conceded', 'penalty_saved', 'duels_total', 'duels_won', 'dribbles_attempts', 'dribbles_success', 'games_appearences', 'substitutes_in', 'substitutes_bench']
npca_cols = df_pos.columns.tolist()
npca_features = [item for item in npca_cols if item not in pca_cols]

# %%
df_ols = pd.concat([df_pos[npca_features].reset_index(drop=True), df_pca.reset_index(drop=True)], axis=1)
df_ols = df_ols.drop('player_name', axis=1)
df_ols
# Out:
#      position   age  height  weight    rating  value  follower  passes_total  \
# 0         2.0  25.0   184.0    78.0  2.333333   20.0     67879       22.1875
# 1         2.0  32.0   180.0    75.0  4.833333   32.0  11513791       32.2437
# 2         2.0  27.0   184.0    75.0  4.666667   20.0     46206       46.3437
# 3         2.0  24.0   180.0    69.0  4.666667   20.0     11440       35.1882
# 4         2.0  23.0   180.0    67.0  6.714286   24.0   1019540       29.4830
# ..        ...   ...     ...     ...       ...    ...       ...           ...
# 151       2.0  26.0   172.0    66.0  4.100000   16.0    170526       51.2126
# 152       2.0  27.0   178.0    74.0  6.000000   16.0    820996       42.0829
# 153       2.0  22.0   185.0    84.0  7.000000   20.0    152427       28.4346
# 154       2.0  24.0   183.0    74.0  7.125000   36.0    529117       42.6547
# 155       2.0  23.0   176.0    72.0  4.384615   44.0    282254       38.4359
#
#      passes_accuracy  tackles_total  ...  penalty_success  penalty_missed  \
# 0             3.2985         1.2112  ...           0.0000          0.0000
# 1             6.1453         0.4321  ...           0.0096          0.0096
# 2             4.6792         1.9632  ...           0.0000          0.0000
# 3             6.6347         0.8218  ...           0.0000          0.0100
# 4             8.3347         0.4204  ...           0.0435          0.0000
# ..               ...            ...  ...              ...             ...
# 151           5.2251         2.2731  ...           0.0103          0.0309
# 152           7.3445         1.6140  ...           0.0000          0.0000
# 153           8.1058         0.8685  ...           0.0000          0.0000
# 154           6.2107         3.8404  ...           0.0000          0.0000
# 155           6.6011         1.0018  ...           0.0105          0.0000
#
#      games_lineups  substitutes_out  games_played  \
# 0           0.9277           0.2577       77.6111
# 1           1.0754           0.5857      104.1444
# 2           1.0006           0.1048      104.9333
# 3           1.0323           0.3408       99.7778
# 4           1.0002           0.4928       68.9889
# ..             ...              ...           ...
# 151         1.0183           0.2571       97.2222
# 152         1.0217           0.1037       67.5333
# 153         0.9811           0.3538       62.1778
# 154         1.0001           0.1000       99.9889
# 155         1.0334           0.3058       94.8333
#
#      shotsOnTotal_goalsTotalAssists_passesKey  goalsConceded_penaltySaved  \
# 0                                    0.048409                2.237793e-16
# 1                                    0.787350                1.561251e-17
# 2                                    0.298519                0.000000e+00
# 3                                    0.366173                0.000000e+00
# 4                                    0.341665                0.000000e+00
# ..                                        ...                         ...
# 151                                  0.329289                0.000000e+00
# 152                                  0.036148                0.000000e+00
# 153                                  0.202299                0.000000e+00
# 154                                  0.156162                0.000000e+00
# 155                                  0.345472                0.000000e+00
#
#      duelsWonTotal  dribblesAtmptsSuc  gamesAppearance_sub
# 0         0.168614           0.185963             0.528566
# 1         0.196216           0.346131             0.186032
# 2         0.496571           0.182581             0.018626
# 3         0.384989           0.265660             0.070777
# 4         0.501690           0.491508             0.346803
# ..             ...                ...                  ...
# 151       0.349238           0.211291             0.110835
# 152       0.463436           0.148212             0.005196
# 153       0.501902           0.149297             0.465286
# 154       0.825752           0.149969             0.063765
# 155       0.486266           0.163228             0.212191
#
# [156 rows x 29 columns]

# %%
df_ols_1 = df_ols.drop(['position'], axis=1)

# %% [markdown]
# # OLS - 1차

# %%
from sklearn.model_selection import train_test_split

df_ols = df_ols_1
dfX = df_ols.drop(['value'], axis=1)
dfy = df_ols['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

formula = "value ~ " + "+".join(feature_names)

model = sm.OLS.from_formula(formula, data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula(formula, data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
#    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.557
# Model:                            OLS   Adj. R-squared:                  0.410
# Method:                 Least Squares   F-statistic:                     3.774
# Date:                Mon, 22 Jun 2020   Prob (F-statistic):           1.97e-06
# Time:                        19:17:15   Log-Likelihood:                -435.09
# No. Observations:                 109   AIC:                             926.2
# Df Residuals:                      81   BIC:                             1002.
# Df Model:                          27
# Covariance Type:            nonrobust
# ===================================================================================================================
#                                                       coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# Intercept                                          34.9220      1.456     23.989      0.000      32.026      37.818
# scale(age)                                         -6.5746      2.107     -3.121      0.002     -10.766      -2.383
# scale(height)                                       0.7468      1.981      0.377      0.707      -3.195       4.689
# scale(weight)                                      -0.7787      1.942     -0.401      0.689      -4.642       3.085
# scale(rating)                                      -1.4292      2.157     -0.663      0.510      -5.721       2.863
# scale(follower)                                     5.4533      1.739      3.135      0.002       1.993       8.914
# scale(passes_total)                                 3.0001      2.423      1.238      0.219      -1.820       7.821
# scale(passes_accuracy)                              6.4968      2.735      2.375      0.020       1.055      11.939
# scale(tackles_total)                                3.3057      2.250      1.470      0.146      -1.170       7.782
# scale(tackles_blocks)                              -5.0325      2.433     -2.069      0.042      -9.873      -0.192
# scale(tackles_interceptions)                        0.1426      2.854      0.050      0.960      -5.536       5.821
# scale(fouls_drawn)                                 -6.2865      2.371     -2.652      0.010     -11.003      -1.570
# scale(fouls_committed)                             -4.4826      2.574     -1.742      0.085      -9.603       0.638
# scale(cards_yellow)                                 4.3134      2.374      1.817      0.073      -0.410       9.037
# scale(cards_yellowred)                             -0.5891      1.893     -0.311      0.756      -4.355       3.177
# scale(cards_red)                                   -3.2827      1.708     -1.922      0.058      -6.681       0.116
# scale(penalty_won)                                  0.3429      1.992      0.172      0.864      -3.621       4.306
# scale(penalty_commited)                            -5.4071      1.634     -3.309      0.001      -8.658      -2.156
# scale(penalty_success)                              1.4055      1.973      0.712      0.478      -2.521       5.332
# scale(penalty_missed)                              -3.0541      1.936     -1.578      0.119      -6.906       0.798
# scale(games_lineups)                               -2.6730      3.398     -0.787      0.434      -9.433       4.087
# scale(substitutes_out)                             -3.1038      4.069     -0.763      0.448     -11.200       4.993
# scale(games_played)                                 5.2572      2.314      2.272      0.026       0.653       9.862
# scale(shotsOnTotal_goalsTotalAssists_passesKey)     5.3304      2.539      2.099      0.039       0.279      10.382
# scale(goalsConceded_penaltySaved)                   0.3195      1.783      0.179      0.858      -3.229       3.868
# scale(duelsWonTotal)                                1.9108      2.718      0.703      0.484      -3.496       7.318
# scale(dribblesAtmptsSuc)                            4.4672      2.717      1.644      0.104      -0.939       9.873
# scale(gamesAppearance_sub)                         -5.3489      3.853     -1.388      0.169     -13.015       2.317
# ==============================================================================
# Omnibus:                       25.196   Durbin-Watson:                   1.868
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               46.405
# Skew:                           0.963   Prob(JB):                     8.38e-11
# Kurtosis:                       5.551   Cond. No.                         9.72
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 모델 성능 : -0.28680201707143826

# %%
# OLS - 2차

# %%
df_ols_2 = df_ols_1.drop(['tackles_interceptions'], axis=1)
len(df_ols_1.columns), len(df_ols_2.columns)
# Out:
# (28, 27)

# %%
from sklearn.model_selection import train_test_split

df_ols = df_ols_2
dfX = df_ols.drop(['value'], axis=1)
dfy = df_ols['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

formula = "value ~ " + "+".join(feature_names)

model = sm.OLS.from_formula(formula, data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula(formula, data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
#    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.557
# Model:                            OLS   Adj. R-squared:                  0.417
# Method:                 Least Squares   F-statistic:                     3.967
# Date:                Mon, 22 Jun 2020   Prob (F-statistic):           9.62e-07
# Time:                        19:18:26   Log-Likelihood:                -435.10
# No. Observations:                 109   AIC:                             924.2
# Df Residuals:                      82   BIC:                             996.9
# Df Model:                          26
# Covariance Type:            nonrobust
# ===================================================================================================================
#                                                       coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# Intercept                                          34.9220      1.447     24.136      0.000      32.044      37.800
# scale(age)                                         -6.5471      2.021     -3.240      0.002     -10.568      -2.527
# scale(height)                                       0.7479      1.969      0.380      0.705      -3.169       4.665
# scale(weight)                                      -0.7821      1.929     -0.405      0.686      -4.619       3.055
# scale(rating)                                      -1.4084      2.104     -0.669      0.505      -5.593       2.777
# scale(follower)                                     5.4416      1.713      3.177      0.002       2.034       8.849
# scale(passes_total)                                 3.0226      2.366      1.278      0.205      -1.684       7.729
# scale(passes_accuracy)                              6.4791      2.695      2.404      0.018       1.117      11.841
# scale(tackles_total)                                3.3252      2.202      1.510      0.135      -1.056       7.706
# scale(tackles_blocks)                              -5.0101      2.377     -2.108      0.038      -9.738      -0.282
# scale(fouls_drawn)                                 -6.3122      2.300     -2.744      0.007     -10.888      -1.736
# scale(fouls_committed)                             -4.4584      2.512     -1.775      0.080      -9.456       0.539
# scale(cards_yellow)                                 4.3041      2.352      1.830      0.071      -0.375       8.983
# scale(cards_yellowred)                             -0.5747      1.859     -0.309      0.758      -4.273       3.124
# scale(cards_red)                                   -3.2881      1.694     -1.941      0.056      -6.658       0.082
# scale(penalty_won)                                  0.3559      1.963      0.181      0.857      -3.549       4.261
# scale(penalty_commited)                            -5.4055      1.624     -3.329      0.001      -8.635      -2.176
# scale(penalty_success)                              1.4126      1.956      0.722      0.472      -2.479       5.304
# scale(penalty_missed)                              -3.0667      1.908     -1.608      0.112      -6.862       0.728
# scale(games_lineups)                               -2.6514      3.349     -0.792      0.431      -9.314       4.012
# scale(substitutes_out)                             -3.1350      3.996     -0.784      0.435     -11.085       4.815
# scale(games_played)                                 5.2457      2.289      2.292      0.024       0.693       9.799
# scale(shotsOnTotal_goalsTotalAssists_passesKey)     5.3047      2.471      2.147      0.035       0.388      10.221
# scale(goalsConceded_penaltySaved)                   0.3046      1.747      0.174      0.862      -3.172       3.781
# scale(duelsWonTotal)                                1.9425      2.627      0.739      0.462      -3.283       7.168
# scale(dribblesAtmptsSuc)                            4.4507      2.680      1.660      0.101      -0.881       9.783
# scale(gamesAppearance_sub)                         -5.3224      3.793     -1.403      0.164     -12.868       2.223
# ==============================================================================
# Omnibus:                       25.084   Durbin-Watson:                   1.868
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               46.023
# Skew:                           0.961   Prob(JB):                     1.01e-10
# Kurtosis:                       5.538   Cond. No.                         8.97
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 모델 성능 : -0.2545948137885065

# %%
# OLS - 3차

# %%
df_ols_3 = df_ols_2.drop(['goalsConceded_penaltySaved'], axis=1)
len(df_ols_2.columns), len(df_ols_3.columns)
# Out:
# (27, 26)

# %%
from sklearn.model_selection import train_test_split

df_ols = df_ols_3
dfX = df_ols.drop(['value'], axis=1)
dfy = df_ols['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

formula = "value ~ " + "+".join(feature_names)

model = sm.OLS.from_formula(formula, data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula(formula, data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
#    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.557
# Model:                            OLS   Adj. R-squared:                  0.424
# Method:                 Least Squares   F-statistic:                     4.174
# Date:                Mon, 22 Jun 2020   Prob (F-statistic):           4.64e-07
# Time:                        19:20:00   Log-Likelihood:                -435.12
# No. Observations:                 109   AIC:                             922.2
# Df Residuals:                      83   BIC:                             992.2
# Df Model:                          25
# Covariance Type:            nonrobust
# ===================================================================================================================
#                                                       coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# Intercept                                          34.9220      1.438     24.279      0.000      32.061      37.783
# scale(age)                                         -6.5303      2.007     -3.254      0.002     -10.522      -2.539
# scale(height)                                       0.7401      1.957      0.378      0.706      -3.152       4.633
# scale(weight)                                      -0.7727      1.917     -0.403      0.688      -4.585       3.040
# scale(rating)                                      -1.3876      2.088     -0.665      0.508      -5.541       2.765
# scale(follower)                                     5.4465      1.703      3.199      0.002       2.060       8.833
# scale(passes_total)                                 2.9959      2.347      1.276      0.205      -1.672       7.664
# scale(passes_accuracy)                              6.4965      2.678      2.426      0.017       1.171      11.822
# scale(tackles_total)                                3.2913      2.181      1.509      0.135      -1.046       7.629
# scale(tackles_blocks)                              -5.0721      2.336     -2.171      0.033      -9.718      -0.426
# scale(fouls_drawn)                                 -6.2951      2.285     -2.755      0.007     -10.839      -1.751
# scale(fouls_committed)                             -4.4904      2.491     -1.803      0.075      -9.444       0.464
# scale(cards_yellow)                                 4.2673      2.329      1.832      0.070      -0.365       8.899
# scale(cards_yellowred)                             -0.5891      1.846     -0.319      0.750      -4.262       3.083
# scale(cards_red)                                   -3.3286      1.668     -1.995      0.049      -6.647      -0.010
# scale(penalty_won)                                  0.3780      1.947      0.194      0.847      -3.495       4.251
# scale(penalty_commited)                            -5.4358      1.605     -3.387      0.001      -8.628      -2.244
# scale(penalty_success)                              1.4143      1.945      0.727      0.469      -2.454       5.282
# scale(penalty_missed)                              -3.0484      1.894     -1.610      0.111      -6.815       0.718
# scale(games_lineups)                               -2.4025      3.012     -0.798      0.427      -8.393       3.588
# scale(substitutes_out)                             -3.3997      3.675     -0.925      0.358     -10.709       3.909
# scale(games_played)                                 5.2018      2.262      2.300      0.024       0.704       9.700
# scale(shotsOnTotal_goalsTotalAssists_passesKey)     5.2349      2.424      2.159      0.034       0.413      10.057
# scale(duelsWonTotal)                                1.8978      2.599      0.730      0.467      -3.272       7.067
# scale(dribblesAtmptsSuc)                            4.4384      2.664      1.666      0.099      -0.860       9.736
# scale(gamesAppearance_sub)                         -5.1523      3.644     -1.414      0.161     -12.399       2.095
# ==============================================================================
# Omnibus:                       25.122   Durbin-Watson:                   1.868
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               46.208
# Skew:                           0.961   Prob(JB):                     9.25e-11
# Kurtosis:                       5.546   Cond. No.                         8.24
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 모델 성능 : -0.1717997276915331

# %%
# OLS - 4차

# %%
df_ols_4 = df_ols_3.drop(['penalty_won'], axis=1)
len(df_ols_3.columns), len(df_ols_4.columns)
# Out:
# (26, 25)

# %%
from sklearn.model_selection import train_test_split

df_ols = df_ols_4
dfX = df_ols.drop(['value'], axis=1)
dfy = df_ols['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

formula = "value ~ " + "+".join(feature_names)

model = sm.OLS.from_formula(formula, data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula(formula, data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
#    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.557
# Model:                            OLS   Adj. R-squared:                  0.430
# Method:                 Least Squares   F-statistic:                     4.396
# Date:                Mon, 22 Jun 2020   Prob (F-statistic):           2.18e-07
# Time:                        19:21:14   Log-Likelihood:                -435.14
# No. Observations:                 109   AIC:                             920.3
# Df Residuals:                      84   BIC:                             987.6
# Df Model:                          24
# Covariance Type:            nonrobust
# ===================================================================================================================
#                                                       coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# Intercept                                          34.9220      1.430     24.419      0.000      32.078      37.766
# scale(age)                                         -6.5797      1.979     -3.324      0.001     -10.516      -2.644
# scale(height)                                       0.7668      1.941      0.395      0.694      -3.093       4.627
# scale(weight)                                      -0.7752      1.906     -0.407      0.685      -4.565       3.015
# scale(rating)                                      -1.3488      2.067     -0.653      0.516      -5.458       2.761
# scale(follower)                                     5.4535      1.692      3.222      0.002       2.088       8.819
# scale(passes_total)                                 2.9542      2.324      1.271      0.207      -1.667       7.575
# scale(passes_accuracy)                              6.5271      2.658      2.456      0.016       1.242      11.812
# scale(tackles_total)                                3.2804      2.168      1.513      0.134      -1.030       7.591
# scale(tackles_blocks)                              -5.0714      2.323     -2.183      0.032      -9.690      -0.453
# scale(fouls_drawn)                                 -6.1549      2.155     -2.856      0.005     -10.441      -1.869
# scale(fouls_committed)                             -4.4903      2.476     -1.813      0.073      -9.415       0.434
# scale(cards_yellow)                                 4.2622      2.315      1.841      0.069      -0.342       8.866
# scale(cards_yellowred)                             -0.6303      1.824     -0.346      0.730      -4.257       2.996
# scale(cards_red)                                   -3.3327      1.659     -2.009      0.048      -6.631      -0.034
# scale(penalty_commited)                            -5.4453      1.595     -3.414      0.001      -8.617      -2.274
# scale(penalty_success)                              1.4180      1.933      0.733      0.465      -2.427       5.263
# scale(penalty_missed)                              -3.0245      1.879     -1.610      0.111      -6.761       0.712
# scale(games_lineups)                               -2.5372      2.914     -0.871      0.386      -8.332       3.258
# scale(substitutes_out)                             -3.2768      3.599     -0.910      0.365     -10.434       3.880
# scale(games_played)                                 5.1720      2.243      2.305      0.024       0.711       9.633
# scale(shotsOnTotal_goalsTotalAssists_passesKey)     5.2993      2.388      2.219      0.029       0.551      10.047
# scale(duelsWonTotal)                                1.8798      2.582      0.728      0.469      -3.256       7.015
# scale(dribblesAtmptsSuc)                            4.4361      2.648      1.675      0.098      -0.831       9.703
# scale(gamesAppearance_sub)                         -5.2589      3.581     -1.468      0.146     -12.381       1.863
# ==============================================================================
# Omnibus:                       25.123   Durbin-Watson:                   1.868
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               46.227
# Skew:                           0.961   Prob(JB):                     9.16e-11
# Kurtosis:                       5.547   Cond. No.                         7.91
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 모델 성능 : -0.1579436065757004

# %%
# OLS - 5차

# %%
df_ols_5 = df_ols_4.drop(['cards_yellowred'], axis=1)
len(df_ols_4.columns), len(df_ols_5.columns)
# Out:
# (25, 24)

# %%
from sklearn.model_selection import train_test_split

df_ols = df_ols_5
dfX = df_ols.drop(['value'], axis=1)
dfy = df_ols['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

formula = "value ~ " + "+".join(feature_names)

model = sm.OLS.from_formula(formula, data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula(formula, data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
#    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.556
# Model:                            OLS   Adj. R-squared:                  0.436
# Method:                 Least Squares   F-statistic:                     4.630
# Date:                Mon, 22 Jun 2020   Prob (F-statistic):           1.04e-07
# Time:                        19:22:24   Log-Likelihood:                -435.22
# No. Observations:                 109   AIC:                             918.4
# Df Residuals:                      85   BIC:                             983.0
# Df Model:                          23
# Covariance Type:            nonrobust
# ===================================================================================================================
#                                                       coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# Intercept                                          34.9220      1.423     24.546      0.000      32.093      37.751
# scale(age)                                         -6.5245      1.963     -3.324      0.001     -10.427      -2.622
# scale(height)                                       0.8723      1.907      0.457      0.649      -2.919       4.664
# scale(weight)                                      -0.8012      1.894     -0.423      0.673      -4.568       2.965
# scale(rating)                                      -1.3067      2.052     -0.637      0.526      -5.387       2.774
# scale(follower)                                     5.3306      1.646      3.238      0.002       2.058       8.604
# scale(passes_total)                                 3.0168      2.305      1.309      0.194      -1.566       7.599
# scale(passes_accuracy)                              6.4630      2.637      2.451      0.016       1.219      11.707
# scale(tackles_total)                                3.1398      2.118      1.482      0.142      -1.071       7.351
# scale(tackles_blocks)                              -5.0118      2.304     -2.175      0.032      -9.593      -0.430
# scale(fouls_drawn)                                 -6.2657      2.120     -2.955      0.004     -10.481      -2.051
# scale(fouls_committed)                             -4.6097      2.439     -1.890      0.062      -9.460       0.241
# scale(cards_yellow)                                 4.0354      2.209      1.827      0.071      -0.356       8.427
# scale(cards_red)                                   -3.4147      1.633     -2.091      0.040      -6.662      -0.168
# scale(penalty_commited)                            -5.4646      1.586     -3.446      0.001      -8.617      -2.312
# scale(penalty_success)                              1.5063      1.907      0.790      0.432      -2.284       5.297
# scale(penalty_missed)                              -3.0470      1.868     -1.631      0.107      -6.761       0.667
# scale(games_lineups)                               -2.6702      2.873     -0.929      0.355      -8.383       3.043
# scale(substitutes_out)                             -3.0831      3.537     -0.872      0.386     -10.115       3.949
# scale(games_played)                                 5.1343      2.229      2.303      0.024       0.702       9.566
# scale(shotsOnTotal_goalsTotalAssists_passesKey)     5.3810      2.364      2.277      0.025       0.682      10.081
# scale(duelsWonTotal)                                2.0005      2.545      0.786      0.434      -3.060       7.062
# scale(dribblesAtmptsSuc)                            4.3108      2.610      1.652      0.102      -0.878       9.500
# scale(gamesAppearance_sub)                         -5.3624      3.550     -1.510      0.135     -12.421       1.697
# ==============================================================================
# Omnibus:                       25.271   Durbin-Watson:                   1.861
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               46.865
# Skew:                           0.963   Prob(JB):                     6.66e-11
# Kurtosis:                       5.571   Cond. No.                         7.76
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 모델 성능 : -0.08998870029930262

# %%
# OLS - 6차

# %%
df_ols_6 = df_ols_5.drop(['weight'], axis=1)
len(df_ols_5.columns), len(df_ols_6.columns)
# Out:
# (24, 23)

# %%
from sklearn.model_selection import train_test_split

df_ols = df_ols_6
dfX = df_ols.drop(['value'], axis=1)
dfy = df_ols['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

formula = "value ~ " + "+".join(feature_names)

model = sm.OLS.from_formula(formula, data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula(formula, data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
#    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.555
# Model:                            OLS   Adj. R-squared:                  0.441
# Method:                 Least Squares   F-statistic:                     4.879
# Date:                Mon, 22 Jun 2020   Prob (F-statistic):           4.90e-08
# Time:                        19:23:24   Log-Likelihood:                -435.33
# No. Observations:                 109   AIC:                             916.7
# Df Residuals:                      86   BIC:                             978.6
# Df Model:                          22
# Covariance Type:            nonrobust
# ===================================================================================================================
#                                                       coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# Intercept                                          34.9220      1.416     24.664      0.000      32.107      37.737
# scale(age)                                         -6.6805      1.918     -3.482      0.001     -10.494      -2.867
# scale(height)                                       0.5273      1.715      0.307      0.759      -2.883       3.937
# scale(rating)                                      -1.4268      2.023     -0.705      0.482      -5.448       2.594
# scale(follower)                                     5.3298      1.638      3.253      0.002       2.073       8.587
# scale(passes_total)                                 3.1085      2.283      1.361      0.177      -1.431       7.648
# scale(passes_accuracy)                              6.4941      2.624      2.475      0.015       1.278      11.710
# scale(tackles_total)                                3.2094      2.101      1.527      0.130      -0.968       7.387
# scale(tackles_blocks)                              -5.0774      2.288     -2.219      0.029      -9.626      -0.529
# scale(fouls_drawn)                                 -6.2330      2.108     -2.956      0.004     -10.424      -2.041
# scale(fouls_committed)                             -4.7204      2.414     -1.956      0.054      -9.519       0.078
# scale(cards_yellow)                                 4.2229      2.154      1.961      0.053      -0.058       8.504
# scale(cards_red)                                   -3.4373      1.624     -2.116      0.037      -6.666      -0.208
# scale(penalty_commited)                            -5.5036      1.575     -3.494      0.001      -8.635      -2.372
# scale(penalty_success)                              1.5144      1.897      0.798      0.427      -2.257       5.286
# scale(penalty_missed)                              -3.0488      1.859     -1.640      0.105      -6.744       0.647
# scale(games_lineups)                               -2.5837      2.852     -0.906      0.368      -8.254       3.087
# scale(substitutes_out)                             -3.2218      3.505     -0.919      0.361     -10.189       3.745
# scale(games_played)                                 5.0617      2.212      2.288      0.025       0.665       9.459
# scale(shotsOnTotal_goalsTotalAssists_passesKey)     5.4308      2.349      2.312      0.023       0.760      10.101
# scale(duelsWonTotal)                                1.7558      2.467      0.712      0.479      -3.148       6.660
# scale(dribblesAtmptsSuc)                            4.3931      2.590      1.696      0.093      -0.756       9.542
# scale(gamesAppearance_sub)                         -5.4633      3.525     -1.550      0.125     -12.471       1.545
# ==============================================================================
# Omnibus:                       25.347   Durbin-Watson:                   1.856
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               47.325
# Skew:                           0.962   Prob(JB):                     5.29e-11
# Kurtosis:                       5.592   Cond. No.                         7.68
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 모델 성능 : -0.10439022011989776

# %%
# OLS - 7차

# %%
df_ols_7 = df_ols_6.drop(['height'], axis=1)
len(df_ols_6.columns), len(df_ols_7.columns)
# Out:
# (23, 22)

# %%
from sklearn.model_selection import train_test_split

df_ols = df_ols_7
dfX = df_ols.drop(['value'], axis=1)
dfy = df_ols['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

formula = "value ~ " + "+".join(feature_names)

model = sm.OLS.from_formula(formula, data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula(formula, data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
#    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.555
# Model:                            OLS   Adj. R-squared:                  0.447
# Method:                 Least Squares   F-statistic:                     5.161
# Date:                Mon, 22 Jun 2020   Prob (F-statistic):           2.18e-08
# Time:                        19:24:18   Log-Likelihood:                -435.39
# No. Observations:                 109   AIC:                             914.8
# Df Residuals:                      87   BIC:                             974.0
# Df Model:                          21
# Covariance Type:            nonrobust
# ===================================================================================================================
#                                                       coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# Intercept                                          34.9220      1.409     24.794      0.000      32.122      37.722
# scale(age)                                         -6.6859      1.908     -3.503      0.001     -10.479      -2.893
# scale(rating)                                      -1.2810      1.956     -0.655      0.514      -5.169       2.607
# scale(follower)                                     5.3949      1.616      3.338      0.001       2.183       8.607
# scale(passes_total)                                 3.1183      2.271      1.373      0.173      -1.396       7.633
# scale(passes_accuracy)                              6.3871      2.587      2.469      0.016       1.245      11.529
# scale(tackles_total)                                3.0964      2.058      1.504      0.136      -0.995       7.187
# scale(tackles_blocks)                              -4.9923      2.259     -2.210      0.030      -9.483      -0.502
# scale(fouls_drawn)                                 -6.3887      2.036     -3.138      0.002     -10.436      -2.342
# scale(fouls_committed)                             -4.6108      2.375     -1.942      0.055      -9.331       0.109
# scale(cards_yellow)                                 4.2726      2.136      2.000      0.049       0.027       8.519
# scale(cards_red)                                   -3.3585      1.596     -2.105      0.038      -6.530      -0.187
# scale(penalty_commited)                            -5.4944      1.567     -3.507      0.001      -8.609      -2.380
# scale(penalty_success)                              1.4949      1.886      0.792      0.430      -2.254       5.244
# scale(penalty_missed)                              -3.0222      1.847     -1.636      0.105      -6.694       0.649
# scale(games_lineups)                               -2.6386      2.832     -0.932      0.354      -8.268       2.990
# scale(substitutes_out)                             -3.2417      3.486     -0.930      0.355     -10.170       3.686
# scale(games_played)                                 4.9852      2.186      2.280      0.025       0.640       9.331
# scale(shotsOnTotal_goalsTotalAssists_passesKey)     5.4722      2.333      2.345      0.021       0.835      10.110
# scale(duelsWonTotal)                                1.8719      2.425      0.772      0.442      -2.948       6.692
# scale(dribblesAtmptsSuc)                            4.3612      2.575      1.694      0.094      -0.756       9.478
# scale(gamesAppearance_sub)                         -5.4480      3.507     -1.554      0.124     -12.418       1.522
# ==============================================================================
# Omnibus:                       24.896   Durbin-Watson:                   1.865
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               46.266
# Skew:                           0.947   Prob(JB):                     8.98e-11
# Kurtosis:                       5.569   Cond. No.                         7.57
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 모델 성능 : -0.0807203834593478

# %%
# OLS - 8차

# %%
df_ols_8 = df_ols_7.drop(['rating'], axis=1)
len(df_ols_7.columns), len(df_ols_8.columns)
# Out:
# (22, 21)

# %%
from sklearn.model_selection import train_test_split

df_ols = df_ols_8
dfX = df_ols.drop(['value'], axis=1)
dfy = df_ols['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

formula = "value ~ " + "+".join(feature_names)

model = sm.OLS.from_formula(formula, data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula(formula, data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
#    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.553
# Model:                            OLS   Adj. R-squared:                  0.451
# Method:                 Least Squares   F-statistic:                     5.433
# Date:                Mon, 22 Jun 2020   Prob (F-statistic):           1.09e-08
# Time:                        19:25:23   Log-Likelihood:                -435.66
# No. Observations:                 109   AIC:                             913.3
# Df Residuals:                      88   BIC:                             969.8
# Df Model:                          20
# Covariance Type:            nonrobust
# ===================================================================================================================
#                                                       coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# Intercept                                          34.9220      1.404     24.875      0.000      32.132      37.712
# scale(age)                                         -6.6431      1.901     -3.494      0.001     -10.421      -2.865
# scale(follower)                                     5.4911      1.604      3.423      0.001       2.303       8.679
# scale(passes_total)                                 2.9722      2.253      1.319      0.191      -1.505       7.450
# scale(passes_accuracy)                              5.6818      2.344      2.423      0.017       1.023      10.341
# scale(tackles_total)                                3.0606      2.051      1.492      0.139      -1.015       7.136
# scale(tackles_blocks)                              -5.1292      2.242     -2.287      0.025      -9.585      -0.673
# scale(fouls_drawn)                                 -6.3054      2.025     -3.113      0.002     -10.331      -2.280
# scale(fouls_committed)                             -4.8279      2.344     -2.060      0.042      -9.486      -0.170
# scale(cards_yellow)                                 4.3939      2.121      2.071      0.041       0.178       8.609
# scale(cards_red)                                   -3.2791      1.586     -2.068      0.042      -6.431      -0.127
# scale(penalty_commited)                            -5.4199      1.558     -3.480      0.001      -8.515      -2.324
# scale(penalty_success)                              1.3465      1.867      0.721      0.473      -2.363       5.056
# scale(penalty_missed)                              -2.8991      1.832     -1.583      0.117      -6.539       0.741
# scale(games_lineups)                               -2.3715      2.793     -0.849      0.398      -7.923       3.180
# scale(substitutes_out)                             -3.3012      3.473     -0.950      0.344     -10.203       3.601
# scale(games_played)                                 4.8188      2.164      2.226      0.029       0.517       9.120
# scale(shotsOnTotal_goalsTotalAssists_passesKey)     5.0874      2.251      2.260      0.026       0.615       9.560
# scale(duelsWonTotal)                                1.8071      2.415      0.748      0.456      -2.993       6.607
# scale(dribblesAtmptsSuc)                            4.3971      2.566      1.714      0.090      -0.701       9.496
# scale(gamesAppearance_sub)                         -5.0862      3.452     -1.474      0.144     -11.945       1.773
# ==============================================================================
# Omnibus:                       24.602   Durbin-Watson:                   1.850
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               45.122
# Skew:                           0.942   Prob(JB):                     1.59e-10
# Kurtosis:                       5.527   Cond. No.                         7.45
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 모델 성능 : -0.06086171699172782

# %%
# OLS - 9차

# %%
df_ols_9 = df_ols_8.drop(['penalty_success'], axis=1)
len(df_ols_8.columns), len(df_ols_9.columns)
# Out:
# (21, 20)

# %%
from sklearn.model_selection import train_test_split

df_ols = df_ols_9
dfX = df_ols.drop(['value'], axis=1)
dfy = df_ols['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

formula = "value ~ " + "+".join(feature_names)

model = sm.OLS.from_formula(formula, data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula(formula, data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
#    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.550
# Model:                            OLS   Adj. R-squared:                  0.454
# Method:                 Least Squares   F-statistic:                     5.722
# Date:                Mon, 22 Jun 2020   Prob (F-statistic):           5.50e-09
# Time:                        19:26:27   Log-Likelihood:                -435.98
# No. Observations:                 109   AIC:                             912.0
# Df Residuals:                      89   BIC:                             965.8
# Df Model:                          19
# Covariance Type:            nonrobust
# ===================================================================================================================
#                                                       coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# Intercept                                          34.9220      1.400     24.942      0.000      32.140      37.704
# scale(age)                                         -6.6478      1.896     -3.506      0.001     -10.415      -2.881
# scale(follower)                                     5.6868      1.577      3.607      0.001       2.554       8.820
# scale(passes_total)                                 3.0326      2.245      1.351      0.180      -1.429       7.494
# scale(passes_accuracy)                              5.6297      2.337      2.409      0.018       0.986      10.273
# scale(tackles_total)                                3.0390      2.045      1.486      0.141      -1.024       7.103
# scale(tackles_blocks)                              -5.0727      2.235     -2.270      0.026      -9.513      -0.632
# scale(fouls_drawn)                                 -6.2257      2.017     -3.087      0.003     -10.233      -2.218
# scale(fouls_committed)                             -4.8965      2.336     -2.096      0.039      -9.538      -0.255
# scale(cards_yellow)                                 4.5295      2.107      2.150      0.034       0.343       8.717
# scale(cards_red)                                   -3.1120      1.565     -1.989      0.050      -6.221      -0.003
# scale(penalty_commited)                            -5.2893      1.543     -3.428      0.001      -8.355      -2.224
# scale(penalty_missed)                              -2.2182      1.566     -1.417      0.160      -5.329       0.892
# scale(games_lineups)                               -2.3188      2.785     -0.833      0.407      -7.852       3.215
# scale(substitutes_out)                             -3.2434      3.463     -0.937      0.351     -10.124       3.637
# scale(games_played)                                 4.8877      2.156      2.266      0.026       0.603       9.173
# scale(shotsOnTotal_goalsTotalAssists_passesKey)     5.2961      2.226      2.379      0.019       0.873       9.719
# scale(duelsWonTotal)                                1.8728      2.407      0.778      0.439      -2.910       6.656
# scale(dribblesAtmptsSuc)                            4.1108      2.528      1.626      0.107      -0.912       9.134
# scale(gamesAppearance_sub)                         -5.0896      3.442     -1.479      0.143     -11.929       1.750
# ==============================================================================
# Omnibus:                       23.688   Durbin-Watson:                   1.852
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               43.706
# Skew:                           0.903   Prob(JB):                     3.23e-10
# Kurtosis:                       5.522   Cond. No.                         7.44
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 모델 성능 : -0.05078192061631367

# %%
# OLS - 10차

# %%
df_ols_10 = df_ols_9.drop(['duelsWonTotal'], axis=1)
len(df_ols_9.columns), len(df_ols_10.columns)
# Out:
# (20, 19)

# %%
from sklearn.model_selection import train_test_split

df_ols = df_ols_10
dfX = df_ols.drop(['value'], axis=1)
dfy = df_ols['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

formula = "value ~ " + "+".join(feature_names)

model = sm.OLS.from_formula(formula, data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula(formula, data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
#    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.547
# Model:                            OLS   Adj. R-squared:                  0.456
# Method:                 Least Squares   F-statistic:                     6.033
# Date:                Mon, 22 Jun 2020   Prob (F-statistic):           2.81e-09
# Time:                        19:27:42   Log-Likelihood:                -436.35
# No. Observations:                 109   AIC:                             910.7
# Df Residuals:                      90   BIC:                             961.8
# Df Model:                          18
# Covariance Type:            nonrobust
# ===================================================================================================================
#                                                       coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# Intercept                                          34.9220      1.397     24.997      0.000      32.147      37.698
# scale(age)                                         -6.7500      1.887     -3.577      0.001     -10.499      -3.001
# scale(follower)                                     5.8448      1.560      3.746      0.000       2.745       8.944
# scale(passes_total)                                 2.9554      2.238      1.320      0.190      -1.491       7.402
# scale(passes_accuracy)                              5.8923      2.307      2.554      0.012       1.308      10.477
# scale(tackles_total)                                3.6263      1.897      1.912      0.059      -0.141       7.394
# scale(tackles_blocks)                              -4.8642      2.214     -2.197      0.031      -9.263      -0.466
# scale(fouls_drawn)                                 -5.4968      1.782     -3.084      0.003      -9.038      -1.956
# scale(fouls_committed)                             -4.4359      2.255     -1.968      0.052      -8.915       0.043
# scale(cards_yellow)                                 4.4340      2.099      2.112      0.037       0.264       8.604
# scale(cards_red)                                   -3.1492      1.560     -2.018      0.047      -6.249      -0.049
# scale(penalty_commited)                            -5.2254      1.537     -3.399      0.001      -8.280      -2.171
# scale(penalty_missed)                              -2.2245      1.562     -1.424      0.158      -5.328       0.879
# scale(games_lineups)                               -2.0248      2.753     -0.735      0.464      -7.494       3.445
# scale(substitutes_out)                             -3.5816      3.428     -1.045      0.299     -10.392       3.229
# scale(games_played)                                 5.1354      2.128      2.413      0.018       0.907       9.363
# scale(shotsOnTotal_goalsTotalAssists_passesKey)     5.2369      2.220      2.359      0.020       0.827       9.647
# scale(dribblesAtmptsSuc)                            4.9353      2.290      2.155      0.034       0.386       9.485
# scale(gamesAppearance_sub)                         -5.0977      3.435     -1.484      0.141     -11.921       1.726
# ==============================================================================
# Omnibus:                       23.400   Durbin-Watson:                   1.831
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               42.985
# Skew:                           0.894   Prob(JB):                     4.63e-10
# Kurtosis:                       5.503   Cond. No.                         7.37
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 모델 성능 : -0.038330915556824253

# %%
# OLS - 11차

# %%
df_ols_11 = df_ols_10.drop(['games_lineups'], axis=1)
len(df_ols_10.columns), len(df_ols_11.columns)
# Out:
# (19, 18)

# %%
from sklearn.model_selection import train_test_split

df_ols = df_ols_11
dfX = df_ols.drop(['value'], axis=1)
dfy = df_ols['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

formula = "value ~ " + "+".join(feature_names)

model = sm.OLS.from_formula(formula, data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula(formula, data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
#    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.544
# Model:                            OLS   Adj. R-squared:                  0.459
# Method:                 Least Squares   F-statistic:                     6.388
# Date:                Mon, 22 Jun 2020   Prob (F-statistic):           1.36e-09
# Time:                        19:28:45   Log-Likelihood:                -436.68
# No. Observations:                 109   AIC:                             909.4
# Df Residuals:                      91   BIC:                             957.8
# Df Model:                          17
# Covariance Type:            nonrobust
# ===================================================================================================================
#                                                       coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# Intercept                                          34.9220      1.394     25.060      0.000      32.154      37.690
# scale(age)                                         -6.6163      1.874     -3.531      0.001     -10.338      -2.894
# scale(follower)                                     5.8036      1.555      3.732      0.000       2.714       8.893
# scale(passes_total)                                 2.9350      2.232      1.315      0.192      -1.499       7.370
# scale(passes_accuracy)                              5.7916      2.298      2.521      0.013       1.228      10.356
# scale(tackles_total)                                3.4517      1.877      1.839      0.069      -0.276       7.180
# scale(tackles_blocks)                              -4.8258      2.208     -2.186      0.031      -9.211      -0.441
# scale(fouls_drawn)                                 -5.2234      1.739     -3.004      0.003      -8.677      -1.770
# scale(fouls_committed)                             -4.7956      2.195     -2.185      0.031      -9.156      -0.435
# scale(cards_yellow)                                 4.3639      2.092      2.086      0.040       0.209       8.519
# scale(cards_red)                                   -3.3384      1.535     -2.175      0.032      -6.388      -0.289
# scale(penalty_commited)                            -5.1131      1.526     -3.351      0.001      -8.144      -2.082
# scale(penalty_missed)                              -2.1033      1.549     -1.357      0.178      -5.181       0.974
# scale(substitutes_out)                             -5.5367      2.159     -2.565      0.012      -9.825      -1.249
# scale(games_played)                                 5.1787      2.122      2.441      0.017       0.964       9.394
# scale(shotsOnTotal_goalsTotalAssists_passesKey)     5.2808      2.213      2.386      0.019       0.884       9.678
# scale(dribblesAtmptsSuc)                            5.1661      2.263      2.283      0.025       0.672       9.661
# scale(gamesAppearance_sub)                         -3.3072      2.417     -1.369      0.175      -8.107       1.493
# ==============================================================================
# Omnibus:                       23.106   Durbin-Watson:                   1.829
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               42.050
# Skew:                           0.887   Prob(JB):                     7.39e-10
# Kurtosis:                       5.472   Cond. No.                         4.82
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 모델 성능 : -0.01606848606656258

# %%
# OLS - 12차

# %%
df_ols_12 = df_ols_11.drop(['passes_total'], axis=1)
len(df_ols_11.columns), len(df_ols_12.columns)
# Out:
# (18, 17)

# %%
from sklearn.model_selection import train_test_split

df_ols = df_ols_12
dfX = df_ols.drop(['value'], axis=1)
dfy = df_ols['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

formula = "value ~ " + "+".join(feature_names)

model = sm.OLS.from_formula(formula, data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula(formula, data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
#    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.535
# Model:                            OLS   Adj. R-squared:                  0.455
# Method:                 Least Squares   F-statistic:                     6.627
# Date:                Mon, 22 Jun 2020   Prob (F-statistic):           1.08e-09
# Time:                        19:29:40   Log-Likelihood:                -437.70
# No. Observations:                 109   AIC:                             909.4
# Df Residuals:                      92   BIC:                             955.2
# Df Model:                          16
# Covariance Type:            nonrobust
# ===================================================================================================================
#                                                       coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# Intercept                                          34.9220      1.399     24.961      0.000      32.143      37.701
# scale(age)                                         -5.8436      1.786     -3.272      0.002      -9.391      -2.296
# scale(follower)                                     6.3106      1.513      4.172      0.000       3.306       9.315
# scale(passes_accuracy)                              6.7838      2.179      3.114      0.002       2.457      11.111
# scale(tackles_total)                                3.8686      1.857      2.083      0.040       0.180       7.557
# scale(tackles_blocks)                              -4.6130      2.210     -2.087      0.040      -9.003      -0.223
# scale(fouls_drawn)                                 -4.9125      1.729     -2.841      0.006      -8.347      -1.478
# scale(fouls_committed)                             -4.7954      2.204     -2.176      0.032      -9.173      -0.418
# scale(cards_yellow)                                 4.9016      2.059      2.380      0.019       0.812       8.992
# scale(cards_red)                                   -3.5948      1.529     -2.351      0.021      -6.631      -0.558
# scale(penalty_commited)                            -5.3575      1.520     -3.524      0.001      -8.377      -2.338
# scale(penalty_missed)                              -2.0747      1.555     -1.334      0.186      -5.164       1.015
# scale(substitutes_out)                             -5.7679      2.160     -2.670      0.009     -10.058      -1.478
# scale(games_played)                                 6.3296      1.941      3.262      0.002       2.475      10.184
# scale(shotsOnTotal_goalsTotalAssists_passesKey)     4.9228      2.205      2.232      0.028       0.543       9.303
# scale(dribblesAtmptsSuc)                            5.4997      2.257      2.436      0.017       1.017       9.983
# scale(gamesAppearance_sub)                         -2.9930      2.414     -1.240      0.218      -7.788       1.802
# ==============================================================================
# Omnibus:                       26.018   Durbin-Watson:                   1.918
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               51.199
# Skew:                           0.963   Prob(JB):                     7.63e-12
# Kurtosis:                       5.751   Cond. No.                         4.70
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 모델 성능 : 0.014237847589960306

# %%
# OLS - 13차

# %%
df_ols_13 = df_ols_12.drop(['gamesAppearance_sub'], axis=1)
len(df_ols_12.columns), len(df_ols_13.columns)
# Out:
# (17, 16)

# %%
from sklearn.model_selection import train_test_split

df_ols = df_ols_13
dfX = df_ols.drop(['value'], axis=1)
dfy = df_ols['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

formula = "value ~ " + "+".join(feature_names)

model = sm.OLS.from_formula(formula, data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula(formula, data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
#    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.528
# Model:                            OLS   Adj. R-squared:                  0.451
# Method:                 Least Squares   F-statistic:                     6.926
# Date:                Mon, 22 Jun 2020   Prob (F-statistic):           7.71e-10
# Time:                        19:30:29   Log-Likelihood:                -438.61
# No. Observations:                 109   AIC:                             909.2
# Df Residuals:                      93   BIC:                             952.3
# Df Model:                          15
# Covariance Type:            nonrobust
# ===================================================================================================================
#                                                       coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# Intercept                                          34.9220      1.403     24.890      0.000      32.136      37.708
# scale(age)                                         -5.1769      1.708     -3.031      0.003      -8.569      -1.785
# scale(follower)                                     6.2750      1.517      4.137      0.000       3.263       9.287
# scale(passes_accuracy)                              5.1844      1.761      2.945      0.004       1.688       8.681
# scale(tackles_total)                                4.0490      1.857      2.181      0.032       0.362       7.736
# scale(tackles_blocks)                              -4.1342      2.183     -1.894      0.061      -8.469       0.200
# scale(fouls_drawn)                                 -4.4102      1.686     -2.616      0.010      -7.758      -1.062
# scale(fouls_committed)                             -4.6889      2.209     -2.123      0.036      -9.075      -0.303
# scale(cards_yellow)                                 4.3854      2.023      2.168      0.033       0.369       8.402
# scale(cards_red)                                   -3.2506      1.508     -2.156      0.034      -6.245      -0.257
# scale(penalty_commited)                            -5.0282      1.501     -3.349      0.001      -8.010      -2.047
# scale(penalty_missed)                              -2.0979      1.560     -1.345      0.182      -5.195       0.999
# scale(substitutes_out)                             -6.0280      2.156     -2.796      0.006     -10.309      -1.746
# scale(games_played)                                 7.1310      1.835      3.886      0.000       3.487      10.775
# scale(shotsOnTotal_goalsTotalAssists_passesKey)     5.0525      2.209      2.287      0.024       0.665       9.440
# scale(dribblesAtmptsSuc)                            5.2037      2.251      2.312      0.023       0.734       9.674
# ==============================================================================
# Omnibus:                       27.361   Durbin-Watson:                   1.887
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               53.180
# Skew:                           1.020   Prob(JB):                     2.83e-12
# Kurtosis:                       5.747   Cond. No.                         4.07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 모델 성능 : 0.03337046945077966

# %%
# OLS - 14차

# %%
df_ols_14 = df_ols_13.drop(['penalty_missed'], axis=1)
len(df_ols_13.columns), len(df_ols_14.columns)
# Out:
# (16, 15)

# %%
from sklearn.model_selection import train_test_split

df_ols = df_ols_14
dfX = df_ols.drop(['value'], axis=1)
dfy = df_ols['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

formula = "value ~ " + "+".join(feature_names)

model = sm.OLS.from_formula(formula, data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula(formula, data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
#    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.518
# Model:                            OLS   Adj. R-squared:                  0.447
# Method:                 Least Squares   F-statistic:                     7.229
# Date:                Mon, 22 Jun 2020   Prob (F-statistic):           6.09e-10
# Time:                        19:31:33   Log-Likelihood:                -439.66
# No. Observations:                 109   AIC:                             909.3
# Df Residuals:                      94   BIC:                             949.7
# Df Model:                          14
# Covariance Type:            nonrobust
# ===================================================================================================================
#                                                       coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# Intercept                                          34.9220      1.409     24.783      0.000      32.124      37.720
# scale(age)                                         -5.4859      1.700     -3.227      0.002      -8.861      -2.111
# scale(follower)                                     6.2983      1.523      4.135      0.000       3.274       9.323
# scale(passes_accuracy)                              5.6693      1.731      3.276      0.001       2.233       9.106
# scale(tackles_total)                                4.0092      1.865      2.150      0.034       0.307       7.711
# scale(tackles_blocks)                              -4.1777      2.192     -1.906      0.060      -8.530       0.174
# scale(fouls_drawn)                                 -4.5139      1.692     -2.668      0.009      -7.873      -1.155
# scale(fouls_committed)                             -4.8796      2.214     -2.204      0.030      -9.275      -0.485
# scale(cards_yellow)                                 4.5131      2.029      2.224      0.029       0.484       8.542
# scale(cards_red)                                   -3.5907      1.493     -2.405      0.018      -6.555      -0.627
# scale(penalty_commited)                            -5.0447      1.508     -3.346      0.001      -8.038      -2.051
# scale(substitutes_out)                             -6.0614      2.165     -2.800      0.006     -10.360      -1.762
# scale(games_played)                                 6.9718      1.839      3.791      0.000       3.320      10.623
# scale(shotsOnTotal_goalsTotalAssists_passesKey)     4.4771      2.177      2.057      0.042       0.155       8.799
# scale(dribblesAtmptsSuc)                            5.1847      2.261      2.293      0.024       0.696       9.673
# ==============================================================================
# Omnibus:                       31.369   Durbin-Watson:                   1.886
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               65.876
# Skew:                           1.136   Prob(JB):                     4.96e-15
# Kurtosis:                       6.057   Cond. No.                         4.06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 모델 성능 : 0.024960367818635875

# %%
# OLS - 15차

# %%
df_ols_15 = df_ols_14.drop(['tackles_blocks'], axis=1)
len(df_ols_14.columns), len(df_ols_15.columns)
# Out:
# (15, 14)

# %%
from sklearn.model_selection import train_test_split

df_ols = df_ols_15
dfX = df_ols.drop(['value'], axis=1)
dfy = df_ols['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

formula = "value ~ " + "+".join(feature_names)

model = sm.OLS.from_formula(formula, data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula(formula, data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
#    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.500
# Model:                            OLS   Adj. R-squared:                  0.431
# Method:                 Least Squares   F-statistic:                     7.304
# Date:                Mon, 22 Jun 2020   Prob (F-statistic):           1.05e-09
# Time:                        19:32:47   Log-Likelihood:                -441.72
# No. Observations:                 109   AIC:                             911.4
# Df Residuals:                      95   BIC:                             949.1
# Df Model:                          13
# Covariance Type:            nonrobust
# ===================================================================================================================
#                                                       coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# Intercept                                          34.9220      1.428     24.447      0.000      32.086      37.758
# scale(age)                                         -5.2742      1.720     -3.067      0.003      -8.688      -1.860
# scale(follower)                                     6.2460      1.544      4.046      0.000       3.181       9.311
# scale(passes_accuracy)                              5.5767      1.754      3.180      0.002       2.095       9.059
# scale(tackles_total)                                3.2597      1.848      1.764      0.081      -0.408       6.928
# scale(fouls_drawn)                                 -4.4229      1.714     -2.580      0.011      -7.826      -1.020
# scale(fouls_committed)                             -6.2253      2.127     -2.927      0.004     -10.447      -2.003
# scale(cards_yellow)                                 4.7551      2.053      2.316      0.023       0.680       8.831
# scale(cards_red)                                   -3.4177      1.510     -2.263      0.026      -6.416      -0.419
# scale(penalty_commited)                            -4.8717      1.526     -3.193      0.002      -7.901      -1.843
# scale(substitutes_out)                             -4.8750      2.102     -2.319      0.023      -9.049      -0.701
# scale(games_played)                                 7.1876      1.861      3.862      0.000       3.493      10.882
# scale(shotsOnTotal_goalsTotalAssists_passesKey)     5.0605      2.185      2.316      0.023       0.723       9.398
# scale(dribblesAtmptsSuc)                            6.2553      2.220      2.818      0.006       1.848      10.662
# ==============================================================================
# Omnibus:                       26.950   Durbin-Watson:                   1.868
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               48.366
# Skew:                           1.046   Prob(JB):                     3.14e-11
# Kurtosis:                       5.504   Cond. No.                         3.65
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 모델 성능 : 0.02583158294777076

# %%
# OLS - 16차

# %%
df_ols_16 = df_ols_15.drop(['tackles_total'], axis=1)
len(df_ols_15.columns), len(df_ols_16.columns)
# Out:
# (14, 13)

# %%
from sklearn.model_selection import train_test_split

df_ols = df_ols_16
dfX = df_ols.drop(['value'], axis=1)
dfy = df_ols['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

formula = "value ~ " + "+".join(feature_names)

model = sm.OLS.from_formula(formula, data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula(formula, data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
#    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.483
# Model:                            OLS   Adj. R-squared:                  0.419
# Method:                 Least Squares   F-statistic:                     7.488
# Date:                Mon, 22 Jun 2020   Prob (F-statistic):           1.43e-09
# Time:                        19:33:52   Log-Likelihood:                -443.48
# No. Observations:                 109   AIC:                             913.0
# Df Residuals:                      96   BIC:                             947.9
# Df Model:                          12
# Covariance Type:            nonrobust
# ===================================================================================================================
#                                                       coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# Intercept                                          34.9220      1.444     24.182      0.000      32.055      37.789
# scale(age)                                         -4.8236      1.719     -2.806      0.006      -8.236      -1.411
# scale(follower)                                     6.0899      1.558      3.908      0.000       2.997       9.183
# scale(passes_accuracy)                              5.9575      1.760      3.386      0.001       2.465       9.450
# scale(fouls_drawn)                                 -4.8482      1.716     -2.826      0.006      -8.254      -1.443
# scale(fouls_committed)                             -4.6593      1.954     -2.385      0.019      -8.538      -0.781
# scale(cards_yellow)                                 4.3281      2.061      2.100      0.038       0.237       8.419
# scale(cards_red)                                   -3.6928      1.519     -2.431      0.017      -6.708      -0.678
# scale(penalty_commited)                            -4.8989      1.542     -3.176      0.002      -7.961      -1.837
# scale(substitutes_out)                             -5.6722      2.076     -2.733      0.007      -9.792      -1.552
# scale(games_played)                                 7.4786      1.874      3.991      0.000       3.759      11.198
# scale(shotsOnTotal_goalsTotalAssists_passesKey)     4.3665      2.173      2.010      0.047       0.054       8.679
# scale(dribblesAtmptsSuc)                            6.8446      2.219      3.085      0.003       2.441      11.249
# ==============================================================================
# Omnibus:                       28.442   Durbin-Watson:                   1.841
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               56.376
# Skew:                           1.052   Prob(JB):                     5.73e-13
# Kurtosis:                       5.825   Cond. No.                         3.38
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 모델 성능 : 0.025909713335018913

# %%
# OLS - 17차

# %%
df_ols_17 = df_ols_16.drop(['shotsOnTotal_goalsTotalAssists_passesKey'], axis=1)
len(df_ols_16.columns), len(df_ols_17.columns)
# Out:
# (13, 12)

# %%
from sklearn.model_selection import train_test_split

df_ols = df_ols_17
dfX = df_ols.drop(['value'], axis=1)
dfy = df_ols['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

formula = "value ~ " + "+".join(feature_names)

model = sm.OLS.from_formula(formula, data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula(formula, data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
#    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.462
# Model:                            OLS   Adj. R-squared:                  0.401
# Method:                 Least Squares   F-statistic:                     7.565
# Date:                Mon, 22 Jun 2020   Prob (F-statistic):           2.91e-09
# Time:                        19:35:24   Log-Likelihood:                -445.73
# No. Observations:                 109   AIC:                             915.5
# Df Residuals:                      97   BIC:                             947.7
# Df Model:                          11
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                   34.9220      1.467     23.812      0.000      32.011      37.833
# scale(age)                  -4.3275      1.728     -2.505      0.014      -7.757      -0.898
# scale(follower)              6.5320      1.567      4.170      0.000       3.423       9.641
# scale(passes_accuracy)       5.7550      1.784      3.226      0.002       2.214       9.296
# scale(fouls_drawn)          -4.4664      1.732     -2.579      0.011      -7.903      -1.030
# scale(fouls_committed)      -4.3717      1.979     -2.209      0.030      -8.299      -0.444
# scale(cards_yellow)          3.3609      2.035      1.651      0.102      -0.678       7.400
# scale(cards_red)            -3.0878      1.512     -2.042      0.044      -6.089      -0.087
# scale(penalty_commited)     -4.8943      1.566     -3.125      0.002      -8.003      -1.785
# scale(substitutes_out)      -4.2412      1.980     -2.142      0.035      -8.171      -0.311
# scale(games_played)          8.2888      1.858      4.460      0.000       4.600      11.977
# scale(dribblesAtmptsSuc)     8.5616      2.079      4.117      0.000       4.435      12.689
# ==============================================================================
# Omnibus:                       35.219   Durbin-Watson:                   1.756
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               88.151
# Skew:                           1.194   Prob(JB):                     7.22e-20
# Kurtosis:                       6.703   Cond. No.                         3.07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 모델 성능 : 0.07312325956149572

# %%
# OLS - 18차

# %%
df_ols_18 = df_ols_17.drop(['cards_yellow'], axis=1)
len(df_ols_17.columns), len(df_ols_18.columns)
# Out:
# (12, 11)

# %%
from sklearn.model_selection import train_test_split

df_ols = df_ols_18
dfX = df_ols.drop(['value'], axis=1)
dfy = df_ols['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

formula = "value ~ " + "+".join(feature_names)

model = sm.OLS.from_formula(formula, data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula(formula, data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
#    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.447
# Model:                            OLS   Adj. R-squared:                  0.390
# Method:                 Least Squares   F-statistic:                     7.909
# Date:                Mon, 22 Jun 2020   Prob (F-statistic):           3.30e-09
# Time:                        19:36:44   Log-Likelihood:                -447.24
# No. Observations:                 109   AIC:                             916.5
# Df Residuals:                      98   BIC:                             946.1
# Df Model:                          10
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                   34.9220      1.479     23.605      0.000      31.986      37.858
# scale(age)                  -4.2219      1.742     -2.424      0.017      -7.678      -0.765
# scale(follower)              6.3695      1.577      4.038      0.000       3.240       9.499
# scale(passes_accuracy)       5.4093      1.787      3.027      0.003       1.863       8.956
# scale(fouls_drawn)          -3.8767      1.709     -2.268      0.026      -7.269      -0.485
# scale(fouls_committed)      -2.6087      1.681     -1.552      0.124      -5.944       0.727
# scale(cards_red)            -2.8212      1.516     -1.860      0.066      -5.831       0.188
# scale(penalty_commited)     -4.6650      1.574     -2.964      0.004      -7.788      -1.542
# scale(substitutes_out)      -4.3591      1.996     -2.184      0.031      -8.320      -0.398
# scale(games_played)          7.8363      1.854      4.226      0.000       4.157      11.516
# scale(dribblesAtmptsSuc)     7.4038      1.975      3.749      0.000       3.485      11.323
# ==============================================================================
# Omnibus:                       34.361   Durbin-Watson:                   1.822
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               81.279
# Skew:                           1.189   Prob(JB):                     2.24e-18
# Kurtosis:                       6.498   Cond. No.                         2.60
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 모델 성능 : 0.06976565044850055

# %%
# OLS - 19차

# %%
df_ols_19 = df_ols_18.drop(['fouls_committed'], axis=1)
len(df_ols_18.columns), len(df_ols_19.columns)
# Out:
# (11, 10)

# %%
from sklearn.model_selection import train_test_split

df_ols = df_ols_19
dfX = df_ols.drop(['value'], axis=1)
dfy = df_ols['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

formula = "value ~ " + "+".join(feature_names)

model = sm.OLS.from_formula(formula, data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula(formula, data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
#    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.433
# Model:                            OLS   Adj. R-squared:                  0.381
# Method:                 Least Squares   F-statistic:                     8.401
# Date:                Mon, 22 Jun 2020   Prob (F-statistic):           3.18e-09
# Time:                        19:37:34   Log-Likelihood:                -448.56
# No. Observations:                 109   AIC:                             917.1
# Df Residuals:                      99   BIC:                             944.0
# Df Model:                           9
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                   34.9220      1.490     23.439      0.000      31.966      37.878
# scale(age)                  -4.2219      1.754     -2.407      0.018      -7.702      -0.741
# scale(follower)              6.4495      1.588      4.063      0.000       3.300       9.600
# scale(passes_accuracy)       4.4329      1.685      2.631      0.010       1.090       7.776
# scale(fouls_drawn)          -4.4813      1.676     -2.674      0.009      -7.807      -1.156
# scale(cards_red)            -2.9688      1.524     -1.948      0.054      -5.993       0.056
# scale(penalty_commited)     -4.8088      1.582     -3.039      0.003      -7.948      -1.669
# scale(substitutes_out)      -3.7262      1.968     -1.894      0.061      -7.631       0.178
# scale(games_played)          7.5571      1.859      4.066      0.000       3.869      11.245
# scale(dribblesAtmptsSuc)     7.8168      1.971      3.966      0.000       3.906      11.727
# ==============================================================================
# Omnibus:                       35.994   Durbin-Watson:                   1.772
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               86.302
# Skew:                           1.245   Prob(JB):                     1.82e-19
# Kurtosis:                       6.579   Cond. No.                         2.59
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 모델 성능 : 0.0818483829854616

# %%
# OLS - 20차

# %%
df_ols_20 = df_ols_19.drop(['substitutes_out'], axis=1)
len(df_ols_19.columns), len(df_ols_20.columns)
# Out:
# (10, 9)

# %%
from sklearn.model_selection import train_test_split

df_ols = df_ols_20
dfX = df_ols.drop(['value'], axis=1)
dfy = df_ols['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

formula = "value ~ " + "+".join(feature_names)

model = sm.OLS.from_formula(formula, data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula(formula, data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
#    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.412
# Model:                            OLS   Adj. R-squared:                  0.365
# Method:                 Least Squares   F-statistic:                     8.776
# Date:                Mon, 22 Jun 2020   Prob (F-statistic):           5.06e-09
# Time:                        19:38:37   Log-Likelihood:                -450.50
# No. Observations:                 109   AIC:                             919.0
# Df Residuals:                     100   BIC:                             943.2
# Df Model:                           8
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                   34.9220      1.509     23.141      0.000      31.928      37.916
# scale(age)                  -4.2727      1.776     -2.405      0.018      -7.797      -0.748
# scale(follower)              6.5693      1.607      4.089      0.000       3.382       9.757
# scale(passes_accuracy)       3.8527      1.678      2.296      0.024       0.524       7.182
# scale(fouls_drawn)          -4.4249      1.697     -2.607      0.011      -7.793      -1.057
# scale(cards_red)            -2.4971      1.523     -1.640      0.104      -5.519       0.524
# scale(penalty_commited)     -4.0857      1.555     -2.627      0.010      -7.171      -1.000
# scale(games_played)          8.2804      1.842      4.495      0.000       4.625      11.935
# scale(dribblesAtmptsSuc)     6.0832      1.768      3.442      0.001       2.576       9.590
# ==============================================================================
# Omnibus:                       33.419   Durbin-Watson:                   1.687
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               71.395
# Skew:                           1.206   Prob(JB):                     3.14e-16
# Kurtosis:                       6.147   Cond. No.                         2.13
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 모델 성능 : 0.06747939027351603

# %%
# OLS - 21차

# %%
df_ols_21 = df_ols_20.drop(['cards_red'], axis=1)
len(df_ols_20.columns), len(df_ols_21.columns)
# Out:
# (9, 8)

# %%
from sklearn.model_selection import train_test_split

df_ols = df_ols_21
dfX = df_ols.drop(['value'], axis=1)
dfy = df_ols['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

formula = "value ~ " + "+".join(feature_names)

model = sm.OLS.from_formula(formula, data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula(formula, data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
#    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.397
# Model:                            OLS   Adj. R-squared:                  0.355
# Method:                 Least Squares   F-statistic:                     9.487
# Date:                Mon, 22 Jun 2020   Prob (F-statistic):           5.24e-09
# Time:                        19:40:43   Log-Likelihood:                -451.94
# No. Observations:                 109   AIC:                             919.9
# Df Residuals:                     101   BIC:                             941.4
# Df Model:                           7
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                   34.9220      1.522     22.950      0.000      31.904      37.941
# scale(age)                  -4.1962      1.791     -2.343      0.021      -7.748      -0.644
# scale(follower)              6.5415      1.620      4.038      0.000       3.328       9.755
# scale(passes_accuracy)       3.7101      1.690      2.196      0.030       0.358       7.062
# scale(fouls_drawn)          -4.6234      1.707     -2.708      0.008      -8.010      -1.237
# scale(penalty_commited)     -3.9523      1.566     -2.524      0.013      -7.059      -0.846
# scale(games_played)          8.3914      1.856      4.520      0.000       4.709      12.074
# scale(dribblesAtmptsSuc)     6.1686      1.782      3.463      0.001       2.635       9.703
# ==============================================================================
# Omnibus:                       35.348   Durbin-Watson:                   1.652
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               77.299
# Skew:                           1.269   Prob(JB):                     1.64e-17
# Kurtosis:                       6.253   Cond. No.                         2.11
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 모델 성능 : 0.08006207051140081

# %% [markdown]
# # 가중치

# %%
from sklearn.model_selection import train_test_split

df_ols = df_ols_21
dfX = df_ols.drop(['value'], axis=1)
dfy = df_ols['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

formula = "value ~ scale(age) + scale(I(age**2)) + scale(I(age**3)) + \
            scale(follower) + \
            scale(passes_accuracy) + \
            scale(fouls_drawn) + \
            scale(penalty_commited) + \
            scale(games_played) + \
            scale(dribblesAtmptsSuc)"

model = sm.OLS.from_formula(formula, data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula(formula, data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
#    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.481
# Model:                            OLS   Adj. R-squared:                  0.434
# Method:                 Least Squares   F-statistic:                     10.19
# Date:                Mon, 22 Jun 2020   Prob (F-statistic):           5.71e-11
# Time:                        19:48:38   Log-Likelihood:                -443.75
# No. Observations:                 109   AIC:                             907.5
# Df Residuals:                      99   BIC:                             934.4
# Df Model:                           9
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                   34.9220      1.426     24.497      0.000      32.093      37.751
# scale(age)                -926.6236    246.801     -3.755      0.000   -1416.330    -436.917
# scale(I(age ** 2))        1835.3404    500.432      3.668      0.000     842.374    2828.306
# scale(I(age ** 3))        -916.4345    255.138     -3.592      0.001   -1422.684    -410.185
# scale(follower)              6.1919      1.523      4.067      0.000       3.171       9.213
# scale(passes_accuracy)       3.9334      1.589      2.475      0.015       0.780       7.087
# scale(fouls_drawn)          -3.2126      1.638     -1.962      0.053      -6.462       0.037
# scale(penalty_commited)     -3.9534      1.468     -2.693      0.008      -6.867      -1.040
# scale(games_played)          8.3355      1.751      4.759      0.000       4.860      11.811
# scale(dribblesAtmptsSuc)     5.6114      1.687      3.326      0.001       2.264       8.959
# ==============================================================================
# Omnibus:                       25.143   Durbin-Watson:                   1.671
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               39.695
# Skew:                           1.047   Prob(JB):                     2.40e-09
# Kurtosis:                       5.087   Cond. No.                         795.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 모델 성능 : 0.12731792378793302
