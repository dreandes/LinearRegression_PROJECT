# %% [markdown]
# # 작업할 데이터 받기

# %%
df_ols = pd.read_csv('df_OLS.csv', encoding='utf-8-sig', index_col=0)

# %%
df_ols
# Out:
#      position        age    rating  value  follower  passes_total  \
# 0    2.000000  25.000000  2.333333   20.0     67879       22.1875
# 1    4.000000  27.000000  5.250000   32.0    740918       12.3211
# 2    3.000000  24.000000  6.000000   24.0    601838       58.0175
# 3    4.000000  25.000000  7.000000   32.0    652886       23.4897
# 4    2.000000  32.000000  4.833333   32.0  11513791       32.2437
# ..        ...        ...       ...    ...       ...           ...
# 366  4.000000  28.000000  3.888889   44.0   1028085       21.4995
# 367  3.769231  23.076923  1.615385   24.0     57900        4.1158
# 368  4.000000  32.000000  6.153846   22.5   8983450       38.4786
# 369  4.000000  26.000000  6.545455   24.0    109000       16.8656
# 370  2.000000  23.000000  4.384615   44.0    282254       38.4359
#
#      passes_accuracy  tackles_total  tackles_blocks  tackles_interceptions  \
# 0             3.2985         1.2112          0.1417                 0.8504
# 1             4.0184         0.4629          0.0985                 0.2659
# 2            13.4528         1.0301          0.3802                 1.3367
# 3             9.1609         0.7758          0.1141                 0.9355
# 4             6.1453         0.4321          0.0480                 0.4225
# ..               ...            ...             ...                    ...
# 366           4.2611         1.1758          0.0216                 0.3452
# 367           2.3642         0.1397          0.0215                 0.0430
# 368           8.6552         0.7696          0.0300                 0.5297
# 369           7.4315         0.3936          0.0695                 0.3010
# 370           6.6011         1.0018          0.1371                 0.9807
#
#      ...  penalty_missed  games_lineups  games_played        hw  \
# 0    ...          0.0000         0.9277       77.6111 -0.392274
# 1    ...          0.0295         0.9947      101.5333  0.141002
# 2    ...          0.0000         1.0056       81.5444 -0.580321
# 3    ...          0.0000         0.9697       87.6556  0.741866
# 4    ...          0.0096         1.0754      104.1444 -0.008107
# ..   ...             ...            ...           ...       ...
# 366  ...          0.0000         0.9924       92.7000  0.580254
# 367  ...          0.0107         1.0531       93.0556 -1.164444
# 368  ...          0.0000         1.0294      100.0556  0.096205
# 369  ...          0.0000         0.9492       86.3889 -1.160608
# 370  ...          0.0000         1.0334       94.8333  0.376061
#
#      shotsOnTotal_goalsTotal  goasConceded_penaltySaved  \
# 0                  -1.612784                  -0.285146
# 1                   1.822336                  -0.285146
# 2                  -1.817034                  -0.285146
# 3                   0.551484                  -0.285146
# 4                   2.104335                  -0.285146
# ..                       ...                        ...
# 366                 0.448326                  -0.285146
# 367                -0.497805                  -0.285146
# 368                 1.152975                  -0.285146
# 369                 0.759456                  -0.285146
# 370                -0.098556                  -0.285146
#
#      goalsAssist_passesKey  duelsWonTotal  dribblesAtmptsSuc  \
# 0                -1.738633      -1.924682          -0.276160
# 1                -0.383844       1.580211          -0.167363
# 2                -1.744717      -0.246207          -1.650098
# 3                 1.006489       1.352523           2.219212
# 4                 2.797874      -1.700012           0.984943
# ..                     ...            ...                ...
# 366               0.257094       3.975849           4.594321
# 367              -1.725265      -2.941022          -1.572458
# 368               2.862916       0.141037           2.276803
# 369               1.050869       2.395041          -0.209080
# 370               0.096454       0.718212          -0.450281
#
#      gamesApperance_sub
# 0              2.236486
# 1             -1.808610
# 2              0.163037
# 3              4.054520
# 4              0.382540
# ..                  ...
# 366           -2.079535
# 367            0.538228
# 368            2.749932
# 369            2.181788
# 370           -0.028808
#
# [371 rows x 28 columns]

# %% [markdown]
# # position 데이터 정리 - 반올림

# %%
df_ols.position.unique()
# Out:
# array([2.        , 4.        , 3.        , 1.        , 3.33333333,
#        1.84615385, 3.43478261, 1.09090909, 3.29411765, 2.56818182,
#        2.25      , 2.4       , 3.75      , 3.2       , 1.66666667,
#        2.16666667, 2.91304348, 2.63636364, 3.76923077])

# %%
df_ols.position = df_ols.position.round()

# %%
df_ols.position.unique()
# Out:
# array([2., 4., 3., 1.])

# %% [markdown]
# # 아웃라이어 확인

# %%
from statsmodels.graphics import utils

dfX0 = df_ols.drop('value', axis=1)
dfX = sm.add_constant(dfX0)
dfy = df_ols['value']

model_p = sm.OLS(dfy, dfX)
result_p = model_p.fit()
pred = result_p.predict(dfX)

influence_p = result_p.get_influence()
cooks_d2, pvals = influence_p.cooks_distance
K = influence_p.k_vars
fox_cr = 4 / (len(dfy) - K - 1)
idx = np.where(cooks_d2 > fox_cr)[0]

ax = plt.subplot()
plt.scatter(dfy, pred)
plt.scatter(dfy[idx], pred[idx], s=300, c="r", alpha=0.5)
utils.annotate_axes(range(len(idx)), idx, list(zip(dfy[idx], pred[idx])), [(-20, 15)] * len(idx), size="small", ax=ax)
plt.title("아웃라이어")
plt.show()
print(idx)
# Out:
# [ 36  52  85 123 150 166 168 169 180 183 189 195 217 259 282 283 309 323
#  336 349]

# %% [markdown]
# # 아웃라이어 제거

# %%
idx2 = list(set(range(len(dfX))).difference(idx))
df_out = df_ols.iloc[idx2].reset_index(drop=True)

# %% [markdown]
# # 아웃라이어 제거 후, OLS with Position Categorized

# %%
from sklearn.model_selection import train_test_split

dfX = df_out.drop(['value'], axis=1)
dfy = df_out['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.drop(['position'], axis=1).columns)
feature_names = ["scale({})".format(name) for name in feature_names]

model = sm.OLS.from_formula("value ~ C(position) + " + "+".join(feature_names), data=df_train)
result = model.fit()
print(result.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.463
# Model:                            OLS   Adj. R-squared:                  0.391
# Method:                 Least Squares   F-statistic:                     6.397
# Date:                Mon, 22 Jun 2020   Prob (F-statistic):           8.90e-17
# Time:                        18:25:02   Log-Likelihood:                -941.27
# No. Observations:                 245   AIC:                             1943.
# Df Residuals:                     215   BIC:                             2048.
# Df Model:                          29
# Covariance Type:            nonrobust
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Intercept                           11.6196     14.446      0.804      0.422     -16.854      40.093
# C(position)[T.2.0]                  24.0782     14.956      1.610      0.109      -5.401      53.557
# C(position)[T.3.0]                  20.3603     15.074      1.351      0.178      -9.351      50.071
# C(position)[T.4.0]                  23.1029     15.086      1.531      0.127      -6.633      52.839
# scale(age)                          -4.6592      0.955     -4.879      0.000      -6.542      -2.777
# scale(rating)                        0.2251      1.067      0.211      0.833      -1.878       2.328
# scale(follower)                      3.8305      0.913      4.195      0.000       2.031       5.630
# scale(passes_total)                  3.5776      1.365      2.621      0.009       0.887       6.268
# scale(passes_accuracy)               3.7719      1.425      2.646      0.009       0.963       6.581
# scale(tackles_total)                -0.1466      1.216     -0.121      0.904      -2.544       2.251
# scale(tackles_blocks)               -1.7258      1.347     -1.281      0.201      -4.381       0.929
# scale(tackles_interceptions)        -0.2005      1.496     -0.134      0.894      -3.149       2.748
# scale(fouls_drawn)                  -3.6833      1.325     -2.780      0.006      -6.295      -1.072
# scale(fouls_committed)              -1.5955      1.411     -1.131      0.260      -4.377       1.186
# scale(cards_yellow)                  0.8536      1.202      0.710      0.478      -1.515       3.222
# scale(cards_yellowred)               0.0132      0.901      0.015      0.988      -1.763       1.789
# scale(cards_red)                     0.7272      0.829      0.877      0.381      -0.907       2.362
# scale(penalty_won)                   1.7976      1.097      1.639      0.103      -0.364       3.959
# scale(penalty_commited)              0.1954      0.919      0.213      0.832      -1.615       2.006
# scale(penalty_success)              -2.4537      1.153     -2.127      0.035      -4.727      -0.180
# scale(penalty_missed)                1.7409      1.118      1.557      0.121      -0.464       3.945
# scale(games_lineups)                -2.0361      0.928     -2.194      0.029      -3.865      -0.207
# scale(games_played)                  6.2958      1.152      5.464      0.000       4.025       8.567
# scale(hw)                           -1.0234      1.058     -0.967      0.334      -3.108       1.062
# scale(shotsOnTotal_goalsTotal)       5.5040      1.914      2.875      0.004       1.731       9.277
# scale(goasConceded_penaltySaved)     4.5893      2.623      1.750      0.082      -0.581       9.760
# scale(goalsAssist_passesKey)        -1.2238      1.425     -0.859      0.391      -4.033       1.585
# scale(duelsWonTotal)                 1.4864      1.490      0.998      0.319      -1.450       4.423
# scale(dribblesAtmptsSuc)             2.8110      1.538      1.827      0.069      -0.221       5.843
# scale(gamesApperance_sub)           -3.3173      1.544     -2.148      0.033      -6.361      -0.274
# ==============================================================================
# Omnibus:                        2.371   Durbin-Watson:                   2.097
# Prob(Omnibus):                  0.306   Jarque-Bera (JB):                2.213
# Skew:                           0.232   Prob(JB):                        0.331
# Kurtosis:                       3.026   Cond. No.                         91.3
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
pred = result.predict(df_test)

rss = ((df_test.value - pred) ** 2).sum()
tss = ((df_test.value - df_test.value.mean()) ** 2).sum()
rsquared = 1 - rss / tss
rsquared
# Out:
# 0.4016902445970141

# %% [markdown]
# # VIF Factor 확인

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = pd.DataFrame()
vif["VIF Factor"] = [variance_inflation_factor(dfX.values, i) for i in range(dfX.shape[1])]
vif["features"] = dfX.columns
vif.sort_values(by='VIF Factor', ascending=False)

# %% [markdown]
# `다른 변수에 의존적일 수록 VIF가 커진다.`
#
# 가장 VIF가 큰 feature들은 아래와 같다.
#
# VIF | Factor | features
# ---|---|---
# 19 | 189.332686 |	games_lineups
# 1 | 116.897291 |	age
# 20 | 49.140535 |	games_played
# 4 | 49.007109 |	goals_assists
# 2 | 42.252726 |	rating
#
#
# 하지만 위 5개 feature들은 모두 중요한 feature들로 제거할 수 없기에 VIF Factor는 무시하기로 했다.

# %% [markdown]
# # P값 큰 feature 제거 - 1차

# %%
df_out_1 = df_out.drop(['tackles_total', 'cards_yellowred'], axis=1)
len(df_out.columns), len(df_out_1.columns)

# %%
from sklearn.model_selection import train_test_split

dfX = df_out_1.drop(['value'], axis=1)
dfy = df_out_1['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.drop(['position'], axis=1).columns)
feature_names = ["scale({})".format(name) for name in feature_names]

model = sm.OLS.from_formula("value ~ C(position) + " + "+".join(feature_names), data=df_train)
result = model.fit()
print(result.summary())

# %%
pred = result.predict(df_test)

rss = ((df_test.value - pred) ** 2).sum()
tss = ((df_test.value - df_test.value.mean()) ** 2).sum()
rsquared = 1 - rss / tss
rsquared

# %% [markdown]
# # P값 큰 feature 제거 - 2차

# %%
df_out_2 = df_out_1.drop(['rating', 'tackles_interceptions', 'penalty_commited'], axis=1)
len(df_out_1.columns), len(df_out_2.columns)

# %%
from sklearn.model_selection import train_test_split

dfX = df_out_2.drop(['value'], axis=1)
dfy = df_out_2['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.drop(['position'], axis=1).columns)
feature_names = ["scale({})".format(name) for name in feature_names]

model = sm.OLS.from_formula("value ~ C(position) + " + "+".join(feature_names), data=df_train)
result = model.fit()
print(result.summary())

# %%
pred = result.predict(df_test)

rss = ((df_test.value - pred) ** 2).sum()
tss = ((df_test.value - df_test.value.mean()) ** 2).sum()
rsquared = 1 - rss / tss
rsquared

# %% [markdown]
# # P값 큰 feature 제거 - 3차

# %%
df_out_3 = df_out_2.drop(['cards_yellow'], axis=1)
len(df_out_2.columns), len(df_out_3.columns)

# %%
from sklearn.model_selection import train_test_split

dfX = df_out_3.drop(['value'], axis=1)
dfy = df_out_3['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.drop(['position'], axis=1).columns)
feature_names = ["scale({})".format(name) for name in feature_names]

model = sm.OLS.from_formula("value ~ C(position) + " + "+".join(feature_names), data=df_train)
result = model.fit()
print(result.summary())

# %%
pred = result.predict(df_test)

rss = ((df_test.value - pred) ** 2).sum()
tss = ((df_test.value - df_test.value.mean()) ** 2).sum()
rsquared = 1 - rss / tss
rsquared

# %% [markdown]
# # P값 큰 feature 제거 - 4차

# %%
df_out_4 = df_out_3.drop(['duelsWonTotal', 'fouls_committed'], axis=1)
len(df_out_3.columns), len(df_out_4.columns)

# %%
from sklearn.model_selection import train_test_split

dfX = df_out_4.drop(['value'], axis=1)
dfy = df_out_4['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.drop(['position'], axis=1).columns)
feature_names = ["scale({})".format(name) for name in feature_names]

model = sm.OLS.from_formula("value ~ C(position) + " + "+".join(feature_names), data=df_train)
result = model.fit()
print(result.summary())

# %%
pred = result.predict(df_test)

rss = ((df_test.value - pred) ** 2).sum()
tss = ((df_test.value - df_test.value.mean()) ** 2).sum()
rsquared = 1 - rss / tss
rsquared

# %% [markdown]
# # P값 큰 feature 제거 - 5차

# %%
df_out_5 = df_out_4.drop(['cards_red', 'goalsAssist_passesKey'], axis=1)
len(df_out_4.columns), len(df_out_5.columns)

# %%
from sklearn.model_selection import train_test_split

dfX = df_out_5.drop(['value'], axis=1)
dfy = df_out_5['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.drop(['position'], axis=1).columns)
feature_names = ["scale({})".format(name) for name in feature_names]

model = sm.OLS.from_formula("value ~ C(position) + " + "+".join(feature_names), data=df_train)
result = model.fit()
print(result.summary())

# %%
pred = result.predict(df_test)

rss = ((df_test.value - pred) ** 2).sum()
tss = ((df_test.value - df_test.value.mean()) ** 2).sum()
rsquared = 1 - rss / tss
rsquared

# %% [markdown]
# # P값 큰 feature 제거 - 6차

# %%
df_out_6 = df_out_5.drop(['tackles_blocks'], axis=1)
len(df_out_5.columns), len(df_out_6.columns)

# %%
from sklearn.model_selection import train_test_split

dfX = df_out_6.drop(['value'], axis=1)
dfy = df_out_6['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.drop(['position'], axis=1).columns)
feature_names = ["scale({})".format(name) for name in feature_names]

model = sm.OLS.from_formula("value ~ C(position) + " + "+".join(feature_names), data=df_train)
result = model.fit()
print(result.summary())

pred = result.predict(df_test)

rss = ((df_test.value - pred) ** 2).sum()
tss = ((df_test.value - df_test.value.mean()) ** 2).sum()
rsquared = 1 - rss / tss
rsquared

# %% [markdown]
# # P값 큰 feature 제거 - 7차

# %%
df_out_7 = df_out_6.drop(['hw'], axis=1)
len(df_out_6.columns), len(df_out_7.columns)

# %%
from sklearn.model_selection import train_test_split

dfX = df_out_7.drop(['value'], axis=1)
dfy = df_out_7['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.drop(['position'], axis=1).columns)
feature_names = ["scale({})".format(name) for name in feature_names]

model = sm.OLS.from_formula("value ~ C(position) + " + "+".join(feature_names), data=df_train)
result = model.fit()
print(result.summary())

pred = result.predict(df_test)

rss = ((df_test.value - pred) ** 2).sum()
tss = ((df_test.value - df_test.value.mean()) ** 2).sum()
rsquared = 1 - rss / tss
rsquared

# %% [markdown]
# # P값 큰 feature 제거 - 8차

# %%
df_out_8 = df_out_7.drop(['penalty_missed'], axis=1)
len(df_out_7.columns), len(df_out_8.columns)

# %%
from sklearn.model_selection import train_test_split

dfX = df_out_8.drop(['value'], axis=1)
dfy = df_out_8['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.drop(['position'], axis=1).columns)
feature_names = ["scale({})".format(name) for name in feature_names]

model = sm.OLS.from_formula("value ~ C(position) + " + "+".join(feature_names), data=df_train)
result = model.fit()
print(result.summary())

pred = result.predict(df_test)

rss = ((df_test.value - pred) ** 2).sum()
tss = ((df_test.value - df_test.value.mean()) ** 2).sum()
rsquared = 1 - rss / tss
rsquared

# %% [markdown]
# # P값 큰 feature 제거 - 9차

# %%
df_out_9 = df_out_8.drop(['penalty_success', 'penalty_won'], axis=1)
len(df_out_8.columns), len(df_out_9.columns)

# %%
from sklearn.model_selection import train_test_split

dfX = df_out_9.drop(['value'], axis=1)
dfy = df_out_9['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.drop(['position'], axis=1).columns)
feature_names = ["scale({})".format(name) for name in feature_names]

model = sm.OLS.from_formula("value ~ C(position) + " + "+".join(feature_names), data=df_train)
result = model.fit()
print(result.summary())

pred = result.predict(df_test)

rss = ((df_test.value - pred) ** 2).sum()
tss = ((df_test.value - df_test.value.mean()) ** 2).sum()
rsquared = 1 - rss / tss
rsquared

# %% [markdown]
# # P값 큰 feature 제거 - 10차

# %%
df_out_10 = df_out_9.drop(['goasConceded_penaltySaved'], axis=1)
len(df_out_9.columns), len(df_out_10.columns)

# %%
from sklearn.model_selection import train_test_split

dfX = df_out_10.drop(['value'], axis=1)
dfy = df_out_10['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.drop(['position'], axis=1).columns)
feature_names = ["scale({})".format(name) for name in feature_names]

model = sm.OLS.from_formula("value ~ C(position) + " + "+".join(feature_names), data=df_train)
result = model.fit()
print(result.summary())

pred = result.predict(df_test)

rss = ((df_test.value - pred) ** 2).sum()
tss = ((df_test.value - df_test.value.mean()) ** 2).sum()
rsquared = 1 - rss / tss
rsquared

# %% [markdown]
# # P값 큰 feature 제거 - 11차

# %%
df_out_11 = df_out_10.drop(['games_lineups'], axis=1)
len(df_out_10.columns), len(df_out_11.columns)

# %%
from sklearn.model_selection import train_test_split

dfX = df_out_11.drop(['value'], axis=1)
dfy = df_out_11['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.drop(['position'], axis=1).columns)
feature_names = ["scale({})".format(name) for name in feature_names]

model = sm.OLS.from_formula("value ~ C(position) + " + "+".join(feature_names), data=df_train)
result = model.fit()
print(result.summary())

pred = result.predict(df_test)

rss = ((df_test.value - pred) ** 2).sum()
tss = ((df_test.value - df_test.value.mean()) ** 2).sum()
rsquared = 1 - rss / tss
rsquared

# %% [markdown]
# # P값 큰 feature 제거 - 12차

# %%
df_out_12 = df_out_11.drop(['gamesApperance_sub'], axis=1)
len(df_out_11.columns), len(df_out_12.columns)

# %%
from sklearn.model_selection import train_test_split

dfX = df_out_12.drop(['value'], axis=1)
dfy = df_out_12['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.drop(['position'], axis=1).columns)
feature_names = ["scale({})".format(name) for name in feature_names]

model = sm.OLS.from_formula("value ~ C(position) + " + "+".join(feature_names), data=df_train)
result = model.fit()
print(result.summary())

pred = result.predict(df_test)

rss = ((df_test.value - pred) ** 2).sum()
tss = ((df_test.value - df_test.value.mean()) ** 2).sum()
rsquared = 1 - rss / tss
rsquared

# %% [markdown]
# # P값 큰 feature 제거 - 13차

# %%
df_out_13 = df_out_12.drop(['dribblesAtmptsSuc'], axis=1)
len(df_out_12.columns), len(df_out_13.columns)

# %%
from sklearn.model_selection import train_test_split

dfX = df_out_13.drop(['value'], axis=1)
dfy = df_out_13['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.drop(['position'], axis=1).columns)
feature_names = ["scale({})".format(name) for name in feature_names]

model = sm.OLS.from_formula("value ~ C(position) + " + "+".join(feature_names), data=df_train)
result = model.fit()
print(result.summary())

pred = result.predict(df_test)

rss = ((df_test.value - pred) ** 2).sum()
tss = ((df_test.value - df_test.value.mean()) ** 2).sum()
rsquared = 1 - rss / tss
rsquared

# %% [markdown]
# # P값 큰 feature 제거 - 14차

# %%
df_out_14 = df_out_13.drop(['fouls_drawn'], axis=1)
len(df_out_13.columns), len(df_out_14.columns)

# %%
from sklearn.model_selection import train_test_split

dfX = df_out_14.drop(['value'], axis=1)
dfy = df_out_14['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.drop(['position'], axis=1).columns)
feature_names = ["scale({})".format(name) for name in feature_names]

model = sm.OLS.from_formula("value ~ C(position) + " + "+".join(feature_names), data=df_train)
result = model.fit()
print(result.summary())

pred = result.predict(df_test)

rss = ((df_test.value - pred) ** 2).sum()
tss = ((df_test.value - df_test.value.mean()) ** 2).sum()
rsquared = 1 - rss / tss
rsquared

# %% [markdown]
# # Position 제거 후, OLS

# %%
df_out_15 = df_out_14.drop(['position'], axis=1)
len(df_out_14.columns), len(df_out_15.columns)

# %%
from sklearn.model_selection import train_test_split

dfX = df_out_15.drop(['value'], axis=1)
dfy = df_out_15['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
result = model.fit()
print(result.summary())

pred = result.predict(df_test)

rss = ((df_test.value - pred) ** 2).sum()
tss = ((df_test.value - df_test.value.mean()) ** 2).sum()
rsquared = 1 - rss / tss
rsquared

# %% [markdown]
# # P값 큰 feature 제거 - 16차

# %%
df_out_16 = df_out_15.drop(['passes_total'], axis=1)
len(df_out_15.columns), len(df_out_16.columns)

# %%
from sklearn.model_selection import train_test_split

dfX = df_out_16.drop(['value'], axis=1)
dfy = df_out_16['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
result = model.fit()
print(result.summary())

pred = result.predict(df_test)

rss = ((df_test.value - pred) ** 2).sum()
tss = ((df_test.value - df_test.value.mean()) ** 2).sum()
rsquared = 1 - rss / tss
rsquared

# %% [markdown]
# # 검증 1차

# %%
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_out_16)):
    df_train = df_out_16.iloc[idx_train]
    df_test = df_out_16.iloc[idx_test]
    
    model = sm.OLS.from_formula("value ~ scale(age) + scale(follower) + scale(passes_accuracy) + \
                                scale(games_played) + scale(shotsOnTotal_goalsTotal)", data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))

# %% [markdown]
# # 검증 2차

# %%
from sklearn.base import BaseEstimator, RegressorMixin
import statsmodels.formula.api as smf
import statsmodels.api as sm

class StatsmodelsOLS(BaseEstimator, RegressorMixin):
    def __init__(self, formula):
        self.formula = formula
        self.model = None
        self.data = None
        self.result = None
        
    def fit(self, dfX, dfy):
        self.data = pd.concat([dfX, dfy], axis=1)
        self.model = smf.ols(self.formula, data=self.data)
        self.result = self.model.fit()
        
    def predict(self, new_data):
        return self.result.predict(new_data)

# %%
from sklearn.model_selection import cross_val_score

model = StatsmodelsOLS("value ~ scale(age) + scale(follower) + scale(passes_accuracy) + \
                                scale(games_played) + scale(shotsOnTotal_goalsTotal)")
cv = KFold(10, shuffle=True, random_state=0)
cross_val_score(model, dfX, dfy, scoring="r2", cv=cv).mean()

# %% [markdown]
# # 아웃라이어 먼저 제거 후, OLS

# %%
from sklearn.model_selection import train_test_split

dfX = df_out.drop(['value'], axis=1)
dfy = df_out['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
result = model.fit()
print(result.summary())

pred = result.predict(df_test)

rss = ((df_test.value - pred) ** 2).sum()
tss = ((df_test.value - df_test.value.mean()) ** 2).sum()
rsquared = 1 - rss / tss
rsquared
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.454
# Model:                            OLS   Adj. R-squared:                  0.386
# Method:                 Least Squares   F-statistic:                     6.675
# Date:                Mon, 22 Jun 2020   Prob (F-statistic):           6.57e-17
# Time:                        18:25:43   Log-Likelihood:                -943.41
# No. Observations:                 245   AIC:                             1943.
# Df Residuals:                     217   BIC:                             2041.
# Df Model:                          27
# Covariance Type:            nonrobust
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Intercept                           33.6000      0.772     43.500      0.000      32.078      35.122
# scale(position)                     -0.7787      1.102     -0.707      0.481      -2.951       1.394
# scale(age)                          -4.7471      0.955     -4.969      0.000      -6.630      -2.864
# scale(rating)                        0.2133      1.068      0.200      0.842      -1.891       2.318
# scale(follower)                      3.7676      0.916      4.112      0.000       1.962       5.574
# scale(passes_total)                  3.8176      1.361      2.804      0.005       1.135       6.501
# scale(passes_accuracy)               3.5442      1.416      2.504      0.013       0.754       6.334
# scale(tackles_total)                -0.0850      1.215     -0.070      0.944      -2.479       2.309
# scale(tackles_blocks)               -2.0056      1.278     -1.570      0.118      -4.524       0.512
# scale(tackles_interceptions)        -0.3382      1.486     -0.228      0.820      -3.267       2.590
# scale(fouls_drawn)                  -3.8023      1.329     -2.861      0.005      -6.422      -1.183
# scale(fouls_committed)              -1.4104      1.410     -1.000      0.318      -4.190       1.369
# scale(cards_yellow)                  0.9712      1.196      0.812      0.418      -1.387       3.329
# scale(cards_yellowred)              -0.0012      0.905     -0.001      0.999      -1.784       1.782
# scale(cards_red)                     0.7101      0.832      0.853      0.395      -0.931       2.351
# scale(penalty_won)                   1.7598      1.101      1.598      0.111      -0.410       3.930
# scale(penalty_commited)             -0.0204      0.902     -0.023      0.982      -1.799       1.758
# scale(penalty_success)              -2.3100      1.156     -1.999      0.047      -4.588      -0.032
# scale(penalty_missed)                1.6982      1.121      1.515      0.131      -0.512       3.908
# scale(games_lineups)                -1.7074      0.916     -1.864      0.064      -3.513       0.098
# scale(games_played)                  5.9622      1.133      5.262      0.000       3.729       8.196
# scale(hw)                           -0.5934      1.028     -0.577      0.564      -2.620       1.433
# scale(shotsOnTotal_goalsTotal)       6.3203      1.812      3.488      0.001       2.749       9.892
# scale(goasConceded_penaltySaved)     0.9151      1.239      0.738      0.461      -1.528       3.358
# scale(goalsAssist_passesKey)        -1.3436      1.424     -0.944      0.346      -4.150       1.463
# scale(duelsWonTotal)                 1.8586      1.482      1.254      0.211      -1.063       4.780
# scale(dribblesAtmptsSuc)             2.4475      1.533      1.597      0.112      -0.574       5.469
# scale(gamesApperance_sub)           -2.8586      1.510     -1.893      0.060      -5.835       0.118
# ==============================================================================
# Omnibus:                        3.809   Durbin-Watson:                   2.081
# Prob(Omnibus):                  0.149   Jarque-Bera (JB):                3.566
# Skew:                           0.292   Prob(JB):                        0.168
# Kurtosis:                       3.092   Cond. No.                         6.73
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.428758806890296

# %% [markdown]
# # VIF Factor 확인

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = pd.DataFrame()
vif["VIF Factor"] = [variance_inflation_factor(dfX.values, i) for i in range(dfX.shape[1])]
vif["features"] = dfX.columns
vif.sort_values(by='VIF Factor', ascending=False)
# Out:
#     VIF Factor                   features
# 18  168.340850              games_lineups
# 1   114.777359                        age
# 19   48.141862               games_played
# 2    41.385453                     rating
# 5    28.546988            passes_accuracy
# 0    21.820481                   position
# 10   18.356539            fouls_committed
# 4    17.160414               passes_total
# 8    13.108061      tackles_interceptions
# 11   10.571770               cards_yellow
# 9    10.454331                fouls_drawn
# 6     8.695544              tackles_total
# 21    5.975453    shotsOnTotal_goalsTotal
# 7     4.741032             tackles_blocks
# 25    3.839697          dribblesAtmptsSuc
# 24    3.406575              duelsWonTotal
# 26    3.400618         gamesApperance_sub
# 23    3.079480      goalsAssist_passesKey
# 16    2.954165            penalty_success
# 14    2.832978                penalty_won
# 17    2.497690             penalty_missed
# 22    2.430726  goasConceded_penaltySaved
# 15    2.000108           penalty_commited
# 12    1.709078            cards_yellowred
# 3     1.652145                   follower
# 13    1.391397                  cards_red
# 20    1.304013                         hw

# %% [markdown]
# # 큰 P값 feature 제거 - 1차

# %%
df_out_1 = df_out.drop(['cards_yellowred', 'penalty_commited', 'tackles_total'], axis=1)
len(df_out.columns), len(df_out_1.columns)
# Out:
# (28, 25)

# %%
from sklearn.model_selection import train_test_split

dfX = df_out_1.drop(['value'], axis=1)
dfy = df_out_1['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
#    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.454
# Model:                            OLS   Adj. R-squared:                  0.394
# Method:                 Least Squares   F-statistic:                     7.613
# Date:                Mon, 22 Jun 2020   Prob (F-statistic):           3.18e-18
# Time:                        18:29:33   Log-Likelihood:                -943.41
# No. Observations:                 245   AIC:                             1937.
# Df Residuals:                     220   BIC:                             2024.
# Df Model:                          24
# Covariance Type:            nonrobust
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Intercept                           33.6000      0.767     43.799      0.000      32.088      35.112
# scale(position)                     -0.7654      1.069     -0.716      0.475      -2.873       1.342
# scale(age)                          -4.7478      0.945     -5.023      0.000      -6.611      -2.885
# scale(rating)                        0.2042      1.050      0.194      0.846      -1.865       2.274
# scale(follower)                      3.7654      0.905      4.163      0.000       1.983       5.548
# scale(passes_total)                  3.8105      1.345      2.834      0.005       1.161       6.461
# scale(passes_accuracy)               3.5482      1.404      2.527      0.012       0.781       6.316
# scale(tackles_blocks)               -2.0066      1.268     -1.583      0.115      -4.505       0.492
# scale(tackles_interceptions)        -0.3701      1.394     -0.265      0.791      -3.118       2.378
# scale(fouls_drawn)                  -3.7733      1.256     -3.004      0.003      -6.249      -1.298
# scale(fouls_committed)              -1.4279      1.364     -1.047      0.296      -4.116       1.260
# scale(cards_yellow)                  0.9778      1.159      0.844      0.400      -1.305       3.261
# scale(cards_red)                     0.7078      0.824      0.859      0.391      -0.916       2.332
# scale(penalty_won)                   1.7620      1.086      1.623      0.106      -0.378       3.902
# scale(penalty_success)              -2.3102      1.148     -2.013      0.045      -4.572      -0.049
# scale(penalty_missed)                1.6930      1.104      1.533      0.127      -0.484       3.869
# scale(games_lineups)                -1.7039      0.904     -1.886      0.061      -3.485       0.077
# scale(games_played)                  5.9766      1.105      5.409      0.000       3.799       8.154
# scale(hw)                           -0.6096      0.995     -0.613      0.541      -2.570       1.351
# scale(shotsOnTotal_goalsTotal)       6.3326      1.790      3.537      0.000       2.804       9.861
# scale(goasConceded_penaltySaved)     0.9222      1.225      0.753      0.452      -1.492       3.337
# scale(goalsAssist_passesKey)        -1.3388      1.406     -0.952      0.342      -4.109       1.431
# scale(duelsWonTotal)                 1.8244      1.360      1.342      0.181      -0.855       4.504
# scale(dribblesAtmptsSuc)             2.4400      1.497      1.630      0.105      -0.510       5.390
# scale(gamesApperance_sub)           -2.8495      1.474     -1.933      0.055      -5.755       0.056
# ==============================================================================
# Omnibus:                        3.833   Durbin-Watson:                   2.081
# Prob(Omnibus):                  0.147   Jarque-Bera (JB):                3.589
# Skew:                           0.293   Prob(JB):                        0.166
# Kurtosis:                       3.094   Cond. No.                         6.35
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 모델 성능 : 0.1488789678502215

# %% [markdown]
# # 큰 P값 feature 제거 - 2차

# %%
df_out_2 = df_out_1.drop(['rating'], axis=1)
len(df_out_1.columns), len(df_out_2.columns)
# Out:
# (25, 24)

# %%
from sklearn.model_selection import train_test_split

dfX = df_out_2.drop(['value'], axis=1)
dfy = df_out_2['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
#    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.454
# Model:                            OLS   Adj. R-squared:                  0.397
# Method:                 Least Squares   F-statistic:                     7.977
# Date:                Mon, 22 Jun 2020   Prob (F-statistic):           1.12e-18
# Time:                        18:29:49   Log-Likelihood:                -943.44
# No. Observations:                 245   AIC:                             1935.
# Df Residuals:                     221   BIC:                             2019.
# Df Model:                          23
# Covariance Type:            nonrobust
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Intercept                           33.6000      0.765     43.894      0.000      32.091      35.109
# scale(position)                     -0.7579      1.066     -0.711      0.478      -2.859       1.343
# scale(age)                          -4.7626      0.940     -5.066      0.000      -6.615      -2.910
# scale(follower)                      3.7638      0.903      4.170      0.000       1.985       5.542
# scale(passes_total)                  3.8276      1.339      2.859      0.005       1.189       6.466
# scale(passes_accuracy)               3.6698      1.255      2.925      0.004       1.197       6.142
# scale(tackles_blocks)               -2.0100      1.265     -1.589      0.113      -4.503       0.483
# scale(tackles_interceptions)        -0.3259      1.373     -0.237      0.813      -3.031       2.379
# scale(fouls_drawn)                  -3.7727      1.253     -3.010      0.003      -6.243      -1.303
# scale(fouls_committed)              -1.3902      1.347     -1.032      0.303      -4.045       1.265
# scale(cards_yellow)                  0.9823      1.156      0.850      0.396      -1.295       3.260
# scale(cards_red)                     0.6986      0.821      0.851      0.396      -0.919       2.316
# scale(penalty_won)                   1.7704      1.083      1.635      0.103      -0.363       3.904
# scale(penalty_success)              -2.2889      1.140     -2.008      0.046      -4.535      -0.043
# scale(penalty_missed)                1.6755      1.098      1.526      0.129      -0.489       3.840
# scale(games_lineups)                -1.7145      0.900     -1.905      0.058      -3.488       0.059
# scale(games_played)                  6.0262      1.073      5.618      0.000       3.912       8.140
# scale(hw)                           -0.6332      0.985     -0.643      0.521      -2.574       1.308
# scale(shotsOnTotal_goalsTotal)       6.3782      1.771      3.601      0.000       2.888       9.869
# scale(goasConceded_penaltySaved)     0.9689      1.199      0.808      0.420      -1.394       3.331
# scale(goalsAssist_passesKey)        -1.2929      1.383     -0.935      0.351      -4.018       1.432
# scale(duelsWonTotal)                 1.8215      1.356      1.343      0.181      -0.852       4.495
# scale(dribblesAtmptsSuc)             2.4488      1.493      1.640      0.102      -0.494       5.391
# scale(gamesApperance_sub)           -2.8902      1.456     -1.985      0.048      -5.760      -0.021
# ==============================================================================
# Omnibus:                        3.614   Durbin-Watson:                   2.084
# Prob(Omnibus):                  0.164   Jarque-Bera (JB):                3.398
# Skew:                           0.286   Prob(JB):                        0.183
# Kurtosis:                       3.070   Cond. No.                         6.26
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 모델 성능 : 0.15406388318769143

# %% [markdown]
# # 큰 P값 feature 제거 - 3차

# %%
df_out_3 = df_out_2.drop(['tackles_interceptions'], axis=1)
len(df_out_2.columns), len(df_out_3.columns)
# Out:
# (24, 23)

# %%
from sklearn.model_selection import train_test_split

dfX = df_out_3.drop(['value'], axis=1)
dfy = df_out_3['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
#    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.453
# Model:                            OLS   Adj. R-squared:                  0.399
# Method:                 Least Squares   F-statistic:                     8.373
# Date:                Mon, 22 Jun 2020   Prob (F-statistic):           3.90e-19
# Time:                        18:30:04   Log-Likelihood:                -943.47
# No. Observations:                 245   AIC:                             1933.
# Df Residuals:                     222   BIC:                             2013.
# Df Model:                          22
# Covariance Type:            nonrobust
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Intercept                           33.6000      0.764     43.988      0.000      32.095      35.105
# scale(position)                     -0.7507      1.063     -0.706      0.481      -2.847       1.345
# scale(age)                          -4.7689      0.938     -5.086      0.000      -6.617      -2.921
# scale(follower)                      3.7833      0.897      4.218      0.000       2.016       5.551
# scale(passes_total)                  3.7455      1.291      2.902      0.004       1.202       6.289
# scale(passes_accuracy)               3.6452      1.248      2.922      0.004       1.187       6.104
# scale(tackles_blocks)               -2.0763      1.231     -1.686      0.093      -4.502       0.350
# scale(fouls_drawn)                  -3.7447      1.245     -3.008      0.003      -6.198      -1.291
# scale(fouls_committed)              -1.4283      1.335     -1.070      0.286      -4.059       1.202
# scale(cards_yellow)                  0.9461      1.143      0.828      0.409      -1.307       3.199
# scale(cards_red)                     0.6871      0.818      0.840      0.402      -0.924       2.298
# scale(penalty_won)                   1.7893      1.077      1.661      0.098      -0.334       3.913
# scale(penalty_success)              -2.2997      1.136     -2.024      0.044      -4.539      -0.060
# scale(penalty_missed)                1.6709      1.096      1.525      0.129      -0.489       3.830
# scale(games_lineups)                -1.7184      0.898     -1.914      0.057      -3.488       0.051
# scale(games_played)                  6.0312      1.070      5.635      0.000       3.922       8.140
# scale(hw)                           -0.6522      0.980     -0.666      0.506      -2.583       1.278
# scale(shotsOnTotal_goalsTotal)       6.4810      1.714      3.782      0.000       3.104       9.858
# scale(goasConceded_penaltySaved)     1.0303      1.168      0.882      0.379      -1.272       3.332
# scale(goalsAssist_passesKey)        -1.2732      1.377     -0.924      0.356      -3.987       1.441
# scale(duelsWonTotal)                 1.7792      1.342      1.326      0.186      -0.865       4.424
# scale(dribblesAtmptsSuc)             2.4485      1.490      1.643      0.102      -0.488       5.385
# scale(gamesApperance_sub)           -2.8634      1.449     -1.977      0.049      -5.718      -0.009
# ==============================================================================
# Omnibus:                        3.746   Durbin-Watson:                   2.088
# Prob(Omnibus):                  0.154   Jarque-Bera (JB):                3.543
# Skew:                           0.293   Prob(JB):                        0.170
# Kurtosis:                       3.062   Cond. No.                         6.08
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 모델 성능 : 0.15575234010994476

# %% [markdown]
# # 큰 P값 feature 제거 - 4차

# %%
df_out_4 = df_out_3.drop(['hw'], axis=1)
len(df_out_3.columns), len(df_out_4.columns)
# Out:
# (23, 22)

# %%
from sklearn.model_selection import train_test_split

dfX = df_out_4.drop(['value'], axis=1)
dfy = df_out_4['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
#    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.452
# Model:                            OLS   Adj. R-squared:                  0.401
# Method:                 Least Squares   F-statistic:                     8.772
# Date:                Mon, 22 Jun 2020   Prob (F-statistic):           1.58e-19
# Time:                        18:30:14   Log-Likelihood:                -943.71
# No. Observations:                 245   AIC:                             1931.
# Df Residuals:                     223   BIC:                             2008.
# Df Model:                          21
# Covariance Type:            nonrobust
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Intercept                           33.6000      0.763     44.043      0.000      32.097      35.103
# scale(position)                     -0.6868      1.058     -0.649      0.517      -2.771       1.398
# scale(age)                          -4.7946      0.936     -5.124      0.000      -6.639      -2.951
# scale(follower)                      3.8280      0.893      4.286      0.000       2.068       5.588
# scale(passes_total)                  3.8592      1.278      3.020      0.003       1.341       6.377
# scale(passes_accuracy)               3.7232      1.241      3.001      0.003       1.279       6.168
# scale(tackles_blocks)               -1.9769      1.221     -1.620      0.107      -4.382       0.428
# scale(fouls_drawn)                  -3.8321      1.237     -3.099      0.002      -6.269      -1.395
# scale(fouls_committed)              -1.2732      1.313     -0.970      0.333      -3.860       1.314
# scale(cards_yellow)                  0.8034      1.122      0.716      0.475      -1.407       3.014
# scale(cards_red)                     0.7322      0.814      0.900      0.369      -0.871       2.336
# scale(penalty_won)                   1.7806      1.076      1.655      0.099      -0.340       3.901
# scale(penalty_success)              -2.2935      1.135     -2.021      0.045      -4.530      -0.057
# scale(penalty_missed)                1.6067      1.090      1.474      0.142      -0.542       3.755
# scale(games_lineups)                -1.7327      0.897     -1.933      0.055      -3.500       0.034
# scale(games_played)                  6.0444      1.069      5.656      0.000       3.938       8.150
# scale(shotsOnTotal_goalsTotal)       6.7097      1.677      4.001      0.000       3.405      10.014
# scale(goasConceded_penaltySaved)     1.2211      1.131      1.080      0.281      -1.007       3.450
# scale(goalsAssist_passesKey)        -1.4521      1.349     -1.076      0.283      -4.111       1.206
# scale(duelsWonTotal)                 1.9046      1.327      1.435      0.153      -0.710       4.520
# scale(dribblesAtmptsSuc)             2.2675      1.463      1.550      0.123      -0.616       5.151
# scale(gamesApperance_sub)           -2.9146      1.445     -2.017      0.045      -5.762      -0.067
# ==============================================================================
# Omnibus:                        3.778   Durbin-Watson:                   2.085
# Prob(Omnibus):                  0.151   Jarque-Bera (JB):                3.589
# Skew:                           0.295   Prob(JB):                        0.166
# Kurtosis:                       3.052   Cond. No.                         6.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 모델 성능 : 0.15091892463407913

# %% [markdown]
# # 큰 P값 feature 제거 - 5차

# %%
df_out_5 = df_out_4.drop(['position'], axis=1)
len(df_out_4.columns), len(df_out_5.columns)
# Out:
# (22, 21)

# %%
from sklearn.model_selection import train_test_split

dfX = df_out_5.drop(['value'], axis=1)
dfy = df_out_5['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
#    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.451
# Model:                            OLS   Adj. R-squared:                  0.402
# Method:                 Least Squares   F-statistic:                     9.214
# Date:                Mon, 22 Jun 2020   Prob (F-statistic):           6.15e-20
# Time:                        18:30:23   Log-Likelihood:                -943.94
# No. Observations:                 245   AIC:                             1930.
# Df Residuals:                     224   BIC:                             2003.
# Df Model:                          20
# Covariance Type:            nonrobust
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Intercept                           33.6000      0.762     44.100      0.000      32.099      35.101
# scale(age)                          -4.8276      0.933     -5.174      0.000      -6.666      -2.989
# scale(follower)                      3.8013      0.891      4.266      0.000       2.045       5.557
# scale(passes_total)                  4.0448      1.244      3.252      0.001       1.594       6.496
# scale(passes_accuracy)               3.7035      1.239      2.990      0.003       1.263       6.144
# scale(tackles_blocks)               -2.0779      1.209     -1.719      0.087      -4.460       0.305
# scale(fouls_drawn)                  -3.7664      1.231     -3.060      0.002      -6.192      -1.341
# scale(fouls_committed)              -1.2752      1.311     -0.973      0.332      -3.858       1.308
# scale(cards_yellow)                  0.8770      1.114      0.787      0.432      -1.319       3.073
# scale(cards_red)                     0.6482      0.802      0.808      0.420      -0.933       2.229
# scale(penalty_won)                   1.6399      1.053      1.558      0.121      -0.434       3.714
# scale(penalty_success)              -2.2319      1.130     -1.976      0.049      -4.458      -0.006
# scale(penalty_missed)                1.5486      1.085      1.427      0.155      -0.590       3.687
# scale(games_lineups)                -1.6697      0.890     -1.876      0.062      -3.424       0.084
# scale(games_played)                  6.0014      1.065      5.634      0.000       3.902       8.101
# scale(shotsOnTotal_goalsTotal)       6.4548      1.628      3.964      0.000       3.246       9.663
# scale(goasConceded_penaltySaved)     1.5066      1.041      1.448      0.149      -0.544       3.557
# scale(goalsAssist_passesKey)        -1.3631      1.340     -1.017      0.310      -4.004       1.278
# scale(duelsWonTotal)                 1.9029      1.325      1.436      0.152      -0.709       4.514
# scale(dribblesAtmptsSuc)             2.3049      1.460      1.579      0.116      -0.572       5.182
# scale(gamesApperance_sub)           -2.8326      1.437     -1.971      0.050      -5.665      -0.000
# ==============================================================================
# Omnibus:                        4.127   Durbin-Watson:                   2.078
# Prob(Omnibus):                  0.127   Jarque-Bera (JB):                3.953
# Skew:                           0.310   Prob(JB):                        0.139
# Kurtosis:                       3.048   Cond. No.                         5.90
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 모델 성능 : 0.1584859257951757

# %% [markdown]
# # 큰 P값 feature 제거 - 6차

# %%
df_out_6 = df_out_5.drop(['cards_yellow'], axis=1)
len(df_out_5.columns), len(df_out_6.columns)
# Out:
# (21, 20)

# %%
from sklearn.model_selection import train_test_split

dfX = df_out_6.drop(['value'], axis=1)
dfy = df_out_6['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
#    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.450
# Model:                            OLS   Adj. R-squared:                  0.403
# Method:                 Least Squares   F-statistic:                     9.682
# Date:                Mon, 22 Jun 2020   Prob (F-statistic):           2.56e-20
# Time:                        18:30:30   Log-Likelihood:                -944.28
# No. Observations:                 245   AIC:                             1929.
# Df Residuals:                     225   BIC:                             1999.
# Df Model:                          19
# Covariance Type:            nonrobust
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Intercept                           33.6000      0.761     44.137      0.000      32.100      35.100
# scale(age)                          -4.8431      0.932     -5.196      0.000      -6.680      -3.006
# scale(follower)                      3.7710      0.890      4.239      0.000       2.018       5.524
# scale(passes_total)                  4.0805      1.242      3.286      0.001       1.633       6.528
# scale(passes_accuracy)               3.7103      1.237      2.998      0.003       1.272       6.149
# scale(tackles_blocks)               -2.0556      1.208     -1.702      0.090      -4.435       0.324
# scale(fouls_drawn)                  -3.5342      1.194     -2.960      0.003      -5.887      -1.181
# scale(fouls_committed)              -0.6876      1.077     -0.639      0.524      -2.809       1.434
# scale(cards_red)                     0.7275      0.795      0.915      0.361      -0.840       2.295
# scale(penalty_won)                   1.5457      1.045      1.479      0.140      -0.513       3.605
# scale(penalty_success)              -2.1767      1.126     -1.932      0.055      -4.396       0.043
# scale(penalty_missed)                1.5232      1.084      1.406      0.161      -0.612       3.659
# scale(games_lineups)                -1.6629      0.889     -1.870      0.063      -3.415       0.090
# scale(games_played)                  6.0496      1.063      5.693      0.000       3.956       8.144
# scale(shotsOnTotal_goalsTotal)       6.2307      1.602      3.890      0.000       3.074       9.387
# scale(goasConceded_penaltySaved)     1.3873      1.029      1.349      0.179      -0.640       3.414
# scale(goalsAssist_passesKey)        -1.4551      1.334     -1.091      0.277      -4.084       1.174
# scale(duelsWonTotal)                 1.6743      1.292      1.296      0.196      -0.872       4.220
# scale(dribblesAtmptsSuc)             2.2856      1.459      1.567      0.119      -0.589       5.160
# scale(gamesApperance_sub)           -2.8209      1.436     -1.964      0.051      -5.651       0.009
# ==============================================================================
# Omnibus:                        4.382   Durbin-Watson:                   2.080
# Prob(Omnibus):                  0.112   Jarque-Bera (JB):                4.175
# Skew:                           0.317   Prob(JB):                        0.124
# Kurtosis:                       3.076   Cond. No.                         5.77
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 모델 성능 : 0.16006970090875877

# %% [markdown]
# # 큰 P값 feature 제거 - 7차

# %%
df_out_7 = df_out_6.drop(['fouls_committed'], axis=1)
len(df_out_6.columns), len(df_out_7.columns)
# Out:
# (20, 19)

# %%
from sklearn.model_selection import train_test_split

dfX = df_out_7.drop(['value'], axis=1)
dfy = df_out_7['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
#    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.449
# Model:                            OLS   Adj. R-squared:                  0.405
# Method:                 Least Squares   F-statistic:                     10.22
# Date:                Mon, 22 Jun 2020   Prob (F-statistic):           9.43e-21
# Time:                        18:30:40   Log-Likelihood:                -944.50
# No. Observations:                 245   AIC:                             1927.
# Df Residuals:                     226   BIC:                             1994.
# Df Model:                          18
# Covariance Type:            nonrobust
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Intercept                           33.6000      0.760     44.195      0.000      32.102      35.098
# scale(age)                          -4.9003      0.927     -5.288      0.000      -6.726      -3.074
# scale(follower)                      3.8361      0.883      4.347      0.000       2.097       5.575
# scale(passes_total)                  4.0315      1.238      3.257      0.001       1.592       6.471
# scale(passes_accuracy)               3.7642      1.233      3.053      0.003       1.335       6.194
# scale(tackles_blocks)               -2.0250      1.205     -1.680      0.094      -4.400       0.350
# scale(fouls_drawn)                  -3.6713      1.173     -3.130      0.002      -5.983      -1.360
# scale(cards_red)                     0.7021      0.793      0.885      0.377      -0.861       2.265
# scale(penalty_won)                   1.5218      1.043      1.459      0.146      -0.533       3.577
# scale(penalty_success)              -2.1239      1.122     -1.893      0.060      -4.335       0.087
# scale(penalty_missed)                1.4012      1.065      1.315      0.190      -0.698       3.500
# scale(games_lineups)                -1.6920      0.887     -1.907      0.058      -3.440       0.056
# scale(games_played)                  6.1593      1.047      5.881      0.000       4.096       8.223
# scale(shotsOnTotal_goalsTotal)       6.1943      1.599      3.875      0.000       3.044       9.344
# scale(goasConceded_penaltySaved)     1.4778      1.017      1.453      0.148      -0.527       3.483
# scale(goalsAssist_passesKey)        -1.4230      1.331     -1.069      0.286      -4.047       1.201
# scale(duelsWonTotal)                 1.3010      1.151      1.131      0.259      -0.966       3.568
# scale(dribblesAtmptsSuc)             2.5553      1.394      1.833      0.068      -0.192       5.303
# scale(gamesApperance_sub)           -2.9582      1.418     -2.086      0.038      -5.753      -0.164
# ==============================================================================
# Omnibus:                        4.349   Durbin-Watson:                   2.081
# Prob(Omnibus):                  0.114   Jarque-Bera (JB):                4.093
# Skew:                           0.312   Prob(JB):                        0.129
# Kurtosis:                       3.112   Cond. No.                         5.63
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 모델 성능 : 0.15368134190777555

# %% [markdown]
# # 큰 P값 feature 제거 - 8차

# %%
df_out_8 = df_out_7.drop(['cards_red'], axis=1)
len(df_out_7.columns), len(df_out_8.columns)
# Out:
# (19, 18)

# %%
from sklearn.model_selection import train_test_split

dfX = df_out_8.drop(['value'], axis=1)
dfy = df_out_8['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
#    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.447
# Model:                            OLS   Adj. R-squared:                  0.406
# Method:                 Least Squares   F-statistic:                     10.79
# Date:                Mon, 22 Jun 2020   Prob (F-statistic):           4.02e-21
# Time:                        18:30:53   Log-Likelihood:                -944.93
# No. Observations:                 245   AIC:                             1926.
# Df Residuals:                     227   BIC:                             1989.
# Df Model:                          17
# Covariance Type:            nonrobust
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Intercept                           33.6000      0.760     44.216      0.000      32.103      35.097
# scale(age)                          -4.8496      0.924     -5.246      0.000      -6.671      -3.028
# scale(follower)                      3.7933      0.881      4.307      0.000       2.058       5.529
# scale(passes_total)                  3.9942      1.237      3.230      0.001       1.558       6.431
# scale(passes_accuracy)               3.7643      1.232      3.054      0.003       1.336       6.193
# scale(tackles_blocks)               -1.9843      1.204     -1.649      0.101      -4.356       0.388
# scale(fouls_drawn)                  -3.6386      1.172     -3.105      0.002      -5.948      -1.330
# scale(penalty_won)                   1.4468      1.039      1.393      0.165      -0.600       3.494
# scale(penalty_success)              -2.0421      1.118     -1.827      0.069      -4.244       0.160
# scale(penalty_missed)                1.5190      1.056      1.438      0.152      -0.563       3.601
# scale(games_lineups)                -1.6398      0.885     -1.854      0.065      -3.383       0.103
# scale(games_played)                  6.1444      1.047      5.870      0.000       4.082       8.207
# scale(shotsOnTotal_goalsTotal)       6.1913      1.598      3.875      0.000       3.043       9.340
# scale(goasConceded_penaltySaved)     1.5423      1.014      1.521      0.130      -0.456       3.541
# scale(goalsAssist_passesKey)        -1.5359      1.325     -1.159      0.247      -4.146       1.074
# scale(duelsWonTotal)                 1.2934      1.150      1.125      0.262      -0.973       3.559
# scale(dribblesAtmptsSuc)             2.6691      1.388      1.923      0.056      -0.065       5.403
# scale(gamesApperance_sub)           -2.8902      1.415     -2.042      0.042      -5.679      -0.101
# ==============================================================================
# Omnibus:                        4.571   Durbin-Watson:                   2.090
# Prob(Omnibus):                  0.102   Jarque-Bera (JB):                4.326
# Skew:                           0.321   Prob(JB):                        0.115
# Kurtosis:                       3.109   Cond. No.                         5.62
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 모델 성능 : 0.16393156844944037

# %% [markdown]
# # 큰 P값 feature 제거 - 9차

# %%
df_out_9 = df_out_8.drop(['duelsWonTotal'], axis=1)
len(df_out_8.columns), len(df_out_9.columns)
# Out:
# (18, 17)

# %%
from sklearn.model_selection import train_test_split

dfX = df_out_9.drop(['value'], axis=1)
dfy = df_out_9['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
#    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.444
# Model:                            OLS   Adj. R-squared:                  0.405
# Method:                 Least Squares   F-statistic:                     11.37
# Date:                Mon, 22 Jun 2020   Prob (F-statistic):           2.08e-21
# Time:                        18:31:02   Log-Likelihood:                -945.61
# No. Observations:                 245   AIC:                             1925.
# Df Residuals:                     228   BIC:                             1985.
# Df Model:                          16
# Covariance Type:            nonrobust
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Intercept                           33.6000      0.760     44.191      0.000      32.102      35.098
# scale(age)                          -4.7948      0.924     -5.191      0.000      -6.615      -2.975
# scale(follower)                      3.7210      0.879      4.234      0.000       1.989       5.453
# scale(passes_total)                  4.0284      1.237      3.257      0.001       1.591       6.466
# scale(passes_accuracy)               3.9472      1.222      3.229      0.001       1.539       6.356
# scale(tackles_blocks)               -1.6878      1.175     -1.436      0.152      -4.003       0.628
# scale(fouls_drawn)                  -3.0844      1.064     -2.899      0.004      -5.180      -0.988
# scale(penalty_won)                   1.3530      1.036      1.306      0.193      -0.689       3.395
# scale(penalty_success)              -2.0518      1.118     -1.835      0.068      -4.255       0.151
# scale(penalty_missed)                1.4051      1.052      1.335      0.183      -0.668       3.478
# scale(games_lineups)                -1.7230      0.882     -1.953      0.052      -3.461       0.015
# scale(games_played)                  6.2055      1.046      5.933      0.000       4.145       8.266
# scale(shotsOnTotal_goalsTotal)       6.4107      1.587      4.040      0.000       3.284       9.537
# scale(goasConceded_penaltySaved)     1.2979      0.991      1.309      0.192      -0.655       3.251
# scale(goalsAssist_passesKey)        -1.7291      1.314     -1.316      0.190      -4.319       0.860
# scale(dribblesAtmptsSuc)             3.3077      1.267      2.611      0.010       0.811       5.804
# scale(gamesApperance_sub)           -3.1436      1.398     -2.249      0.025      -5.898      -0.389
# ==============================================================================
# Omnibus:                        4.772   Durbin-Watson:                   2.076
# Prob(Omnibus):                  0.092   Jarque-Bera (JB):                4.521
# Skew:                           0.327   Prob(JB):                        0.104
# Kurtosis:                       3.118   Cond. No.                         5.47
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 모델 성능 : 0.17025299343438988

# %% [markdown]
# # 큰 P값 feature 제거 - 10차

# %%
df_out_10 = df_out_9.drop(['penalty_won'], axis=1)
len(df_out_9.columns), len(df_out_10.columns)
# Out:
# (17, 16)

# %%
from sklearn.model_selection import train_test_split

dfX = df_out_10.drop(['value'], axis=1)
dfy = df_out_10['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
#    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.440
# Model:                            OLS   Adj. R-squared:                  0.403
# Method:                 Least Squares   F-statistic:                     11.98
# Date:                Mon, 22 Jun 2020   Prob (F-statistic):           1.29e-21
# Time:                        18:31:17   Log-Likelihood:                -946.52
# No. Observations:                 245   AIC:                             1925.
# Df Residuals:                     229   BIC:                             1981.
# Df Model:                          15
# Covariance Type:            nonrobust
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Intercept                           33.6000      0.762     44.123      0.000      32.100      35.100
# scale(age)                          -4.6404      0.917     -5.058      0.000      -6.448      -2.833
# scale(follower)                      3.7661      0.880      4.282      0.000       2.033       5.499
# scale(passes_total)                  3.7629      1.222      3.079      0.002       1.355       6.171
# scale(passes_accuracy)               3.9320      1.224      3.212      0.002       1.520       6.344
# scale(tackles_blocks)               -1.6979      1.177     -1.443      0.150      -4.017       0.621
# scale(fouls_drawn)                  -2.6591      1.014     -2.622      0.009      -4.657      -0.661
# scale(penalty_success)              -2.0496      1.120     -1.830      0.069      -4.256       0.157
# scale(penalty_missed)                1.5266      1.050      1.454      0.147      -0.542       3.595
# scale(games_lineups)                -1.9211      0.870     -2.208      0.028      -3.636      -0.206
# scale(games_played)                  6.2361      1.047      5.955      0.000       4.173       8.300
# scale(shotsOnTotal_goalsTotal)       6.7275      1.571      4.283      0.000       3.633       9.822
# scale(goasConceded_penaltySaved)     1.2779      0.993      1.287      0.199      -0.678       3.234
# scale(goalsAssist_passesKey)        -1.8820      1.311     -1.436      0.152      -4.465       0.701
# scale(dribblesAtmptsSuc)             3.5458      1.256      2.824      0.005       1.072       6.020
# scale(gamesApperance_sub)           -3.1098      1.400     -2.221      0.027      -5.868      -0.351
# ==============================================================================
# Omnibus:                        4.808   Durbin-Watson:                   2.075
# Prob(Omnibus):                  0.090   Jarque-Bera (JB):                4.519
# Skew:                           0.324   Prob(JB):                        0.104
# Kurtosis:                       3.153   Cond. No.                         5.21
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 모델 성능 : 0.1664361066644372

# %% [markdown]
# # 큰 P값 feature 제거 - 11차

# %%
df_out_11 = df_out_10.drop(['goasConceded_penaltySaved'], axis=1)
len(df_out_10.columns), len(df_out_11.columns)
# Out:
# (16, 15)

# %%
from sklearn.model_selection import train_test_split

dfX = df_out_11.drop(['value'], axis=1)
dfy = df_out_11['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
#    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.436
# Model:                            OLS   Adj. R-squared:                  0.401
# Method:                 Least Squares   F-statistic:                     12.68
# Date:                Mon, 22 Jun 2020   Prob (F-statistic):           7.57e-22
# Time:                        18:31:25   Log-Likelihood:                -947.40
# No. Observations:                 245   AIC:                             1925.
# Df Residuals:                     230   BIC:                             1977.
# Df Model:                          14
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                         33.6000      0.763     44.060      0.000      32.097      35.103
# scale(age)                        -4.6124      0.919     -5.022      0.000      -6.422      -2.803
# scale(follower)                    3.9064      0.874      4.469      0.000       2.184       5.629
# scale(passes_total)                3.2678      1.162      2.813      0.005       0.979       5.557
# scale(passes_accuracy)             4.2052      1.207      3.483      0.001       1.826       6.584
# scale(tackles_blocks)             -2.3627      1.059     -2.231      0.027      -4.449      -0.276
# scale(fouls_drawn)                -2.8218      1.008     -2.800      0.006      -4.807      -0.836
# scale(penalty_success)            -2.0843      1.121     -1.859      0.064      -4.293       0.125
# scale(penalty_missed)              1.5521      1.051      1.477      0.141      -0.519       3.623
# scale(games_lineups)              -1.9307      0.871     -2.215      0.028      -3.648      -0.214
# scale(games_played)                6.3566      1.045      6.086      0.000       4.299       8.415
# scale(shotsOnTotal_goalsTotal)     6.2219      1.523      4.086      0.000       3.221       9.222
# scale(goalsAssist_passesKey)      -2.0997      1.302     -1.613      0.108      -4.665       0.465
# scale(dribblesAtmptsSuc)           3.4052      1.253      2.718      0.007       0.937       5.873
# scale(gamesApperance_sub)         -3.4153      1.382     -2.472      0.014      -6.138      -0.693
# ==============================================================================
# Omnibus:                        5.247   Durbin-Watson:                   2.044
# Prob(Omnibus):                  0.073   Jarque-Bera (JB):                4.983
# Skew:                           0.342   Prob(JB):                       0.0828
# Kurtosis:                       3.145   Cond. No.                         5.01
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 모델 성능 : 0.1640066810188225

# %% [markdown]
# # 큰 P값 feature 제거 - 12차

# %%
df_out_12 = df_out_11.drop(['penalty_missed'], axis=1)
len(df_out_11.columns), len(df_out_12.columns)
# Out:
# (15, 14)

# %%
from sklearn.model_selection import train_test_split

dfX = df_out_12.drop(['value'], axis=1)
dfy = df_out_12['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
#    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.430
# Model:                            OLS   Adj. R-squared:                  0.398
# Method:                 Least Squares   F-statistic:                     13.42
# Date:                Mon, 22 Jun 2020   Prob (F-statistic):           5.54e-22
# Time:                        18:31:51   Log-Likelihood:                -948.56
# No. Observations:                 245   AIC:                             1925.
# Df Residuals:                     231   BIC:                             1974.
# Df Model:                          13
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                         33.6000      0.765     43.948      0.000      32.094      35.106
# scale(age)                        -4.6549      0.920     -5.057      0.000      -6.468      -2.841
# scale(follower)                    3.8583      0.876      4.406      0.000       2.133       5.584
# scale(passes_total)                3.3379      1.164      2.869      0.005       1.045       5.630
# scale(passes_accuracy)             4.0602      1.206      3.365      0.001       1.683       6.437
# scale(tackles_blocks)             -2.3794      1.062     -2.241      0.026      -4.471      -0.287
# scale(fouls_drawn)                -2.7973      1.010     -2.769      0.006      -4.788      -0.807
# scale(penalty_success)            -1.4653      1.043     -1.406      0.161      -3.519       0.589
# scale(games_lineups)              -1.9128      0.874     -2.190      0.030      -3.634      -0.192
# scale(games_played)                6.2298      1.044      5.969      0.000       4.174       8.286
# scale(shotsOnTotal_goalsTotal)     6.8832      1.459      4.717      0.000       4.008       9.758
# scale(goalsAssist_passesKey)      -2.1508      1.305     -1.648      0.101      -4.722       0.420
# scale(dribblesAtmptsSuc)           3.3052      1.254      2.636      0.009       0.834       5.776
# scale(gamesApperance_sub)         -3.5285      1.383     -2.551      0.011      -6.254      -0.803
# ==============================================================================
# Omnibus:                        6.116   Durbin-Watson:                   2.023
# Prob(Omnibus):                  0.047   Jarque-Bera (JB):                5.809
# Skew:                           0.347   Prob(JB):                       0.0548
# Kurtosis:                       3.294   Cond. No.                         4.80
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 모델 성능 : 0.16813128312799264

# %% [markdown]
# # 큰 P값 feature 제거 - 13차

# %%
df_out_13 = df_out_12.drop(['penalty_success'], axis=1)
len(df_out_12.columns), len(df_out_13.columns)
# Out:
# (14, 13)

# %%
from sklearn.model_selection import train_test_split

dfX = df_out_13.drop(['value'], axis=1)
dfy = df_out_13['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
#    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.425
# Model:                            OLS   Adj. R-squared:                  0.396
# Method:                 Least Squares   F-statistic:                     14.31
# Date:                Mon, 22 Jun 2020   Prob (F-statistic):           3.58e-22
# Time:                        18:32:54   Log-Likelihood:                -949.60
# No. Observations:                 245   AIC:                             1925.
# Df Residuals:                     232   BIC:                             1971.
# Df Model:                          12
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                         33.6000      0.766     43.856      0.000      32.091      35.109
# scale(age)                        -4.8988      0.906     -5.408      0.000      -6.683      -3.114
# scale(follower)                    3.8705      0.877      4.411      0.000       2.142       5.599
# scale(passes_total)                3.3032      1.166      2.834      0.005       1.006       5.600
# scale(passes_accuracy)             4.1576      1.207      3.445      0.001       1.780       6.536
# scale(tackles_blocks)             -2.3046      1.063     -2.169      0.031      -4.398      -0.211
# scale(fouls_drawn)                -2.8525      1.012     -2.820      0.005      -4.845      -0.859
# scale(games_lineups)              -1.7998      0.872     -2.065      0.040      -3.517      -0.082
# scale(games_played)                6.2521      1.046      5.979      0.000       4.192       8.312
# scale(shotsOnTotal_goalsTotal)     5.8592      1.267      4.625      0.000       3.363       8.355
# scale(goalsAssist_passesKey)      -2.1411      1.307     -1.638      0.103      -4.717       0.435
# scale(dribblesAtmptsSuc)           3.5349      1.246      2.837      0.005       1.080       5.990
# scale(gamesApperance_sub)         -3.2790      1.375     -2.386      0.018      -5.987      -0.571
# ==============================================================================
# Omnibus:                        7.883   Durbin-Watson:                   2.025
# Prob(Omnibus):                  0.019   Jarque-Bera (JB):                7.715
# Skew:                           0.395   Prob(JB):                       0.0211
# Kurtosis:                       3.364   Cond. No.                         4.54
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 모델 성능 : 0.16961511407130767

# %% [markdown]
# # 큰 P값 feature 제거 - 14차

# %%
df_out_14 = df_out_13.drop(['goalsAssist_passesKey'], axis=1)
len(df_out_13.columns), len(df_out_14.columns)
# Out:
# (13, 12)

# %%
from sklearn.model_selection import train_test_split

dfX = df_out_14.drop(['value'], axis=1)
dfy = df_out_14['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
#    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.419
# Model:                            OLS   Adj. R-squared:                  0.391
# Method:                 Least Squares   F-statistic:                     15.26
# Date:                Mon, 22 Jun 2020   Prob (F-statistic):           3.12e-22
# Time:                        18:33:39   Log-Likelihood:                -951.01
# No. Observations:                 245   AIC:                             1926.
# Df Residuals:                     233   BIC:                             1968.
# Df Model:                          11
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                         33.6000      0.769     43.698      0.000      32.085      35.115
# scale(age)                        -5.0746      0.903     -5.622      0.000      -6.853      -3.296
# scale(follower)                    3.9265      0.880      4.462      0.000       2.193       5.660
# scale(passes_total)                2.7299      1.116      2.446      0.015       0.531       4.928
# scale(passes_accuracy)             4.2545      1.210      3.517      0.001       1.871       6.638
# scale(tackles_blocks)             -1.8585      1.031     -1.803      0.073      -3.889       0.172
# scale(fouls_drawn)                -2.7561      1.013     -2.719      0.007      -4.753      -0.759
# scale(games_lineups)              -2.0262      0.864     -2.346      0.020      -3.728      -0.324
# scale(games_played)                6.1286      1.047      5.855      0.000       4.066       8.191
# scale(shotsOnTotal_goalsTotal)     4.9991      1.157      4.320      0.000       2.719       7.279
# scale(dribblesAtmptsSuc)           2.6751      1.134      2.359      0.019       0.441       4.909
# scale(gamesApperance_sub)         -3.5221      1.371     -2.568      0.011      -6.224      -0.820
# ==============================================================================
# Omnibus:                        6.250   Durbin-Watson:                   2.027
# Prob(Omnibus):                  0.044   Jarque-Bera (JB):                5.949
# Skew:                           0.352   Prob(JB):                       0.0511
# Kurtosis:                       3.293   Cond. No.                         3.97
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 모델 성능 : 0.17896386311366308

# %% [markdown]
# # 큰 P값 feature 제거 - 15차

# %%
df_out_15 = df_out_14.drop(['tackles_blocks'], axis=1)
len(df_out_14.columns), len(df_out_15.columns)
# Out:
# (12, 11)

# %%
from sklearn.model_selection import train_test_split

dfX = df_out_15.drop(['value'], axis=1)
dfy = df_out_15['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
#    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.411
# Model:                            OLS   Adj. R-squared:                  0.385
# Method:                 Least Squares   F-statistic:                     16.30
# Date:                Mon, 22 Jun 2020   Prob (F-statistic):           3.45e-22
# Time:                        18:33:52   Log-Likelihood:                -952.71
# No. Observations:                 245   AIC:                             1927.
# Df Residuals:                     234   BIC:                             1966.
# Df Model:                          10
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                         33.6000      0.773     43.490      0.000      32.078      35.122
# scale(age)                        -4.8742      0.900     -5.415      0.000      -6.647      -3.101
# scale(follower)                    4.0389      0.882      4.579      0.000       2.301       5.777
# scale(passes_total)                2.2759      1.092      2.083      0.038       0.124       4.428
# scale(passes_accuracy)             3.9579      1.204      3.286      0.001       1.585       6.331
# scale(fouls_drawn)                -2.6609      1.017     -2.617      0.009      -4.664      -0.657
# scale(games_lineups)              -1.8943      0.865     -2.190      0.029      -3.598      -0.190
# scale(games_played)                6.3750      1.043      6.114      0.000       4.321       8.429
# scale(shotsOnTotal_goalsTotal)     5.1922      1.158      4.485      0.000       2.911       7.473
# scale(dribblesAtmptsSuc)           3.0892      1.116      2.768      0.006       0.891       5.288
# scale(gamesApperance_sub)         -2.7969      1.317     -2.123      0.035      -5.392      -0.201
# ==============================================================================
# Omnibus:                        8.298   Durbin-Watson:                   2.063
# Prob(Omnibus):                  0.016   Jarque-Bera (JB):                8.152
# Skew:                           0.426   Prob(JB):                       0.0170
# Kurtosis:                       3.269   Cond. No.                         3.67
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 모델 성능 : 0.1662485328522778

# %% [markdown]
# # 15차 기준 전체 P값 0.05 미만
# # 파일 하단에서 가중치 작업 진행

# %% [markdown]
# # 큰 P값 feature 제거 - 16차

# %%
df_out_16 = df_out_15.drop(['passes_total'], axis=1)
len(df_out_15.columns), len(df_out_16.columns)
# Out:
# (11, 10)

# %%
from sklearn.model_selection import train_test_split

dfX = df_out_16.drop(['value'], axis=1)
dfy = df_out_16['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
#    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.400
# Model:                            OLS   Adj. R-squared:                  0.377
# Method:                 Least Squares   F-statistic:                     17.39
# Date:                Mon, 22 Jun 2020   Prob (F-statistic):           6.17e-22
# Time:                        18:35:02   Log-Likelihood:                -954.96
# No. Observations:                 245   AIC:                             1930.
# Df Residuals:                     235   BIC:                             1965.
# Df Model:                           9
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                         33.6000      0.778     43.184      0.000      32.067      35.133
# scale(age)                        -4.5676      0.894     -5.108      0.000      -6.329      -2.806
# scale(follower)                    4.4084      0.870      5.067      0.000       2.694       6.123
# scale(passes_accuracy)             5.1550      1.066      4.836      0.000       3.055       7.255
# scale(fouls_drawn)                -2.3932      1.016     -2.356      0.019      -4.395      -0.392
# scale(games_lineups)              -1.9045      0.871     -2.187      0.030      -3.620      -0.189
# scale(games_played)                6.8494      1.025      6.684      0.000       4.830       8.868
# scale(shotsOnTotal_goalsTotal)     4.1194      1.044      3.945      0.000       2.062       6.177
# scale(dribblesAtmptsSuc)           3.2098      1.122      2.860      0.005       0.999       5.421
# scale(gamesApperance_sub)         -3.3648      1.298     -2.592      0.010      -5.922      -0.808
# ==============================================================================
# Omnibus:                        6.482   Durbin-Watson:                   2.036
# Prob(Omnibus):                  0.039   Jarque-Bera (JB):                6.221
# Skew:                           0.375   Prob(JB):                       0.0446
# Kurtosis:                       3.213   Cond. No.                         3.52
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 모델 성능 : 0.1570892233181961

# %% [markdown]
# # 큰 P값 feature 제거 - 17차

# %%
df_out_17 = df_out_16.drop(['games_lineups'], axis=1)
len(df_out_16.columns), len(df_out_17.columns)
# Out:
# (10, 9)

# %%
from sklearn.model_selection import train_test_split

dfX = df_out_17.drop(['value'], axis=1)
dfy = df_out_17['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
#    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.388
# Model:                            OLS   Adj. R-squared:                  0.367
# Method:                 Least Squares   F-statistic:                     18.66
# Date:                Mon, 22 Jun 2020   Prob (F-statistic):           1.32e-21
# Time:                        18:35:14   Log-Likelihood:                -957.43
# No. Observations:                 245   AIC:                             1933.
# Df Residuals:                     236   BIC:                             1964.
# Df Model:                           8
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                         33.6000      0.784     42.842      0.000      32.055      35.145
# scale(age)                        -4.8190      0.894     -5.391      0.000      -6.580      -3.058
# scale(follower)                    4.3642      0.877      4.978      0.000       2.637       6.092
# scale(passes_accuracy)             5.1935      1.074      4.834      0.000       3.077       7.310
# scale(fouls_drawn)                -2.1687      1.019     -2.129      0.034      -4.176      -0.162
# scale(games_played)                6.9054      1.033      6.687      0.000       4.871       8.940
# scale(shotsOnTotal_goalsTotal)     3.8255      1.044      3.665      0.000       1.769       5.882
# scale(dribblesAtmptsSuc)           2.5911      1.095      2.367      0.019       0.435       4.748
# scale(gamesApperance_sub)         -2.5484      1.253     -2.034      0.043      -5.017      -0.080
# ==============================================================================
# Omnibus:                        6.105   Durbin-Watson:                   2.049
# Prob(Omnibus):                  0.047   Jarque-Bera (JB):                5.796
# Skew:                           0.350   Prob(JB):                       0.0551
# Kurtosis:                       3.278   Cond. No.                         3.37
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 모델 성능 : 0.1410713555990354

# %% [markdown]
# # 큰 P값 feature 제거 - 18차

# %%
df_out_18 = df_out_17.drop(['gamesApperance_sub'], axis=1)
len(df_out_17.columns), len(df_out_18.columns)
# Out:
# (9, 8)

# %%
from sklearn.model_selection import train_test_split

dfX = df_out_18.drop(['value'], axis=1)
dfy = df_out_18['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
#    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.377
# Model:                            OLS   Adj. R-squared:                  0.358
# Method:                 Least Squares   F-statistic:                     20.47
# Date:                Mon, 22 Jun 2020   Prob (F-statistic):           1.99e-21
# Time:                        18:35:22   Log-Likelihood:                -959.55
# No. Observations:                 245   AIC:                             1935.
# Df Residuals:                     237   BIC:                             1963.
# Df Model:                           7
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                         33.6000      0.789     42.561      0.000      32.045      35.155
# scale(age)                        -4.6486      0.896     -5.189      0.000      -6.414      -2.884
# scale(follower)                    4.4204      0.882      5.011      0.000       2.683       6.158
# scale(passes_accuracy)             4.0423      0.919      4.398      0.000       2.232       5.853
# scale(fouls_drawn)                -2.0968      1.025     -2.046      0.042      -4.116      -0.078
# scale(games_played)                7.6760      0.967      7.938      0.000       5.771       9.581
# scale(shotsOnTotal_goalsTotal)     3.1171      0.990      3.147      0.002       1.166       5.068
# scale(dribblesAtmptsSuc)           2.1116      1.076      1.962      0.051      -0.008       4.231
# ==============================================================================
# Omnibus:                        7.304   Durbin-Watson:                   2.062
# Prob(Omnibus):                  0.026   Jarque-Bera (JB):                7.087
# Skew:                           0.399   Prob(JB):                       0.0289
# Kurtosis:                       3.236   Cond. No.                         2.52
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 모델 성능 : 0.12806529354928048

# %% [markdown]
# # 큰 P값 feature 제거 - 19차

# %%
df_out_19 = df_out_18.drop(['dribblesAtmptsSuc'], axis=1)
len(df_out_18.columns), len(df_out_19.columns)
# Out:
# (8, 7)

# %%
from sklearn.model_selection import train_test_split

dfX = df_out_19.drop(['value'], axis=1)
dfy = df_out_19['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
#    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.367
# Model:                            OLS   Adj. R-squared:                  0.351
# Method:                 Least Squares   F-statistic:                     22.96
# Date:                Mon, 22 Jun 2020   Prob (F-statistic):           2.50e-21
# Time:                        18:35:30   Log-Likelihood:                -961.53
# No. Observations:                 245   AIC:                             1937.
# Df Residuals:                     238   BIC:                             1962.
# Df Model:                           6
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                         33.6000      0.794     42.309      0.000      32.036      35.164
# scale(age)                        -4.9466      0.888     -5.569      0.000      -6.696      -3.197
# scale(follower)                    4.5036      0.886      5.081      0.000       2.758       6.250
# scale(passes_accuracy)             4.2863      0.916      4.679      0.000       2.482       6.091
# scale(fouls_drawn)                -1.2473      0.935     -1.335      0.183      -3.088       0.594
# scale(games_played)                7.5657      0.971      7.791      0.000       5.653       9.479
# scale(shotsOnTotal_goalsTotal)     3.8241      0.928      4.120      0.000       1.996       5.652
# ==============================================================================
# Omnibus:                        7.931   Durbin-Watson:                   2.077
# Prob(Omnibus):                  0.019   Jarque-Bera (JB):                7.745
# Skew:                           0.411   Prob(JB):                       0.0208
# Kurtosis:                       3.290   Cond. No.                         1.99
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 모델 성능 : 0.1042971583721806

# %% [markdown]
# # 큰 P값 feature 제거 - 20차

# %% [markdown]
# # Final

# %%
df_out_20 = df_out_19.drop(['fouls_drawn'], axis=1)
len(df_out_19.columns), len(df_out_20.columns)
# Out:
# (7, 6)

# %%
from sklearn.model_selection import train_test_split

dfX = df_out_20.drop(['value'], axis=1)
dfy = df_out_20['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

formula = "value ~ " + "+".join(feature_names)

model = sm.OLS.from_formula(formula, data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula(formula, data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
#    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.362
# Model:                            OLS   Adj. R-squared:                  0.349
# Method:                 Least Squares   F-statistic:                     27.11
# Date:                Mon, 22 Jun 2020   Prob (F-statistic):           1.07e-21
# Time:                        18:27:34   Log-Likelihood:                -962.44
# No. Observations:                 245   AIC:                             1937.
# Df Residuals:                     239   BIC:                             1958.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                         33.6000      0.795     42.240      0.000      32.033      35.167
# scale(age)                        -4.8268      0.885     -5.454      0.000      -6.570      -3.083
# scale(follower)                    4.4544      0.887      5.022      0.000       2.707       6.202
# scale(passes_accuracy)             4.2533      0.917      4.637      0.000       2.446       6.060
# scale(games_played)                7.8871      0.942      8.370      0.000       6.031       9.743
# scale(shotsOnTotal_goalsTotal)     3.2881      0.838      3.923      0.000       1.637       4.939
# ==============================================================================
# Omnibus:                        9.847   Durbin-Watson:                   2.083
# Prob(Omnibus):                  0.007   Jarque-Bera (JB):                9.863
# Skew:                           0.461   Prob(JB):                      0.00721
# Kurtosis:                       3.339   Cond. No.                         1.93
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 모델 성능 : 0.10572367762374746

# %%
sm.stats.anova_lm(result)
# Out:
#                                    df         sum_sq       mean_sq          F  \
# scale(age)                        1.0     134.229737    134.229737   0.356530
# scale(follower)                   1.0   26213.193704  26213.193704  69.625350
# scale(passes_accuracy)            1.0      22.018184     22.018184   0.058483
# scale(games_played)               1.0    8903.721718   8903.721718  23.649341
# scale(shotsOnTotal_goalsTotal)    1.0    7552.469769   7552.469769  20.060255
# Residual                        328.0  123488.463446    376.489218        NaN
#
#                                       PR(>F)
# scale(age)                      5.508516e-01
# scale(follower)                 2.021134e-15
# scale(passes_accuracy)          8.090612e-01
# scale(games_played)             1.796660e-06
# scale(shotsOnTotal_goalsTotal)  1.037433e-05
# Residual                                 NaN

# %%
sns.jointplot(result.fittedvalues, df_train.value)
plt.show()

# %% [markdown]
# # 검증 1차

# %%
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_out_20)):
    df_train = df_out_20.iloc[idx_train]
    df_test = df_out_20.iloc[idx_test]
    
    model = sm.OLS.from_formula("value ~ scale(age) + scale(follower) + scale(passes_accuracy) + \
                                scale(games_played) + scale(shotsOnTotal_goalsTotal)", data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
# Out:
# 학습 R2 = 0.43588294, 검증 R2 = 0.07340391
# 학습 R2 = 0.37328481, 검증 R2 = 0.56745512
# 학습 R2 = 0.40717668, 검증 R2 = 0.16182307
# 학습 R2 = 0.43362456, 검증 R2 = 0.13921343
# 학습 R2 = 0.41324030, 검증 R2 = 0.41145860
# 학습 R2 = 0.41761305, 검증 R2 = 0.36993465
# 학습 R2 = 0.42769943, 검증 R2 = 0.18453031
# 학습 R2 = 0.40659942, 검증 R2 = 0.47352822
# 학습 R2 = 0.42082016, 검증 R2 = 0.33419352
# 학습 R2 = 0.41943732, 검증 R2 = 0.36001850

# %% [markdown]
# # 검증 2차

# %%
from sklearn.base import BaseEstimator, RegressorMixin
import statsmodels.formula.api as smf
import statsmodels.api as sm

class StatsmodelsOLS(BaseEstimator, RegressorMixin):
    def __init__(self, formula):
        self.formula = formula
        self.model = None
        self.data = None
        self.result = None
        
    def fit(self, dfX, dfy):
        self.data = pd.concat([dfX, dfy], axis=1)
        self.model = smf.ols(self.formula, data=self.data)
        self.result = self.model.fit()
        
    def predict(self, new_data):
        return self.result.predict(new_data)

# %%
from sklearn.model_selection import cross_val_score

model = StatsmodelsOLS("value ~ scale(age) + scale(follower) + scale(passes_accuracy) + \
                       scale(games_played) + scale(shotsOnTotal_goalsTotal)")
cv = KFold(10, shuffle=True, random_state=0)
cross_val_score(model, dfX, dfy, scoring="r2", cv=cv).mean()
# Out:
# 0.3075559319985198

# %%
from sklearn.model_selection import train_test_split

dfX = df_out_20.drop(['value'], axis=1)
dfy = df_out_20['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

formula = "value ~ " + "+".join(feature_names)

model = sm.OLS.from_formula(formula, data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula(formula, data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
#    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))

# %% [markdown]
# # 아웃라이어 2차 제거

# %%
from statsmodels.graphics import utils

dfX0 = df_out_20.drop('value', axis=1)
dfX = sm.add_constant(dfX0)
dfy = df_out_20['value']

model_p = sm.OLS(dfy, dfX)
result_p = model_p.fit()
pred = result_p.predict(dfX)

influence_p = result_p.get_influence()
cooks_d2, pvals = influence_p.cooks_distance
K = influence_p.k_vars
fox_cr = 4 / (len(dfy) - K - 1)
idx = np.where(cooks_d2 > fox_cr)[0]

ax = plt.subplot()
plt.scatter(dfy, pred)
plt.scatter(dfy[idx], pred[idx], s=300, c="r", alpha=0.5)
utils.annotate_axes(range(len(idx)), idx, list(zip(dfy[idx], pred[idx])), [(-20, 15)] * len(idx), size="small", ax=ax)
plt.title("아웃라이어")
plt.show()
print(idx)

# %%
idx2 = list(set(range(len(dfX))).difference(idx))
len(idx2)

# %%
df_out2 = df_out_20.iloc[idx2].reset_index(drop=True)
df_out2

# %%
from sklearn.model_selection import train_test_split

dfX = df_out2.drop(['value'], axis=1)
dfy = df_out2['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
result = model.fit()
print(result.summary())

# %%
pred = result.predict(df_test)

rss = ((df_test.value - pred) ** 2).sum()
tss = ((df_test.value - df_test.value.mean()) ** 2).sum()
rsquared = 1 - rss / tss
rsquared

# %% [markdown]
# # 검증 1차

# %%
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_out2)):
    df_train = df_out2.iloc[idx_train]
    df_test = df_out2.iloc[idx_test]
    
    model = sm.OLS.from_formula("value ~ scale(age) + scale(follower) + scale(passes_accuracy) + \
                                scale(games_played) + scale(shotsOnTotal_goalsTotal)", data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))

# %% [markdown]
# # 검증 2차

# %%
from sklearn.base import BaseEstimator, RegressorMixin
import statsmodels.formula.api as smf
import statsmodels.api as sm

class StatsmodelsOLS(BaseEstimator, RegressorMixin):
    def __init__(self, formula):
        self.formula = formula
        self.model = None
        self.data = None
        self.result = None
        
    def fit(self, dfX, dfy):
        self.data = pd.concat([dfX, dfy], axis=1)
        self.model = smf.ols(self.formula, data=self.data)
        self.result = self.model.fit()
        
    def predict(self, new_data):
        return self.result.predict(new_data)

# %%
from sklearn.model_selection import cross_val_score

model = StatsmodelsOLS("value ~ scale(age) + scale(follower) + scale(passes_accuracy) + \
                       scale(games_played) + scale(shotsOnTotal_goalsTotal)")
cv = KFold(10, shuffle=True, random_state=0)
cross_val_score(model, dfX, dfy, scoring="r2", cv=cv).mean()

# %% [markdown]
# # Data 가중 - 20200622

# %%
from sklearn.model_selection import train_test_split

dfX = df_out_15.drop(['value'], axis=1)
dfy = df_out_15['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

formula = "value ~ scale(age) + scale(I(age**2)) + scale(I(age**3)) + \
            scale(follower) + scale(I(follower**2)) +\
            scale(passes_total) + scale(I(passes_total**2)) +\
            scale(passes_accuracy) + \
            scale(fouls_drawn) + \
            scale(games_lineups) + \
            scale(games_played) + \
            scale(shotsOnTotal_goalsTotal) + \
            scale(dribblesAtmptsSuc) + \
            scale(gamesApperance_sub)"

model = sm.OLS.from_formula(formula, data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula(formula, data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
#    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.456
# Model:                            OLS   Adj. R-squared:                  0.423
# Method:                 Least Squares   F-statistic:                     13.79
# Date:                Mon, 22 Jun 2020   Prob (F-statistic):           1.36e-23
# Time:                        18:55:05   Log-Likelihood:                -942.83
# No. Observations:                 245   AIC:                             1916.
# Df Residuals:                     230   BIC:                             1968.
# Df Model:                          14
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                         33.6000      0.748     44.891      0.000      32.125      35.075
# scale(age)                      -326.1528    124.753     -2.614      0.010    -571.958     -80.348
# scale(I(age ** 2))               667.5216    250.940      2.660      0.008     173.087    1161.956
# scale(I(age ** 3))              -347.9868    127.030     -2.739      0.007    -598.277     -97.696
# scale(follower)                    6.7309      2.238      3.008      0.003       2.322      11.140
# scale(I(follower ** 2))           -2.4825      2.072     -1.198      0.232      -6.566       1.601
# scale(passes_total)               -8.0634      3.652     -2.208      0.028     -15.259      -0.868
# scale(I(passes_total ** 2))        9.9163      3.493      2.839      0.005       3.035      16.798
# scale(passes_accuracy)             4.2079      1.186      3.548      0.000       1.871       6.544
# scale(fouls_drawn)                -2.7461      0.998     -2.753      0.006      -4.712      -0.780
# scale(games_lineups)              -1.6139      0.841     -1.919      0.056      -3.271       0.043
# scale(games_played)                6.0424      1.039      5.817      0.000       3.996       8.089
# scale(shotsOnTotal_goalsTotal)     4.7734      1.136      4.202      0.000       2.535       7.012
# scale(dribblesAtmptsSuc)           3.5687      1.113      3.206      0.002       1.375       5.762
# scale(gamesApperance_sub)         -3.3423      1.297     -2.577      0.011      -5.898      -0.787
# ==============================================================================
# Omnibus:                        9.595   Durbin-Watson:                   1.973
# Prob(Omnibus):                  0.008   Jarque-Bera (JB):                9.599
# Skew:                           0.447   Prob(JB):                      0.00823
# Kurtosis:                       3.378   Cond. No.                         806.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 모델 성능 : 0.2572014963230808
