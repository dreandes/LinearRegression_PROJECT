# %% [markdown]
# # 작업할 데이터 받기

# %%
df_ols = pd.read_csv('df_OLS.csv', encoding='utf-8-sig', index_col=0)

# %%
df_ols
# Out:
#      position        age    rating  value  follower  passes_total  \
# 0    2.000000  25.000000  2.333333   20.0     67879       22.1875
# 1    4.000000  27.000000  5.250000   32.0    740918       12.3211
# 2    3.000000  24.000000  6.000000   24.0    601838       58.0175
# 3    4.000000  25.000000  7.000000   32.0    652886       23.4897
# 4    2.000000  32.000000  4.833333   32.0  11513791       32.2437
# ..        ...        ...       ...    ...       ...           ...
# 366  4.000000  28.000000  3.888889   44.0   1028085       21.4995
# 367  3.769231  23.076923  1.615385   24.0     57900        4.1158
# 368  4.000000  32.000000  6.153846   22.5   8983450       38.4786
# 369  4.000000  26.000000  6.545455   24.0    109000       16.8656
# 370  2.000000  23.000000  4.384615   44.0    282254       38.4359
#
#      passes_accuracy  tackles_total  tackles_blocks  tackles_interceptions  \
# 0             3.2985         1.2112          0.1417                 0.8504
# 1             4.0184         0.4629          0.0985                 0.2659
# 2            13.4528         1.0301          0.3802                 1.3367
# 3             9.1609         0.7758          0.1141                 0.9355
# 4             6.1453         0.4321          0.0480                 0.4225
# ..               ...            ...             ...                    ...
# 366           4.2611         1.1758          0.0216                 0.3452
# 367           2.3642         0.1397          0.0215                 0.0430
# 368           8.6552         0.7696          0.0300                 0.5297
# 369           7.4315         0.3936          0.0695                 0.3010
# 370           6.6011         1.0018          0.1371                 0.9807
#
#      ...  penalty_missed  games_lineups  games_played        hw  \
# 0    ...          0.0000         0.9277       77.6111 -0.392274
# 1    ...          0.0295         0.9947      101.5333  0.141002
# 2    ...          0.0000         1.0056       81.5444 -0.580321
# 3    ...          0.0000         0.9697       87.6556  0.741866
# 4    ...          0.0096         1.0754      104.1444 -0.008107
# ..   ...             ...            ...           ...       ...
# 366  ...          0.0000         0.9924       92.7000  0.580254
# 367  ...          0.0107         1.0531       93.0556 -1.164444
# 368  ...          0.0000         1.0294      100.0556  0.096205
# 369  ...          0.0000         0.9492       86.3889 -1.160608
# 370  ...          0.0000         1.0334       94.8333  0.376061
#
#      shotsOnTotal_goalsTotal  goasConceded_penaltySaved  \
# 0                  -1.612784                  -0.285146
# 1                   1.822336                  -0.285146
# 2                  -1.817034                  -0.285146
# 3                   0.551484                  -0.285146
# 4                   2.104335                  -0.285146
# ..                       ...                        ...
# 366                 0.448326                  -0.285146
# 367                -0.497805                  -0.285146
# 368                 1.152975                  -0.285146
# 369                 0.759456                  -0.285146
# 370                -0.098556                  -0.285146
#
#      goalsAssist_passesKey  duelsWonTotal  dribblesAtmptsSuc  \
# 0                -1.738633      -1.924682          -0.276160
# 1                -0.383844       1.580211          -0.167363
# 2                -1.744717      -0.246207          -1.650098
# 3                 1.006489       1.352523           2.219212
# 4                 2.797874      -1.700012           0.984943
# ..                     ...            ...                ...
# 366               0.257094       3.975849           4.594321
# 367              -1.725265      -2.941022          -1.572458
# 368               2.862916       0.141037           2.276803
# 369               1.050869       2.395041          -0.209080
# 370               0.096454       0.718212          -0.450281
#
#      gamesApperance_sub
# 0              2.236486
# 1             -1.808610
# 2              0.163037
# 3              4.054520
# 4              0.382540
# ..                  ...
# 366           -2.079535
# 367            0.538228
# 368            2.749932
# 369            2.181788
# 370           -0.028808
#
# [371 rows x 28 columns]

# %% [markdown]
# # position 데이터 정리 - 반올림

# %%
df_ols.position.unique()
# Out:
# array([2.        , 4.        , 3.        , 1.        , 3.33333333,
#        1.84615385, 3.43478261, 1.09090909, 3.29411765, 2.56818182,
#        2.25      , 2.4       , 3.75      , 3.2       , 1.66666667,
#        2.16666667, 2.91304348, 2.63636364, 3.76923077])

# %%
df_ols.position = df_ols.position.round()

# %%
df_ols.position.unique()
# Out:
# array([2., 4., 3., 1.])

# %% [markdown]
# # Follower 제거

# %%
df_ols = df_ols.drop('follower', axis=1)
df_ols
# Out:
#      position        age    rating  value  passes_total  passes_accuracy  \
# 0         2.0  25.000000  2.333333   20.0       22.1875           3.2985
# 1         4.0  27.000000  5.250000   32.0       12.3211           4.0184
# 2         3.0  24.000000  6.000000   24.0       58.0175          13.4528
# 3         4.0  25.000000  7.000000   32.0       23.4897           9.1609
# 4         2.0  32.000000  4.833333   32.0       32.2437           6.1453
# ..        ...        ...       ...    ...           ...              ...
# 366       4.0  28.000000  3.888889   44.0       21.4995           4.2611
# 367       4.0  23.076923  1.615385   24.0        4.1158           2.3642
# 368       4.0  32.000000  6.153846   22.5       38.4786           8.6552
# 369       4.0  26.000000  6.545455   24.0       16.8656           7.4315
# 370       2.0  23.000000  4.384615   44.0       38.4359           6.6011
#
#      tackles_total  tackles_blocks  tackles_interceptions  fouls_drawn  ...  \
# 0           1.2112          0.1417                 0.8504       0.5283  ...
# 1           0.4629          0.0985                 0.2659       2.8562  ...
# 2           1.0301          0.3802                 1.3367       0.5641  ...
# 3           0.7758          0.1141                 0.9355       1.6086  ...
# 4           0.4321          0.0480                 0.4225       0.6433  ...
# ..             ...             ...                    ...          ...  ...
# 366         1.1758          0.0216                 0.3452       3.0097  ...
# 367         0.1397          0.0215                 0.0430       0.2794  ...
# 368         0.7696          0.0300                 0.5297       1.6691  ...
# 369         0.3936          0.0695                 0.3010       1.8637  ...
# 370         1.0018          0.1371                 0.9807       1.4341  ...
#
#      penalty_missed  games_lineups  games_played        hw  \
# 0            0.0000         0.9277       77.6111 -0.392274
# 1            0.0295         0.9947      101.5333  0.141002
# 2            0.0000         1.0056       81.5444 -0.580321
# 3            0.0000         0.9697       87.6556  0.741866
# 4            0.0096         1.0754      104.1444 -0.008107
# ..              ...            ...           ...       ...
# 366          0.0000         0.9924       92.7000  0.580254
# 367          0.0107         1.0531       93.0556 -1.164444
# 368          0.0000         1.0294      100.0556  0.096205
# 369          0.0000         0.9492       86.3889 -1.160608
# 370          0.0000         1.0334       94.8333  0.376061
#
#      shotsOnTotal_goalsTotal  goasConceded_penaltySaved  \
# 0                  -1.612784                  -0.285146
# 1                   1.822336                  -0.285146
# 2                  -1.817034                  -0.285146
# 3                   0.551484                  -0.285146
# 4                   2.104335                  -0.285146
# ..                       ...                        ...
# 366                 0.448326                  -0.285146
# 367                -0.497805                  -0.285146
# 368                 1.152975                  -0.285146
# 369                 0.759456                  -0.285146
# 370                -0.098556                  -0.285146
#
#      goalsAssist_passesKey  duelsWonTotal  dribblesAtmptsSuc  \
# 0                -1.738633      -1.924682          -0.276160
# 1                -0.383844       1.580211          -0.167363
# 2                -1.744717      -0.246207          -1.650098
# 3                 1.006489       1.352523           2.219212
# 4                 2.797874      -1.700012           0.984943
# ..                     ...            ...                ...
# 366               0.257094       3.975849           4.594321
# 367              -1.725265      -2.941022          -1.572458
# 368               2.862916       0.141037           2.276803
# 369               1.050869       2.395041          -0.209080
# 370               0.096454       0.718212          -0.450281
#
#      gamesApperance_sub
# 0              2.236486
# 1             -1.808610
# 2              0.163037
# 3              4.054520
# 4              0.382540
# ..                  ...
# 366           -2.079535
# 367            0.538228
# 368            2.749932
# 369            2.181788
# 370           -0.028808
#
# [371 rows x 27 columns]

# %% [markdown]
# # 아웃라이어 확인

# %%
from statsmodels.graphics import utils

dfX0 = df_ols.drop('value', axis=1)
dfX = sm.add_constant(dfX0)
dfy = df_ols['value']

model_p = sm.OLS(dfy, dfX)
result_p = model_p.fit()
pred = result_p.predict(dfX)

influence_p = result_p.get_influence()
cooks_d2, pvals = influence_p.cooks_distance
K = influence_p.k_vars
fox_cr = 4 / (len(dfy) - K - 1)
idx = np.where(cooks_d2 > fox_cr)[0]

ax = plt.subplot()
plt.scatter(dfy, pred)
plt.scatter(dfy[idx], pred[idx], s=300, c="r", alpha=0.5)
utils.annotate_axes(range(len(idx)), idx, list(zip(dfy[idx], pred[idx])), [(-20, 15)] * len(idx), size="small", ax=ax)
plt.title("아웃라이어")
plt.show()
print(idx)
# Out:
# [ 36 123 129 150 166 168 169 180 183 189 195 204 217 253 259 268 282 283
#  309 323 336 349]

# %% [markdown]
# # 아웃라이어 제거

# %%
idx2 = list(set(range(len(dfX))).difference(idx))
df_out = df_ols.iloc[idx2].reset_index(drop=True)

# %% [markdown]
# # 아웃라이어 먼저 제거 후, OLS

# %%
from sklearn.model_selection import train_test_split

dfX = df_out.drop(['value'], axis=1)
dfy = df_out['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
result = model.fit()
print(result.summary())

pred = result.predict(df_test)

rss = ((df_test.value - pred) ** 2).sum()
tss = ((df_test.value - df_test.value.mean()) ** 2).sum()
rsquared = 1 - rss / tss
rsquared
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.431
# Model:                            OLS   Adj. R-squared:                  0.363
# Method:                 Least Squares   F-statistic:                     6.330
# Date:                Wed, 24 Jun 2020   Prob (F-statistic):           1.36e-15
# Time:                        20:18:22   Log-Likelihood:                -951.95
# No. Observations:                 244   AIC:                             1958.
# Df Residuals:                     217   BIC:                             2052.
# Df Model:                          26
# Covariance Type:            nonrobust
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Intercept                           33.7520      0.813     41.533      0.000      32.150      35.354
# scale(position)                     -0.2228      1.157     -0.193      0.847      -2.503       2.057
# scale(age)                          -4.2377      1.018     -4.164      0.000      -6.243      -2.232
# scale(rating)                        0.1461      1.139      0.128      0.898      -2.098       2.390
# scale(passes_total)                  3.6421      1.344      2.711      0.007       0.994       6.290
# scale(passes_accuracy)               5.3530      1.505      3.556      0.000       2.386       8.320
# scale(tackles_total)                 0.8876      1.325      0.670      0.504      -1.725       3.500
# scale(tackles_blocks)               -2.3550      1.343     -1.753      0.081      -5.003       0.293
# scale(tackles_interceptions)         1.2850      1.676      0.767      0.444      -2.018       4.588
# scale(fouls_drawn)                  -1.3288      1.448     -0.918      0.360      -4.182       1.525
# scale(fouls_committed)              -2.4658      1.584     -1.557      0.121      -5.587       0.655
# scale(cards_yellow)                  0.3073      1.367      0.225      0.822      -2.387       3.002
# scale(cards_yellowred)              -0.1214      0.941     -0.129      0.898      -1.977       1.734
# scale(cards_red)                     0.0243      0.870      0.028      0.978      -1.691       1.739
# scale(penalty_won)                   1.0308      1.169      0.882      0.379      -1.273       3.334
# scale(penalty_commited)             -0.7389      0.950     -0.778      0.438      -2.612       1.134
# scale(penalty_success)              -1.1253      1.260     -0.893      0.373      -3.609       1.359
# scale(penalty_missed)               -0.1381      1.175     -0.118      0.907      -2.453       2.177
# scale(games_lineups)                -1.6168      0.956     -1.691      0.092      -3.501       0.267
# scale(games_played)                  7.1911      1.231      5.840      0.000       4.764       9.618
# scale(hw)                           -0.9044      1.071     -0.844      0.399      -3.016       1.207
# scale(shotsOnTotal_goalsTotal)       8.4446      1.928      4.380      0.000       4.645      12.245
# scale(goasConceded_penaltySaved)     1.4462      1.335      1.083      0.280      -1.185       4.078
# scale(goalsAssist_passesKey)        -0.6628      1.421     -0.466      0.641      -3.464       2.138
# scale(duelsWonTotal)                -0.0328      1.645     -0.020      0.984      -3.275       3.209
# scale(dribblesAtmptsSuc)             3.4046      1.598      2.131      0.034       0.256       6.554
# scale(gamesApperance_sub)           -4.5867      1.645     -2.788      0.006      -7.830      -1.344
# ==============================================================================
# Omnibus:                       13.978   Durbin-Watson:                   2.024
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               14.691
# Skew:                           0.571   Prob(JB):                     0.000646
# Kurtosis:                       3.375   Cond. No.                         6.95
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.3304894293609011

# %% [markdown]
# # VIF Factor 확인

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = pd.DataFrame()
vif["VIF Factor"] = [variance_inflation_factor(dfX.values, i) for i in range(dfX.shape[1])]
vif["features"] = dfX.columns
vif.sort_values(by='VIF Factor', ascending=False)
# Out:
#     VIF Factor                   features
# 17  160.344214              games_lineups
# 1   110.554872                        age
# 18   48.225241               games_played
# 2    42.421699                     rating
# 4    29.566428            passes_accuracy
# 0    21.844761                   position
# 9    18.992079            fouls_committed
# 3    16.359092               passes_total
# 7    13.267071      tackles_interceptions
# 8    10.637147                fouls_drawn
# 10   10.608056               cards_yellow
# 5     8.631126              tackles_total
# 20    5.403267    shotsOnTotal_goalsTotal
# 6     4.773280             tackles_blocks
# 24    3.580061          dribblesAtmptsSuc
# 23    3.473848              duelsWonTotal
# 25    3.427920         gamesApperance_sub
# 22    2.982387      goalsAssist_passesKey
# 15    2.969786            penalty_success
# 13    2.817590                penalty_won
# 21    2.453269  goasConceded_penaltySaved
# 16    2.414683             penalty_missed
# 14    1.996386           penalty_commited
# 11    1.725276            cards_yellowred
# 12    1.373075                  cards_red
# 19    1.300498                         hw

# %% [markdown]
# # OLS - 1

# %%
df_out_1 = df_out.drop(['duelsWonTotal'], axis=1)
len(df_out.columns), len(df_out_1.columns)
# Out:
# (27, 26)

# %%
from sklearn.model_selection import train_test_split

df_ols = df_out_1
dfX = df_ols.drop(['value'], axis=1)
dfy = df_ols['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
#    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.431
# Model:                            OLS   Adj. R-squared:                  0.366
# Method:                 Least Squares   F-statistic:                     6.614
# Date:                Wed, 24 Jun 2020   Prob (F-statistic):           5.18e-16
# Time:                        20:18:30   Log-Likelihood:                -951.95
# No. Observations:                 244   AIC:                             1956.
# Df Residuals:                     218   BIC:                             2047.
# Df Model:                          25
# Covariance Type:            nonrobust
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Intercept                           33.7520      0.811     41.629      0.000      32.154      35.350
# scale(position)                     -0.2248      1.150     -0.196      0.845      -2.491       2.041
# scale(age)                          -4.2365      1.013     -4.181      0.000      -6.234      -2.239
# scale(rating)                        0.1480      1.132      0.131      0.896      -2.083       2.379
# scale(passes_total)                  3.6434      1.339      2.721      0.007       1.004       6.283
# scale(passes_accuracy)               5.3483      1.483      3.605      0.000       2.425       8.272
# scale(tackles_total)                 0.8789      1.249      0.704      0.482      -1.583       3.340
# scale(tackles_blocks)               -2.3609      1.308     -1.804      0.073      -4.940       0.218
# scale(tackles_interceptions)         1.2817      1.664      0.770      0.442      -1.997       4.561
# scale(fouls_drawn)                  -1.3415      1.298     -1.034      0.302      -3.899       1.216
# scale(fouls_committed)              -2.4773      1.472     -1.683      0.094      -5.378       0.423
# scale(cards_yellow)                  0.3132      1.333      0.235      0.814      -2.313       2.940
# scale(cards_yellowred)              -0.1193      0.933     -0.128      0.898      -1.959       1.720
# scale(cards_red)                     0.0241      0.868      0.028      0.978      -1.687       1.735
# scale(penalty_won)                   1.0323      1.164      0.887      0.376      -1.261       3.326
# scale(penalty_commited)             -0.7386      0.948     -0.779      0.437      -2.607       1.130
# scale(penalty_success)              -1.1246      1.257     -0.895      0.372      -3.602       1.353
# scale(penalty_missed)               -0.1349      1.161     -0.116      0.908      -2.422       2.152
# scale(games_lineups)                -1.6167      0.954     -1.695      0.091      -3.496       0.263
# scale(games_played)                  7.1859      1.201      5.985      0.000       4.819       9.552
# scale(hw)                           -0.9012      1.057     -0.853      0.395      -2.984       1.181
# scale(shotsOnTotal_goalsTotal)       8.4387      1.900      4.441      0.000       4.693      12.184
# scale(goasConceded_penaltySaved)     1.4471      1.331      1.087      0.278      -1.177       4.071
# scale(goalsAssist_passesKey)        -0.6596      1.409     -0.468      0.640      -3.436       2.117
# scale(dribblesAtmptsSuc)             3.3911      1.444      2.349      0.020       0.546       6.237
# scale(gamesApperance_sub)           -4.5852      1.640     -2.796      0.006      -7.818      -1.353
# ==============================================================================
# Omnibus:                       13.977   Durbin-Watson:                   2.024
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               14.690
# Skew:                           0.571   Prob(JB):                     0.000646
# Kurtosis:                       3.374   Cond. No.                         6.45
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 모델 성능 : 0.29201413355038486

# %% [markdown]
# # OLS - 2

# %%
df_out_2 = df_out_1.drop(['cards_red'], axis=1)
len(df_out_2.columns), len(df_out_1.columns)
# Out:
# (25, 26)

# %%
from sklearn.model_selection import train_test_split

df_ols = df_out_2
dfX = df_ols.drop(['value'], axis=1)
dfy = df_ols['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
#    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.431
# Model:                            OLS   Adj. R-squared:                  0.369
# Method:                 Least Squares   F-statistic:                     6.921
# Date:                Wed, 24 Jun 2020   Prob (F-statistic):           1.93e-16
# Time:                        20:19:11   Log-Likelihood:                -951.95
# No. Observations:                 244   AIC:                             1954.
# Df Residuals:                     219   BIC:                             2041.
# Df Model:                          24
# Covariance Type:            nonrobust
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Intercept                           33.7520      0.809     41.724      0.000      32.158      35.346
# scale(position)                     -0.2204      1.136     -0.194      0.846      -2.459       2.019
# scale(age)                          -4.2365      1.011     -4.190      0.000      -6.229      -2.244
# scale(rating)                        0.1474      1.129      0.131      0.896      -2.078       2.372
# scale(passes_total)                  3.6438      1.336      2.727      0.007       1.011       6.277
# scale(passes_accuracy)               5.3488      1.480      3.614      0.000       2.432       8.265
# scale(tackles_total)                 0.8789      1.246      0.705      0.481      -1.577       3.335
# scale(tackles_blocks)               -2.3608      1.305     -1.808      0.072      -4.934       0.212
# scale(tackles_interceptions)         1.2825      1.660      0.773      0.441      -1.988       4.553
# scale(fouls_drawn)                  -1.3426      1.294     -1.037      0.301      -3.893       1.208
# scale(fouls_committed)              -2.4766      1.468     -1.687      0.093      -5.370       0.417
# scale(cards_yellow)                  0.3164      1.324      0.239      0.811      -2.294       2.927
# scale(cards_yellowred)              -0.1197      0.931     -0.129      0.898      -1.955       1.716
# scale(penalty_won)                   1.0307      1.160      0.889      0.375      -1.255       3.316
# scale(penalty_commited)             -0.7365      0.943     -0.781      0.436      -2.595       1.122
# scale(penalty_success)              -1.1216      1.250     -0.898      0.370      -3.584       1.341
# scale(penalty_missed)               -0.1334      1.157     -0.115      0.908      -2.413       2.146
# scale(games_lineups)                -1.6157      0.951     -1.699      0.091      -3.490       0.258
# scale(games_played)                  7.1856      1.198      5.998      0.000       4.825       9.547
# scale(hw)                           -0.9045      1.047     -0.864      0.389      -2.969       1.160
# scale(shotsOnTotal_goalsTotal)       8.4405      1.895      4.454      0.000       4.706      12.175
# scale(goasConceded_penaltySaved)     1.4533      1.309      1.110      0.268      -1.127       4.033
# scale(goalsAssist_passesKey)        -0.6606      1.405     -0.470      0.639      -3.430       2.109
# scale(dribblesAtmptsSuc)             3.3955      1.432      2.371      0.019       0.574       6.218
# scale(gamesApperance_sub)           -4.5829      1.634     -2.805      0.005      -7.803      -1.362
# ==============================================================================
# Omnibus:                       13.969   Durbin-Watson:                   2.024
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               14.680
# Skew:                           0.571   Prob(JB):                     0.000649
# Kurtosis:                       3.375   Cond. No.                         6.44
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 모델 성능 : 0.29430356097158955

# %% [markdown]
# # OLS - 3

# %%
df_out_3 = df_out_2.drop(['penalty_missed'], axis=1)
len(df_out_3.columns), len(df_out_2.columns)
# Out:
# (24, 25)

# %%
from sklearn.model_selection import train_test_split

df_ols = df_out_3
dfX = df_ols.drop(['value'], axis=1)
dfy = df_ols['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
#    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.431
# Model:                            OLS   Adj. R-squared:                  0.372
# Method:                 Least Squares   F-statistic:                     7.254
# Date:                Wed, 24 Jun 2020   Prob (F-statistic):           7.08e-17
# Time:                        20:20:41   Log-Likelihood:                -951.96
# No. Observations:                 244   AIC:                             1952.
# Df Residuals:                     220   BIC:                             2036.
# Df Model:                          23
# Covariance Type:            nonrobust
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Intercept                           33.7520      0.807     41.818      0.000      32.161      35.343
# scale(position)                     -0.2268      1.132     -0.200      0.841      -2.458       2.004
# scale(age)                          -4.2360      1.009     -4.199      0.000      -6.224      -2.248
# scale(rating)                        0.1522      1.126      0.135      0.893      -2.066       2.371
# scale(passes_total)                  3.6478      1.333      2.738      0.007       1.022       6.274
# scale(passes_accuracy)               5.3437      1.476      3.621      0.000       2.435       8.252
# scale(tackles_total)                 0.8734      1.242      0.703      0.483      -1.575       3.322
# scale(tackles_blocks)               -2.3611      1.302     -1.813      0.071      -4.928       0.206
# scale(tackles_interceptions)         1.2910      1.654      0.780      0.436      -1.969       4.551
# scale(fouls_drawn)                  -1.3506      1.289     -1.047      0.296      -3.892       1.191
# scale(fouls_committed)              -2.4833      1.464     -1.697      0.091      -5.368       0.401
# scale(cards_yellow)                  0.3112      1.321      0.236      0.814      -2.292       2.914
# scale(cards_yellowred)              -0.1126      0.927     -0.121      0.903      -1.940       1.714
# scale(penalty_won)                   1.0373      1.156      0.898      0.370      -1.240       3.315
# scale(penalty_commited)             -0.7400      0.940     -0.787      0.432      -2.593       1.113
# scale(penalty_success)              -1.1759      1.155     -1.018      0.310      -3.452       1.100
# scale(games_lineups)                -1.6151      0.949     -1.702      0.090      -3.485       0.255
# scale(games_played)                  7.1867      1.195      6.013      0.000       4.831       9.542
# scale(hw)                           -0.9105      1.044     -0.872      0.384      -2.967       1.146
# scale(shotsOnTotal_goalsTotal)       8.3877      1.835      4.571      0.000       4.772      12.004
# scale(goasConceded_penaltySaved)     1.4482      1.305      1.109      0.268      -1.125       4.021
# scale(goalsAssist_passesKey)        -0.6606      1.402     -0.471      0.638      -3.423       2.102
# scale(dribblesAtmptsSuc)             3.4078      1.425      2.392      0.018       0.600       6.216
# scale(gamesApperance_sub)           -4.5678      1.625     -2.811      0.005      -7.771      -1.365
# ==============================================================================
# Omnibus:                       13.842   Durbin-Watson:                   2.024
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               14.526
# Skew:                           0.568   Prob(JB):                     0.000701
# Kurtosis:                       3.370   Cond. No.                         6.24
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 모델 성능 : 0.29565331438532627

# %% [markdown]
# # OLS - 4

# %%
df_out_4 = df_out_3.drop(['cards_yellowred'], axis=1)
len(df_out_4.columns), len(df_out_3.columns)
# Out:
# (23, 24)

# %%
from sklearn.model_selection import train_test_split

df_ols = df_out_4
dfX = df_ols.drop(['value'], axis=1)
dfy = df_ols['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
#    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.431
# Model:                            OLS   Adj. R-squared:                  0.375
# Method:                 Least Squares   F-statistic:                     7.617
# Date:                Wed, 24 Jun 2020   Prob (F-statistic):           2.53e-17
# Time:                        20:21:32   Log-Likelihood:                -951.97
# No. Observations:                 244   AIC:                             1950.
# Df Residuals:                     221   BIC:                             2030.
# Df Model:                          22
# Covariance Type:            nonrobust
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Intercept                           33.7520      0.805     41.912      0.000      32.165      35.339
# scale(position)                     -0.2316      1.129     -0.205      0.838      -2.456       1.993
# scale(age)                          -4.2350      1.006     -4.208      0.000      -6.218      -2.252
# scale(rating)                        0.1573      1.122      0.140      0.889      -2.055       2.369
# scale(passes_total)                  3.6462      1.329      2.743      0.007       1.026       6.266
# scale(passes_accuracy)               5.3326      1.470      3.628      0.000       2.436       8.229
# scale(tackles_total)                 0.8808      1.238      0.711      0.478      -1.559       3.321
# scale(tackles_blocks)               -2.3444      1.292     -1.814      0.071      -4.891       0.203
# scale(tackles_interceptions)         1.2758      1.646      0.775      0.439      -1.968       4.519
# scale(fouls_drawn)                  -1.3552      1.286     -1.054      0.293      -3.890       1.179
# scale(fouls_committed)              -2.5113      1.442     -1.741      0.083      -5.353       0.331
# scale(cards_yellow)                  0.2845      1.299      0.219      0.827      -2.276       2.845
# scale(penalty_won)                   1.0547      1.144      0.922      0.358      -1.200       3.310
# scale(penalty_commited)             -0.7394      0.938     -0.788      0.432      -2.589       1.110
# scale(penalty_success)              -1.1764      1.152     -1.021      0.308      -3.447       1.094
# scale(games_lineups)                -1.6117      0.946     -1.703      0.090      -3.476       0.253
# scale(games_played)                  7.1974      1.189      6.052      0.000       4.854       9.541
# scale(hw)                           -0.9105      1.041     -0.874      0.383      -2.963       1.142
# scale(shotsOnTotal_goalsTotal)       8.3842      1.830      4.580      0.000       4.777      11.992
# scale(goasConceded_penaltySaved)     1.4417      1.301      1.108      0.269      -1.123       4.007
# scale(goalsAssist_passesKey)        -0.6454      1.393     -0.463      0.644      -3.391       2.100
# scale(dribblesAtmptsSuc)             3.3962      1.418      2.395      0.017       0.601       6.191
# scale(gamesApperance_sub)           -4.5490      1.614     -2.818      0.005      -7.730      -1.368
# ==============================================================================
# Omnibus:                       13.930   Durbin-Watson:                   2.024
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               14.632
# Skew:                           0.570   Prob(JB):                     0.000665
# Kurtosis:                       3.372   Cond. No.                         6.22
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 모델 성능 : 0.29950762583462565

# %% [markdown]
# # OLS - 5

# %%
df_out_5 = df_out_4.drop(['rating'], axis=1)
len(df_out_5.columns), len(df_out_4.columns)
# Out:
# (22, 23)

# %%
from sklearn.model_selection import train_test_split

df_ols = df_out_5
dfX = df_ols.drop(['value'], axis=1)
dfy = df_ols['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
#    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.431
# Model:                            OLS   Adj. R-squared:                  0.377
# Method:                 Least Squares   F-statistic:                     8.014
# Date:                Wed, 24 Jun 2020   Prob (F-statistic):           8.84e-18
# Time:                        20:22:26   Log-Likelihood:                -951.98
# No. Observations:                 244   AIC:                             1948.
# Df Residuals:                     222   BIC:                             2025.
# Df Model:                          21
# Covariance Type:            nonrobust
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Intercept                           33.7520      0.804     42.004      0.000      32.169      35.336
# scale(position)                     -0.2247      1.125     -0.200      0.842      -2.442       1.993
# scale(age)                          -4.2461      1.001     -4.241      0.000      -6.219      -2.273
# scale(passes_total)                  3.6539      1.325      2.757      0.006       1.042       6.266
# scale(passes_accuracy)               5.4227      1.319      4.112      0.000       2.824       8.021
# scale(tackles_total)                 0.8893      1.234      0.721      0.472      -1.542       3.321
# scale(tackles_blocks)               -2.3498      1.289     -1.823      0.070      -4.890       0.190
# scale(tackles_interceptions)         1.3207      1.611      0.820      0.413      -1.854       4.495
# scale(fouls_drawn)                  -1.3498      1.283     -1.052      0.294      -3.877       1.178
# scale(fouls_committed)              -2.5015      1.437     -1.740      0.083      -5.334       0.331
# scale(cards_yellow)                  0.2934      1.295      0.227      0.821      -2.259       2.845
# scale(penalty_won)                   1.0779      1.130      0.954      0.341      -1.148       3.304
# scale(penalty_commited)             -0.7464      0.935     -0.798      0.426      -2.589       1.096
# scale(penalty_success)              -1.1746      1.150     -1.022      0.308      -3.440       1.091
# scale(games_lineups)                -1.6185      0.943     -1.717      0.087      -3.477       0.240
# scale(games_played)                  7.2396      1.148      6.306      0.000       4.977       9.502
# scale(hw)                           -0.9394      1.018     -0.922      0.357      -2.947       1.068
# scale(shotsOnTotal_goalsTotal)       8.4215      1.807      4.661      0.000       4.861      11.983
# scale(goasConceded_penaltySaved)     1.4694      1.284      1.145      0.254      -1.060       3.999
# scale(goalsAssist_passesKey)        -0.6064      1.362     -0.445      0.657      -3.291       2.078
# scale(dribblesAtmptsSuc)             3.3846      1.413      2.396      0.017       0.601       6.169
# scale(gamesApperance_sub)           -4.5783      1.597     -2.867      0.005      -7.726      -1.431
# ==============================================================================
# Omnibus:                       13.548   Durbin-Watson:                   2.023
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               14.172
# Skew:                           0.563   Prob(JB):                     0.000837
# Kurtosis:                       3.353   Cond. No.                         6.15
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 모델 성능 : 0.30444055351989713

# %% [markdown]
# # OLS - 6

# %%
df_out_6 = df_out_5.drop(['position'], axis=1)
len(df_out_6.columns), len(df_out_5.columns)
# Out:
# (21, 22)

# %%
from sklearn.model_selection import train_test_split

df_ols = df_out_6
dfX = df_ols.drop(['value'], axis=1)
dfy = df_ols['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
#    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.431
# Model:                            OLS   Adj. R-squared:                  0.380
# Method:                 Least Squares   F-statistic:                     8.449
# Date:                Wed, 24 Jun 2020   Prob (F-statistic):           3.03e-18
# Time:                        20:23:16   Log-Likelihood:                -952.00
# No. Observations:                 244   AIC:                             1946.
# Df Residuals:                     223   BIC:                             2019.
# Df Model:                          20
# Covariance Type:            nonrobust
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Intercept                           33.7520      0.802     42.095      0.000      32.172      35.332
# scale(age)                          -4.2380      0.998     -4.246      0.000      -6.205      -2.271
# scale(passes_total)                  3.6993      1.303      2.839      0.005       1.132       6.267
# scale(passes_accuracy)               5.4135      1.315      4.117      0.000       2.822       8.005
# scale(tackles_total)                 0.9330      1.212      0.770      0.442      -1.455       3.321
# scale(tackles_blocks)               -2.3820      1.276     -1.867      0.063      -4.897       0.133
# scale(tackles_interceptions)         1.3111      1.607      0.816      0.415      -1.855       4.477
# scale(fouls_drawn)                  -1.3327      1.277     -1.044      0.298      -3.849       1.184
# scale(fouls_committed)              -2.5010      1.434     -1.744      0.083      -5.327       0.325
# scale(cards_yellow)                  0.3223      1.284      0.251      0.802      -2.208       2.853
# scale(penalty_won)                   1.0363      1.108      0.935      0.351      -1.147       3.220
# scale(penalty_commited)             -0.7610      0.930     -0.818      0.414      -2.594       1.072
# scale(penalty_success)              -1.1698      1.147     -1.020      0.309      -3.430       1.090
# scale(games_lineups)                -1.6119      0.940     -1.714      0.088      -3.465       0.241
# scale(games_played)                  7.2362      1.145      6.317      0.000       4.979       9.493
# scale(hw)                           -0.9299      1.015     -0.916      0.361      -2.931       1.071
# scale(shotsOnTotal_goalsTotal)       8.3320      1.747      4.770      0.000       4.890      11.774
# scale(goasConceded_penaltySaved)     1.5728      1.172      1.342      0.181      -0.737       3.882
# scale(goalsAssist_passesKey)        -0.6026      1.359     -0.443      0.658      -3.281       2.076
# scale(dribblesAtmptsSuc)             3.4107      1.404      2.430      0.016       0.645       6.177
# scale(gamesApperance_sub)           -4.5564      1.590     -2.866      0.005      -7.689      -1.423
# ==============================================================================
# Omnibus:                       13.799   Durbin-Watson:                   2.027
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               14.475
# Skew:                           0.568   Prob(JB):                     0.000719
# Kurtosis:                       3.364   Cond. No.                         6.04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 모델 성능 : 0.3063979908918883

# %% [markdown]
# # OLS - 7

# %%
df_out_7 = df_out_6.drop(['cards_yellow'], axis=1)
len(df_out_7.columns), len(df_out_6.columns)
# Out:
# (20, 21)

# %%
from sklearn.model_selection import train_test_split

df_ols = df_out_7
dfX = df_ols.drop(['value'], axis=1)
dfy = df_ols['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
#    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.431
# Model:                            OLS   Adj. R-squared:                  0.383
# Method:                 Least Squares   F-statistic:                     8.928
# Date:                Wed, 24 Jun 2020   Prob (F-statistic):           1.02e-18
# Time:                        20:24:46   Log-Likelihood:                -952.03
# No. Observations:                 244   AIC:                             1944.
# Df Residuals:                     224   BIC:                             2014.
# Df Model:                          19
# Covariance Type:            nonrobust
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Intercept                           33.7520      0.800     42.183      0.000      32.175      35.329
# scale(age)                          -4.2344      0.996     -4.252      0.000      -6.197      -2.272
# scale(passes_total)                  3.6977      1.300      2.844      0.005       1.135       6.260
# scale(passes_accuracy)               5.3945      1.310      4.118      0.000       2.813       7.976
# scale(tackles_total)                 0.8747      1.187      0.737      0.462      -1.464       3.214
# scale(tackles_blocks)               -2.3277      1.255     -1.855      0.065      -4.801       0.145
# scale(tackles_interceptions)         1.3678      1.587      0.862      0.390      -1.760       4.496
# scale(fouls_drawn)                  -1.2932      1.265     -1.023      0.308      -3.785       1.199
# scale(fouls_committed)              -2.2888      1.156     -1.980      0.049      -4.567      -0.011
# scale(penalty_won)                   1.0111      1.101      0.918      0.359      -1.159       3.181
# scale(penalty_commited)             -0.7388      0.924     -0.800      0.425      -2.559       1.082
# scale(penalty_success)              -1.1495      1.142     -1.007      0.315      -3.399       1.100
# scale(games_lineups)                -1.5921      0.935     -1.703      0.090      -3.435       0.250
# scale(games_played)                  7.2475      1.142      6.345      0.000       4.997       9.498
# scale(hw)                           -0.8776      0.992     -0.885      0.377      -2.832       1.076
# scale(shotsOnTotal_goalsTotal)       8.2833      1.732      4.782      0.000       4.870      11.697
# scale(goasConceded_penaltySaved)     1.5792      1.169      1.351      0.178      -0.725       3.883
# scale(goalsAssist_passesKey)        -0.6272      1.353     -0.464      0.643      -3.293       2.038
# scale(dribblesAtmptsSuc)             3.3786      1.395      2.422      0.016       0.630       6.127
# scale(gamesApperance_sub)           -4.5057      1.574     -2.863      0.005      -7.607      -1.405
# ==============================================================================
# Omnibus:                       13.712   Durbin-Watson:                   2.026
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               14.372
# Skew:                           0.569   Prob(JB):                     0.000757
# Kurtosis:                       3.343   Cond. No.                         6.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 모델 성능 : 0.3075277932522197

# %%
# OLS - 8

# %%
df_out_8 = df_out_7.drop(['goalsAssist_passesKey'], axis=1)
len(df_out_8.columns), len(df_out_7.columns)
# Out:
# (19, 20)

# %%
from sklearn.model_selection import train_test_split

df_ols = df_out_8
dfX = df_ols.drop(['value'], axis=1)
dfy = df_ols['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
#    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.430
# Model:                            OLS   Adj. R-squared:                  0.385
# Method:                 Least Squares   F-statistic:                     9.445
# Date:                Wed, 24 Jun 2020   Prob (F-statistic):           3.59e-19
# Time:                        20:25:35   Log-Likelihood:                -952.15
# No. Observations:                 244   AIC:                             1942.
# Df Residuals:                     225   BIC:                             2009.
# Df Model:                          18
# Covariance Type:            nonrobust
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Intercept                           33.7520      0.799     42.257      0.000      32.178      35.326
# scale(age)                          -4.2666      0.992     -4.302      0.000      -6.221      -2.312
# scale(passes_total)                  3.5270      1.245      2.833      0.005       1.074       5.980
# scale(passes_accuracy)               5.4008      1.308      4.130      0.000       2.824       7.978
# scale(tackles_total)                 0.8540      1.184      0.721      0.471      -1.479       3.187
# scale(tackles_blocks)               -2.2253      1.233     -1.805      0.072      -4.655       0.205
# scale(tackles_interceptions)         1.3983      1.583      0.883      0.378      -1.721       4.518
# scale(fouls_drawn)                  -1.2974      1.262     -1.028      0.305      -3.785       1.190
# scale(fouls_committed)              -2.2686      1.153     -1.967      0.050      -4.541       0.004
# scale(penalty_won)                   1.0199      1.099      0.928      0.354      -1.146       3.185
# scale(penalty_commited)             -0.6950      0.917     -0.758      0.449      -2.503       1.113
# scale(penalty_success)              -1.1728      1.139     -1.030      0.304      -3.416       1.071
# scale(games_lineups)                -1.6175      0.932     -1.736      0.084      -3.454       0.219
# scale(games_played)                  7.1846      1.132      6.346      0.000       4.954       9.416
# scale(hw)                           -0.9888      0.960     -1.030      0.304      -2.881       0.904
# scale(shotsOnTotal_goalsTotal)       8.0688      1.666      4.842      0.000       4.785      11.353
# scale(goasConceded_penaltySaved)     1.6304      1.162      1.403      0.162      -0.659       3.920
# scale(dribblesAtmptsSuc)             3.1983      1.337      2.392      0.018       0.563       5.834
# scale(gamesApperance_sub)           -4.5805      1.563     -2.931      0.004      -7.660      -1.501
# ==============================================================================
# Omnibus:                       13.114   Durbin-Watson:                   2.027
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               13.657
# Skew:                           0.556   Prob(JB):                      0.00108
# Kurtosis:                       3.329   Cond. No.                         5.61
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 모델 성능 : 0.3124346650344757

# %%
# OLS - 9

# %%
df_out_9 = df_out_8.drop(['tackles_total'], axis=1)
len(df_out_9.columns), len(df_out_8.columns)
# Out:
# (18, 19)

# %%
from sklearn.model_selection import train_test_split

df_ols = df_out_9
dfX = df_ols.drop(['value'], axis=1)
dfy = df_ols['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
#    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.429
# Model:                            OLS   Adj. R-squared:                  0.386
# Method:                 Least Squares   F-statistic:                     9.991
# Date:                Wed, 24 Jun 2020   Prob (F-statistic):           1.40e-19
# Time:                        20:26:56   Log-Likelihood:                -952.43
# No. Observations:                 244   AIC:                             1941.
# Df Residuals:                     226   BIC:                             2004.
# Df Model:                          17
# Covariance Type:            nonrobust
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Intercept                           33.7520      0.798     42.302      0.000      32.180      35.324
# scale(age)                          -4.2289      0.989     -4.274      0.000      -6.179      -2.279
# scale(passes_total)                  3.5771      1.242      2.881      0.004       1.130       6.024
# scale(passes_accuracy)               5.4230      1.306      4.152      0.000       2.850       7.996
# scale(tackles_blocks)               -2.1772      1.230     -1.770      0.078      -4.601       0.247
# scale(tackles_interceptions)         1.8233      1.468      1.242      0.215      -1.069       4.716
# scale(fouls_drawn)                  -1.4404      1.245     -1.157      0.249      -3.894       1.014
# scale(fouls_committed)              -2.0161      1.098     -1.837      0.068      -4.179       0.147
# scale(penalty_won)                   0.9696      1.096      0.885      0.377      -1.189       3.128
# scale(penalty_commited)             -0.7254      0.915     -0.792      0.429      -2.529       1.079
# scale(penalty_success)              -1.1698      1.137     -1.029      0.305      -3.411       1.071
# scale(games_lineups)                -1.6432      0.930     -1.767      0.079      -3.476       0.189
# scale(games_played)                  7.1216      1.128      6.316      0.000       4.900       9.343
# scale(hw)                           -0.8732      0.946     -0.923      0.357      -2.737       0.991
# scale(shotsOnTotal_goalsTotal)       8.0173      1.663      4.821      0.000       4.740      11.295
# scale(goasConceded_penaltySaved)     1.6507      1.160      1.423      0.156      -0.636       3.937
# scale(dribblesAtmptsSuc)             3.4602      1.286      2.691      0.008       0.927       5.994
# scale(gamesApperance_sub)           -4.7032      1.552     -3.031      0.003      -7.761      -1.646
# ==============================================================================
# Omnibus:                       12.685   Durbin-Watson:                   2.036
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):               13.152
# Skew:                           0.547   Prob(JB):                      0.00139
# Kurtosis:                       3.312   Cond. No.                         5.54
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 모델 성능 : 0.3150384421128967

# %%
# OLS - 10

# %%
df_out_10 = df_out_9.drop(['penalty_commited'], axis=1)
len(df_out_10.columns), len(df_out_9.columns)
# Out:
# (17, 18)

# %%
from sklearn.model_selection import train_test_split

df_ols = df_out_10
dfX = df_ols.drop(['value'], axis=1)
dfy = df_ols['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
#    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.427
# Model:                            OLS   Adj. R-squared:                  0.387
# Method:                 Least Squares   F-statistic:                     10.59
# Date:                Wed, 24 Jun 2020   Prob (F-statistic):           5.61e-20
# Time:                        20:27:57   Log-Likelihood:                -952.77
# No. Observations:                 244   AIC:                             1940.
# Df Residuals:                     227   BIC:                             1999.
# Df Model:                          16
# Covariance Type:            nonrobust
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Intercept                           33.7520      0.797     42.337      0.000      32.181      35.323
# scale(age)                          -4.2176      0.988     -4.267      0.000      -6.165      -2.270
# scale(passes_total)                  3.5593      1.240      2.870      0.004       1.115       6.003
# scale(passes_accuracy)               5.4742      1.303      4.200      0.000       2.906       8.042
# scale(tackles_blocks)               -2.3069      1.218     -1.894      0.060      -4.707       0.093
# scale(tackles_interceptions)         1.7433      1.463      1.191      0.235      -1.140       4.626
# scale(fouls_drawn)                  -1.3634      1.241     -1.099      0.273      -3.808       1.081
# scale(fouls_committed)              -2.0543      1.096     -1.875      0.062      -4.213       0.105
# scale(penalty_won)                   0.9894      1.094      0.904      0.367      -1.167       3.146
# scale(penalty_success)              -1.1904      1.136     -1.048      0.296      -3.429       1.048
# scale(games_lineups)                -1.5959      0.927     -1.721      0.087      -3.423       0.232
# scale(games_played)                  7.1994      1.122      6.415      0.000       4.988       9.411
# scale(hw)                           -0.8578      0.945     -0.908      0.365      -2.720       1.004
# scale(shotsOnTotal_goalsTotal)       8.1222      1.656      4.903      0.000       4.858      11.386
# scale(goasConceded_penaltySaved)     1.7421      1.154      1.510      0.132      -0.531       4.015
# scale(dribblesAtmptsSuc)             3.4119      1.283      2.659      0.008       0.883       5.940
# scale(gamesApperance_sub)           -4.6013      1.545     -2.978      0.003      -7.646      -1.557
# ==============================================================================
# Omnibus:                       13.059   Durbin-Watson:                   2.034
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               13.597
# Skew:                           0.556   Prob(JB):                      0.00112
# Kurtosis:                       3.316   Cond. No.                         5.43
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 모델 성능 : 0.3177874821843581

# %%
# OLS - 11

# %%
df_out_11 = df_out_10.drop(['penalty_won'], axis=1)
len(df_out_11.columns), len(df_out_10.columns)
# Out:
# (16, 17)

# %%
from sklearn.model_selection import train_test_split

df_ols = df_out_11
dfX = df_ols.drop(['value'], axis=1)
dfy = df_ols['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
#    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.425
# Model:                            OLS   Adj. R-squared:                  0.388
# Method:                 Least Squares   F-statistic:                     11.25
# Date:                Wed, 24 Jun 2020   Prob (F-statistic):           2.38e-20
# Time:                        20:28:48   Log-Likelihood:                -953.21
# No. Observations:                 244   AIC:                             1938.
# Df Residuals:                     228   BIC:                             1994.
# Df Model:                          15
# Covariance Type:            nonrobust
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Intercept                           33.7520      0.797     42.354      0.000      32.182      35.322
# scale(age)                          -4.1594      0.986     -4.219      0.000      -6.102      -2.217
# scale(passes_total)                  3.4457      1.233      2.793      0.006       1.015       5.876
# scale(passes_accuracy)               5.4531      1.303      4.186      0.000       2.887       8.020
# scale(tackles_blocks)               -2.3063      1.218     -1.894      0.059      -4.706       0.093
# scale(tackles_interceptions)         1.5810      1.452      1.089      0.277      -1.279       4.441
# scale(fouls_drawn)                  -1.0698      1.197     -0.894      0.372      -3.428       1.288
# scale(fouls_committed)              -1.9717      1.091     -1.806      0.072      -4.122       0.179
# scale(penalty_success)              -1.2069      1.136     -1.063      0.289      -3.444       1.031
# scale(games_lineups)                -1.7780      0.905     -1.965      0.051      -3.561       0.005
# scale(games_played)                  7.1891      1.122      6.408      0.000       4.979       9.400
# scale(hw)                           -0.8489      0.945     -0.899      0.370      -2.710       1.012
# scale(shotsOnTotal_goalsTotal)       8.3334      1.639      5.084      0.000       5.103      11.563
# scale(goasConceded_penaltySaved)     1.7109      1.153      1.484      0.139      -0.560       3.982
# scale(dribblesAtmptsSuc)             3.5477      1.274      2.785      0.006       1.038       6.058
# scale(gamesApperance_sub)           -4.6347      1.544     -3.002      0.003      -7.677      -1.592
# ==============================================================================
# Omnibus:                       13.642   Durbin-Watson:                   2.041
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               14.294
# Skew:                           0.570   Prob(JB):                     0.000787
# Kurtosis:                       3.328   Cond. No.                         5.14
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 모델 성능 : 0.3172993333361752

# %%
# OLS - 12

# %%
df_out_12 = df_out_11.drop(['fouls_drawn'], axis=1)
len(df_out_12.columns), len(df_out_11.columns)
# Out:
# (15, 16)

# %%
from sklearn.model_selection import train_test_split

df_ols = df_out_12
dfX = df_ols.drop(['value'], axis=1)
dfy = df_ols['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
#    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.423
# Model:                            OLS   Adj. R-squared:                  0.388
# Method:                 Least Squares   F-statistic:                     12.01
# Date:                Wed, 24 Jun 2020   Prob (F-statistic):           9.66e-21
# Time:                        20:29:34   Log-Likelihood:                -953.64
# No. Observations:                 244   AIC:                             1937.
# Df Residuals:                     229   BIC:                             1990.
# Df Model:                          14
# Covariance Type:            nonrobust
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Intercept                           33.7520      0.797     42.372      0.000      32.183      35.322
# scale(age)                          -4.1121      0.984     -4.178      0.000      -6.051      -2.173
# scale(passes_total)                  3.2980      1.222      2.699      0.007       0.890       5.705
# scale(passes_accuracy)               5.5428      1.298      4.270      0.000       2.985       8.101
# scale(tackles_blocks)               -2.2932      1.217     -1.884      0.061      -4.691       0.105
# scale(tackles_interceptions)         1.7533      1.438      1.219      0.224      -1.080       4.587
# scale(fouls_committed)              -2.4119      0.974     -2.477      0.014      -4.330      -0.494
# scale(penalty_success)              -1.3031      1.130     -1.153      0.250      -3.529       0.923
# scale(games_lineups)                -1.7066      0.901     -1.894      0.059      -3.482       0.069
# scale(games_played)                  7.2764      1.117      6.514      0.000       5.075       9.477
# scale(hw)                           -0.9624      0.936     -1.029      0.305      -2.806       0.881
# scale(shotsOnTotal_goalsTotal)       8.2722      1.637      5.053      0.000       5.046      11.498
# scale(goasConceded_penaltySaved)     1.6997      1.152      1.475      0.142      -0.570       3.970
# scale(dribblesAtmptsSuc)             3.0192      1.128      2.677      0.008       0.797       5.241
# scale(gamesApperance_sub)           -4.5444      1.540     -2.951      0.003      -7.579      -1.510
# ==============================================================================
# Omnibus:                       14.775   Durbin-Watson:                   2.037
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               15.665
# Skew:                           0.592   Prob(JB):                     0.000397
# Kurtosis:                       3.371   Cond. No.                         4.87
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 모델 성능 : 0.31221152444463546

# %%
# OLS - 13

# %%
df_out_13 = df_out_12.drop(['hw'], axis=1)
len(df_out_13.columns), len(df_out_12.columns)
# Out:
# (14, 15)

# %%
from sklearn.model_selection import train_test_split

df_ols = df_out_13
dfX = df_ols.drop(['value'], axis=1)
dfy = df_ols['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
#    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.421
# Model:                            OLS   Adj. R-squared:                  0.388
# Method:                 Least Squares   F-statistic:                     12.85
# Date:                Wed, 24 Jun 2020   Prob (F-statistic):           4.28e-21
# Time:                        20:30:27   Log-Likelihood:                -954.20
# No. Observations:                 244   AIC:                             1936.
# Df Residuals:                     230   BIC:                             1985.
# Df Model:                          13
# Covariance Type:            nonrobust
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Intercept                           33.7520      0.797     42.367      0.000      32.182      35.322
# scale(age)                          -4.0628      0.983     -4.133      0.000      -6.000      -2.126
# scale(passes_total)                  3.4053      1.218      2.797      0.006       1.006       5.804
# scale(passes_accuracy)               5.6156      1.296      4.332      0.000       3.061       8.170
# scale(tackles_blocks)               -1.9603      1.173     -1.671      0.096      -4.272       0.352
# scale(tackles_interceptions)         1.5891      1.429      1.112      0.267      -1.227       4.405
# scale(fouls_committed)              -2.2666      0.963     -2.353      0.019      -4.165      -0.368
# scale(penalty_success)              -1.3725      1.128     -1.217      0.225      -3.595       0.850
# scale(games_lineups)                -1.7368      0.901     -1.929      0.055      -3.511       0.038
# scale(games_played)                  7.2873      1.117      6.523      0.000       5.086       9.488
# scale(shotsOnTotal_goalsTotal)       8.5083      1.621      5.248      0.000       5.314      11.703
# scale(goasConceded_penaltySaved)     1.9944      1.116      1.787      0.075      -0.205       4.194
# scale(dribblesAtmptsSuc)             2.7572      1.099      2.509      0.013       0.592       4.922
# scale(gamesApperance_sub)           -4.6292      1.538     -3.010      0.003      -7.660      -1.599
# ==============================================================================
# Omnibus:                       13.932   Durbin-Watson:                   2.028
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               14.636
# Skew:                           0.571   Prob(JB):                     0.000664
# Kurtosis:                       3.370   Cond. No.                         4.76
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 모델 성능 : 0.2975628751047869

# %%
# OLS - 14

# %%
df_out_14 = df_out_13.drop(['tackles_interceptions'], axis=1)
len(df_out_14.columns), len(df_out_13.columns)
# Out:
# (13, 14)

# %%
from sklearn.model_selection import train_test_split

df_ols = df_out_14
dfX = df_ols.drop(['value'], axis=1)
dfy = df_ols['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
#    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.418
# Model:                            OLS   Adj. R-squared:                  0.387
# Method:                 Least Squares   F-statistic:                     13.80
# Date:                Wed, 24 Jun 2020   Prob (F-statistic):           1.99e-21
# Time:                        20:31:28   Log-Likelihood:                -954.85
# No. Observations:                 244   AIC:                             1936.
# Df Residuals:                     231   BIC:                             1981.
# Df Model:                          12
# Covariance Type:            nonrobust
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Intercept                           33.7520      0.797     42.345      0.000      32.182      35.322
# scale(age)                          -4.0332      0.983     -4.102      0.000      -5.970      -2.096
# scale(passes_total)                  3.6911      1.191      3.100      0.002       1.345       6.037
# scale(passes_accuracy)               5.7712      1.289      4.476      0.000       3.231       8.312
# scale(tackles_blocks)               -1.5815      1.123     -1.408      0.161      -3.795       0.632
# scale(fouls_committed)              -1.8825      0.900     -2.092      0.038      -3.655      -0.110
# scale(penalty_success)              -1.2765      1.125     -1.134      0.258      -3.494       0.941
# scale(games_lineups)                -1.6810      0.900     -1.869      0.063      -3.454       0.092
# scale(games_played)                  7.2084      1.115      6.462      0.000       5.011       9.406
# scale(shotsOnTotal_goalsTotal)       7.7539      1.473      5.264      0.000       4.852      10.656
# scale(goasConceded_penaltySaved)     1.6077      1.061      1.515      0.131      -0.483       3.698
# scale(dribblesAtmptsSuc)             2.7770      1.099      2.526      0.012       0.611       4.943
# scale(gamesApperance_sub)           -4.8162      1.530     -3.149      0.002      -7.830      -1.802
# ==============================================================================
# Omnibus:                       13.856   Durbin-Watson:                   2.028
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               14.543
# Skew:                           0.569   Prob(JB):                     0.000695
# Kurtosis:                       3.367   Cond. No.                         4.27
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 모델 성능 : 0.3044316833873341

# %%
# OLS - 15

# %%
df_out_15 = df_out_14.drop(['penalty_success'], axis=1)
len(df_out_15.columns), len(df_out_14.columns)
# Out:
# (12, 13)

# %%
from sklearn.model_selection import train_test_split

df_ols = df_out_15
dfX = df_ols.drop(['value'], axis=1)
dfy = df_ols['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
#    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.414
# Model:                            OLS   Adj. R-squared:                  0.387
# Method:                 Least Squares   F-statistic:                     14.92
# Date:                Wed, 24 Jun 2020   Prob (F-statistic):           9.16e-22
# Time:                        20:32:17   Log-Likelihood:                -955.53
# No. Observations:                 244   AIC:                             1935.
# Df Residuals:                     232   BIC:                             1977.
# Df Model:                          11
# Covariance Type:            nonrobust
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Intercept                           33.7520      0.798     42.319      0.000      32.181      35.323
# scale(age)                          -4.2709      0.961     -4.443      0.000      -6.165      -2.377
# scale(passes_total)                  3.6258      1.190      3.047      0.003       1.281       5.970
# scale(passes_accuracy)               5.8812      1.287      4.571      0.000       3.346       8.416
# scale(tackles_blocks)               -1.5739      1.124     -1.400      0.163      -3.789       0.641
# scale(fouls_committed)              -1.8163      0.898     -2.022      0.044      -3.587      -0.046
# scale(games_lineups)                -1.6172      0.898     -1.800      0.073      -3.387       0.153
# scale(games_played)                  7.2495      1.116      6.498      0.000       5.052       9.447
# scale(shotsOnTotal_goalsTotal)       6.8048      1.213      5.609      0.000       4.415       9.195
# scale(goasConceded_penaltySaved)     1.6228      1.062      1.529      0.128      -0.469       3.714
# scale(dribblesAtmptsSuc)             2.8837      1.096      2.631      0.009       0.725       5.043
# scale(gamesApperance_sub)           -4.5605      1.514     -3.013      0.003      -7.543      -1.578
# ==============================================================================
# Omnibus:                       13.667   Durbin-Watson:                   2.025
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               14.317
# Skew:                           0.567   Prob(JB):                     0.000778
# Kurtosis:                       3.351   Cond. No.                         4.23
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 모델 성능 : 0.30628679647502743

# %%
# OLS - 16

# %%
df_out_16 = df_out_15.drop(['tackles_blocks'], axis=1)
len(df_out_16.columns), len(df_out_15.columns)
# Out:
# (11, 12)

# %%
from sklearn.model_selection import train_test_split

df_ols = df_out_16
dfX = df_ols.drop(['value'], axis=1)
dfy = df_ols['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
#    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.409
# Model:                            OLS   Adj. R-squared:                  0.384
# Method:                 Least Squares   F-statistic:                     16.15
# Date:                Wed, 24 Jun 2020   Prob (F-statistic):           5.55e-22
# Time:                        20:33:01   Log-Likelihood:                -956.56
# No. Observations:                 244   AIC:                             1935.
# Df Residuals:                     233   BIC:                             1974.
# Df Model:                          10
# Covariance Type:            nonrobust
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Intercept                           33.7520      0.799     42.232      0.000      32.177      35.327
# scale(age)                          -4.1416      0.959     -4.320      0.000      -6.031      -2.253
# scale(passes_total)                  3.5441      1.191      2.976      0.003       1.197       5.891
# scale(passes_accuracy)               5.5366      1.265      4.375      0.000       3.043       8.030
# scale(fouls_committed)              -1.9206      0.897     -2.141      0.033      -3.688      -0.153
# scale(games_lineups)                -1.5065      0.897     -1.680      0.094      -3.273       0.260
# scale(games_played)                  7.3773      1.114      6.622      0.000       5.182       9.572
# scale(shotsOnTotal_goalsTotal)       7.2084      1.181      6.105      0.000       4.882       9.535
# scale(goasConceded_penaltySaved)     2.1490      0.995      2.160      0.032       0.189       4.109
# scale(dribblesAtmptsSuc)             3.2967      1.058      3.117      0.002       1.213       5.380
# scale(gamesApperance_sub)           -3.8658      1.433     -2.697      0.007      -6.689      -1.042
# ==============================================================================
# Omnibus:                       14.394   Durbin-Watson:                   2.032
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               15.198
# Skew:                           0.583   Prob(JB):                     0.000501
# Kurtosis:                       3.365   Cond. No.                         3.89
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 모델 성능 : 0.3098913128308978

# %%
# OLS - 17

# %%
df_out_17 = df_out_16.drop(['games_lineups'], axis=1)
len(df_out_17.columns), len(df_out_16.columns)
# Out:
# (10, 11)

# %%
from sklearn.model_selection import train_test_split

df_ols = df_out_17
dfX = df_ols.drop(['value'], axis=1)
dfy = df_ols['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
#    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.402
# Model:                            OLS   Adj. R-squared:                  0.379
# Method:                 Least Squares   F-statistic:                     17.50
# Date:                Wed, 24 Jun 2020   Prob (F-statistic):           4.86e-22
# Time:                        20:37:58   Log-Likelihood:                -958.02
# No. Observations:                 244   AIC:                             1936.
# Df Residuals:                     234   BIC:                             1971.
# Df Model:                           9
# Covariance Type:            nonrobust
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Intercept                           33.7520      0.802     42.069      0.000      32.171      35.333
# scale(age)                          -4.3554      0.954     -4.566      0.000      -6.235      -2.476
# scale(passes_total)                  3.5974      1.195      3.010      0.003       1.243       5.952
# scale(passes_accuracy)               5.4903      1.270      4.323      0.000       2.988       7.992
# scale(fouls_committed)              -2.0259      0.899     -2.255      0.025      -3.796      -0.256
# scale(games_played)                  7.4903      1.116      6.709      0.000       5.291       9.690
# scale(shotsOnTotal_goalsTotal)       7.0040      1.179      5.940      0.000       4.681       9.327
# scale(goasConceded_penaltySaved)     2.1820      0.999      2.185      0.030       0.215       4.149
# scale(dribblesAtmptsSuc)             2.9736      1.044      2.848      0.005       0.917       5.030
# scale(gamesApperance_sub)           -3.0359      1.351     -2.248      0.026      -5.697      -0.375
# ==============================================================================
# Omnibus:                       14.836   Durbin-Watson:                   2.005
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               15.745
# Skew:                           0.587   Prob(JB):                     0.000381
# Kurtosis:                       3.412   Cond. No.                         3.79
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 모델 성능 : 0.3000663479901057

# %%
from sklearn.model_selection import train_test_split

df_ols = df_out_17
dfX = df_ols.drop(['value'], axis=1)
dfy = df_ols['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

#feature_names = list(dfX.columns)
#feature_names = ["scale({})".format(name) for name in feature_names]

formula = "value ~ scale(age) + \
            scale(passes_total) + \
            scale(passes_accuracy) + \
            scale(fouls_committed) + \
            scale(games_played) + \
            scale(shotsOnTotal_goalsTotal) + \
            scale(goasConceded_penaltySaved) + \
            scale(dribblesAtmptsSuc) + scale(gamesApperance_sub)"

model = sm.OLS.from_formula(formula, data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula(formula, data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
#    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.402
# Model:                            OLS   Adj. R-squared:                  0.379
# Method:                 Least Squares   F-statistic:                     17.50
# Date:                Wed, 24 Jun 2020   Prob (F-statistic):           4.86e-22
# Time:                        20:39:49   Log-Likelihood:                -958.02
# No. Observations:                 244   AIC:                             1936.
# Df Residuals:                     234   BIC:                             1971.
# Df Model:                           9
# Covariance Type:            nonrobust
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Intercept                           33.7520      0.802     42.069      0.000      32.171      35.333
# scale(age)                          -4.3554      0.954     -4.566      0.000      -6.235      -2.476
# scale(passes_total)                  3.5974      1.195      3.010      0.003       1.243       5.952
# scale(passes_accuracy)               5.4903      1.270      4.323      0.000       2.988       7.992
# scale(fouls_committed)              -2.0259      0.899     -2.255      0.025      -3.796      -0.256
# scale(games_played)                  7.4903      1.116      6.709      0.000       5.291       9.690
# scale(shotsOnTotal_goalsTotal)       7.0040      1.179      5.940      0.000       4.681       9.327
# scale(goasConceded_penaltySaved)     2.1820      0.999      2.185      0.030       0.215       4.149
# scale(dribblesAtmptsSuc)             2.9736      1.044      2.848      0.005       0.917       5.030
# scale(gamesApperance_sub)           -3.0359      1.351     -2.248      0.026      -5.697      -0.375
# ==============================================================================
# Omnibus:                       14.836   Durbin-Watson:                   2.005
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               15.745
# Skew:                           0.587   Prob(JB):                     0.000381
# Kurtosis:                       3.412   Cond. No.                         3.79
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 모델 성능 : 0.3000663479901057

# %% [markdown]
# # 검증 1차

# %%
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_out_20)):
    df_train = df_out_20.iloc[idx_train]
    df_test = df_out_20.iloc[idx_test]
    
    model = sm.OLS.from_formula("value ~ scale(age) + scale(follower) + scale(passes_accuracy) + \
                                scale(games_played) + scale(shotsOnTotal_goalsTotal)", data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))

# %% [markdown]
# # 검증 2차

# %%
from sklearn.base import BaseEstimator, RegressorMixin
import statsmodels.formula.api as smf
import statsmodels.api as sm

class StatsmodelsOLS(BaseEstimator, RegressorMixin):
    def __init__(self, formula):
        self.formula = formula
        self.model = None
        self.data = None
        self.result = None
        
    def fit(self, dfX, dfy):
        self.data = pd.concat([dfX, dfy], axis=1)
        self.model = smf.ols(self.formula, data=self.data)
        self.result = self.model.fit()
        
    def predict(self, new_data):
        return self.result.predict(new_data)

# %%
from sklearn.model_selection import cross_val_score

model = StatsmodelsOLS("value ~ scale(age) + scale(follower) + scale(passes_accuracy) + \
                       scale(games_played) + scale(shotsOnTotal_goalsTotal)")
cv = KFold(10, shuffle=True, random_state=0)
cross_val_score(model, dfX, dfy, scoring="r2", cv=cv).mean()

# %%
from sklearn.model_selection import train_test_split

dfX = df_out_20.drop(['value'], axis=1)
dfy = df_out_20['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

formula = "value ~ " + "+".join(feature_names)

model = sm.OLS.from_formula(formula, data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula(formula, data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
#    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))

# %% [markdown]
# # 아웃라이어 2차 제거

# %%
from statsmodels.graphics import utils

dfX0 = df_out_20.drop('value', axis=1)
dfX = sm.add_constant(dfX0)
dfy = df_out_20['value']

model_p = sm.OLS(dfy, dfX)
result_p = model_p.fit()
pred = result_p.predict(dfX)

influence_p = result_p.get_influence()
cooks_d2, pvals = influence_p.cooks_distance
K = influence_p.k_vars
fox_cr = 4 / (len(dfy) - K - 1)
idx = np.where(cooks_d2 > fox_cr)[0]

ax = plt.subplot()
plt.scatter(dfy, pred)
plt.scatter(dfy[idx], pred[idx], s=300, c="r", alpha=0.5)
utils.annotate_axes(range(len(idx)), idx, list(zip(dfy[idx], pred[idx])), [(-20, 15)] * len(idx), size="small", ax=ax)
plt.title("아웃라이어")
plt.show()
print(idx)

# %%
idx2 = list(set(range(len(dfX))).difference(idx))
len(idx2)

# %%
df_out2 = df_out_20.iloc[idx2].reset_index(drop=True)
df_out2

# %%
from sklearn.model_selection import train_test_split

dfX = df_out2.drop(['value'], axis=1)
dfy = df_out2['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

model = sm.OLS.from_formula("value ~ " + "+".join(feature_names), data=df_train)
result = model.fit()
print(result.summary())

# %%
pred = result.predict(df_test)

rss = ((df_test.value - pred) ** 2).sum()
tss = ((df_test.value - df_test.value.mean()) ** 2).sum()
rsquared = 1 - rss / tss
rsquared

# %% [markdown]
# # 검증 1차

# %%
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_out2)):
    df_train = df_out2.iloc[idx_train]
    df_test = df_out2.iloc[idx_test]
    
    model = sm.OLS.from_formula("value ~ scale(age) + scale(follower) + scale(passes_accuracy) + \
                                scale(games_played) + scale(shotsOnTotal_goalsTotal)", data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))

# %% [markdown]
# # 검증 2차

# %%
from sklearn.base import BaseEstimator, RegressorMixin
import statsmodels.formula.api as smf
import statsmodels.api as sm

class StatsmodelsOLS(BaseEstimator, RegressorMixin):
    def __init__(self, formula):
        self.formula = formula
        self.model = None
        self.data = None
        self.result = None
        
    def fit(self, dfX, dfy):
        self.data = pd.concat([dfX, dfy], axis=1)
        self.model = smf.ols(self.formula, data=self.data)
        self.result = self.model.fit()
        
    def predict(self, new_data):
        return self.result.predict(new_data)

# %%
from sklearn.model_selection import cross_val_score

model = StatsmodelsOLS("value ~ scale(age) + scale(follower) + scale(passes_accuracy) + \
                       scale(games_played) + scale(shotsOnTotal_goalsTotal)")
cv = KFold(10, shuffle=True, random_state=0)
cross_val_score(model, dfX, dfy, scoring="r2", cv=cv).mean()

# %% [markdown]
# # Data 가중 - 20200622

# %%
from sklearn.model_selection import train_test_split

dfX = df_out_15.drop(['value'], axis=1)
dfy = df_out_15['value']
df = pd.concat([dfX, dfy], axis=1)
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)

feature_names = list(dfX.columns)
feature_names = ["scale({})".format(name) for name in feature_names]

formula = "value ~ scale(age) + scale(I(age**2)) + scale(I(age**3)) + \
            scale(follower) + scale(I(follower**2)) +\
            scale(passes_total) + scale(I(passes_total**2)) +\
            scale(passes_accuracy) + \
            scale(fouls_drawn) + \
            scale(games_lineups) + \
            scale(games_played) + \
            scale(shotsOnTotal_goalsTotal) + \
            scale(dribblesAtmptsSuc) + \
            scale(gamesApperance_sub)"

model = sm.OLS.from_formula(formula, data=df_train)
result = model.fit()
print(result.summary())

##############################################################################
from sklearn.model_selection import KFold

scores = np.zeros(10)
cv = KFold(10, shuffle=True, random_state=0)
for i, (idx_train, idx_test) in enumerate(cv.split(df_ols)):
    df_train = df_ols.iloc[idx_train]
    df_test = df_ols.iloc[idx_test]
    
    model = sm.OLS.from_formula(formula, data=df_train)
    result = model.fit()
    
    pred = result.predict(df_test)
    rss = ((df_test.value - pred) ** 2).sum()
    tss = ((df_test.value - df_test.value.mean())** 2).sum()
    rsquared = 1 - rss / tss
    
    scores[i] = rsquared
#    print("학습 R2 = {:.8f}, 검증 R2 = {:.8f}".format(result.rsquared, rsquared))
print("모델 성능 : {}".format(scores.mean()))
