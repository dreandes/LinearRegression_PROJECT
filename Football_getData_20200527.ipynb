# %% [markdown]
# ### Get data from api-football.com through rapidapi
# - Data: 20200527
# - Author: Gunho Ko

# %%
import requests
from pandas.io.json import json_normalize

url = "https://api-football-v1.p.rapidapi.com/v2/players/player/276"

payload = {}
headers= {
    'x-rapidapi-host': "api-football-v1.p.rapidapi.com",
    'x-rapidapi-key': "6094c6cbafmsha074f84dae16914p180b09jsn2e6469b127b9"
    }

response = requests.request("GET", url, headers=headers, data = payload)
json_object = response.json()
json_object['api']['players']

df = json_normalize(json_object['api']['players'])
df.columns
# Out:
# C:\Users\Gk\anaconda3\lib\site-packages\ipykernel_launcher.py:16: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   app.launch_new_instance()
# Index(['player_id', 'player_name', 'firstname', 'lastname', 'number',
#        'position', 'age', 'birth_date', 'birth_place', 'birth_country',
#        'nationality', 'height', 'weight', 'injured', 'rating', 'team_id',
#        'team_name', 'league', 'season', 'captain', 'shots.total', 'shots.on',
#        'goals.total', 'goals.conceded', 'goals.assists', 'passes.total',
#        'passes.key', 'passes.accuracy', 'tackles.total', 'tackles.blocks',
#        'tackles.interceptions', 'duels.total', 'duels.won',
#        'dribbles.attempts', 'dribbles.success', 'fouls.drawn',
#        'fouls.committed', 'cards.yellow', 'cards.yellowred', 'cards.red',
#        'penalty.won', 'penalty.commited', 'penalty.success', 'penalty.missed',
# ...

# %%
from IPython.display import display

pd.options.display.max_columns = None
display(df)
# Out:
#     player_id player_name firstname                lastname number  position  \
# 0         276      Neymar    Neymar  da Silva Santos Júnior   None  Attacker
# 1         276      Neymar    Neymar  da Silva Santos Júnior   None  Attacker
# 2         276      Neymar    Neymar  da Silva Santos Júnior   None  Attacker
# 3         276      Neymar    Neymar  da Silva Santos Júnior   None  Attacker
# 4         276      Neymar    Neymar  da Silva Santos Júnior   None  Attacker
# ..        ...         ...       ...                     ...    ...       ...
# 57        276      Neymar    Neymar  da Silva Santos Júnior   None  Attacker
# 58        276      Neymar    Neymar  da Silva Santos Júnior   None  Attacker
# 59        276      Neymar    Neymar  da Silva Santos Júnior   None  Attacker
# 60        276      Neymar    Neymar  da Silva Santos Júnior   None  Attacker
# 61        276      Neymar    Neymar  da Silva Santos Júnior   None  Attacker
#
# ...

# %%
import requests
from pandas.io.json import json_normalize

n = 0

key = "6094c6cbafmsha074f84dae16914p180b09jsn2e6469b127b9"
headers= {
        'x-rapidapi-host': "api-football-v1.p.rapidapi.com",
        'x-rapidapi-key': key,
}



data = pd.DataFrame()


for i in range(170, 200):
    response = requests.request("GET", 
                                    "https://api-football-v1.p.rapidapi.com/v2/players/player/{}".format(i), 
                                    headers=headers)
    
    json_object = response.json()
    json_object['api']['players']

    df = json_normalize(json_object['api']['players'])
    
    data = data.append(df, ignore_index = True)
    
    i += 1
# Out:
# C:\Users\Gk\anaconda3\lib\site-packages\ipykernel_launcher.py:25: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead

# %%
data
# Out:
#       player_id    player_name firstname    lastname number  position  age  \
# 0           170  J. Vertonghen       Jan  Vertonghen   None  Defender   33
# 1           170  J. Vertonghen       Jan  Vertonghen   None  Defender   33
# 2           170  J. Vertonghen       Jan  Vertonghen   None  Defender   33
# 3           170  J. Vertonghen       Jan  Vertonghen   None  Defender   33
# 4           170  J. Vertonghen       Jan  Vertonghen   None  Defender   33
# ...         ...            ...       ...         ...    ...       ...  ...
# 1242        199    Š. Vrsaljko      Šime    Vrsaljko   None  Defender   28
# 1243        199    Š. Vrsaljko      Šime    Vrsaljko   None  Defender   28
# 1244        199    Š. Vrsaljko      Šime    Vrsaljko   None  Defender   28
# 1245        199    Š. Vrsaljko      Šime    Vrsaljko   None  Defender   28
# 1246        199    Š. Vrsaljko      Šime    Vrsaljko   None  Defender   28
#
# ...

# %%
data.to_csv("data_1247.csv", encoding='utf-8')

# %%
idx = data['player_name'].str.contains('Vert', na=False)
